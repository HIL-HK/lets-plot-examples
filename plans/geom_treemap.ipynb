# %% [markdown]
# Available as executable or viewable Jupyter Notebook:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/HIL-HK/lets-plot-examples/master?filepath=plans%2Fgeom_treemap.ipynb)
#
# [<img alt="nbviewer" src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png" width="109" height="20">](https://nbviewer.jupyter.org/github/HIL-HK/lets-plot-examples/blob/master/plans/geom_treemap.ipynb)

# %%
import pandas as pd
import geopandas as gpd

from lets_plot import *; LetsPlot.setup_html()
from geoms.treemap import geom_treemap
# Out:
#             <div id="FpsMBp"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.2.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("FpsMBp").appendChild(div);
#                     };
#                     var e = document.getElementById("FpsMBp");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# # Possible New Geometry - Treemap
#
# A treemap chart provides a hierarchical view of your data. It is only a proof of concept, at present it is not part of the library.

# %%
df = pd.DataFrame(dict(
    name=['a', 'b', 'c', 'd', 'e', 'f'],
    sort=['×', '×', '✓', '×', '✓', '×'],
    value=[1, 1, 2, 4, 8, 0],
))
df
# Out:
#   name sort  value
# 0    a    ×      1
# 1    b    ×      1
# 2    c    ✓      2
# 3    d    ×      4
# 4    e    ✓      8
# 5    f    ×      0

# %% [markdown]
# ## Chart by Default

# %%
ggplot() + geom_treemap(aes(value='value'), df)
# Out:
#    <div id="hQSP7O"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"polygon",
# 'data':{
# 'rectangle':["{\"type\": \"Polygon\", \"coordinates\": [[[0.0, 0.0], [0.5, 0.0], [0.5, 1.0], [0.0, 1.0], [0.0, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.5, 0.0], [1.0, 0.0], [1.0, 0.5], [0.5, 0.5], [0.5, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.5, 0.5], [0.75, 0.5], [0.75, 1.0], [0.5, 1.0], [0.5, 0.5]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.75, 0.5], [1.0, 0.5], [1.0, 0.75], [0.75, 0.75], [0.75, 0.5]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.75, 0.75], [1.0, 0.75], [1.0, 1.0], [0.75, 1.0], [0.75, 0.75]]]}"]
# },
# 'mapping':{
# 'value':"value"
# },
# 'data_meta':{
# 'geodataframe':{
# 'geometry':"rectangle"
# }
# }
# }]
# };
#            var plotContainer = document.getElementById("hQSP7O");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Chart with Custom Coloring

# %%
ggplot() + geom_treemap(aes(value='value', fill='sort'), df, color='black', width=40, height=30)
# Out:
#    <div id="kcDetN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"polygon",
# 'data':{
# 'sort':["✓","×","✓","×","×"],
# 'rectangle':["{\"type\": \"Polygon\", \"coordinates\": [[[0.0, 0.0], [20.0, 0.0], [20.0, 30.0], [0.0, 30.0], [0.0, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[20.0, 0.0], [40.0, 0.0], [40.0, 15.0], [20.0, 15.0], [20.0, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[20.0, 15.0], [30.0, 15.0], [30.0, 30.0], [20.0, 30.0], [20.0, 15.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.0, 15.0], [40.0, 15.0], [40.0, 22.5], [30.0, 22.5], [30.0, 15.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.0, 22.5], [40.0, 22.5], [40.0, 30.0], [30.0, 30.0], [30.0, 22.5]]]}"]
# },
# 'mapping':{
# 'value':"value",
# 'fill':"sort"
# },
# 'data_meta':{
# 'geodataframe':{
# 'geometry':"rectangle"
# }
# },
# 'color':"black",
# 'width':40,
# 'height':30
# }]
# };
#            var plotContainer = document.getElementById("kcDetN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Splitting into Groups at the First Level of Tree

# %%
ggplot() + \
    geom_treemap(aes(value='value', group='sort', color='sort', fill='sort', alpha='name', size='value'), df) + \
    scale_alpha(range=[.3, .3]) + \
    scale_size(range=[.5, .5]) + \
    ggtitle('Treemap Based on Test Data') + \
    ggsize(400, 400) + \
    theme(legend_position='none', axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank')
# Out:
#    <div id="YInDdX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Treemap Based on Test Data"
# },
# 'ggsize':{
# 'width':400,
# 'height':400
# },
# 'theme':{
# 'axis_title':"blank",
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"alpha",
# 'range':[0.3,0.3]
# },{
# 'aesthetic':"size",
# 'range':[0.5,0.5]
# }],
# 'layers':[{
# 'geom':"polygon",
# 'data':{
# 'name':["e","c","d","a","b"],
# 'sort':["✓","✓","×","×","×"],
# 'value':[8.0,2.0,4.0,1.0,1.0],
# 'rectangle':["{\"type\": \"Polygon\", \"coordinates\": [[[0.0, 0.0], [0.625, 0.0], [0.625, 0.8], [0.0, 0.8], [0.0, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.0, 0.8], [0.6250000000000001, 0.8], [0.6250000000000001, 1.0], [0.0, 1.0], [0.0, 0.8]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.625, 0.0], [1.0, 0.0], [1.0, 0.6666666666666666], [0.625, 0.6666666666666666], [0.625, 0.0]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.625, 0.6666666666666666], [0.8125, 0.6666666666666666], [0.8125, 1.0], [0.625, 1.0], [0.625, 0.6666666666666666]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[0.8125, 0.6666666666666666], [1.0, 0.6666666666666666], [1.0, 0.9999999999999999], [0.8125, 0.9999999999999999], [0.8125, 0.6666666666666666]]]}"]
# },
# 'mapping':{
# 'value':"value",
# 'group':"sort",
# 'color':"sort",
# 'fill':"sort",
# 'alpha':"name",
# 'size':"value"
# },
# 'data_meta':{
# 'geodataframe':{
# 'geometry':"rectangle"
# }
# }
# }]
# };
#            var plotContainer = document.getElementById("YInDdX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Living Example: World Population

# %%
world_gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

ggplot() + \
    geom_treemap(aes(value='pop_est', group='continent', color='name', fill='continent', alpha='pop_est'), world_gdf) + \
    scale_color_gradient(name='country', low='black', high='black') + \
    scale_alpha(name='population (estimated)', range=[1, 1]) + \
    ggtitle('World Population') + \
    ggsize(800, 800) + \
    theme(legend_position='none', axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank')
# Out:
#    <div id="w4gcyR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"World Population"
# },
# 'ggsize':{
# 'width':800,
# 'height':800
# },
# 'theme':{
# 'axis_title':"blank",
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':