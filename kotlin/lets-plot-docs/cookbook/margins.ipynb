// %% [markdown]
// # Margins
//
//
// The margins around the plot and text elements are controlled by the `plotMargin` parameter in `theme()` and the `margin` parameter in `elementText()` respectively.
//
// Now the parameters `plotMargin` and `margin` accept a number or a list of numbers.
//
// - A number or list of one number is specified: the same margin is applied to **all four sides**.
// - A list of two numbers: the first margin applies to the **top and bottom**, the second - to the **left and right**.
// - A list of three numbers: the first margin applies to the **top**, the second - to the **right and left**, the third - to the **bottom**.
// - A list of four numbers: the margins are applied to the **top, right, bottom and left** in that order.
//
// It is acceptable to use `null` for any side; in this case, the default side value for this element will be used.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="LIdDFv"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("LIdDFv").appendChild(div);
//            };
//            var e = document.getElementById("LIdDFv");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.11.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.7.0.

// %%
import kotlin.random.Random

val rand = Random(37)
val barData = mapOf(
    "x" to List(100) { rand.nextInt(10)}
)

val p = letsPlot(barData) {x = "x"} + 
    geomBar() + 
    ggtitle("Barchart") +
    themeLight() + 
    theme(plotBackground = elementRect(size = 4))

// %% [markdown]
// #### Plot without Margins

// %%
p
// Out:
//    <div id="GVcr39"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("GVcr39").appendChild(div);
//            };
//            var e = document.getElementById("GVcr39");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="2K54ci"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("2K54ci");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Barchart"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"1"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=8be09523-9438-492d-a185-30c3f1b0045b width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p1D10fE .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #p1D10fE .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p1D10fE .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p1D10fE .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p1D10fE .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p1D10fE .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p1D10fE .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p1D10fE .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7WMzkN .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p1D10fE .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p1D10fE .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7WMzkN .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p1D10fE .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p1D10fE .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7WMzkN .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7WMzkN .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7WMzkN .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p1D10fE">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M2.0 2.0 L2.0 398.0 L598.0 398.0 L598.0 2.0 Z">
//     </path>
//     <g transform="translate(25.0 26.0 ) ">
//       <g>
//         <rect x="21.961210910936405" y="0.0" height="330.0" width="543.0387890890636" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="22.190290279580648" y1="0.0" x2="22.190290279580648" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="72.05611113257088" y1="0.0" x2="72.05611113257088" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="121.92193198556112" y1="0.0" x2="121.92193198556112" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="171.78775283855134" y1="0.0" x2="171.78775283855134" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="221.65357369154157" y1="0.0" x2="221.65357369154157" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="271.5193945445318" y1="0.0" x2="271.5193945445318" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="321.385215397522" y1="0.0" x2="321.385215397522" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="371.25103625051224" y1="0.0" x2="371.25103625051224" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="421.11685710350247" y1="0.0" x2="421.11685710350247" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="470.98267795649275" y1="0.0" x2="470.98267795649275" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="520.848498809483" y1="0.0" x2="520.848498809483" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="47.123200706075764" y1="0.0" x2="47.123200706075764" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="96.989021559066" y1="0.0" x2="96.989021559066" y2="330.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="146.8548424120562

// %% [markdown]
// #### Margins Around the Plot

// %%
gggrid(
    listOf(
        p + theme(plotMargin = 40) + ggtitle("plotMargin=40 (all sides)"),
        p + theme(plotMargin = listOf(40, 20)) + 
            ggtitle("plotMargin=[40,20]\n(top/bottom, left/right)"),
        p + theme(plotMargin = listOf(40, 20, 10)) + 
            ggtitle("plotMargin=[40,20,10]\n(top, left/right, bottom)"),
        p + theme(plotMargin = listOf(40, 10, 10, 20)) + 
            ggtitle("plotMargin=[40,10,10,20]\n(top, right, bottom, left)")
    ),
    ncol=2
)
// Out:
//    <div id="bePfaF"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("bePfaF");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":2,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"plotMargin=40 (all sides)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":40.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,20]\n(top/bottom, left/right)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,20.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"4"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,20,10]\n(top, left/right, bottom)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,20.0,10.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,10,10,20]\n(top, right, bottom, left)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,10.0,10.0,20.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"6"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=f8d0b8ac-e571-4c23-9eb7-5d1d07ca1373 width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p0V6Yaa .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #p0V6Yaa .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p0V6Yaa .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p0V6Yaa .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p0V6Yaa .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p0V6Yaa .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p0V6Yaa .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p0V6Yaa .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p0V6Yaa .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p0V6Yaa .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p0V6Yaa .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p0V6Yaa .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p0V6Yaa">
//     <rect x="0.0" y="0.0" height="600.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="442.0" height="292.0" x="6.0" y="6.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pPmE5dG .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pPmE5dG .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pPmE5dG .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pPmE5dG .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pPmE5dG .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: no

// %% [markdown]
// #### Margins Around the Text Element

// %%
p + theme(plotTitle = elementText(margin=40),
          axisTitle = elementText(margin=listOf(20, 20))) +
    ggtitle("plotTitle=40 -> top/bottom=40,\n" +
            "axisTitle=[20,20] -> top/right=20")
// Out:
//    <div id="8Omb1c"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("8Omb1c");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"plotTitle=40 -> top/bottom=40,\naxisTitle=[20,20] -> top/right=20"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_title":{
// "margin":40.0,
// "blank":false
// },
// "axis_title":{
// "margin":[20.0,20.0],
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"11"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=63e0d474-56ad-4fca-a3bf-e88dc84fcd66 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pwgkPc6 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pwgkPc6 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pwgkPc6 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pwgkPc6 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pwgkPc6 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pwgkPc6 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pwgkPc6 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pwgkPc6 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dwff0Ah .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pwgkPc6 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pwgkPc6 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dwff0Ah .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pwgkPc6 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pwgkPc6 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dwff0Ah .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dwff0Ah .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dwff0Ah .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pwgkPc6">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M2.0 2.0 L2.0 398.0 L598.0 398.0 L598.0 2.0 Z">
//     </path>
//     <g transform="translate(65.0 122.0 ) ">
//       <g>
//         <rect x="21.961210910936405" y="0.0" height="194.0" width="503.0387890890636" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="89.84485259671521" y1="0.0" x2="89.84485259671521" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="182.2303051383247" y1="0.0" x2="182.2303051383247" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="274.6157576799342" y1="0.0" x2="274.6157576799342" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="367.00121022154366" y1="0.0" x2="367.00121022154366" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="459.3866627631532" y1="0.0" x2="459.3866627631532" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="43.65212632591048" y1="0.0" x2="43.65212632591048" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="136.03757886751995" y1="0.0" x2="136.03757886751995" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="228.42303140912944" y1="0.0" x2="228.42303140912944" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="320.80848395073895" y1="0.0" x2="320.80848395073895" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="413.1939364923484" y1="0.0" x2="413.1939364923484" y2="194.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="163.20634920634922" x2="503.0387890890636" y2="163.20634920634922" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="101.61904761904762" x2="503.0387890890636" y2="101.61904761904762" stroke="rgb(233,233,233)" strok
