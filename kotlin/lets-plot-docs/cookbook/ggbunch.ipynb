// %% [markdown]
// # `ggbunch()`
//
// `ggbunch()` allows to show a collection of plots on one figure. Each plot in the collection can have arbitrary location and size. There is no automatic layout inside the bunch.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="PaYbr1"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("PaYbr1").appendChild(div);
//            };
//            var e = document.getElementById("PaYbr1");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.10.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.6.1.

// %%
@file:DependsOn("org.apache.commons:commons-math3:3.6.1")

// %%
import kotlin.random.Random
import org.apache.commons.math3.distribution.MultivariateNormalDistribution

// %%
val cov : Array<DoubleArray> = arrayOf(doubleArrayOf(1.0, 0.0),
                                        doubleArrayOf(0.0, 1.0))
val means : DoubleArray = doubleArrayOf(0.0, 0.0)
val xy = MultivariateNormalDistribution(means, cov).sample(400)

val xs = xy.map { it[0] }
val ys = xy.map { it[1] }

// %% [markdown]
// ### View this data as a scatter plot and as a histogram

// %%
val p = letsPlot() + ggsize(600,200)

val scatter = p + geomPoint(color="black", alpha=.4) {x=xs; y=ys}
scatter
// Out:
//    <div id="qO4HHa"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("qO4HHa").appendChild(div);
//            };
//            var e = document.getElementById("qO4HHa");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="KlYagy"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("KlYagy");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.06797298334922704,-0.19854090383597073,2.2608574243843647,0.4745063660256766,1.6024079083893348,-0.5284165485064467,-0.9793723735039375,-1.6733780656262842,0.3758399565332803,-0.8887372096390326,-0.9624268814122158,0.10615747236313741,0.22407526872054248,-0.9558637736940137,-0.4198213755969957,-1.0854190552031433,-0.134119503312233,0.49196119273797995,-0.3901288165150456,-1.1532727041618769,-0.8731812242820266,0.2541147592768892,-0.10446218126271173,0.17655516820079492,-1.3846667007006526,-0.1260875563046045,0.2361470150773646,0.9143672746091062,0.8455367682006716,-0.18349162252546905,0.8129851558635804,1.0981241988297183,0.8022451835766362,0.3046021656942586,1.7228633934393747,0.6583224647795114,-0.28406096225651806,-0.5359306180831779,1.5553410688945373,0.06979024025982879,1.182300672730256,-0.8754469291176509,-0.25836833135270526,-0.34083299220962815,-1.279065928944792,0.7159428214607728,0.12541797494834506,0.25398260103008896,0.1979489432244605,-0.843064060727414,-0.1586269647742216,-1.0478131195517704,0.1161608725530983,1.5425013151935607,0.41426951848916554,-0.4066501813761368,-0.6862373807442574,0.9850755854486083,-0.4694870710248107,1.0280076454901608,0.10144665173107484,0.9428090340259779,-1.6831968790969176,-0.9316216149841876,-0.9603427122169409,-0.7767970583647106,0.05537092418510097,-1.230189131398156,1.1716389520412682,-0.05025666480340076,1.1865999374423197,-0.8094186211622275,0.2630724312445654,-0.5387341992213157,1.6981848200083882,0.952231023694587,1.185403442566537,-0.8517850824183981,0.9458528421805378,1.88918710096025,-2.103378903418657,0.07919346557888338,-0.01658167894758784,0.3543878893220548,1.1147638068274193,0.08802523931387496,-1.8441968779574056,0.27663179491144463,-0.712415124291515,-0.9357890095797465,1.7041786370401735,-1.9488627069605653,2.277467138911688,0.24679935611728326,0.5537204487482569,-1.5699130299066713,-0.010858556739831708,-0.03814372947400083,0.3640421563592526,-1.038144634362903,-0.03980338134585189,-0.49137778492872214,-1.6726744130453897,-1.0572143473986428,0.5189704219365079,-1.286269125041927,-1.3107777930450568,0.5934377563370058,0.5549877530242698,-1.672860912575057,1.1334757378992402,1.8271155184628534,-0.7722794148075048,-0.1525002630610701,-0.8955984237908838,-0.2387371348379987,0.4530445771063893,1.1011865201928992,1.068613319103375,0.5374225433797026,-1.224140546795826,-1.3289852330613474,-0.00884532183882331,-0.5063178159649222,1.7167954561410643,1.2984982142365666,-0.2504319620484415,-0.4404885613178652,1.9635720650489914,0.8452459790495241,0.8054353504295604,-0.22114221924625443,-0.8381311677483481,-0.6929147053061828,-0.0555005643006925,1.6631710100922936,2.0573069546943885,1.6297116284700692,0.23954750159087856,0.6985042277762294,2.1324458629867706,1.634106692425157,-0.1592642899913842,0.8224971590337423,2.0786122600490984,-0.541891636328523,-0.12352145902970325,-1.3962788260896744,-2.4805008180327848,-1.4851963066164589,-1.7052509887703409,1.162430842846428,-0.6992736496178565,0.6341238233192518,0.8026467509312757,0.8112678216506959,1.1481758348469508,-0.28128087128878115,-0.3627327609916391,1.1341292165079908,-1.3282012813371196,0.738165866797114,0.8248607939990172,-0.27321256033619645,0.32276852052497107,2.0950392011676158,-0.20152564586723648,0.3467001121675079,0.04098034329586403,-0.0512247351918602,0.32396003222541486,1.623802631175335,-1.068707583481546,0.8973516012406343,-0.8245655293650266,-0.9302133161340829,-0.6577671940037704,-1.256019990788461,-0.2685100141487462,0.932632500530477,0.14634746629263992,0.8749162392343777,-0.49346214726156107,-1.3773697543758936,-0.7999680004416991,1.2780522683036777,-1.0412826303734166,-0.5015660333114949,-0.0529169473775911,0.2704886617064864,2.773215982624161,-1.2597491686725224,-0.02252369692682117,0.22648534190830175,-1.083906240064123,0.7710334557025705,-0.8768922759788149,-0.5895166613651461,0.3960177805395278,-0.35811638286705283,1.4342646115362503,-1.0255817542854748,1.3360690465614207,-0.3830646817281333 ...

// %%
val histogram = p + geomHistogram(fill="dark_magenta") {x=xs}
histogram
// Out:
//    <div id="Xo4Tr5"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("Xo4Tr5");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[1.0,2.0,1.0,2.0,4.0,8.0,6.0,18.0,19.0,31.0,23.0,25.0,31.0,36.0,24.0,32.0,22.0,25.0,24.0,24.0,9.0,11.0,9.0,5.0,4.0,2.0,0.0,1.0,0.0,1.0],
// "x":[-2.708738139592463,-2.5060350809331173,-2.3033320222737723,-2.100628963614427,-1.8979259049550814,-1.6952228462957362,-1.492519787636391,-1.2898167289770455,-1.0871136703177002,-0.884410611658355,-0.6817075529990095,-0.4790044943396641,-0.27630143568031906,-0.0735983770209736,0.12910468163837185,0.33180774029771687,0.5345107989570623,0.7372138576164078,0.9399169162757528,1.1426199749350983,1.3453230335944437,1.5480260922537892,1.7507291509131346,1.9534322095724792,2.1561352682318247,2.35883832689117,2.5615413855505156,2.764244444209861,2.9669475028692065,3.169650561528551]
// }
// }],
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=b599e4de-75c9-429d-9adf-2029ff83d370 width="100%" height="100%" style="max-width: 600.0px; max-height: 200.0px;" viewBox="0 0 600.0 200.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pRHJBGF .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pRHJBGF .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pRHJBGF .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pRHJBGF .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pRHJBGF .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pRHJBGF .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pRHJBGF .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pRHJBGF .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVRYIT0 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pRHJBGF .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pRHJBGF .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVRYIT0 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pRHJBGF .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pRHJBGF .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVRYIT0 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVRYIT0 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVRYIT0 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pRHJBGF">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 200.0 L600.0 200.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="9.249328192079162" y1="0.0" x2="9.249328192079162" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="90.28124729492629" y1="0.0" x2="90.28124729492629" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="171.31316639777341" y1="0.0" x2="171.31316639777341" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="252.34508550062054" y1="0.0" x2="252.34508550062054" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="333.37700460346764" y1="0.0" x2="333.37700460346764" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="414.4089237063148" y1="0.0" x2="414.4089237063148" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="495.44084280916195" y1="0.0" x2="495.44084280916195" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="141.0" x2="542.0387890890636" y2="141.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="103.6984126984127" x2="542.0387890890636" y2="103.6984126984127" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="66.39682539682539" x2="

// %% [markdown]
// ### Combine both plots in one figure

// %%
// Set scale X limits manually because of computed automatically
// the scale used by each plot would be slightly different
// and the stacked plots wouldn't be aligned.
val scale_x = scaleXContinuous(limits=-3.5 to 3.5)

ggbunch(
    listOf(histogram + scale_x,
           scatter + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5))
)
// Out:
//    <div id="7NHTuw"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("7NHTuw");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5]]
// },
// "figures":[{
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,0.0,3.0,1.0,2.0,6.0,9.0,20.0,21.0,34.0,32.0,29.0,43.0,34.0,34.0,28.0,33.0,28.0,11.0,14.0,7.0,7.0,2.0,0.0,1.0,1.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "spec_id":"5"
// },{
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.06797298334922704,-0.19854090383597073,2.2608574243843647,0.4745063660256766,1.6024079083893348,-0.5284165485064467,-0.9793723735039375,-1.6733780656262842,0.3758399565332803,-0.8887372096390326,-0.9624268814122158,0.10615747236313741,0.22407526872054248,-0.9558637736940137,-0.4198213755969957,-1.0854190552031433,-0.134119503312233,0.49196119273797995,-0.3901288165150456,-1.1532727041618769,-0.8731812242820266,0.2541147592768892,-0.10446218126271173,0.17655516820079492,-1.3846667007006526,-0.1260875563046045,0.2361470150773646,0.9143672746091062,0.8455367682006716,-0.18349162252546905,0.8129851558635804,1.0981241988297183,0.8022451835766362,0.3046021656942586,1.7228633934393747,0.6583224647795114,-0.28406096225651806,-0.5359306180831779,1.5553410688945373,0.06979024025982879,1.182300672730256,-0.8754469291176509,-0.25836833135270526,-0.34083299220962815,-1.279065928944792,0.7159428214607728,0.12541797494834506,0.25398260103008896,0.1979489432244605,-0.843064060727414,-0.1586269647742216,-1.0478131195517704,0.1161608725530983,1.5425013151935607,0.41426951848916554,-0.4066501813761368,-0.6862373807442574,0.9850755854486083,-0.4694870710248107,1.0280076454901608,0.10144665173107484,0.9428090340259779,-1.6831968790969176,-0.9316216149841876,-0.9603427122169409,-0.7767970583647106,0.05537092418510097,-1.230189131398156,1.1716389520412682,-0.05025666480340076,1.1865999374423197,-0.8094186211622275,0.2630724312445654,-0.5387341992213157,1.6981848200083882,0.952231023694587,1.185403442566537,-0.8517850824183981,0.9458528421805378,1.88918710096025,-2.103378903418657,0.07919346557888338,-0.01658167894758784,0.3543878893220548,1.1147638068274193,0.08802523931387496,-1.8441968779574056,0.27663179491144463,-0.712415124291515,-0.9357890095797465,1.7041786370401735,-1.9488627069605653,2.277467138911688,0.24679935611728326,0.5537204487482569,-1.5699130299066713,-0.010858556739831708,-0.03814372947400083,0.3640421563592526,-1.038144634362903,-0.03980338134585189,-0.49137778492872214,-1.6726744130453897,-1.0572143473986428,0.5189704219365079,-1.286269125041927,-1.3107777930450568,0.5934377563370058,0.5549877530242698,-1.672860912575057,1.1334757378992402,1.8271155184628534,-0.7722794148075048,-0.1525002630610701,-0.8955984237908838,-0.2387371348379987,0.4530445771063893,1.1011865201928992,1.068613319103375,0.5374225433797026,-1.224140546795826,-1.3289852330613474,-0.00884532183882331,-0.5063178159649222,1.7167954561410643,1.2984982142365666,-0.2504319620484415,-0.4404885613178652,1.9635720650489914,0.8452459790495241,0.8054353504295604,-0.22114221924625443,-0.8381311677483481,-0.6929147053061828,-0.0555005643006925,1.6631710100922936,2.0573069546943885,1.6297116284700692,0.23954750159087856,0.6985042277762294,2.1324458629867706,1.634106692425157,-0.1592642899913842,0.8224971590337423,2.0786122600490984,-0.541891636328523,-0.12352145902970325,-1.3962788260896744,-2.4805008180327848,-1.4851963066164589,-1.7052509887703409,1.162430842846428,-0.6992736496178565,0.6341238233192518,0.8026467509312757,0.8112678216506959,1.1481758348469508,-0.28128087128878115,-0.3627327609916391,1.1341292165079908,-1.3282012813371196,0.738165866797114,0.8248607939990172,-0.27321256033619645,0.32276852052497107,2.0950392011676158,-0.20152564586723648,0.3467001121675079,0.04098034329586403,-0.0512247351918602,0.32396003222541486,1.623802631175335,-1.068707583481546,0.8973516012406343,-0.8245655293650266,-0.9302133161340829,-0.6577671940037704,-1.256019990788461,-0.2685100141487462,0.932632500530477,0.14634746629263992,0.8749162392343777,-0.49346214726156107,-1.3773697543758936,-0.7999680004416991,1.2780522683036777,-1.0412826303734166,-0.5015660333114949,-0.0529169473775911,0.2704886617064864,2.773215982624161,-1.2597491686725224,-0.02252369692682117,0.22648534190830175,-1.083906240064123,0.7710334557025705,-0.8768922759788149,-0.5895166613651461,0.3960177805395278,-0.35811638286705283,1.4342646115362503,-1.0255817542854748,1.3360690465614207,-0.3830646817281333 ...

// %% [markdown]
// ### Adjust visuals of the bunch figure

// %%
val upper_theme = theme(axis="blank", axisText=elementText(), axisTitleY=elementText(), panelGridMajorY="blank")
val lower_theme = theme(axis="blank", axisTextY=elementText(), axisTitle=elementText())

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5))
)
// Out:
//    <div id="wYDmXP"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("wYDmXP");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,0.0,3.0,1.0,2.0,6.0,9.0,20.0,21.0,34.0,32.0,29.0,43.0,34.0,34.0,28.0,33.0,28.0,11.0,14.0,7.0,7.0,2.0,0.0,1.0,1.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"9"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.06797298334922704,-0.19854090383597073,2.2608574243843647,0.4745063660256766,1.6024079083893348,-0.5284165485064467,-0.9793723735039375,-1.6733780656262842,0.3758399565332803,-0.8887372096390326,-0.9624268814122158,0.10615747236313741,0.22407526872054248,-0.9558637736940137,-0.4198213755969957,-1.0854190552031433,-0.134119503312233,0.49196119273797995,-0.3901288165150456,-1.1532727041618769,-0.8731812242820266,0.2541147592768892,-0.10446218126271173,0.17655516820079492,-1.3846667007006526,-0.1260875563046045,0.2361470150773646,0.9143672746091062,0.8455367682006716,-0.18349162252546905,0.8129851558635804,1.0981241988297183,0.8022451835766362,0.3046021656942586,1.7228633934393747,0.6583224647795114,-0.28406096225651806,-0.5359306180831779,1.5553410688945373,0.06979024025982879,1.182300672730256,-0.8754469291176509,-0.25836833135270526,-0.34083299220962815,-1.279065928944792,0.7159428214607728,0.12541797494834506,0.25398260103008896,0.1979489432244605,-0.843064060727414,-0.1586269647742216,-1.0478131195517704,0.1161608725530983,1.5425013151935607,0.41426951848916554,-0.4066501813761368,-0.6862373807442574,0.9850755854486083,-0.4694870710248107,1.0280076454901608,0.10144665173107484,0.9428090340259779,-1.6831968790969176,-0.9316216149841876,-0.9603427122169409,-0.7767970583647106,0.05537092418510097,-1.230189131398156,1.1716389520412682,-0.05025666480340076,1.1865999374423197,-0.8094186211622275,0.2630724312445654,-0.5387341992213157,1.6981848200083882,0.952231023694587,1.185403442566537,-0.8517850824183981,0.9458528421805378,1.88918710096025,-2.103378903418657,0.07919346557888338,-0.01658167894758784,0.3543878893220548,1.1147638068274193,0.08802523931387496,-1.8441968779574056,0.27663179491144463,-0.712415124291515,-0.9357890095797465,1.7041786370401735,-1.9488627069605653,2.277467138911688,0.24679935611728326,0.5537204487482569,-1.5699130299066713,-0.010858556739831708,-0.03814372947400083,0.3640421563592526,-1.038144634362903,-0.03980338134585189,-0.49137778492872214,-1.6726744130453897,-1.0572143473986428,0.5189704219365079,-1.286269125041927,-1.3107777930450568,0.5934377563370058,0.5549877530242698,-1.672860912575057,1.1334757378992402,1.8271155184628534,-0.7722794148075048,-0.1525002630610701,-0.8955984237908838,-0.2387371348379987,0.4530445771063893,1.1011865201928992,1.068613319103375,0.5374225433797026,-1.224140546795826,-1.3289852330613474,-0.00884532183882331,-0.5063178159649222,1.7167954561410643,1.2984982142365666,-0.2504319620484415,-0.4404885613178652,1.9635720650489914,0.8452459790495241,0.8054353504295604,-0.22114221924625443,-0.8381311677483481,-0.6929147053061828,-0.0555005643006925,1.6631710100922936,2.0573069546943885,1.6297116284700692,0.23954750159087856,0.6985042277762294,2.1324458629867706,1.634106692425157,-0.1592642899913842,0.8224971590337423,2.0786122600490984,-0.541891636328523,-0.12352145902970325,-1.3962788260896744,-2.4805008180327848,-1.4851963066164589,-1.7052509887703409,1.162430842846428,-0.6992736496178565,0.6341238233192518,0.8026467509312757,0.8112678216506959,1.1481758348469508,-0.28128087128878115,-0.3627327609916391,1.1341292165079908,-1.3282012813371196,0.738165866797114,0.8248607939990172,-0.27321256033619645,0.32276852052497107,2.0950392011676158,-0.20152564586723648,0.3467001121675079,0.04098034329586403,-0.0512247351918602,0.32396003222541486,1.623802631175335,-1.068707583481546,0.8973516012406343,-0.8245655293650266,-0.9302133161340829,-0.6577671940037704,-1.256019990788461,-0.2685100141487462,0.932632500530477,0.14634746629263992,0.8749162392343777,-0.49346214726156107,-1.3773697543758936,-0.7999680004416991,1.2780522683036777,-1.0412826303734166,-0.5015660333114949,-0.0529169473775911,0.2704886617064864,2.773215982624161,-1.2597491686725224,-0.02252369692682117,0.22648534190830175,-1.083906240064123,0.7710334557025705,-0.8768922759788149,-0.5895166613651461,0.3960177805395278,-0.35811638286705283,1.4342646115362503,-1.0255817542854748,1.3360690465614207,-0.3830646817281333 ...

// %% [markdown]
// ### Move the regions
//
// You can additionally move the bottom plot up a bit with the last two parameters of the tuple responsible for the layout of the region.

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5, 0, -12)) // Move up 12 pixels
)
// Out:
//    <div id="u33UeJ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("u33UeJ");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5,0,-12]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,0.0,3.0,1.0,2.0,6.0,9.0,20.0,21.0,34.0,32.0,29.0,43.0,34.0,34.0,28.0,33.0,28.0,11.0,14.0,7.0,7.0,2.0,0.0,1.0,1.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"13"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.06797298334922704,-0.19854090383597073,2.2608574243843647,0.4745063660256766,1.6024079083893348,-0.5284165485064467,-0.9793723735039375,-1.6733780656262842,0.3758399565332803,-0.8887372096390326,-0.9624268814122158,0.10615747236313741,0.22407526872054248,-0.9558637736940137,-0.4198213755969957,-1.0854190552031433,-0.134119503312233,0.49196119273797995,-0.3901288165150456,-1.1532727041618769,-0.8731812242820266,0.2541147592768892,-0.10446218126271173,0.17655516820079492,-1.3846667007006526,-0.1260875563046045,0.2361470150773646,0.9143672746091062,0.8455367682006716,-0.18349162252546905,0.8129851558635804,1.0981241988297183,0.8022451835766362,0.3046021656942586,1.7228633934393747,0.6583224647795114,-0.28406096225651806,-0.5359306180831779,1.5553410688945373,0.06979024025982879,1.182300672730256,-0.8754469291176509,-0.25836833135270526,-0.34083299220962815,-1.279065928944792,0.7159428214607728,0.12541797494834506,0.25398260103008896,0.1979489432244605,-0.843064060727414,-0.1586269647742216,-1.0478131195517704,0.1161608725530983,1.5425013151935607,0.41426951848916554,-0.4066501813761368,-0.6862373807442574,0.9850755854486083,-0.4694870710248107,1.0280076454901608,0.10144665173107484,0.9428090340259779,-1.6831968790969176,-0.9316216149841876,-0.9603427122169409,-0.7767970583647106,0.05537092418510097,-1.230189131398156,1.1716389520412682,-0.05025666480340076,1.1865999374423197,-0.8094186211622275,0.2630724312445654,-0.5387341992213157,1.6981848200083882,0.952231023694587,1.185403442566537,-0.8517850824183981,0.9458528421805378,1.88918710096025,-2.103378903418657,0.07919346557888338,-0.01658167894758784,0.3543878893220548,1.1147638068274193,0.08802523931387496,-1.8441968779574056,0.27663179491144463,-0.712415124291515,-0.9357890095797465,1.7041786370401735,-1.9488627069605653,2.277467138911688,0.24679935611728326,0.5537204487482569,-1.5699130299066713,-0.010858556739831708,-0.03814372947400083,0.3640421563592526,-1.038144634362903,-0.03980338134585189,-0.49137778492872214,-1.6726744130453897,-1.0572143473986428,0.5189704219365079,-1.286269125041927,-1.3107777930450568,0.5934377563370058,0.5549877530242698,-1.672860912575057,1.1334757378992402,1.8271155184628534,-0.7722794148075048,-0.1525002630610701,-0.8955984237908838,-0.2387371348379987,0.4530445771063893,1.1011865201928992,1.068613319103375,0.5374225433797026,-1.224140546795826,-1.3289852330613474,-0.00884532183882331,-0.5063178159649222,1.7167954561410643,1.2984982142365666,-0.2504319620484415,-0.4404885613178652,1.9635720650489914,0.8452459790495241,0.8054353504295604,-0.22114221924625443,-0.8381311677483481,-0.6929147053061828,-0.0555005643006925,1.6631710100922936,2.0573069546943885,1.6297116284700692,0.23954750159087856,0.6985042277762294,2.1324458629867706,1.634106692425157,-0.1592642899913842,0.8224971590337423,2.0786122600490984,-0.541891636328523,-0.12352145902970325,-1.3962788260896744,-2.4805008180327848,-1.4851963066164589,-1.7052509887703409,1.162430842846428,-0.6992736496178565,0.6341238233192518,0.8026467509312757,0.8112678216506959,1.1481758348469508,-0.28128087128878115,-0.3627327609916391,1.1341292165079908,-1.3282012813371196,0.738165866797114,0.8248607939990172,-0.27321256033619645,0.32276852052497107,2.0950392011676158,-0.20152564586723648,0.3467001121675079,0.04098034329586403,-0.0512247351918602,0.32396003222541486,1.623802631175335,-1.068707583481546,0.8973516012406343,-0.8245655293650266,-0.9302133161340829,-0.6577671940037704,-1.256019990788461,-0.2685100141487462,0.932632500530477,0.14634746629263992,0.8749162392343777,-0.49346214726156107,-1.3773697543758936,-0.7999680004416991,1.2780522683036777,-1.0412826303734166,-0.5015660333114949,-0.0529169473775911,0.2704886617064864,2.773215982624161,-1.2597491686725224,-0.02252369692682117,0.22648534190830175,-1.083906240064123,0.7710334557025705,-0.8768922759788149,-0.5895166613651461,0.3960177805395278,-0.35811638286705283,1.4342646115362503,-1.0255817542854748,1.3360690465614207,-0.3830646817281333 ...

// %% [markdown]
// ### Adjust plot sizes
//
// The width and height of the plots within `ggbunch()` are given in relative units, but you can change the size of the whole `ggbunch()` plot with `ggsize()`.

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5, 0, -12))
) + ggsize(600, 400)
// Out:
//    <div id="QM2VQE"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("QM2VQE");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5,0,-12]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,0.0,3.0,1.0,2.0,6.0,9.0,20.0,21.0,34.0,32.0,29.0,43.0,34.0,34.0,28.0,33.0,28.0,11.0,14.0,7.0,7.0,2.0,0.0,1.0,1.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"17"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.06797298334922704,-0.19854090383597073,2.2608574243843647,0.4745063660256766,1.6024079083893348,-0.5284165485064467,-0.9793723735039375,-1.6733780656262842,0.3758399565332803,-0.8887372096390326,-0.9624268814122158,0.10615747236313741,0.22407526872054248,-0.9558637736940137,-0.4198213755969957,-1.0854190552031433,-0.134119503312233,0.49196119273797995,-0.3901288165150456,-1.1532727041618769,-0.8731812242820266,0.2541147592768892,-0.10446218126271173,0.17655516820079492,-1.3846667007006526,-0.1260875563046045,0.2361470150773646,0.9143672746091062,0.8455367682006716,-0.18349162252546905,0.8129851558635804,1.0981241988297183,0.8022451835766362,0.3046021656942586,1.7228633934393747,0.6583224647795114,-0.28406096225651806,-0.5359306180831779,1.5553410688945373,0.06979024025982879,1.182300672730256,-0.8754469291176509,-0.25836833135270526,-0.34083299220962815,-1.279065928944792,0.7159428214607728,0.12541797494834506,0.25398260103008896,0.1979489432244605,-0.843064060727414,-0.1586269647742216,-1.0478131195517704,0.1161608725530983,1.5425013151935607,0.41426951848916554,-0.4066501813761368,-0.6862373807442574,0.9850755854486083,-0.4694870710248107,1.0280076454901608,0.10144665173107484,0.9428090340259779,-1.6831968790969176,-0.9316216149841876,-0.9603427122169409,-0.7767970583647106,0.05537092418510097,-1.230189131398156,1.1716389520412682,-0.05025666480340076,1.1865999374423197,-0.8094186211622275,0.2630724312445654,-0.5387341992213157,1.6981848200083882,0.952231023694587,1.185403442566537,-0.8517850824183981,0.9458528421805378,1.88918710096025,-2.103378903418657,0.07919346557888338,-0.01658167894758784,0.3543878893220548,1.1147638068274193,0.08802523931387496,-1.8441968779574056,0.27663179491144463,-0.712415124291515,-0.9357890095797465,1.7041786370401735,-1.9488627069605653,2.277467138911688,0.24679935611728326,0.5537204487482569,-1.5699130299066713,-0.010858556739831708,-0.03814372947400083,0.3640421563592526,-1.038144634362903,-0.03980338134585189,-0.49137778492872214,-1.6726744130453897,-1.0572143473986428,0.5189704219365079,-1.286269125041927,-1.3107777930450568,0.5934377563370058,0.5549877530242698,-1.672860912575057,1.1334757378992402,1.8271155184628534,-0.7722794148075048,-0.1525002630610701,-0.8955984237908838,-0.2387371348379987,0.4530445771063893,1.1011865201928992,1.068613319103375,0.5374225433797026,-1.224140546795826,-1.3289852330613474,-0.00884532183882331,-0.5063178159649222,1.7167954561410643,1.2984982142365666,-0.2504319620484415,-0.4404885613178652,1.9635720650489914,0.8452459790495241,0.8054353504295604,-0.22114221924625443,-0.8381311677483481,-0.6929147053061828,-0.0555005643006925,1.6631710100922936,2.0573069546943885,1.6297116284700692,0.23954750159087856,0.6985042277762294,2.1324458629867706,1.634106692425157,-0.1592642899913842,0.8224971590337423,2.0786122600490984,-0.541891636328523,-0.12352145902970325,-1.3962788260896744,-2.4805008180327848,-1.4851963066164589,-1.7052509887703409,1.162430842846428,-0.6992736496178565,0.6341238233192518,0.8026467509312757,0.8112678216506959,1.1481758348469508,-0.28128087128878115,-0.3627327609916391,1.1341292165079908,-1.3282012813371196,0.738165866797114,0.8248607939990172,-0.27321256033619645,0.32276852052497107,2.0950392011676158,-0.20152564586723648,0.3467001121675079,0.04098034329586403,-0.0512247351918602,0.32396003222541486,1.623802631175335,-1.068707583481546,0.8973516012406343,-0.8245655293650266,-0.9302133161340829,-0.6577671940037704,-1.256019990788461,-0.2685100141487462,0.932632500530477,0.14634746629263992,0.8749162392343777,-0.49346214726156107,-1.3773697543758936,-0.7999680004416991,1.2780522683036777,-1.0412826303734166,-0.5015660333114949,-0.0529169473775911,0.2704886617064864,2.773215982624161,-1.2597491686725224,-0.02252369692682117,0.22648534190830175,-1.083906240064123,0.7710334557025705,-0.8768922759788149,-0.5895166613651461,0.3960177805395278,-0.35811638286705283,1.4342646115362503,-1.0255817542854748,1.3360690465614207,-0.3830646817281333 ...
