// %% [markdown]
// # `ggbunch()`
//
// `ggbunch()` allows to show a collection of plots on one figure. Each plot in the collection can have arbitrary location and size. There is no automatic layout inside the bunch.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="FUOy1u"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("FUOy1u").appendChild(div);
//            };
//            var e = document.getElementById("FUOy1u");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.12.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.8.1.
// Outputs: Web (HTML+JS), Kotlin Notebook (Swing), Static SVG (hidden)

// %%
@file:DependsOn("org.apache.commons:commons-math3:3.6.1")

// %%
import kotlin.random.Random
import org.apache.commons.math3.distribution.MultivariateNormalDistribution

// %%
val cov : Array<DoubleArray> = arrayOf(doubleArrayOf(1.0, 0.0),
                                        doubleArrayOf(0.0, 1.0))
val means : DoubleArray = doubleArrayOf(0.0, 0.0)
val xy = MultivariateNormalDistribution(means, cov).sample(400)

val xs = xy.map { it[0] }
val ys = xy.map { it[1] }

// %% [markdown]
// ### View this data as a scatter plot and as a histogram

// %%
val p = letsPlot() + ggsize(600,200)

val scatter = p + geomPoint(color="black", alpha=.4) {x=xs; y=ys}
scatter
// Out:
//    <div id="T4TiBe"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("T4TiBe").appendChild(div);
//            };
//            var e = document.getElementById("T4TiBe");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="DHnhKh" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("DHnhKh");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.15362223266253422,-0.17605433535309262,1.3927523479608823,-2.2049996834073453,0.6461384512383636,1.1588037584656523,-1.1738790577208857,-0.41224696989139487,0.27016887506900616,-1.3825405426905573,-0.07379191465228034,1.2186526519068086,0.25258354438677294,1.024739396461091,0.3920435155459687,-1.5537638085026375,-0.47279593358897454,0.06817320510569687,0.8731186001572674,-0.830058261057972,-1.453914359750717,-0.42212595310021434,0.059103211218001245,0.539859556966007,1.198341187217703,2.085549448992728,1.1590795726385645,0.9569291634612105,-0.7877881781645285,0.24713728242517477,-1.327192410827333,-0.6862237488344105,0.3754073874357775,0.8348619174334829,0.3872522138674615,0.7567309713217125,-0.07722514400098784,0.0484967387354142,0.08232616771506038,-1.977621844873551,-0.5024778124846327,-0.2193938623517716,-1.066885750478218,0.9515502237417569,-0.1631196209761915,-1.1731767077635586,-1.8267185327771276,-1.5715491407724989,1.07011490189564,-1.9044119448216936,0.3176869072056333,-0.4876592414770111,0.7247331231422246,-0.5347145146652565,0.06748924990801039,1.4611754368848844,-1.7834758168863638,-0.7081564597769853,0.604898297627132,0.04208841013966067,0.22649701106116665,-0.2962701464378605,0.013650864641782619,0.58215181749099,-0.1258755574128869,-0.683550833210354,-0.682530603024815,-0.568986283527393,1.2951588097997693,0.45594288000333977,-0.862409732863635,1.559109691099351,-0.06071876253940036,-1.4346437878819311,1.2428687020542721,0.5205105383359911,0.17666546392078242,0.24938617343969224,0.030270895738807545,-0.8216826125576935,0.5349298192031047,-0.060549955637670363,1.8526666974237624,-0.7594122445404873,-0.428828796576219,-0.9005520479178746,1.4660625190391567,-0.76620565643672,0.45566049081209997,0.5193035201353405,-1.623554891627033,-0.06287438649189997,-0.13582387369274032,-0.12592446830632884,-0.5012198951466743,-0.5372848692532547,0.9890806002140101,-0.07354599789167077,-0.2788471630834738,1.6570426326449657,0.22314923738949552,0.1523075774465205,-0.27757980417811723,1.7696591962533936,1.384394109416331,1.2673043513612334,-0.6826104789208901,0.3151108752294986,0.4093157732948638,1.087446227107052,-1.218316714836242,-0.2685332262125996,0.8359638168840271,0.4741269026348195,0.2847238856655045,0.7516625245999204,-1.7053084410376396,0.14162551651608724,0.6415127880346594,1.2388851819630204,0.770487784056554,-0.02788738933637577,0.24467690560305003,-1.0892241284786277,1.2884898042984818,0.35376120636599917,-0.624453806627975,1.7051491447928127,-0.18287458225545594,0.38772935886078724,-0.19578881150873334,0.16130224112750666,-0.05750751446083762,-0.261285115626365,-0.8284958842164989,0.2108590426382104,0.8462179261117703,0.053139255476908585,2.113436459509197,-0.7057182341707194,-1.00427078142292,0.1242727035306678,-2.398393236367476,1.5192390444471158,0.6991351530070388,0.02885527755070091,0.1680649583477364,-1.1332277841666103,-0.0027599782837276544,1.1687274833998542,0.4508014577751736,0.8578041209502796,-0.032663764772026635,0.19638233918147946,0.05630669048727528,-0.06304805888220107,2.5461011889840526,-2.100553812026583,0.7892301570617128,-0.25118314235065625,-1.5235353992372271,-0.641901257139472,-0.9149890276617241,-2.3668225554722464,-0.38751494351827703,1.866067893432212,0.22713487649175312,-0.36953136997661606,-0.862111817213686,1.678209488360012,-0.5119421529173995,1.2286752372920837,-1.2790066519120291,-2.2074739404518606,1.7305961339924607,0.5373653910307693,0.6766614953210229,-0.001082573310527883,-1.823471949526382,-0.13271340590739442,-0.46800761736047447,0.08099953654376385,0.8717743348848154,2.136266079221931,-0.5862701081466926,-0.22651923784178754,-0.4133104618922339,1.4547478102757219,0.6374851208735358,-0.4972760290116976,0.1697476428095221,0.45859717886185175,-0.4338791000955569,-0.06363362347337403,0.16626444295984374,0.04217563655914079,0.0017958690642549545,0.08858225324661347,-0.1193313262530923,0.6722353635593521,1.6044749816140593,-0.4929244329698068,-0.055722085244275306,-2.45809 ...

// %%
val histogram = p + geomHistogram(fill="dark_magenta") {x=xs}
histogram
// Out:
//    <div id="QBM49Q" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("QBM49Q");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[1.0,1.0,5.0,4.0,3.0,8.0,7.0,9.0,8.0,12.0,18.0,18.0,24.0,27.0,27.0,45.0,38.0,17.0,24.0,19.0,16.0,11.0,15.0,12.0,10.0,6.0,9.0,2.0,1.0,3.0],
// "x":[-2.7325345022177556,-2.5494469503523667,-2.3663593984869773,-2.1832718466215884,-2.000184294756199,-1.81709674289081,-1.634009191025421,-1.450921639160032,-1.2678340872946428,-1.0847465354292536,-0.9016589835638644,-0.7185714316984755,-0.5354838798330865,-0.35239632796769715,-0.1693087761023082,0.013778775763081175,0.19686632762847012,0.37995387949385906,0.5630414313592484,0.7461289832246374,0.9292165350900268,1.1123040869554157,1.2953916388208047,1.478479190686194,1.6615667425515825,1.844654294416972,2.0277418462823613,2.2108293981477507,2.393916950013139,2.5770045018785286]
// }
// }],
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=95cb57fb-615c-46c8-aa15-4d5ce83a66f3 width="100%" height="100%" style="max-width: 600.0px; max-height: 200.0px;" viewBox="0 0 600.0 200.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pvvG89p .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pvvG89p .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pvvG89p .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pvvG89p .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pvvG89p .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pvvG89p .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pvvG89p .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pvvG89p .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daLUKud .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pvvG89p .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pvvG89p .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daLUKud .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pvvG89p .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pvvG89p .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daLUKud .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daLUKud .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daLUKud .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pvvG89p">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 200.0 L600.0 200.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <g transform="translate(17.961210910936405 0.0 ) ">
//           <g>
//             <line x1="9.067968352072171" y1="0.0" x2="9.067968352072171" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="100.93307372793726" y1="0.0" x2="100.93307372793726" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="192.79817910380237" y1="0.0" x2="192.79817910380237" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="284.6632844796675" y1="0.0" x2="284.6632844796675" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="376.5283898555326" y1="0.0" x2="376.5283898555326" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="468.3934952313977" y1="0.0" x2="468.3934952313977" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(17.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="154.0" x2="555.0387890890636" y2="154.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="88.81481481481482" x2="555.0387890890636" y2="88.81481481481482" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="23.629629629629648" x2="555.0387890890636" y2="23.629629629629648" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c7oZGMd)" clip-bounds-jfx="[rect (17.961210910936405, 0.0), (555.0387890890636, 154.0)]">
//         <g transform="translate(17.961210910936405 0.0 ) ">
//           <g>
//             <g>
//               <rect x="512.9903959762557" y="144.22222222222223" height="9.77777777

// %% [markdown]
// ### Combine both plots in one figure

// %%
// Set scale X limits manually because of computed automatically
// the scale used by each plot would be slightly different
// and the stacked plots wouldn't be aligned.
val scale_x = scaleXContinuous(limits=-3.5 to 3.5)

ggbunch(
    listOf(histogram + scale_x,
           scatter + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5))
)
// Out:
//    <div id="noPk8Q" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("noPk8Q");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5]]
// },
// "figures":[{
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,1.0,1.0,8.0,4.0,8.0,11.0,12.0,15.0,19.0,35.0,32.0,46.0,52.0,31.0,32.0,21.0,15.0,19.0,15.0,9.0,10.0,1.0,3.0,0.0,0.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "spec_id":"5"
// },{
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.15362223266253422,-0.17605433535309262,1.3927523479608823,-2.2049996834073453,0.6461384512383636,1.1588037584656523,-1.1738790577208857,-0.41224696989139487,0.27016887506900616,-1.3825405426905573,-0.07379191465228034,1.2186526519068086,0.25258354438677294,1.024739396461091,0.3920435155459687,-1.5537638085026375,-0.47279593358897454,0.06817320510569687,0.8731186001572674,-0.830058261057972,-1.453914359750717,-0.42212595310021434,0.059103211218001245,0.539859556966007,1.198341187217703,2.085549448992728,1.1590795726385645,0.9569291634612105,-0.7877881781645285,0.24713728242517477,-1.327192410827333,-0.6862237488344105,0.3754073874357775,0.8348619174334829,0.3872522138674615,0.7567309713217125,-0.07722514400098784,0.0484967387354142,0.08232616771506038,-1.977621844873551,-0.5024778124846327,-0.2193938623517716,-1.066885750478218,0.9515502237417569,-0.1631196209761915,-1.1731767077635586,-1.8267185327771276,-1.5715491407724989,1.07011490189564,-1.9044119448216936,0.3176869072056333,-0.4876592414770111,0.7247331231422246,-0.5347145146652565,0.06748924990801039,1.4611754368848844,-1.7834758168863638,-0.7081564597769853,0.604898297627132,0.04208841013966067,0.22649701106116665,-0.2962701464378605,0.013650864641782619,0.58215181749099,-0.1258755574128869,-0.683550833210354,-0.682530603024815,-0.568986283527393,1.2951588097997693,0.45594288000333977,-0.862409732863635,1.559109691099351,-0.06071876253940036,-1.4346437878819311,1.2428687020542721,0.5205105383359911,0.17666546392078242,0.24938617343969224,0.030270895738807545,-0.8216826125576935,0.5349298192031047,-0.060549955637670363,1.8526666974237624,-0.7594122445404873,-0.428828796576219,-0.9005520479178746,1.4660625190391567,-0.76620565643672,0.45566049081209997,0.5193035201353405,-1.623554891627033,-0.06287438649189997,-0.13582387369274032,-0.12592446830632884,-0.5012198951466743,-0.5372848692532547,0.9890806002140101,-0.07354599789167077,-0.2788471630834738,1.6570426326449657,0.22314923738949552,0.1523075774465205,-0.27757980417811723,1.7696591962533936,1.384394109416331,1.2673043513612334,-0.6826104789208901,0.3151108752294986,0.4093157732948638,1.087446227107052,-1.218316714836242,-0.2685332262125996,0.8359638168840271,0.4741269026348195,0.2847238856655045,0.7516625245999204,-1.7053084410376396,0.14162551651608724,0.6415127880346594,1.2388851819630204,0.770487784056554,-0.02788738933637577,0.24467690560305003,-1.0892241284786277,1.2884898042984818,0.35376120636599917,-0.624453806627975,1.7051491447928127,-0.18287458225545594,0.38772935886078724,-0.19578881150873334,0.16130224112750666,-0.05750751446083762,-0.261285115626365,-0.8284958842164989,0.2108590426382104,0.8462179261117703,0.053139255476908585,2.113436459509197,-0.7057182341707194,-1.00427078142292,0.1242727035306678,-2.398393236367476,1.5192390444471158,0.6991351530070388,0.02885527755070091,0.1680649583477364,-1.1332277841666103,-0.0027599782837276544,1.1687274833998542,0.4508014577751736,0.8578041209502796,-0.032663764772026635,0.19638233918147946,0.05630669048727528,-0.06304805888220107,2.5461011889840526,-2.100553812026583,0.7892301570617128,-0.25118314235065625,-1.5235353992372271,-0.641901257139472,-0.9149890276617241,-2.3668225554722464,-0.38751494351827703,1.866067893432212,0.22713487649175312,-0.36953136997661606,-0.862111817213686,1.678209488360012,-0.5119421529173995,1.2286752372920837,-1.2790066519120291,-2.2074739404518606,1.7305961339924607,0.5373653910307693,0.6766614953210229,-0.001082573310527883,-1.823471949526382,-0.13271340590739442,-0.46800761736047447,0.08099953654376385,0.8717743348848154,2.136266079221931,-0.5862701081466926,-0.22651923784178754,-0.4133104618922339,1.4547478102757219,0.6374851208735358,-0.4972760290116976,0.1697476428095221,0.45859717886185175,-0.4338791000955569,-0.06363362347337403,0.16626444295984374,0.04217563655914079,0.0017958690642549545,0.08858225324661347,-0.1193313262530923,0.6722353635593521,1.6044749816140593,-0.4929244329698068,-0.055722085244275306,-2.45809 ...

// %% [markdown]
// ### Adjust visuals of the bunch figure

// %%
val upper_theme = theme(axis="blank", axisText=elementText(), axisTitleY=elementText(), panelGridMajorY="blank")
val lower_theme = theme(axis="blank", axisTextY=elementText(), axisTitle=elementText())

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5))
)
// Out:
//    <div id="GyrEIf" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("GyrEIf");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,1.0,1.0,8.0,4.0,8.0,11.0,12.0,15.0,19.0,35.0,32.0,46.0,52.0,31.0,32.0,21.0,15.0,19.0,15.0,9.0,10.0,1.0,3.0,0.0,0.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"9"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.15362223266253422,-0.17605433535309262,1.3927523479608823,-2.2049996834073453,0.6461384512383636,1.1588037584656523,-1.1738790577208857,-0.41224696989139487,0.27016887506900616,-1.3825405426905573,-0.07379191465228034,1.2186526519068086,0.25258354438677294,1.024739396461091,0.3920435155459687,-1.5537638085026375,-0.47279593358897454,0.06817320510569687,0.8731186001572674,-0.830058261057972,-1.453914359750717,-0.42212595310021434,0.059103211218001245,0.539859556966007,1.198341187217703,2.085549448992728,1.1590795726385645,0.9569291634612105,-0.7877881781645285,0.24713728242517477,-1.327192410827333,-0.6862237488344105,0.3754073874357775,0.8348619174334829,0.3872522138674615,0.7567309713217125,-0.07722514400098784,0.0484967387354142,0.08232616771506038,-1.977621844873551,-0.5024778124846327,-0.2193938623517716,-1.066885750478218,0.9515502237417569,-0.1631196209761915,-1.1731767077635586,-1.8267185327771276,-1.5715491407724989,1.07011490189564,-1.9044119448216936,0.3176869072056333,-0.4876592414770111,0.7247331231422246,-0.5347145146652565,0.06748924990801039,1.4611754368848844,-1.7834758168863638,-0.7081564597769853,0.604898297627132,0.04208841013966067,0.22649701106116665,-0.2962701464378605,0.013650864641782619,0.58215181749099,-0.1258755574128869,-0.683550833210354,-0.682530603024815,-0.568986283527393,1.2951588097997693,0.45594288000333977,-0.862409732863635,1.559109691099351,-0.06071876253940036,-1.4346437878819311,1.2428687020542721,0.5205105383359911,0.17666546392078242,0.24938617343969224,0.030270895738807545,-0.8216826125576935,0.5349298192031047,-0.060549955637670363,1.8526666974237624,-0.7594122445404873,-0.428828796576219,-0.9005520479178746,1.4660625190391567,-0.76620565643672,0.45566049081209997,0.5193035201353405,-1.623554891627033,-0.06287438649189997,-0.13582387369274032,-0.12592446830632884,-0.5012198951466743,-0.5372848692532547,0.9890806002140101,-0.07354599789167077,-0.2788471630834738,1.6570426326449657,0.22314923738949552,0.1523075774465205,-0.27757980417811723,1.7696591962533936,1.384394109416331,1.2673043513612334,-0.6826104789208901,0.3151108752294986,0.4093157732948638,1.087446227107052,-1.218316714836242,-0.2685332262125996,0.8359638168840271,0.4741269026348195,0.2847238856655045,0.7516625245999204,-1.7053084410376396,0.14162551651608724,0.6415127880346594,1.2388851819630204,0.770487784056554,-0.02788738933637577,0.24467690560305003,-1.0892241284786277,1.2884898042984818,0.35376120636599917,-0.624453806627975,1.7051491447928127,-0.18287458225545594,0.38772935886078724,-0.19578881150873334,0.16130224112750666,-0.05750751446083762,-0.261285115626365,-0.8284958842164989,0.2108590426382104,0.8462179261117703,0.053139255476908585,2.113436459509197,-0.7057182341707194,-1.00427078142292,0.1242727035306678,-2.398393236367476,1.5192390444471158,0.6991351530070388,0.02885527755070091,0.1680649583477364,-1.1332277841666103,-0.0027599782837276544,1.1687274833998542,0.4508014577751736,0.8578041209502796,-0.032663764772026635,0.19638233918147946,0.05630669048727528,-0.06304805888220107,2.5461011889840526,-2.100553812026583,0.7892301570617128,-0.25118314235065625,-1.5235353992372271,-0.641901257139472,-0.9149890276617241,-2.3668225554722464,-0.38751494351827703,1.866067893432212,0.22713487649175312,-0.36953136997661606,-0.862111817213686,1.678209488360012,-0.5119421529173995,1.2286752372920837,-1.2790066519120291,-2.2074739404518606,1.7305961339924607,0.5373653910307693,0.6766614953210229,-0.001082573310527883,-1.823471949526382,-0.13271340590739442,-0.46800761736047447,0.08099953654376385,0.8717743348848154,2.136266079221931,-0.5862701081466926,-0.22651923784178754,-0.4133104618922339,1.4547478102757219,0.6374851208735358,-0.4972760290116976,0.1697476428095221,0.45859717886185175,-0.4338791000955569,-0.06363362347337403,0.16626444295984374,0.04217563655914079,0.0017958690642549545,0.08858225324661347,-0.1193313262530923,0.6722353635593521,1.6044749816140593,-0.4929244329698068,-0.055722085244275306,-2.45809 ...

// %% [markdown]
// ### Move the regions
//
// You can additionally move the bottom plot up a bit with the last two parameters of the tuple responsible for the layout of the region.

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5, 0, -12)) // Move up 12 pixels
)
// Out:
//    <div id="J3Qcx7" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("J3Qcx7");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5,0,-12]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,1.0,1.0,8.0,4.0,8.0,11.0,12.0,15.0,19.0,35.0,32.0,46.0,52.0,31.0,32.0,21.0,15.0,19.0,15.0,9.0,10.0,1.0,3.0,0.0,0.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"13"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.15362223266253422,-0.17605433535309262,1.3927523479608823,-2.2049996834073453,0.6461384512383636,1.1588037584656523,-1.1738790577208857,-0.41224696989139487,0.27016887506900616,-1.3825405426905573,-0.07379191465228034,1.2186526519068086,0.25258354438677294,1.024739396461091,0.3920435155459687,-1.5537638085026375,-0.47279593358897454,0.06817320510569687,0.8731186001572674,-0.830058261057972,-1.453914359750717,-0.42212595310021434,0.059103211218001245,0.539859556966007,1.198341187217703,2.085549448992728,1.1590795726385645,0.9569291634612105,-0.7877881781645285,0.24713728242517477,-1.327192410827333,-0.6862237488344105,0.3754073874357775,0.8348619174334829,0.3872522138674615,0.7567309713217125,-0.07722514400098784,0.0484967387354142,0.08232616771506038,-1.977621844873551,-0.5024778124846327,-0.2193938623517716,-1.066885750478218,0.9515502237417569,-0.1631196209761915,-1.1731767077635586,-1.8267185327771276,-1.5715491407724989,1.07011490189564,-1.9044119448216936,0.3176869072056333,-0.4876592414770111,0.7247331231422246,-0.5347145146652565,0.06748924990801039,1.4611754368848844,-1.7834758168863638,-0.7081564597769853,0.604898297627132,0.04208841013966067,0.22649701106116665,-0.2962701464378605,0.013650864641782619,0.58215181749099,-0.1258755574128869,-0.683550833210354,-0.682530603024815,-0.568986283527393,1.2951588097997693,0.45594288000333977,-0.862409732863635,1.559109691099351,-0.06071876253940036,-1.4346437878819311,1.2428687020542721,0.5205105383359911,0.17666546392078242,0.24938617343969224,0.030270895738807545,-0.8216826125576935,0.5349298192031047,-0.060549955637670363,1.8526666974237624,-0.7594122445404873,-0.428828796576219,-0.9005520479178746,1.4660625190391567,-0.76620565643672,0.45566049081209997,0.5193035201353405,-1.623554891627033,-0.06287438649189997,-0.13582387369274032,-0.12592446830632884,-0.5012198951466743,-0.5372848692532547,0.9890806002140101,-0.07354599789167077,-0.2788471630834738,1.6570426326449657,0.22314923738949552,0.1523075774465205,-0.27757980417811723,1.7696591962533936,1.384394109416331,1.2673043513612334,-0.6826104789208901,0.3151108752294986,0.4093157732948638,1.087446227107052,-1.218316714836242,-0.2685332262125996,0.8359638168840271,0.4741269026348195,0.2847238856655045,0.7516625245999204,-1.7053084410376396,0.14162551651608724,0.6415127880346594,1.2388851819630204,0.770487784056554,-0.02788738933637577,0.24467690560305003,-1.0892241284786277,1.2884898042984818,0.35376120636599917,-0.624453806627975,1.7051491447928127,-0.18287458225545594,0.38772935886078724,-0.19578881150873334,0.16130224112750666,-0.05750751446083762,-0.261285115626365,-0.8284958842164989,0.2108590426382104,0.8462179261117703,0.053139255476908585,2.113436459509197,-0.7057182341707194,-1.00427078142292,0.1242727035306678,-2.398393236367476,1.5192390444471158,0.6991351530070388,0.02885527755070091,0.1680649583477364,-1.1332277841666103,-0.0027599782837276544,1.1687274833998542,0.4508014577751736,0.8578041209502796,-0.032663764772026635,0.19638233918147946,0.05630669048727528,-0.06304805888220107,2.5461011889840526,-2.100553812026583,0.7892301570617128,-0.25118314235065625,-1.5235353992372271,-0.641901257139472,-0.9149890276617241,-2.3668225554722464,-0.38751494351827703,1.866067893432212,0.22713487649175312,-0.36953136997661606,-0.862111817213686,1.678209488360012,-0.5119421529173995,1.2286752372920837,-1.2790066519120291,-2.2074739404518606,1.7305961339924607,0.5373653910307693,0.6766614953210229,-0.001082573310527883,-1.823471949526382,-0.13271340590739442,-0.46800761736047447,0.08099953654376385,0.8717743348848154,2.136266079221931,-0.5862701081466926,-0.22651923784178754,-0.4133104618922339,1.4547478102757219,0.6374851208735358,-0.4972760290116976,0.1697476428095221,0.45859717886185175,-0.4338791000955569,-0.06363362347337403,0.16626444295984374,0.04217563655914079,0.0017958690642549545,0.08858225324661347,-0.1193313262530923,0.6722353635593521,1.6044749816140593,-0.4929244329698068,-0.055722085244275306,-2.45809 ...

// %% [markdown]
// ### Adjust plot sizes
//
// The width and height of the plots within `ggbunch()` are given in relative units, but you can change the size of the whole `ggbunch()` plot with `ggsize()`.

// %%
ggbunch(
    listOf(histogram + upper_theme + scale_x,
           scatter + lower_theme + scale_x),
    listOf(listOf(0, 0, 1, .5),
           listOf(0, .5, 1, .5, 0, -12))
) + ggsize(600, 400)
// Out:
//    <div id="c5VbQQ" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("c5VbQQ");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"free",
// "regions":[[0,0,1,0.5],[0,0.5,1,0.5,0,-12]]
// },
// "figures":[{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,0.0,0.0,1.0,1.0,8.0,4.0,8.0,11.0,12.0,15.0,19.0,35.0,32.0,46.0,52.0,31.0,32.0,21.0,15.0,19.0,15.0,9.0,10.0,1.0,3.0,0.0,0.0,0.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"17"
// },{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.15362223266253422,-0.17605433535309262,1.3927523479608823,-2.2049996834073453,0.6461384512383636,1.1588037584656523,-1.1738790577208857,-0.41224696989139487,0.27016887506900616,-1.3825405426905573,-0.07379191465228034,1.2186526519068086,0.25258354438677294,1.024739396461091,0.3920435155459687,-1.5537638085026375,-0.47279593358897454,0.06817320510569687,0.8731186001572674,-0.830058261057972,-1.453914359750717,-0.42212595310021434,0.059103211218001245,0.539859556966007,1.198341187217703,2.085549448992728,1.1590795726385645,0.9569291634612105,-0.7877881781645285,0.24713728242517477,-1.327192410827333,-0.6862237488344105,0.3754073874357775,0.8348619174334829,0.3872522138674615,0.7567309713217125,-0.07722514400098784,0.0484967387354142,0.08232616771506038,-1.977621844873551,-0.5024778124846327,-0.2193938623517716,-1.066885750478218,0.9515502237417569,-0.1631196209761915,-1.1731767077635586,-1.8267185327771276,-1.5715491407724989,1.07011490189564,-1.9044119448216936,0.3176869072056333,-0.4876592414770111,0.7247331231422246,-0.5347145146652565,0.06748924990801039,1.4611754368848844,-1.7834758168863638,-0.7081564597769853,0.604898297627132,0.04208841013966067,0.22649701106116665,-0.2962701464378605,0.013650864641782619,0.58215181749099,-0.1258755574128869,-0.683550833210354,-0.682530603024815,-0.568986283527393,1.2951588097997693,0.45594288000333977,-0.862409732863635,1.559109691099351,-0.06071876253940036,-1.4346437878819311,1.2428687020542721,0.5205105383359911,0.17666546392078242,0.24938617343969224,0.030270895738807545,-0.8216826125576935,0.5349298192031047,-0.060549955637670363,1.8526666974237624,-0.7594122445404873,-0.428828796576219,-0.9005520479178746,1.4660625190391567,-0.76620565643672,0.45566049081209997,0.5193035201353405,-1.623554891627033,-0.06287438649189997,-0.13582387369274032,-0.12592446830632884,-0.5012198951466743,-0.5372848692532547,0.9890806002140101,-0.07354599789167077,-0.2788471630834738,1.6570426326449657,0.22314923738949552,0.1523075774465205,-0.27757980417811723,1.7696591962533936,1.384394109416331,1.2673043513612334,-0.6826104789208901,0.3151108752294986,0.4093157732948638,1.087446227107052,-1.218316714836242,-0.2685332262125996,0.8359638168840271,0.4741269026348195,0.2847238856655045,0.7516625245999204,-1.7053084410376396,0.14162551651608724,0.6415127880346594,1.2388851819630204,0.770487784056554,-0.02788738933637577,0.24467690560305003,-1.0892241284786277,1.2884898042984818,0.35376120636599917,-0.624453806627975,1.7051491447928127,-0.18287458225545594,0.38772935886078724,-0.19578881150873334,0.16130224112750666,-0.05750751446083762,-0.261285115626365,-0.8284958842164989,0.2108590426382104,0.8462179261117703,0.053139255476908585,2.113436459509197,-0.7057182341707194,-1.00427078142292,0.1242727035306678,-2.398393236367476,1.5192390444471158,0.6991351530070388,0.02885527755070091,0.1680649583477364,-1.1332277841666103,-0.0027599782837276544,1.1687274833998542,0.4508014577751736,0.8578041209502796,-0.032663764772026635,0.19638233918147946,0.05630669048727528,-0.06304805888220107,2.5461011889840526,-2.100553812026583,0.7892301570617128,-0.25118314235065625,-1.5235353992372271,-0.641901257139472,-0.9149890276617241,-2.3668225554722464,-0.38751494351827703,1.866067893432212,0.22713487649175312,-0.36953136997661606,-0.862111817213686,1.678209488360012,-0.5119421529173995,1.2286752372920837,-1.2790066519120291,-2.2074739404518606,1.7305961339924607,0.5373653910307693,0.6766614953210229,-0.001082573310527883,-1.823471949526382,-0.13271340590739442,-0.46800761736047447,0.08099953654376385,0.8717743348848154,2.136266079221931,-0.5862701081466926,-0.22651923784178754,-0.4133104618922339,1.4547478102757219,0.6374851208735358,-0.4972760290116976,0.1697476428095221,0.45859717886185175,-0.4338791000955569,-0.06363362347337403,0.16626444295984374,0.04217563655914079,0.0017958690642549545,0.08858225324661347,-0.1193313262530923,0.6722353635593521,1.6044749816140593,-0.4929244329698068,-0.055722085244275306,-2.45809 ...
