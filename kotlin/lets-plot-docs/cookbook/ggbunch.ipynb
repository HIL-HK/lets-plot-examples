// %% [markdown]
// # GGBunch
//
// *GGBunch* allows to show a collection of plots on one figure. Each plot in the collection can have arbitrary location and size. There is no automatic layout inside the bunch.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="5gkARS"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("5gkARS").appendChild(div);
//            };
//            var e = document.getElementById("5gkARS");
//            e.appendChild(script);
//        })();
//    </script>

// %%
@file:DependsOn("org.apache.commons:commons-math3:3.6.1")

// %%
import kotlin.random.Random
import org.apache.commons.math3.distribution.MultivariateNormalDistribution

// %%
val cov : Array<DoubleArray> = arrayOf(doubleArrayOf(1.0, 0.0),
                                        doubleArrayOf(0.0, 1.0))
val means : DoubleArray = doubleArrayOf(0.0, 0.0)
val xy = MultivariateNormalDistribution(means, cov).sample(400)

val xs = xy.map { it[0] }
val ys = xy.map { it[1] }

// %% [markdown]
// ### View this data as a scatter plot and as a histogram

// %%
val p = letsPlot() + ggsize(600,200)

val scatter = p + geomPoint(color="black", alpha=.4) {x=xs; y=ys}
scatter
// Out:
//    <div id="PLJA2O"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("PLJA2O");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.9815319409222186,1.0626258308217764,-0.7654715015285579,0.9789366700076662,-0.14475243707091742,-0.2554706710956172,-1.1215798734663527,1.6697615068090077,-1.0093520908169087,-0.561489270288172,-1.3134866967546812,-0.46783812558286614,-1.9964577753554285,0.5352992545119053,-2.638682480440078,-0.24230109911359476,1.4194243429566513,-0.5924335049506165,0.7429518156816134,-0.4987206001734053,-0.08012091803877298,0.24755874713177842,0.4528731053820754,-1.8679394786478931,0.4399580472741854,-0.8756795140757547,0.3570238458628456,-0.9279824739166365,-0.22064431978329194,-0.15934629083321555,0.20781767284099814,1.9851457526564003,0.6345371343792356,-0.8523203992789457,-0.5980801552978809,-1.4629236423059737,-0.29440981836881336,-0.17840661274477346,-1.0522577600162433,-1.8003300226778538,1.135202043829583,0.16112025037717928,-0.05156686652750041,-1.6454423250661194,0.02726691557969976,-1.274663359257665,-0.0409561876606333,-0.6408531204303913,0.311044761651467,-0.07865772358956487,-0.16552037392001032,-0.7479401004992935,-0.07548808676406316,-0.3530562866377955,0.740934945795748,-0.9623236909866513,-0.009891208299413536,0.09013439134576456,-1.2030884745948673,-1.0116053732731773,0.1221734796059998,0.6766777421242453,-1.3369273693631827,-0.9942979476103871,-0.38478248267500476,-0.12479118237944894,-0.6843570483350881,1.1613455879902503,-3.226391399328434,0.13311972848486592,1.6779446005887027,-0.9151394915165507,0.9580677983066864,-0.28759133701011963,-0.07283266964682324,0.9770833309980452,-0.3273328195977589,-0.150497176683709,0.06252626354936308,0.4505452610858531,-0.3979601098989083,-1.3711093021205518,-0.34848569639949567,-1.5869401147718611,0.04087387127498206,-0.6320676099489627,0.07939664098538367,-0.33520633052226756,-0.12286160086566142,1.436200011984811,-2.3155271954025793,-2.064393696355506,-1.1046980114479608,-0.3914250527528525,-1.658211559770904,0.80695533243722,1.1425171893334451,-2.089604546799655,-1.4540339619305422,0.7674716848232624,0.30554884104602603,1.15627629650161,-0.9082304921660717,0.4418886026633614,-1.4736651462917418,0.028836718492492346,-0.2578853428103588,0.3164463774444058,-1.8080048414610506,-0.322327132147817,-1.8119343052408539,-0.0246437343245578,-0.47721483714376656,0.0748678031466245,0.05857390660229916,1.1640199493513215,-0.7428098567239931,-0.29583558762378115,0.6054915636470126,0.2520366243212744,-0.7531878437725956,-0.6079291789438569,-1.1498468614180017,1.6700510273945277,-1.4292015397417164,1.023885136880972,-0.13064679010538477,0.11382403200619122,0.8698971687806945,-0.9990899236757556,0.42989490388809454,-0.350239147427939,0.6894550976997619,1.2458064664445478,-0.20021946626797124,0.005206621780504494,-0.15569900872345782,2.212206732684981,0.8915343625470076,0.8437051852436136,1.4321759463350736,0.18200214245686236,0.0656467921949524,1.848288436292507,1.437595752470186,0.2926997397599094,-0.05827827873815938,0.732428168977181,-0.36429959399782236,-1.1329237038682505,1.4075785010447028,-0.3969011850021705,0.3232474479324874,-1.463368020564679,-0.9749828384067486,0.050085917196540236,0.5054345581972364,-1.4259231930479892,-2.2531660194350605,-0.7401370217382971,0.34873302855894167,0.44351008707650325,0.7860714518039567,-0.46771307887910046,-0.14592110373996814,0.8556560394021862,0.7922922865576331,-0.3427033009973036,0.3818802617930721,0.3342614519682711,-0.21829920364055458,-1.1363779199714303,0.055601177633283594,0.6459184379894302,0.3068172030003371,-0.9263647909609874,-0.5548805272064571,-1.2808313498973276,-1.096416452263948,-0.812431910092375,-0.37750826298504797,0.7881922891120343,1.7083055901057296,0.36181352701928143,1.1516939368014563,0.1755287030057399,-1.9966603941963534,1.4186754709890455,-0.654535905442091,-0.5502175199354304,-0.935094517783841,0.14144854997050788,0.31086723074036615,-0.17438156225946216,0.765423655881984,-1.2004193003213735,-1.0207982719277109,-1.34926961569919,0.656990302091712,0.7084263023410915,-2.4722022575189078,-0.2281623321897263,0.894654160173 ...

// %%
val histogram = p + geomHistogram(fill="dark_magenta") {x=xs}
histogram
// Out:
//    <div id="FWjuwV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("FWjuwV");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[1.0,0.0,1.0,3.0,5.0,3.0,9.0,8.0,12.0,19.0,23.0,17.0,21.0,42.0,45.0,35.0,31.0,30.0,29.0,27.0,12.0,9.0,10.0,1.0,3.0,1.0,1.0,1.0,0.0,1.0],
// "x":[-3.264900109632506,-3.036754165566872,-2.808608221501238,-2.580462277435603,-2.352316333369969,-2.124170389304335,-1.8960244452387007,-1.6678785011730664,-1.4397325571074322,-1.2115866130417978,-0.9834406689761637,-0.7552947249105295,-0.5271487808448954,-0.2990028367792612,-0.0708568927136266,0.15728905135200755,0.3854349954176417,0.6135809394832759,0.8417268835489105,1.0698728276145446,1.2980187716801788,1.526164715745813,1.754310659811447,1.9824566038770812,2.2106025479427154,2.4387484920083495,2.6668944360739837,2.8950403801396187,3.123186324205253,3.351332268270887]
// }
// }],
// "spec_id":"2"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### Combine both plots in one figure

// %%
// Set scale X limits manually because of computed automatically
// the scale used by each plot would be slightly different
// and the stacked plots wouldn't be aligned.
val scale_x = scaleXContinuous(limits=-3.5 to 3.5)
GGBunch().addPlot(histogram + scale_x, 0, 0)
         .addPlot(scatter + scale_x, 0, 200)
// Out:
//    <div id="XCjESc"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("XCjESc");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":null,
// "y":0,
// "feature_spec":{
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,1.0,0.0,1.0,3.0,5.0,6.0,8.0,10.0,18.0,21.0,25.0,19.0,40.0,46.0,37.0,35.0,31.0,31.0,24.0,19.0,9.0,3.0,2.0,3.0,1.0,1.0,0.0,1.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "spec_id":"3"
// },
// "height":null
// },{
// "x":0,
// "width":null,
// "y":200,
// "feature_spec":{
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.9815319409222186,1.0626258308217764,-0.7654715015285579,0.9789366700076662,-0.14475243707091742,-0.2554706710956172,-1.1215798734663527,1.6697615068090077,-1.0093520908169087,-0.561489270288172,-1.3134866967546812,-0.46783812558286614,-1.9964577753554285,0.5352992545119053,-2.638682480440078,-0.24230109911359476,1.4194243429566513,-0.5924335049506165,0.7429518156816134,-0.4987206001734053,-0.08012091803877298,0.24755874713177842,0.4528731053820754,-1.8679394786478931,0.4399580472741854,-0.8756795140757547,0.3570238458628456,-0.9279824739166365,-0.22064431978329194,-0.15934629083321555,0.20781767284099814,1.9851457526564003,0.6345371343792356,-0.8523203992789457,-0.5980801552978809,-1.4629236423059737,-0.29440981836881336,-0.17840661274477346,-1.0522577600162433,-1.8003300226778538,1.135202043829583,0.16112025037717928,-0.05156686652750041,-1.6454423250661194,0.02726691557969976,-1.274663359257665,-0.0409561876606333,-0.6408531204303913,0.311044761651467,-0.07865772358956487,-0.16552037392001032,-0.7479401004992935,-0.07548808676406316,-0.3530562866377955,0.740934945795748,-0.9623236909866513,-0.009891208299413536,0.09013439134576456,-1.2030884745948673,-1.0116053732731773,0.1221734796059998,0.6766777421242453,-1.3369273693631827,-0.9942979476103871,-0.38478248267500476,-0.12479118237944894,-0.6843570483350881,1.1613455879902503,-3.226391399328434,0.13311972848486592,1.6779446005887027,-0.9151394915165507,0.9580677983066864,-0.28759133701011963,-0.07283266964682324,0.9770833309980452,-0.3273328195977589,-0.150497176683709,0.06252626354936308,0.4505452610858531,-0.3979601098989083,-1.3711093021205518,-0.34848569639949567,-1.5869401147718611,0.04087387127498206,-0.6320676099489627,0.07939664098538367,-0.33520633052226756,-0.12286160086566142,1.436200011984811,-2.3155271954025793,-2.064393696355506,-1.1046980114479608,-0.3914250527528525,-1.658211559770904,0.80695533243722,1.1425171893334451,-2.089604546799655,-1.4540339619305422,0.7674716848232624,0.30554884104602603,1.15627629650161,-0.9082304921660717,0.4418886026633614,-1.4736651462917418,0.028836718492492346,-0.2578853428103588,0.3164463774444058,-1.8080048414610506,-0.322327132147817,-1.8119343052408539,-0.0246437343245578,-0.47721483714376656,0.0748678031466245,0.05857390660229916,1.1640199493513215,-0.7428098567239931,-0.29583558762378115,0.6054915636470126,0.2520366243212744,-0.7531878437725956,-0.6079291789438569,-1.1498468614180017,1.6700510273945277,-1.4292015397417164,1.023885136880972,-0.13064679010538477,0.11382403200619122,0.8698971687806945,-0.9990899236757556,0.42989490388809454,-0.350239147427939,0.6894550976997619,1.2458064664445478,-0.20021946626797124,0.005206621780504494,-0.15569900872345782,2.212206732684981,0.8915343625470076,0.8437051852436136,1.4321759463350736,0.18200214245686236,0.0656467921949524,1.848288436292507,1.437595752470186,0.2926997397599094,-0.05827827873815938,0.732428168977181,-0.36429959399782236,-1.1329237038682505,1.4075785010447028,-0.3969011850021705,0.3232474479324874,-1.463368020564679,-0.9749828384067486,0.050085917196540236,0.5054345581972364,-1.4259231930479892,-2.2531660194350605,-0.7401370217382971,0.34873302855894167,0.44351008707650325,0.7860714518039567,-0.46771307887910046,-0.14592110373996814,0.8556560394021862,0.7922922865576331,-0.3427033009973036,0.3818802617930721,0.3342614519682711,-0.21829920364055458,-1.1363779199714303,0.055601177633283594,0.6459184379894302,0.3068172030003371,-0.9263647909609874,-0.5548805272064571,-1.2808313498973276,-1.096416452263948,-0.812431910092375,-0.37750826298504797,0.7881922891120343,1.7083055901057296,0.36181352701928143,1.1516939368014563,0.1755287030057399,-1.9966603941963534,1.4186754709890455,-0.654535905442091,-0.5502175199354304,-0.935094517783841,0.14144854997050788,0.31086723074036615,-0.17438156225946216,0.765423655881984,-1.2004193003213735,-1.0207982719277109,-1.34926961569919,0.656990302091712,0.7084263023410915,-2.4722022575189078,-0.2281623321897263,0.894654160173 ...

// %% [markdown]
// ### Adjust visuals of the bunch figure

// %%
val upper_theme = theme(axis="blank", axisText=elementText(), axisTitleY=elementText(), panelGridMajorY="blank")
val lower_theme = theme(axis="blank", axisTextY=elementText(), axisTitle=elementText())

// %%
GGBunch().addPlot(histogram + upper_theme + scale_x, 0, 0)
         .addPlot(scatter + lower_theme + scale_x, 0, 200)
// Out:
//    <div id="KvG8wP"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("KvG8wP");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":null,
// "y":0,
// "feature_spec":{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,1.0,0.0,1.0,3.0,5.0,6.0,8.0,10.0,18.0,21.0,25.0,19.0,40.0,46.0,37.0,35.0,31.0,31.0,24.0,19.0,9.0,3.0,2.0,3.0,1.0,1.0,0.0,1.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"5"
// },
// "height":null
// },{
// "x":0,
// "width":null,
// "y":200,
// "feature_spec":{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.9815319409222186,1.0626258308217764,-0.7654715015285579,0.9789366700076662,-0.14475243707091742,-0.2554706710956172,-1.1215798734663527,1.6697615068090077,-1.0093520908169087,-0.561489270288172,-1.3134866967546812,-0.46783812558286614,-1.9964577753554285,0.5352992545119053,-2.638682480440078,-0.24230109911359476,1.4194243429566513,-0.5924335049506165,0.7429518156816134,-0.4987206001734053,-0.08012091803877298,0.24755874713177842,0.4528731053820754,-1.8679394786478931,0.4399580472741854,-0.8756795140757547,0.3570238458628456,-0.9279824739166365,-0.22064431978329194,-0.15934629083321555,0.20781767284099814,1.9851457526564003,0.6345371343792356,-0.8523203992789457,-0.5980801552978809,-1.4629236423059737,-0.29440981836881336,-0.17840661274477346,-1.0522577600162433,-1.8003300226778538,1.135202043829583,0.16112025037717928,-0.05156686652750041,-1.6454423250661194,0.02726691557969976,-1.274663359257665,-0.0409561876606333,-0.6408531204303913,0.311044761651467,-0.07865772358956487,-0.16552037392001032,-0.7479401004992935,-0.07548808676406316,-0.3530562866377955,0.740934945795748,-0.9623236909866513,-0.009891208299413536,0.09013439134576456,-1.2030884745948673,-1.0116053732731773,0.1221734796059998,0.6766777421242453,-1.3369273693631827,-0.9942979476103871,-0.38478248267500476,-0.12479118237944894,-0.6843570483350881,1.1613455879902503,-3.226391399328434,0.13311972848486592,1.6779446005887027,-0.9151394915165507,0.9580677983066864,-0.28759133701011963,-0.07283266964682324,0.9770833309980452,-0.3273328195977589,-0.150497176683709,0.06252626354936308,0.4505452610858531,-0.3979601098989083,-1.3711093021205518,-0.34848569639949567,-1.5869401147718611,0.04087387127498206,-0.6320676099489627,0.07939664098538367,-0.33520633052226756,-0.12286160086566142,1.436200011984811,-2.3155271954025793,-2.064393696355506,-1.1046980114479608,-0.3914250527528525,-1.658211559770904,0.80695533243722,1.1425171893334451,-2.089604546799655,-1.4540339619305422,0.7674716848232624,0.30554884104602603,1.15627629650161,-0.9082304921660717,0.4418886026633614,-1.4736651462917418,0.028836718492492346,-0.2578853428103588,0.3164463774444058,-1.8080048414610506,-0.322327132147817,-1.8119343052408539,-0.0246437343245578,-0.47721483714376656,0.0748678031466245,0.05857390660229916,1.1640199493513215,-0.7428098567239931,-0.29583558762378115,0.6054915636470126,0.2520366243212744,-0.7531878437725956,-0.6079291789438569,-1.1498468614180017,1.6700510273945277,-1.4292015397417164,1.023885136880972,-0.13064679010538477,0.11382403200619122,0.8698971687806945,-0.9990899236757556,0.42989490388809454,-0.350239147427939,0.6894550976997619,1.2458064664445478,-0.20021946626797124,0.005206621780504494,-0.15569900872345782,2.212206732684981,0.8915343625470076,0.8437051852436136,1.4321759463350736,0.18200214245686236,0.0656467921949524,1.848288436292507,1.437595752470186,0.2926997397599094,-0.05827827873815938,0.732428168977181,-0.36429959399782236,-1.1329237038682505,1.4075785010447028,-0.3969011850021705,0.3232474479324874,-1.463368020564679,-0.9749828384067486,0.050085917196540236,0.5054345581972364,-1.4259231930479892,-2.2531660194350605,-0.7401370217382971,0.34873302855894167,0.44351008707650325,0.7860714518039567,-0.46771307887910046,-0.14592110373996814,0.8556560394021862,0.7922922865576331,-0.3427033009973036,0.3818802617930721,0.3342614519682711,-0.21829920364055458,-1.1363779199714303,0.055601177633283594,0.6459184379894302,0.3068172030003371,-0.9263647909609874,-0.5548805272064571,-1.2808313498973276,-1.096416452263948,-0.812431910092375,-0.37750826298504797,0.7881922891120343,1.7083055901057296,0.36181352701928143,1.1516939368014563,0.1755287030057399,-1.9966603941963534,1.4186754709890455,-0.654535905442091,-0.5502175199354304,-0.935094517783841,0.14144854997050788,0.31086723074036615,-0.17438156225946216,0.765423655881984,-1.2004193003213735,-1.0207982719277109,-1.34926961569919,0.656990302091712,0.7084263023410915,-2.4722022575189078,-0.2281623321897263,0.894654160173 ...

// %% [markdown]
// ### Adjust plot sizes
//
// *addPlot()* method has two more (optional) parameters: *width* and *height*.
//
// This values will override plot size earlier defined via *ggsize()* function.

// %%
GGBunch().addPlot(histogram + upper_theme + scale_x, 0, 0, 600, 100)
         .addPlot(scatter + lower_theme + scale_x, 0, 100, 600, 300)
// Out:
//    <div id="zVkBP1"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("zVkBP1");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":600,
// "y":0,
// "feature_spec":{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"bin",
// "position":"stack",
// "geom":"histogram",
// "fill":"dark_magenta",
// "data":{
// "..count..":[0.0,1.0,0.0,1.0,3.0,5.0,6.0,8.0,10.0,18.0,21.0,25.0,19.0,40.0,46.0,37.0,35.0,31.0,31.0,24.0,19.0,9.0,3.0,2.0,3.0,1.0,1.0,0.0,1.0,0.0],
// "x":[-3.541222222222222,-3.2969999999999997,-3.0527777777777776,-2.8085555555555555,-2.564333333333333,-2.320111111111111,-2.0758888888888887,-1.8316666666666663,-1.5874444444444442,-1.3432222222222219,-1.0989999999999998,-0.8547777777777776,-0.6105555555555555,-0.3663333333333334,-0.12211111111111084,0.12211111111111128,0.3663333333333334,0.6105555555555555,0.8547777777777781,1.0989999999999998,1.3432222222222223,1.587444444444444,1.8316666666666666,2.075888888888889,2.320111111111111,2.5643333333333334,2.808555555555555,3.0527777777777776,3.297,3.541222222222222]
// }
// }],
// "theme":{
// "axis_title_y":{
// "blank":false
// },
// "axis":"blank",
// "axis_text":{
// "blank":false
// },
// "panel_grid_major_y":"blank"
// },
// "spec_id":"7"
// },
// "height":100
// },{
// "x":0,
// "width":600,
// "y":100,
// "feature_spec":{
// "mapping":{
// },
// "ggsize":{
// "width":600.0,
// "height":200.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[-3.5,3.5]
// }],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "color":"black",
// "alpha":0.4,
// "position":"identity",
// "geom":"point",
// "data":{
// "x":[-0.9815319409222186,1.0626258308217764,-0.7654715015285579,0.9789366700076662,-0.14475243707091742,-0.2554706710956172,-1.1215798734663527,1.6697615068090077,-1.0093520908169087,-0.561489270288172,-1.3134866967546812,-0.46783812558286614,-1.9964577753554285,0.5352992545119053,-2.638682480440078,-0.24230109911359476,1.4194243429566513,-0.5924335049506165,0.7429518156816134,-0.4987206001734053,-0.08012091803877298,0.24755874713177842,0.4528731053820754,-1.8679394786478931,0.4399580472741854,-0.8756795140757547,0.3570238458628456,-0.9279824739166365,-0.22064431978329194,-0.15934629083321555,0.20781767284099814,1.9851457526564003,0.6345371343792356,-0.8523203992789457,-0.5980801552978809,-1.4629236423059737,-0.29440981836881336,-0.17840661274477346,-1.0522577600162433,-1.8003300226778538,1.135202043829583,0.16112025037717928,-0.05156686652750041,-1.6454423250661194,0.02726691557969976,-1.274663359257665,-0.0409561876606333,-0.6408531204303913,0.311044761651467,-0.07865772358956487,-0.16552037392001032,-0.7479401004992935,-0.07548808676406316,-0.3530562866377955,0.740934945795748,-0.9623236909866513,-0.009891208299413536,0.09013439134576456,-1.2030884745948673,-1.0116053732731773,0.1221734796059998,0.6766777421242453,-1.3369273693631827,-0.9942979476103871,-0.38478248267500476,-0.12479118237944894,-0.6843570483350881,1.1613455879902503,-3.226391399328434,0.13311972848486592,1.6779446005887027,-0.9151394915165507,0.9580677983066864,-0.28759133701011963,-0.07283266964682324,0.9770833309980452,-0.3273328195977589,-0.150497176683709,0.06252626354936308,0.4505452610858531,-0.3979601098989083,-1.3711093021205518,-0.34848569639949567,-1.5869401147718611,0.04087387127498206,-0.6320676099489627,0.07939664098538367,-0.33520633052226756,-0.12286160086566142,1.436200011984811,-2.3155271954025793,-2.064393696355506,-1.1046980114479608,-0.3914250527528525,-1.658211559770904,0.80695533243722,1.1425171893334451,-2.089604546799655,-1.4540339619305422,0.7674716848232624,0.30554884104602603,1.15627629650161,-0.9082304921660717,0.4418886026633614,-1.4736651462917418,0.028836718492492346,-0.2578853428103588,0.3164463774444058,-1.8080048414610506,-0.322327132147817,-1.8119343052408539,-0.0246437343245578,-0.47721483714376656,0.0748678031466245,0.05857390660229916,1.1640199493513215,-0.7428098567239931,-0.29583558762378115,0.6054915636470126,0.2520366243212744,-0.7531878437725956,-0.6079291789438569,-1.1498468614180017,1.6700510273945277,-1.4292015397417164,1.023885136880972,-0.13064679010538477,0.11382403200619122,0.8698971687806945,-0.9990899236757556,0.42989490388809454,-0.350239147427939,0.6894550976997619,1.2458064664445478,-0.20021946626797124,0.005206621780504494,-0.15569900872345782,2.212206732684981,0.8915343625470076,0.8437051852436136,1.4321759463350736,0.18200214245686236,0.0656467921949524,1.848288436292507,1.437595752470186,0.2926997397599094,-0.05827827873815938,0.732428168977181,-0.36429959399782236,-1.1329237038682505,1.4075785010447028,-0.3969011850021705,0.3232474479324874,-1.463368020564679,-0.9749828384067486,0.050085917196540236,0.5054345581972364,-1.4259231930479892,-2.2531660194350605,-0.7401370217382971,0.34873302855894167,0.44351008707650325,0.7860714518039567,-0.46771307887910046,-0.14592110373996814,0.8556560394021862,0.7922922865576331,-0.3427033009973036,0.3818802617930721,0.3342614519682711,-0.21829920364055458,-1.1363779199714303,0.055601177633283594,0.6459184379894302,0.3068172030003371,-0.9263647909609874,-0.5548805272064571,-1.2808313498973276,-1.096416452263948,-0.812431910092375,-0.37750826298504797,0.7881922891120343,1.7083055901057296,0.36181352701928143,1.1516939368014563,0.1755287030057399,-1.9966603941963534,1.4186754709890455,-0.654535905442091,-0.5502175199354304,-0.935094517783841,0.14144854997050788,0.31086723074036615,-0.17438156225946216,0.765423655881984,-1.2004193003213735,-1.0207982719277109,-1.34926961569919,0.656990302091712,0.7084263023410915,-2.4722022575189078,-0.2281623321897263,0.894654160173 ...
