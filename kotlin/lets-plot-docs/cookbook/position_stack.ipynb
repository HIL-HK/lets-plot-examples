// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="QRtrFB"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("QRtrFB").appendChild(div);
//            };
//            var e = document.getElementById("QRtrFB");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.11.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.7.0.

// %%
val data = mapOf(
    "x" to listOf(1, 1, 2, 2, 2),
    "y" to listOf(1, 3, 2, 1, -3),
    "grp" to listOf("a", "b", "a", "b", "c")
)

val p = letsPlot(data) { x = "x"; y = "y"; group = "grp" } + 
    geomBar(stat = Stat.identity, color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)

// %%
val w = 600
val h = 400

gggrid(listOf(
    p + geomLabel(position = positionStack()) { label = "y" } + ggtitle("Default"),
    p + geomLabel(position = positionStack(0.0)) { label = "y" } + ggtitle("vjust = 0.0"),
    p + geomLabel(position = positionStack(0.3)) { label = "y" } + ggtitle("vjust = 0.3"),
    p + geomLabel(position = positionStack(0.5)) { label = "y" } + ggtitle("vjust = 0.5"),
    p + geomLabel(position = positionStack(0.7)) { label = "y" } + ggtitle("vjust = 0.7"),
    p + geomLabel(position = positionStack(1.0)) { label = "y" } + ggtitle("vjust = 1.0")
), ncol = 2) + ggsize(2 * w, 3 * h)
// Out:
//    <div id="IRR9jt"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("IRR9jt").appendChild(div);
//            };
//            var e = document.getElementById("IRR9jt");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="YLbAXN"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("YLbAXN");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":3,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"Default"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":"stack",
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"1"
// },{
// "ggtitle":{
// "text":"vjust = 0.0"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"2"
// },{
// "ggtitle":{
// "text":"vjust = 0.3"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.3
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"vjust = 0.5"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.5
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"4"
// },{
// "ggtitle":{
// "text":"vjust = 0.7"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.7
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"vjust = 1.0"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":1.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"6"
// }],
// "ggsize":{
// "width":1200.0,
// "height":1200.0
// },
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=756b702d-7e15-496d-8e33-f9000908616c width="100%" height="100%" style="max-width: 1200.0px; max-height: 1200.0px;" viewBox="0 0 1200.0 1200.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pA3lsjp .plot-title {
// fill: #474747;
// font-w

// %%
// position = "fill"

letsPlot(data) { x = "x"; y = "y"; group = "grp" } + 
    geomBar(stat = Stat.identity, position = positionFill(), color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    geomText(position = positionFill(0.5)) { label = "y" } +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)
// Out:
//    <div id="uXpBlo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("uXpBlo");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"fill",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"fill",
// "vjust":0.5
// },
// "geom":"text",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"13"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=64e595af-ee42-47f3-8dcb-881335c66c83 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pK0M9t2 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pK0M9t2 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pK0M9t2 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pK0M9t2 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pK0M9t2 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pK0M9t2 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pK0M9t2 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pK0M9t2 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d0hd0iO .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pK0M9t2 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pK0M9t2 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d0hd0iO .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pK0M9t2 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pK0M9t2 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d0hd0iO .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d0hd0iO .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d0hd0iO .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pK0M9t2">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="10.701253747056057" y1="0.0" x2="10.701253747056057" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="129.60407315879004" y1="0.0" x2="129.60407315879004" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="248.50689257052406" y1="0.0" x2="248.50689257052406" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="367.40971198225805" y1="0.0" x2="367.40971198225805" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="486.312531393992" y1="0.0" x2="486.312531393992" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="341.72727272727275" x2="497.0137851410481" y2="341.72727272727275" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="260.3636363636364" x2="497.0137851410481" y2="260.3636363636364" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="179.0" x2="497.0137851410481" y2="179.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="97.63636363636364" x2="497.0137851410481" y2="97.63636363636364" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="16.27272727272728" x2="497.0137851410481" y2="16.27272727272728" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c8rpg02)" clip-bounds-jfx="[rect (31.015306675749617, 0.0), (497.0137851410481, 358.0)]">
//         <g transform="translate(31.015306675749617
