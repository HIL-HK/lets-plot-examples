// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="DNG7Bl"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.9.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("DNG7Bl").appendChild(div);
//            };
//            var e = document.getElementById("DNG7Bl");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.9.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.13.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.9.0.
// Outputs: Web (HTML+JS), Kotlin Notebook (Swing), Static SVG (hidden)

// %%
val data = mapOf(
    "x" to listOf(1, 1, 2, 2, 2),
    "y" to listOf(1, 3, 2, 1, -3),
    "grp" to listOf("a", "b", "a", "b", "c")
)

val p = letsPlot(data) { x = "x"; y = "y" } + 
    geomBar(stat = Stat.identity, color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)

// %%
val w = 600
val h = 400

gggrid(listOf(
    p + geomLabel(position = positionStack()) { label = "y"; group = "grp" } + ggtitle("Default"),
    p + geomLabel(position = positionStack(0.0)) { label = "y"; group = "grp" } + ggtitle("vjust = 0.0"),
    p + geomLabel(position = positionStack(0.3)) { label = "y"; group = "grp" } + ggtitle("vjust = 0.3"),
    p + geomLabel(position = positionStack(0.5)) { label = "y"; group = "grp" } + ggtitle("vjust = 0.5"),
    p + geomLabel(position = positionStack(0.7)) { label = "y"; group = "grp" } + ggtitle("vjust = 0.7"),
    p + geomLabel(position = positionStack(1.0)) { label = "y"; group = "grp" } + ggtitle("vjust = 1.0")
), ncol = 2) + ggsize(2 * w, 3 * h)
// Out:
//    <div id="FzKjHG"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.9.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("FzKjHG").appendChild(div);
//            };
//            var e = document.getElementById("FzKjHG");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="InmeQo" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("InmeQo");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":3,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"Default"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":"stack",
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"1"
// },{
// "ggtitle":{
// "text":"vjust = 0.0"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"2"
// },{
// "ggtitle":{
// "text":"vjust = 0.3"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.3
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"vjust = 0.5"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.5
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"4"
// },{
// "ggtitle":{
// "text":"vjust = 0.7"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.7
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"vjust = 1.0"
// },
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":1.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"6"
// }],
// "ggsize":{
// "width":1200.0,
// "height":1200.0
// },
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=702df78a-2b58-4ad7-9d9b-ff583bc4d426 width="100%" height="100%" style="max-width: 1200.0px; max-height: 1200.0px;" viewBox="0 0 1200.0 1200.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pr3VQOi .plot-title {
// fill: #474747;
// font-

// %%
// position = "fill"

letsPlot(data) { x = "x"; y = "y" } + 
    geomBar(stat = Stat.identity, position = positionFill(), color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    geomText(position = positionFill(0.5)) { label = "y"; group = "grp" } +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)
// Out:
//    <div id="UxzmTv" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("UxzmTv");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"fill",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// "label":"y",
// "group":"grp"
// },
// "stat":"identity",
// "position":{
// "name":"fill",
// "vjust":0.5
// },
// "geom":"text",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"13"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=97395ef1-cac0-4873-9038-ceb461648b0b width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pGEdlHz .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pGEdlHz .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pGEdlHz .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pGEdlHz .plot-tag {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pGEdlHz .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pGEdlHz .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pGEdlHz .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pGEdlHz .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pGEdlHz .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dImeVqH .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pGEdlHz .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pGEdlHz .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dImeVqH .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pGEdlHz .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pGEdlHz .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dImeVqH .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dImeVqH .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dImeVqH .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pGEdlHz">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="10.701253747056057" y1="0.0" x2="10.701253747056057" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="129.60407315879004" y1="0.0" x2="129.60407315879004" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="248.50689257052406" y1="0.0" x2="248.50689257052406" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="367.40971198225805" y1="0.0" x2="367.40971198225805" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="486.312531393992" y1="0.0" x2="486.312531393992" y2="358.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="341.72727272727275" x2="497.0137851410481" y2="341.72727272727275" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="260.3636363636364" x2="497.0137851410481" y2="260.3636363636364" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="179.0" x2="497.0137851410481" y2="179.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="97.63636363636364" x2="497.0137851410481" y2="97.63636363636364" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="16.27272727272728" x2="497.0137851410481" y2="16.27272727272728" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cDHmdGb)" clip-bounds-jfx="[rect (31.015306675749
