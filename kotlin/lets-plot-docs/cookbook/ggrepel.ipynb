// %% [markdown]
// # Dynamic Text Positioning with Repel Geometries
//
// - `geomTextRepel()`
// - `geomLabelRepel()`
//
// These functions use a force-based layout algorithm to automatically reposition text labels and resolve overlaps.
//
// Labels repel each other and their associated data points while staying within the plot boundaries.

// %%
%useLatestDescriptors
%use dataframe
%use lets-plot
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>
//    <div id="SGfYbN"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("SGfYbN").appendChild(div);
//            };
//            var e = document.getElementById("SGfYbN");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.11.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.7.0.

// %%
import kotlin.random.Random
import org.jetbrains.letsPlot.interact.ggtb

// %%
val df = DataFrame.readCsv(
    fileOrUrl = "https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv",
    delimiter = ',',
    header = listOf(),
    colTypes = mapOf(),
    skipLines = 0,
    readLines = null,
    allowMissingColumns = true,
    parserOptions = null
)
println(df.size())
println(df.head())
// Out:
// 32 x 12
//                model  mpg cyl  disp  hp drat    wt  qsec vs am gear carb
//  0         Mazda RX4 21.0   6 160.0 110 3.90 2.620 16.46  0  1    4    4
//  1     Mazda RX4 Wag 21.0   6 160.0 110 3.90 2.875 17.02  0  1    4    4
//  2        Datsun 710 22.8   4 108.0  93 3.85 2.320 18.61  1  1    4    1
//  3    Hornet 4 Drive 21.4   6 258.0 110 3.08 3.215 19.44  1  0    3    1
//  4 Hornet Sportabout 18.7   8 360.0 175 3.15 3.440 17.02  0  0    3    2

// %%
val df1 = df.filter { (2.0 < it["wt"] as Double) && ((it["wt"] as Double) < 3.65) }
val df2 = df
    .filter { (2.0 < it["wt"] as Double) && ((it["wt"] as Double) < 3) }
    .add("shape") { if (it["am"] == 0.0) 16 else 21 }

// %%
val plot1 = ggplot(df1.toMap()) { x = "wt"; y = "mpg"; label = "model" } + geomPoint(color = "red")
val plot2 = ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" } + geomPoint(color = "red")

// %% [markdown]
// ### Comparison of geomText() and geomTextRepel()

// %%
gggrid(
    listOf(
        plot2 + geomText() + ggtitle("geomText()"),
        plot2 + geomTextRepel() + ggtitle("geomTextRepel()")
    )
).show()
// Out:
//    <div id="edo6RF"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("edo6RF");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"geomText()"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"1"
// },{
// "ggtitle":{
// "text":"geomTextRepel()"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"2"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### geomLabelRepel()
// All of the parameters discussed below apply equally to both `geomTextRepel()` and `geomLabelRepel()`. For simplicity, we will use `geomTextRepel()` in the examples.

// %%
gggrid(
    listOf(
        plot2 + geomLabel() + ggtitle("geomText()"),
        plot2 + geomLabelRepel() + ggtitle("geomTextRepel()")
    )
).show()
// Out:
//    <div id="UZ1tPT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("UZ1tPT");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"geomText()"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"label",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"geomTextRepel()"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"label_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"4"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `seed` parameter
//
// Controls the randomization to produce the same label layout each time the plot is generated.

// %%
gggrid(
    listOf(
        plot2 + geomTextRepel() + ggtitle("Without seed"),
        plot2 + geomTextRepel() + ggtitle("Without seed"),
        plot2 + geomTextRepel(seed = 4) + ggtitle("With seed"),
        plot2 + geomTextRepel(seed = 4) + ggtitle("With seed"),
    ), ncol = 2
).show()
// Out:
//    <div id="DCn3Nd"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("DCn3Nd");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":2,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"Without seed"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"Without seed"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"6"
// },{
// "ggtitle":{
// "text":"With seed"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":4.0,
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"7"
// },{
// "ggtitle":{
// "text":"With seed"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":4.0,
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"8"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// In some cases, it may be necessary to find a seed value that produces a more optimal label arrangement. A simple approach is to re-render the plot multiple times until you're satisfied with the result, then use the corresponding seed to reproduce it.

// %%
val randomSeed = Random.nextInt()
print("seed = $randomSeed")
(plot2 + geomTextRepel(seed = randomSeed) + ggtitle("Seed = $randomSeed")).show()
// Out:
//    <div id="CV6HUz"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("CV6HUz");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "ggtitle":{
// "text":"Seed = -1821402599"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":-1.821402599E9,
// "position":"identity",
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"9"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>
// seed = -1821402599

// %% [markdown]
// ### `maxIter` parameter
//
// Controls the maximum number of iterations used by the layout algorithm, helping to reduce notebook rendering time. More iterations generally lead to better label placement, but at the cost of increased computation time. For plots with a small number of labels, 200–300 iterations are often sufficient.
// The default value is 2000.

// %%
val seed = 530
gggrid(
    listOf(
        plot2 + geomTextRepel(seed = seed, maxIter = 2) + ggtitle("max_iter=2"),
        plot2 + geomTextRepel(seed = seed, maxIter = 20) + ggtitle("max_iter=20"),
        plot2 + geomTextRepel(seed = seed, maxIter = 200) + ggtitle("max_iter=200"),
    )
).show()
// Out:
//    <div id="MAxPO3"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("MAxPO3");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":3,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"max_iter=2"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "max_iter":2.0,
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"10"
// },{
// "ggtitle":{
// "text":"max_iter=20"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "max_iter":20.0,
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"11"
// },{
// "ggtitle":{
// "text":"max_iter=200"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "max_iter":200.0,
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"12"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `maxTime` parameter
//
// Another way to limit plot rendering time is by using the `maxTime` parameter. This primarily serves as a safeguard against excessive computation when a large number of text labels are involved. Time is specified in seconds. The default value is `5` seconds, but you can disable the time limit by setting it to `-1` if needed.

// %%
gggrid(
    listOf(
        plot2 + geomTextRepel(seed = seed, maxTime = 0.001) + ggtitle("max_time=0.001"),
        plot2 + geomTextRepel(seed = seed, maxTime = 0.01) + ggtitle("max_time=0.01"),
        plot2 + geomTextRepel(seed = seed, maxTime = -1.0) + ggtitle("max_time=-1"),
    )
).show()
// Out:
//    <div id="WxmLtB"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("WxmLtB");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":3,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"max_time=0.001"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":0.001,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"13"
// },{
// "ggtitle":{
// "text":"max_time=0.01"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":0.01,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"14"
// },{
// "ggtitle":{
// "text":"max_time=-1"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"15"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `direction` parameter
//
// Restricts the movement of a text label relative to its anchor point to a specific direction. The default value is `both`.

// %%
gggrid(
    listOf(
        plot2 + geomTextRepel(seed = seed, direction = "x") + ggtitle("direction = 'x'"),
        plot2 + geomTextRepel(seed = seed, direction = "y") + ggtitle("direction = 'y'"),
        plot2 + geomTextRepel(seed = seed, direction = "both") + ggtitle("direction = 'both'"),
    )
).show()
// Out:
//    <div id="gdakvn"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("gdakvn");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":3,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"direction = 'x'"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "direction":"x",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"16"
// },{
// "ggtitle":{
// "text":"direction = 'y'"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "direction":"y",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"17"
// },{
// "ggtitle":{
// "text":"direction = 'both'"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "geom":"text_repel",
// "direction":"both",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"18"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// As we can see, this option is of limited use for randomly scattered points, but in certain cases it can be extremely helpful:

// %%
val plotX = ggplot(df2.toMap()) { x = "wt"; label = "model" } +
        geomPoint(y = 1, color = "red") + xlim(2 to 3) + ylim(1 to 1.3) +
        geomTextRepel(y = 1, nudgeY = 0.05, direction = "x", angle = 90, hjust = 0.0, seed = seed)

val plotY = ggplot(df2.toMap()) { y = "mpg"; label = "model" } +
        geomPoint(x = 1, color = "red") + xlim(0.9 to 1.3) + ylim(19 to 35) +
        geomTextRepel(x = 1, nudgeX = 0.05, direction = "y", hjust = 0.0, seed = seed)

gggrid(
    listOf(
        plotX + ggtitle("direction = x"),
        plotY + ggtitle("direction = y"),
    )
).show()
// Out:
//    <div id="GuFXDh"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("GuFXDh");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"direction = x"
// },
// "mapping":{
// "x":"wt",
// "label":"model"
// },
// "data":{
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[2.0,3.0]
// },{
// "aesthetic":"y",
// "limits":[1.0,1.3]
// }],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "y":1.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "nudge_y":0.05,
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "y":1.0,
// "angle":90.0,
// "position":"identity",
// "geom":"text_repel",
// "hjust":0.0,
// "direction":"x",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"19"
// },{
// "ggtitle":{
// "text":"direction = y"
// },
// "mapping":{
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[0.9,1.3]
// },{
// "aesthetic":"y",
// "limits":[19.0,35.0]
// }],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "x":1.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "nudge_x":0.05,
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "x":1.0,
// "position":"identity",
// "geom":"text_repel",
// "hjust":0.0,
// "direction":"y",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"20"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `pointPadding` and `boxPadding` parameters
//
// These parameters control the amount of spacing around text labels.
//
// - `pointPadding` adds space between the label and all nearby points, but does not affect spacing between labels.
//
// - `boxPadding` adds space between labels, but does not affect spacing between the label and the data point.

// %%
gggrid(
    listOf(
        plot2 + geomTextRepel(seed = seed, maxTime = -1.0, pointPadding = 10) + ggtitle("pointPadding"),
        plot2 + geomTextRepel(seed = seed, maxTime = -1.0, boxPadding = 10) + ggtitle("boxPadding"),
    )
).show()
// Out:
//    <div id="2TFG8o"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("2TFG8o");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"pointPadding"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_padding":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"21"
// },{
// "ggtitle":{
// "text":"boxPadding"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "box_padding":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"22"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `maxOverlaps` parameter
//
// Specifies the maximum allowed number of overlaps with other labels. Labels that exceed this threshold will be omitted from the plot. The default value is `10`. You can disable overlap filtering entirely by setting this parameter to `-1`.

// %%
gggrid(
    listOf(
        plot1 + geomTextRepel(seed = seed, maxTime = -1.0, maxOverlaps = 5) + ggtitle("maxOverlaps=5"),
        plot1 + geomTextRepel(seed = seed, maxTime = -1.0, maxOverlaps = -1) + ggtitle("maxOverlaps=-1"),
    )
).show()
// Out:
//    <div id="MbiUMR"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("MbiUMR");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"maxOverlaps=5"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "max_overlaps":5.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// }]
// },
// "spec_id":"23"
// },{
// "ggtitle":{
// "text":"maxOverlaps=-1"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "max_overlaps":-1.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// }]
// },
// "spec_id":"24"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `minSegmentLength` parameter
//
// Sets the minimum length for the line connecting a label to its associated point. Lines shorter than this length will not be drawn. To display all lines, use the default value of `0`. To hide all lines, set the value to something very large.
// `minSegmentLength` uses the same units as `pointSize`, so be careful when using `minSegmentLength` together with `sizeUnit` (see below).

// %%
gggrid(
    listOf(
        plot1 + geomTextRepel(seed = seed, maxTime = -1.0, minSegmentLength = 0) + ggtitle("minSegmentLength=0"),
        plot1 + geomTextRepel(
            seed = seed,
            maxTime = -1.0,
            minSegmentLength = 9999
        ) + ggtitle("minSegmentLength=9999"),
    )
).show()
// Out:
//    <div id="Ebkz6y"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("Ebkz6y");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"minSegmentLength=0"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "min_segment_length":0.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// }]
// },
// "spec_id":"25"
// },{
// "ggtitle":{
// "text":"minSegmentLength=9999"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
// "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "min_segment_length":9999.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// }]
// },
// "spec_id":"26"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ## Point settings
//
// `geomTextRepel()` does not draw points itself, but for it to work correctly, the values of parameters and aesthetics that control point size must match those used in the associated `geomPoint()` layer.

// %%
(ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + geomPoint(sizeUnit = "y") { size = "gear"; stroke = "vs"; shape = "shape" }
        + geomTextRepel(sizeUnit = "y") { pointSize = "gear"; pointStroke = "vs"; shape = "shape" }
        + theme().legendPositionNone()
        + scaleSize(range = 0.5 to 1, guide = "none")
        + scaleStroke(range = 1 to 4, guide = "none")
        + scaleShapeIdentity()
        )
    .show()
// Out:
//    <div id="4TTjyO"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("4TTjyO");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "shape":[21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0],
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
// "vs":[0.0,0.0,1.0,1.0,1.0,0.0,0.0,1.0],
// "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"size",
// "range":[0.5,1.0],
// "guide":"none"
// },{
// "aesthetic":"stroke",
// "range":[1.0,4.0],
// "guide":"none"
// },{
// "aesthetic":"shape",
// "discrete":true,
// "scale_mapper_kind":"identity",
// "guide":"none"
// }],
// "layers":[{
// "mapping":{
// "shape":"shape",
// "size":"gear",
// "stroke":"vs"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "size_unit":"y",
// "data":{
// }
// },{
// "mapping":{
// "shape":"shape",
// "point_size":"gear",
// "point_stroke":"vs"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text_repel",
// "size_unit":"y",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"27"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `pointSize` aesthetic
//
// Allows you to pass to `geomTextRepel()` the data used to determine point sizes in a `geomPoint()` layer. This helps accurately detect overlaps between labels and points when point sizes vary.

// %%
val plot31 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + geomPoint(color = "red") { size = "gear" }
        + theme().legendPositionNone())

gggrid(
    listOf(
        plot31 + geomTextRepel(seed = seed, maxTime = -1.0) + ggtitle("without pointSize"),
        plot31 + geomTextRepel(seed = seed, maxTime = -1.0) { pointSize = "gear" } + ggtitle("with pointSize"),
    )).show()
// Out:
//    <div id="uwRtKM"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("uwRtKM");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without pointSize"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
// "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "size":"gear"
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"28"
// },{
// "ggtitle":{
// "text":"with pointSize"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
// "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "size":"gear"
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// "point_size":"gear"
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"29"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// You can also provide a constant value instead.

// %%
val plot32 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + geomPoint(size = 10, color = "red")
        + theme().legendPositionNone())

gggrid(
    listOf(
        plot32 + geomTextRepel(seed = seed, maxTime = -1.0) + ggtitle("without pointSize"),
        plot32 + geomTextRepel(seed = seed, maxTime = -1.0, pointSize = 10) + ggtitle("with pointSize"),
    )
).show()
// Out:
//    <div id="okgLTu"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("okgLTu");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without pointSize"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":10.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"30"
// },{
// "ggtitle":{
// "text":"with pointSize"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":10.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_size":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"31"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// Set `pointSize = 0` to prevent label repulsion away from data points.
//
// Labels will still move away from each other and away from the edges of the plot.

// %%
val plot33 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
    + geomPoint(color = "red"))

gggrid(
    listOf(
        plot33 + geomTextRepel(seed = seed, maxTime = -1.0) + ggtitle("without pointSize"),
        plot33 + geomTextRepel(seed = seed, maxTime = -1.0, pointSize = 0) + ggtitle("with pointSize = 0"),
    )
)
// Out:
//    <div id="w28WDd"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("w28WDd").appendChild(div);
//            };
//            var e = document.getElementById("w28WDd");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="x5KlRQ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("x5KlRQ");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without pointSize"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"32"
// },{
// "ggtitle":{
// "text":"with pointSize = 0"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_size":0.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"33"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=7f607af4-a405-4133-a4eb-780dd232e1fb width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pRJIhzP .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pRJIhzP .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pRJIhzP .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pRJIhzP .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pRJIhzP .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pRJIhzP .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pRJIhzP .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pRJIhzP .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pRJIhzP .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pRJIhzP .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pRJIhzP .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pRJIhzP .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pRJIhzP">
//     <rect x="0.0" y="0.0" height="400.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="442.0" height="388.0" x="6.0" y="6.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjXCgpm .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pjXCgpm .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pjXCgpm .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pjXCgpm .hyperlink-element {
// fill: #118ed8;
// fo

// %% [markdown]
// ### `pointStroke` and `shape` aesthetics
//
// Allow you to pass to `geomTextRepel()` the data used to determine point stroke width and shape in a `geomPoint()` layer. This ensures accurate collision detection between labels and points.

// %%
val plot34 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label="model" }
    + geomPoint(shape=21, size=10, color="red") { stroke="gear" }
    + theme().legendPositionNone())

gggrid(listOf(
    plot34 + geomTextRepel(seed=seed, maxTime=-1.0, pointSize=10) + ggtitle("without pointStroke"),
    plot34 + geomTextRepel(shape=21, pointSize=10, seed=seed, maxTime=-1.0) { pointStroke="gear" } + ggtitle("with pointStroke"),
)).show()
// Out:
//    <div id="R0GmUe"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("R0GmUe");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without pointStroke"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
// "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "stroke":"gear"
// },
// "stat":"identity",
// "color":"red",
// "shape":21.0,
// "size":10.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_size":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"36"
// },{
// "ggtitle":{
// "text":"with pointStroke"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
// "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "stroke":"gear"
// },
// "stat":"identity",
// "color":"red",
// "shape":21.0,
// "size":10.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// "point_stroke":"gear"
// },
// "stat":"identity",
// "shape":21.0,
// "seed":530.0,
// "point_size":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"37"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `sizeUnit` parameter
//
// The `sizeUnit` parameter can be used in `geomPoint()` to define the unit of measurement for the `size` aesthetic. In this case, it is recommended to also use `sizeUnit` in `geomTextRepel()` to ensure that point sizes are calculated correctly.

// %%
val plot4 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + geomPoint(size = 1, sizeUnit = "y", color = "red")
        + theme().legendPositionNone())

(gggrid(
    listOf(
        plot4 + geomTextRepel(seed = seed, maxTime = -1.0, pointSize = 1) + ggtitle("without sizeUnit"),
        plot4 + geomTextRepel(
            seed = seed,
            maxTime = -1.0,
            pointSize = 1,
            sizeUnit = "y"
        ) + ggtitle("with sizeUnit"),
    )
) + ggtb()).show()
// Out:
//    <div id="v3w30L"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("v3w30L");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without sizeUnit"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":1.0,
// "position":"identity",
// "geom":"point",
// "size_unit":"y",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_size":1.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"38"
// },{
// "ggtitle":{
// "text":"with sizeUnit"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":1.0,
// "position":"identity",
// "geom":"point",
// "size_unit":"y",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "point_size":1.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "size_unit":"y",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"39"
// }],
// "kind":"subplots",
// "ggtoolbar":{
// }
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ##### `sizeUnit` applies to all size-related parameters: `pointSize`, `minSegmentLength`, `pointPadding`, and `boxPadding`
//
// As an example, consider how it affects `minSegmentLength`.
// As mentioned earlier, `minSegmentLength` uses the same units as `pointSize`. Therefore, in the following example, with the same `minSegmentLength` value, some lines are not drawn in the second case because their length is less than one unit along the y-axis.

// %%
val plot5 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + theme().legendPositionNone())

(gggrid(
    listOf(
        (plot5 + geomPoint(size = 10, color = "red")
                + geomTextRepel(seed = seed, maxTime = -1.0, pointSize = 10, minSegmentLength = 1)
                + ggtitle("without sizeUnit")),
        (plot5 + geomPoint(size = 1, sizeUnit = "y", color = "red")
                + geomTextRepel(seed = seed, maxTime = -1.0, pointSize = 1, minSegmentLength = 1, sizeUnit = "y")
                + ggtitle("with sizeUnit")),
    )
) + ggtb()).show()
// Out:
//    <div id="02Qv7G"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("02Qv7G");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"without sizeUnit"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":10.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "min_segment_length":1.0,
// "point_size":10.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"40"
// },{
// "ggtitle":{
// "text":"with sizeUnit"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "size":1.0,
// "position":"identity",
// "geom":"point",
// "size_unit":"y",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "min_segment_length":1.0,
// "point_size":1.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "size_unit":"y",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"41"
// }],
// "kind":"subplots",
// "ggtoolbar":{
// }
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `segmentColor` aesthetic
//
// Allows you to specify the color of the line connecting the label to the point. By default, the line color matches the text color and follows the `color` aesthetic. In the example below, the `color` aesthetic is defined globally for all layers, so the colors of the points, text, and lines are the same.

// %%
(ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model"; color = "wt" }
        + geomPoint()
        + geomTextRepel(seed = seed, maxTime = -1.0)
        )
    .show()
// Out:
//    <div id="Hmjuv4"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("Hmjuv4");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "color":"wt",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"42"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// By using the `color` and `segmentColor` aesthetics together, you can assign different colors to the points, labels, and connecting lines.

// %%
val plot6 = (ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + theme().legendPositionNone())

gggrid(
    listOf(
        plot6 + geomPoint() { color = "wt" }
                + geomTextRepel(seed = seed, maxTime = -1.0) { segmentColor = "wt" }
                + ggtitle("Same color for points and lines"),
        plot6 + geomPoint(color = "red")
                + geomTextRepel(seed = seed, maxTime = -1.0) { color = "wt" }
                + ggtitle("Same color for text and line"),
        plot6 + geomPoint(color = "red")
                + geomTextRepel(color = "green", segmentColor = "blue", seed = seed, maxTime = -1.0)
                + ggtitle("Different colors"),
    )).show()
// Out:
//    <div id="RvY7kw"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("RvY7kw");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":3,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"Same color for points and lines"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "color":"wt"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// "segment_color":"wt"
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"43"
// },{
// "ggtitle":{
// "text":"Same color for text and line"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// "color":"wt"
// },
// "stat":"identity",
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"44"
// },{
// "ggtitle":{
// "text":"Different colors"
// },
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"green",
// "seed":530.0,
// "segment_color":"blue",
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "theme":{
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"45"
// }],
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `segmentAlpha` aesthetic
//
// Specifies the transparency level of the connecting lines between labels and points. By default, the segment transparency inherits from the text and is governed by the `alpha` aesthetic.

// %%
(ggplot(df2.toMap()) { x = "wt"; y = "mpg"; label = "model" }
        + geomPoint(color = "red")
        + geomTextRepel(pointPadding = 20, color = "red", segmentAlpha = 0.1, seed = seed, maxTime = -1.0)
        ).show()
// Out:
//    <div id="XcamTp"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("XcamTp");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "seed":530.0,
// "point_padding":20.0,
// "segment_alpha":0.1,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"46"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `segmentSize` aesthetic
//
// Specifies the width of the line connecting the label to the point.

// %%
(plot2 + geomTextRepel(segmentSize=2, seed=seed, maxTime=-1.0)).show()
// Out:
//    <div id="GXhIy0"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("GXhIy0");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"wt",
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "segment_size":2.0,
// "seed":530.0,
// "position":"identity",
// "max_time":-1.0,
// "geom":"text_repel",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"47"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `linetype` aesthetic

// %%
(ggplot(df2.toMap()) { y="mpg"; label="model" } + geomPoint(x=1, color="red") + xlim(0.9 to 1.3) + ylim(19 to 35)
    + geomTextRepel(x=1, nudgeX=0.2, direction="y", hjust=0.0, seed=seed) { linetype="disp" })
    .show()
// Out:
//    <div id="WirhMg"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("WirhMg");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
// "disp":[160.0,160.0,108.0,78.7,120.1,120.3,145.0,121.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[0.9,1.3]
// },{
// "aesthetic":"y",
// "limits":[19.0,35.0]
// }],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "x":1.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "nudge_x":0.2,
// "mapping":{
// "linetype":"disp"
// },
// "stat":"identity",
// "seed":530.0,
// "x":1.0,
// "position":"identity",
// "geom":"text_repel",
// "hjust":0.0,
// "direction":"y",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"48"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>

// %% [markdown]
// ### `arrow` parameter

// %%
(ggplot(df2.toMap()) { y="mpg"; label="model" }
        + geomPoint(x=1, color="red")
        + geomTextRepel(
            x = 1,
            nudgeX = 0.2,
            direction = "y",
            hjust = 0.0,
            arrow = arrow(type = "closed", angle = 10, ends = "both"),
            seed = seed
        )
        + xlim(0.9 to 1.3)
        + ylim(19 to 35)
    ).show()
// Out:
//    <div id="77QI3h"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("77QI3h");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "y":"mpg",
// "label":"model"
// },
// "data":{
// "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
// "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[0.9,1.3]
// },{
// "aesthetic":"y",
// "limits":[19.0,35.0]
// }],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "color":"red",
// "x":1.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// },{
// "nudge_x":0.2,
// "mapping":{
// },
// "stat":"identity",
// "seed":530.0,
// "arrow":{
// "name":"arrow",
// "angle":10.0,
// "ends":"both",
// "type":"closed"
// },
// "x":1.0,
// "position":"identity",
// "geom":"text_repel",
// "hjust":0.0,
// "direction":"y",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"model"
// },{
// "type":"float",
// "column":"mpg"
// },{
// "type":"int",
// "column":"cyl"
// },{
// "type":"float",
// "column":"disp"
// },{
// "type":"int",
// "column":"hp"
// },{
// "type":"float",
// "column":"drat"
// },{
// "type":"float",
// "column":"wt"
// },{
// "type":"float",
// "column":"qsec"
// },{
// "type":"int",
// "column":"vs"
// },{
// "type":"int",
// "column":"am"
// },{
// "type":"int",
// "column":"gear"
// },{
// "type":"int",
// "column":"carb"
// },{
// "type":"int",
// "column":"shape"
// }]
// },
// "spec_id":"49"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>
