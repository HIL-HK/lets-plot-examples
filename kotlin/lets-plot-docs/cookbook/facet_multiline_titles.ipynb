// %% [markdown]
// # Multi-line Labels in Facets
//
//
// The 'newline' character (`\n`) now works as a 'line break' in the facet titles.</br>
// Automatic line breaking is performed according to the  text length limit specified with parameters `labWidth` in `facetWrap()` and `xLabWidth`/`yLabWidth` in `facetGrid()`.
//
// The margins around the facet titles are controlled by the `margin` parameter in `elementText()`.</br>
// Horizontal and vertical justifications - using `hjust` and `vjust` parameter in `elementText()`.

// %%
%useLatestDescriptors
%use dataframe
%use lets-plot
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>
//    <div id="dyq4Kk"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("dyq4Kk").appendChild(div);
//            };
//            var e = document.getElementById("dyq4Kk");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.9.3. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.5.2.

// %%
val df = dataFrameOf("animal_type", "animal", "weight", "diet")(
    "pet", "cat", 5, "carnivore",
    "pet", "dog", 10, "carnivore",
    "pet", "rabbit", 2, "herbivore",
    "pet", "hamster", 1, "herbivore",

    "farm animal", "cow", 500, "herbivore",
    "farm animal", "pig", 100, "carnivore",
    "farm animal", "horse", 700, "herbivore",
)

// %% [markdown]
// ### Facet Labels

// %%
val p = letsPlot(df.toMap()) { x = "animal"; y = "weight" } +
    geomBar(stat = Stat.identity) +
    themeBW() +
    theme(panelGridMinor = elementBlank())

// %% [markdown]
// #### Default

// %%
p + facetWrap(facets = "animal_type", ncol = 2, scales = "free")
// Out:
//    <div id="16P9Mm"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("16P9Mm").appendChild(div);
//            };
//            var e = document.getElementById("16P9Mm");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="K9NUEg"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("K9NUEg");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":2.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":"animal_type",
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"1"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=fa2eff4b-34a5-4d36-80d8-ef8fde83dd55 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pCVtmb7 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pCVtmb7 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pCVtmb7 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pCVtmb7 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pCVtmb7 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pCVtmb7 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pCVtmb7 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pCVtmb7 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d4cAIIz .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pCVtmb7 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pCVtmb7 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d4cAIIz .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pCVtmb7 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pCVtmb7 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d4cAIIz .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d4cAIIz .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d4cAIIz .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pCVtmb7">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5 0.0 L1.5 400.0 L898.5 400.0 L898.5 0.0 Z">
//     </path>
//     <g transform="translate(31.0 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="22.0" height="319.0" width="395.5484863613295" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 22.0 ) ">
//           <g>
//             <line x1="77.91106549541338" y1="0.0" x2="77.91106549541338" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="197.7742431806647" y1="0.0" x2="197.7742431806647" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="317.63742086591606" y1="0.0" x2="317.63742086591606" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 22.0 ) ">
//           <g>
//             <line x1="0.0" y1="275.5986394557823" x2="395.5484863613295" y2="275.5986394557823" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="232.19727891156464" x2="395.5484863613295" y2="232.19727891156464" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="188.79591836734693" x2="395.5484863613295" y2="188.79591836734693" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="145.39455782312925" x2="395.5484863613295" y2="145.39455782312925" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="101.99319727891157" x2="395.5484863613295" y2="101.99319727891157" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="58.59183673469386" x2="395.5484863613295" y2="58.59183673469386" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="15.190476190476204" x2="395.5484863613295" y2="15.190476190476204" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#ctAJprg)" clip-bounds-jfx="[rect (33.94181636640461, 22.0), (395.5484863613295, 319.0)]">
//         <g transform="translate(33.94181636640461 22.0 ) ">
//           <g>
//             <g>
//               <rect x="263.69899090755297" y="15.190476190476204" height="303.8095238095238" width="107.87685991672623" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,1

// %% [markdown]
// #### Wrap Labels using `labWidth`-parameters

// %%
p + facetWrap(facets = "animal_type", ncol = 2, scales = "free", labWidth = 6)
// Out:
//    <div id="Y7TldW"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Y7TldW");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":2.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "labwidth":6.0,
// "facets":"animal_type",
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"3"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6c18810d-75aa-42c0-b554-e8a939aee267 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pB7trZ4 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pB7trZ4 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7trZ4 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7trZ4 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pB7trZ4 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7trZ4 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7trZ4 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7trZ4 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOug6Ne .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7trZ4 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pB7trZ4 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOug6Ne .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7trZ4 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pB7trZ4 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOug6Ne .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOug6Ne .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dOug6Ne .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pB7trZ4">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5 0.0 L1.5 400.0 L898.5 400.0 L898.5 0.0 Z">
//     </path>
//     <g transform="translate(31.0 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="35.0" height="306.0" width="395.5484863613295" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="77.91106549541338" y1="0.0" x2="77.91106549541338" y2="306.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="197.7742431806647" y1="0.0" x2="197.7742431806647" y2="306.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="317.63742086591606" y1="0.0" x2="317.63742086591606" y2="306.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="264.36734693877554" x2="395.5484863613295" y2="264.36734693877554" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="222.73469387755102" x2="395.5484863613295" y2="222.73469387755102" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="181.10204081632654" x2="395.5484863613295" y2="181.10204081632654" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="139.46938775510205" x2="395.5484863613295" y2="139.46938775510205" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="97.83673469387756" x2="395.5484863613295" y2="97.83673469387756" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="56.20408163265307" x2="395.5484863613295" y2="56.20408163265307" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="14.571428571428555" x2="395.5484863613295" y2="14.571428571428555" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#ceooavl)" clip-bounds-jfx="[rect (33.94181636640461, 35.0), (395.5484863613295, 306.0)]">
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <g>
//               <rect x="263.69899090755297" y="14.571428571428555" height="291.42857142857144" width="107.87685991672623" stroke="rgb(255,255,255)" stroke-opacity="1.

// %%
p + facetGrid(x = "animal_type", y = "diet", scales = "free", xLabWidth = 6)
// Out:
//    <div id="VjDKyV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("VjDKyV");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "x_labwidth":6.0,
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"5"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=7444c623-8fd7-4ce9-92a0-b1d5e7620beb width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pI7dNoD .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pI7dNoD .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pI7dNoD .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pI7dNoD .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pI7dNoD .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pI7dNoD .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pI7dNoD .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pI7dNoD .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djaABf7 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pI7dNoD .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pI7dNoD .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djaABf7 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pI7dNoD .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pI7dNoD .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djaABf7 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djaABf7 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djaABf7 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pI7dNoD">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="35.0" height="248.0" width="399.0290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="78.59663929724802" y1="0.0" x2="78.59663929724802" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="199.51454590839882" y1="0.0" x2="199.51454590839882" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="320.4324525195496" y1="0.0" x2="320.4324525195496" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="200.76190476190476" x2="399.0290918167977" y2="200.76190476190476" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="153.52380952380952" x2="399.0290918167977" y2="153.52380952380952" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="106.28571428571428" x2="399.0290918167977" y2="106.28571428571428" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="59.04761904761904" x2="399.0290918167977" y2="59.04761904761904" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="11.809523809523796" x2="399.0290918167977" y2="11.809523809523796" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cjLQgds)" clip-bounds-jfx="[rect (33.94181636640461, 35.0), (399.0290918167977, 248.0)]">
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <g>
//               <rect x="145.10148793338095" y="11.809523809523796" height="236.1904761904762" width="108.82611595003573" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cjLQgds">
//             <rect x="33.94181636640461" y="35.0" width="399.0290918167977" height="248.0">

// %% [markdown]
// #### Line Breaks Using `\n` in Facet Values

// %%
val df2 = df.update { animal_type }.with { it.replace(' ', '\n') }

val p2 = letsPlot(df2.toMap()) { x = "animal"; y = "weight" } +
    geomBar(stat = Stat.identity) +
    themeBW() +
    theme(panelGridMinor = elementBlank())

// %%
p2 + facetGrid(x = "animal_type", y = "diet", scales = "free")
// Out:
//    <div id="dRspLc"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("dRspLc");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"7"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0988e344-7f32-4c8a-ad83-479d5d55814e width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjvgVnC .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pjvgVnC .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjvgVnC .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjvgVnC .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pjvgVnC .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjvgVnC .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjvgVnC .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjvgVnC .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d6Zvr7S .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjvgVnC .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjvgVnC .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d6Zvr7S .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjvgVnC .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjvgVnC .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d6Zvr7S .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d6Zvr7S .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d6Zvr7S .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pjvgVnC">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="35.0" height="248.0" width="399.0290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="78.59663929724802" y1="0.0" x2="78.59663929724802" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="199.51454590839882" y1="0.0" x2="199.51454590839882" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="320.4324525195496" y1="0.0" x2="320.4324525195496" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="200.76190476190476" x2="399.0290918167977" y2="200.76190476190476" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="153.52380952380952" x2="399.0290918167977" y2="153.52380952380952" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="106.28571428571428" x2="399.0290918167977" y2="106.28571428571428" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="59.04761904761904" x2="399.0290918167977" y2="59.04761904761904" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="11.809523809523796" x2="399.0290918167977" y2="11.809523809523796" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cJQ4Ld9)" clip-bounds-jfx="[rect (33.94181636640461, 35.0), (399.0290918167977, 248.0)]">
//         <g transform="translate(33.94181636640461 35.0 ) ">
//           <g>
//             <g>
//               <rect x="145.10148793338095" y="11.809523809523796" height="236.1904761904762" width="108.82611595003573" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cJQ4Ld9">
//             <rect x="33.94181636640461" y="35.0" width="399.0290918167977" height="248.0">
//             </rect>

// %%
p2 + facetWrap(facets = listOf("animal_type", "diet"), ncol = 4, scales = "free")
// Out:
//    <div id="O9BiFW"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("O9BiFW");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":4.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":["animal_type","diet"],
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"9"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=bd50a559-7d28-44c9-9694-b888cf5598ec width="100%" height="100%" style="max-width: 1500.0px; max-height: 400.0px;" viewBox="0 0 1500.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pM4P05e .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pM4P05e .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pM4P05e .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pM4P05e .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pM4P05e .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pM4P05e .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pM4P05e .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pM4P05e .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ds9q4H2 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pM4P05e .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pM4P05e .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ds9q4H2 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pM4P05e .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pM4P05e .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ds9q4H2 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ds9q4H2 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ds9q4H2 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pM4P05e">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5000000000001137 0.0 L1.5000000000001137 400.0 L1498.5 400.0 L1498.5 0.0 Z">
//     </path>
//     <g transform="translate(31.000000000000114 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="54.0" height="287.0" width="326.5301137839932" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <line x1="163.2650568919966" y1="0.0" x2="163.2650568919966" y2="287.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <line x1="0.0" y1="232.33333333333331" x2="326.5301137839932" y2="232.33333333333331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="177.66666666666666" x2="326.5301137839932" y2="177.66666666666666" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="123.0" x2="326.5301137839932" y2="123.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="68.33333333333331" x2="326.5301137839932" y2="68.33333333333331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="13.666666666666686" x2="326.5301137839932" y2="13.666666666666686" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cpeMlCb)" clip-bounds-jfx="[rect (33.94181636640461, 54.0), (326.5301137839932, 287.0)]">
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <g>
//               <rect x="50.23540212061434" y="13.666666666666686" height="273.3333333333333" width="226.0593095427645" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cpeMlCb">
//             <rect x="33.94181636640461" y="54.0" width="326.5301137839932" height="287.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(33.94181636640461 341.0 ) ">
//           <g transform="translate(163.2650568919966 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(51,51,51)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//             </line>
//             <g transform="translate(0.0 7.0

// %% [markdown]
// ### Text Justifications

// %%
p2 + facetWrap(facets = listOf("animal_type", "diet"), ncol = 4, scales = "free") +
    theme(stripText = elementText(hjust = 1, vjust = 1))
// Out:
//    <div id="Dph8qO"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Dph8qO");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// },
// "strip_text":{
// "hjust":1.0,
// "vjust":1.0,
// "blank":false
// }
// },
// "facet":{
// "ncol":4.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":["animal_type","diet"],
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"11"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=69091204-5a83-4600-9a0d-985ab340289c width="100%" height="100%" style="max-width: 1500.0px; max-height: 400.0px;" viewBox="0 0 1500.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pUKqkM2 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pUKqkM2 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pUKqkM2 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pUKqkM2 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pUKqkM2 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pUKqkM2 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pUKqkM2 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pUKqkM2 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dKN7NiP .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pUKqkM2 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pUKqkM2 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dKN7NiP .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pUKqkM2 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pUKqkM2 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dKN7NiP .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dKN7NiP .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dKN7NiP .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pUKqkM2">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5000000000001137 0.0 L1.5000000000001137 400.0 L1498.5 400.0 L1498.5 0.0 Z">
//     </path>
//     <g transform="translate(31.000000000000114 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="54.0" height="287.0" width="326.5301137839932" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <line x1="163.2650568919966" y1="0.0" x2="163.2650568919966" y2="287.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <line x1="0.0" y1="232.33333333333331" x2="326.5301137839932" y2="232.33333333333331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="177.66666666666666" x2="326.5301137839932" y2="177.66666666666666" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="123.0" x2="326.5301137839932" y2="123.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="68.33333333333331" x2="326.5301137839932" y2="68.33333333333331" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="13.666666666666686" x2="326.5301137839932" y2="13.666666666666686" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c8r7HOh)" clip-bounds-jfx="[rect (33.94181636640461, 54.0), (326.5301137839932, 287.0)]">
//         <g transform="translate(33.94181636640461 54.0 ) ">
//           <g>
//             <g>
//               <rect x="50.23540212061434" y="13.666666666666686" height="273.3333333333333" width="226.0593095427645" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="c8r7HOh">
//             <rect x="33.94181636640461" y="54.0" width="326.5301137839932" height="287.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(33.94181636640461 341.0 ) ">
//           <g transform="translate(163.2650568919966 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(51,51,51)" stroke-opacity="1.0" x2="0.0" y2="4.0">

// %% [markdown]
// ### Margins Around the Text Element

// %%
p2 + facetGrid(x = "animal_type", y = "diet", scales = "free") +
    theme(stripText = elementText(margin = listOf(10, 30), hjust = 0, vjust = 1))
// Out:
//    <div id="4DlorX"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("4DlorX");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// },
// "strip_text":{
// "hjust":0.0,
// "vjust":1.0,
// "margin":[10.0,30.0],
// "blank":false
// }
// },
// "facet":{
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"13"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=b81a56ee-0097-482f-9fbb-860adb630852 width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pMOQ0zR .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pMOQ0zR .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMOQ0zR .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMOQ0zR .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pMOQ0zR .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMOQ0zR .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMOQ0zR .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMOQ0zR .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dILOvab .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMOQ0zR .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMOQ0zR .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dILOvab .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMOQ0zR .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMOQ0zR .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dILOvab .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dILOvab .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dILOvab .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pMOQ0zR">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <rect x="33.94181636640461" y="49.0" height="241.0" width="372.0290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(33.94181636640461 49.0 ) ">
//           <g>
//             <line x1="73.2784574790662" y1="0.0" x2="73.2784574790662" y2="241.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="186.01454590839882" y1="0.0" x2="186.01454590839882" y2="241.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="298.75063433773147" y1="0.0" x2="298.75063433773147" y2="241.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(33.94181636640461 49.0 ) ">
//           <g>
//             <line x1="0.0" y1="195.0952380952381" x2="372.0290918167977" y2="195.0952380952381" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="149.1904761904762" x2="372.0290918167977" y2="149.1904761904762" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="103.2857142857143" x2="372.0290918167977" y2="103.2857142857143" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="57.38095238095241" x2="372.0290918167977" y2="57.38095238095241" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="11.476190476190482" x2="372.0290918167977" y2="11.476190476190482" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cxpF1sg)" clip-bounds-jfx="[rect (33.94181636640461, 49.0), (372.0290918167977, 241.0)]">
//         <g transform="translate(33.94181636640461 49.0 ) ">
//           <g>
//             <g>
//               <rect x="135.28330611519914" y="11.476190476190482" height="229.52380952380952" width="101.46247958639941" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cxpF1sg">
//             <rect x="33.94181636640461"
