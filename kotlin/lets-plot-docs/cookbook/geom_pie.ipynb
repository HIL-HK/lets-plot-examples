// %% [markdown]
// # geomPie()

// %% [markdown]
// A pie chart is a circular statistical graphic, which is divided into slices to illustrate numerical proportion.

// %% [markdown]
// 1. [Default presentation](#1.-Default-presentation)
//
//     1.1. [Basic pie chart](#1.1.-Basic-pie-chart)
//
//     1.2. [Improve appearance](#1.2.-Improve-appearance)
//
//     1.3. [Adding labels to pie sectors](#1.3.-Adding-labels-to-pie-sectors)
//
//     1.4. [Use "count2d" statistical transformation](#1.4.-Use-"count2d"-statistical-transformation)
//
//
// 2. [Pie size depending on data](#2.-Pie-size-depending-on-data)
//
//
// 3. [Explode](#3.-Explode)

// %%
%useLatestDescriptors
%use dataframe
%use lets-plot
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>
//    <div id="9YMl54"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("9YMl54").appendChild(div);
//            };
//            var e = document.getElementById("9YMl54");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.9.3. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.5.2.

// %%
val blankTheme = theme(line=elementBlank(), axis=elementBlank())

// %%
val (w, h) = 400 to 250

val data = mapOf(
    "name" to listOf('a', 'b', 'c', 'd', 'b'),
    "value" to listOf(40, 90, 10,  50,  20)
)

val p = letsPlot(data) + ggsize(w,h)

// %% [markdown]
// ## 1. Default presentation

// %% [markdown]
// ### 1.1. Basic pie chart

// %% [markdown]
// Use "identity" statistical transformation to leave the data unchanged.

// %%
p + geomPie(stat = Stat.identity) { slice = "value"; fill = "name" }
// Out:
//    <div id="tX9BWR"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("tX9BWR").appendChild(div);
//            };
//            var e = document.getElementById("tX9BWR");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="6NSWAc"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("6NSWAc");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"1"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=83217cf1-ab7b-4ec3-9ac7-fa431bac2002 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pmqjNPu .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pmqjNPu .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmqjNPu .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmqjNPu .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pmqjNPu .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmqjNPu .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmqjNPu .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmqjNPu .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5jFjoE .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmqjNPu .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmqjNPu .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5jFjoE .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmqjNPu .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmqjNPu .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5jFjoE .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5jFjoE .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5jFjoE .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pmqjNPu">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="27.103317968557974" y1="0.0" x2="27.103317968557974" y2="191.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="81.30995390567395" y1="0.0" x2="81.30995390567395" y2="191.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="135.51658984278993" y1="0.0" x2="135.51658984278993" y2="191.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="189.7232257799059" y1="0.0" x2="189.7232257799059" y2="191.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="243.92986171702188" y1="0.0" x2="243.92986171702188" y2="191.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="171.9" x2="271.03317968557985" y2="171.9" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="133.7" x2="271.03317968557985" y2="133.7" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="95.5" x2="271.03317968557985" y2="95.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="57.3" x2="271.03317968557985" y2="57.3" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="19.099999999999994" x2="271.03317968557985" y2="19.099999999999994" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cjFgjwP)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (271.03317968557985, 191.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <path d="M135.51658984278993 95.5 L88.97290241057972 77.23294878168024 A50.0 50.0 0.0 0 1 135.51658984278993 45.5 L135.51658984278993 95.5 A0.0 0.0 0.0 0 0 135.51658984278993 95.5 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M135.51658984278993 95.5 L135.51658984278993 45.5 A50.0 50.0 0.0 0 1 157.21077679866784 140.54844339512096 L135.51658984278993 95.5 A0.0 0.0 0.0 0 0 135.51658984278993 95.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M135.51658984278993 95.5 L157.21077679866784 140.54844339512096 A50.0 50.0 0.0 0 1 142.96870315159865 144.94154131125643

// %% [markdown]
// ### 1.2. Improve appearance

// %% [markdown]
// - add stroke (`stroke` and `color`)
// - make the pie bigger (`size`)
// - add hole to draw donut-like chart (`hole`)
// - use blank theme (remove axis and grid)
// - use better colors

// %%
p +
    geomPie(stat = Stat.identity,
            size = 20, stroke = 1, color = "white", hole = 0.5) { slice = "value"; fill = "name" } +
    blankTheme + 
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="vzCNFR"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("vzCNFR");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"3"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0fd839a6-1659-42a5-9def-e2967c0731f6 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pmpnjSb .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pmpnjSb .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmpnjSb .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmpnjSb .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pmpnjSb .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmpnjSb .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmpnjSb .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmpnjSb .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doSlm9o .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmpnjSb .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmpnjSb .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doSlm9o .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmpnjSb .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmpnjSb .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doSlm9o .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doSlm9o .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #doSlm9o .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pmpnjSb">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cjzwtft)" clip-bounds-jfx="[rect (0.0, 0.0), (329.0484863613295, 237.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M117.98055574845453 100.23294878168024 L71.43686831624433 81.96589756336047 A100.0 100.0 0.0 0 1 164.52424318066474 18.5 L164.52424318066474 68.5 A50.0 50.0 0.0 0 0 117.98055574845453 100.23294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M164.52424318066474 68.5 L164.52424318066474 18.5 A100.0 100.0 0.0 0 1 207.91261709242056 208.5968867902419 L186.21843013654265 163.54844339512096 A50.0 50.0 0.0 0 0 164.52424318066474 68.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M186.21843013654265 163.54844339512096 L207.91261709242056 208.5968867902419 A100.0 100.0 0.0 0 1 179.4284697982822 217.38308262251286 L171.97635648947346 167.94154131125643 A50.0 50.0 0.0 0 0 186.21843013654265 163.54844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M171.97635648947346 167.94154131125643 L179.4284697982822 217.38308262251286 A100.0 100.0 0.0 0 1 67.03145196248238 140.75209339563145 L115.77784757157356 129.62604669781572 A50.0 50.0 0.0 0 0 171.97635648947346 167.94154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M115.77784757157356 129.62604669781572 L67.03145196248238 140.75209339563145 A100.0 100.0 0.0 0 1 71.4368683162443 81.96589756336054 L117.98055574845452 100.23294878168028 A50.0 50.0 0.0 0 0 115.77784757157356 129.62604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M71.43686831624433 81.96589756336047 A100.0 100.0 0.0 0 1 164.52424318066474 18.5 M164.52424318066474 68.5 A50.0 50.0 0.0 0 0 117.98055574845453 100.23294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M164.52424318066474 18.5 A100.0 100.0 0.0 0 1 207.91261709242056 208.5968867902419 M186.21843013654265 163.54844339512096 A50.0 50.0 0.0 0 0 164.52424318066474 68.5 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path

// %% [markdown]
// ### 1.3. Adding labels to pie sectors

// %% [markdown]
// Let's label the sectors with their names - configure annotations via `layerLabels()` function:

// %%
p + 
    geomPie(
        stat = Stat.identity,
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16)
    ) { slice = "value"; fill = "name" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="SUCMOR"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("SUCMOR");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"5"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=776e8ff2-cd8f-4ae4-9346-bc0598a8ae5a width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pWW96E2 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pWW96E2 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pWW96E2 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pWW96E2 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pWW96E2 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pWW96E2 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pWW96E2 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pWW96E2 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkLiGDD .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pWW96E2 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pWW96E2 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkLiGDD .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pWW96E2 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pWW96E2 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkLiGDD .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkLiGDD .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkLiGDD .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pWW96E2">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cqxRziG)" clip-bounds-jfx="[rect (0.0, 0.0), (387.0, 237.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M146.95631256778978 100.23294878168024 L100.41262513557959 81.96589756336047 A100.0 100.0 0.0 0 1 193.5 18.5 L193.5 68.5 A50.0 50.0 0.0 0 0 146.95631256778978 100.23294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 68.5 L193.5 18.5 A100.0 100.0 0.0 0 1 236.88837391175582 208.5968867902419 L215.1941869558779 163.54844339512096 A50.0 50.0 0.0 0 0 193.5 68.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M215.1941869558779 163.54844339512096 L236.88837391175582 208.5968867902419 A100.0 100.0 0.0 0 1 208.40422661761747 217.38308262251286 L200.95211330880872 167.94154131125643 A50.0 50.0 0.0 0 0 215.1941869558779 163.54844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M200.95211330880872 167.94154131125643 L208.40422661761747 217.38308262251286 A100.0 100.0 0.0 0 1 96.00720878181764 140.75209339563145 L144.75360439090883 129.62604669781572 A50.0 50.0 0.0 0 0 200.95211330880872 167.94154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M144.75360439090883 129.62604669781572 L96.00720878181764 140.75209339563145 A100.0 100.0 0.0 0 1 100.41262513557956 81.96589756336054 L146.95631256778978 100.23294878168028 A50.0 50.0 0.0 0 0 144.75360439090883 129.62604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M100.41262513557959 81.96589756336047 A100.0 100.0 0.0 0 1 193.5 18.5 M193.5 68.5 A50.0 50.0 0.0 0 0 146.95631256778978 100.23294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 18.5 A100.0 100.0 0.0 0 1 236.88837391175582 208.5968867902419 M215.1941869558779 163.54844339512096 A50.0 50.0 0.0 0 0 193.5 68.5 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M236.88837391175582 208.5968867902419 A100.

// %% [markdown]
// ### 1.4. Use "count2d" statistical transformation

// %% [markdown]
// `geomPie()` uses `count2d` stat by default.
// It allows to make a slice sizes proportional to the number of cases in each group  (or if the weight aesthetic is supplied, the sum of the weights). Also `count2d` provides variables for proportion ('..prop..') and proportion in percent ('..proppct..').

// %% [markdown]
// Using `layerTooltips()` prepare the information for tooltips by adding the variables provided by 'count2d':

// %%
val tooltipContent = layerTooltips()
                        .line("count|@{..count..} (@{..prop..})")
                        .line("total|@{..sum..}")
                        .format("..prop..", ".0%")
                        .format("..count..", ".1f")
                        .format("..sum..", ".1f")

// %% [markdown]
// Apply 'count2d' to get slices proportional to the number of cases.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = "name" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="e3N1xk"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("e3N1xk");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[5.0,5.0,5.0,5.0],
// "..count..":[1.0,2.0,1.0,1.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["a","b","c","d"],
// "..prop..":[0.2,0.4,0.2,0.2]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"7"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=d6b11b3f-0713-47e3-af90-5327199e1f44 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pdOlyVf .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pdOlyVf .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pdOlyVf .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pdOlyVf .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pdOlyVf .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pdOlyVf .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pdOlyVf .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pdOlyVf .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dctZCeZ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pdOlyVf .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pdOlyVf .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dctZCeZ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pdOlyVf .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pdOlyVf .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dctZCeZ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dctZCeZ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dctZCeZ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pdOlyVf">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#chGATHy)" clip-bounds-jfx="[rect (0.0, 0.0), (387.0, 237.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M145.94717418524232 103.04915028125262 L98.39434837048465 87.59830056250524 A100.0 100.0 0.0 0 1 193.5 18.5 L193.5 68.5 A50.0 50.0 0.0 0 0 145.94717418524232 103.04915028125262 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 68.5 L193.5 18.5 A100.0 100.0 0.0 0 1 252.27852522924732 199.40169943749476 L222.88926261462365 158.95084971874738 A50.0 50.0 0.0 0 0 193.5 68.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M222.88926261462365 158.95084971874738 L252.27852522924732 199.40169943749476 A100.0 100.0 0.0 0 1 134.7214747707527 199.40169943749476 L164.11073738537635 158.95084971874738 A50.0 50.0 0.0 0 0 222.88926261462365 158.95084971874738 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M164.11073738537635 158.95084971874738 L134.7214747707527 199.40169943749476 A100.0 100.0 0.0 0 1 98.39434837048464 87.59830056250527 L145.94717418524232 103.04915028125264 A50.0 50.0 0.0 0 0 164.11073738537635 158.95084971874738 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M98.39434837048465 87.59830056250524 A100.0 100.0 0.0 0 1 193.5 18.5 M193.5 68.5 A50.0 50.0 0.0 0 0 145.94717418524232 103.04915028125262 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 18.5 A100.0 100.0 0.0 0 1 252.27852522924732 199.40169943749476 M222.88926261462365 158.95084971874738 A50.0 50.0 0.0 0 0 193.5 68.5 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M252.27852522924732 199.40169943749476 A100.0 100.0 0.0 0 1 134.7214747707527 199.40169943749476 M164.11073738537635 158.95084

// %% [markdown]
// Compute weighted sum instead of simple count with aesthetic `weight`.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = "name"; weight = "value" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="33MnLv"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("33MnLv");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name",
// "weight":"value"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[210.0,210.0,210.0,210.0],
// "..count..":[40.0,110.0,10.0,50.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["a","b","c","d"],
// "..prop..":[0.19047619047619047,0.5238095238095238,0.047619047619047616,0.23809523809523808]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"9"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=b2ff45e5-9b32-428f-a871-a5a5e1ee5fde width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pLMPC15 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pLMPC15 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pLMPC15 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pLMPC15 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pLMPC15 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pLMPC15 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pLMPC15 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pLMPC15 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d2bZN6G .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pLMPC15 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pLMPC15 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d2bZN6G .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pLMPC15 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pLMPC15 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d2bZN6G .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d2bZN6G .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d2bZN6G .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pLMPC15">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cE0q8RB)" clip-bounds-jfx="[rect (0.0, 0.0), (387.0, 237.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M146.95631256778978 100.23294878168024 L100.41262513557959 81.96589756336047 A100.0 100.0 0.0 0 1 193.5 18.5 L193.5 68.5 A50.0 50.0 0.0 0 0 146.95631256778978 100.23294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 68.5 L193.5 18.5 A100.0 100.0 0.0 1 1 178.59577338238256 217.38308262251286 L186.04788669119128 167.94154131125643 A50.0 50.0 0.0 1 0 193.5 68.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M186.04788669119128 167.94154131125643 L178.59577338238256 217.38308262251286 A100.0 100.0 0.0 0 1 150.11162608824418 208.5968867902419 L171.8058130441221 163.54844339512096 A50.0 50.0 0.0 0 0 186.04788669119128 167.94154131125643 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M171.8058130441221 163.54844339512096 L150.11162608824418 208.5968867902419 A100.0 100.0 0.0 0 1 100.41262513557956 81.96589756336054 L146.95631256778978 100.23294878168028 A50.0 50.0 0.0 0 0 171.8058130441221 163.54844339512096 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M100.41262513557959 81.96589756336047 A100.0 100.0 0.0 0 1 193.5 18.5 M193.5 68.5 A50.0 50.0 0.0 0 0 146.95631256778978 100.23294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.5 18.5 A100.0 100.0 0.0 1 1 178.59577338238256 217.38308262251286 M186.04788669119128 167.94154131125643 A50.0 50.0 0.0 1 0 193.5 68.5 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M178.59577338238256 217.3830826

// %% [markdown]
// Order sectors by count.
//
// The following ordering rule is used for the pie chart: the first slice goes to the left of 12 o'clock and others go clockwise.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = asDiscrete("name", orderBy = "..count.."); weight = "value" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="gAq5Wf"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("gAq5Wf");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name",
// "weight":"value"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data_meta":{
// "mapping_annotations":[{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"name",
// "order_by":"..count.."
// }
// }]
// },
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[210.0,210.0,210.0,210.0],
// "..count..":[110.0,50.0,40.0,10.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["b","d","a","c"],
// "..prop..":[0.5238095238095238,0.23809523809523808,0.19047619047619047,0.047619047619047616]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"11"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=671f53e5-413a-4b12-8793-d07be74c56b8 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pSmX70P .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pSmX70P .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pSmX70P .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pSmX70P .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pSmX70P .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pSmX70P .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pSmX70P .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pSmX70P .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVCZ4PC .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pSmX70P .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pSmX70P .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVCZ4PC .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pSmX70P .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pSmX70P .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVCZ4PC .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVCZ4PC .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dVCZ4PC .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pSmX70P">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#crXPLi4)" clip-bounds-jfx="[rect (0.0, 0.0), (387.0, 237.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M200.95211330880875 167.94154131125643 L208.4042266176175 217.38308262251286 A100.0 100.0 0.0 1 1 193.49999999999997 18.5 L193.49999999999997 68.5 A50.0 50.0 0.0 1 0 200.95211330880875 167.94154131125643 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.49999999999997 68.5 L193.49999999999997 18.5 A100.0 100.0 0.0 0 1 293.220379718118 111.02699064135753 L243.360189859059 114.76349532067876 A50.0 50.0 0.0 0 0 193.49999999999997 68.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M243.360189859059 114.76349532067876 L293.220379718118 111.02699064135753 A100.0 100.0 0.0 0 1 236.88837391175588 208.59688679024188 L215.19418695587794 163.54844339512096 A50.0 50.0 0.0 0 0 243.360189859059 114.76349532067876 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M215.19418695587794 163.54844339512096 L236.88837391175588 208.59688679024188 A100.0 100.0 0.0 0 1 208.4042266176175 217.38308262251286 L200.95211330880875 167.94154131125643 A50.0 50.0 0.0 0 0 215.19418695587794 163.54844339512096 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M208.4042266176175 217.38308262251286 A100.0 100.0 0.0 1 1 193.49999999999997 18.5 M193.49999999999997 68.5 A50.0 50.0 0.0 1 0 200.95211330880875 167.94154131125643 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.49999999999997 18.5 A100.0 100.0 0.0 0 1 293.220379718118 111.02699064135753 M243.360189859059 114.7634

// %% [markdown]
// ## 2. Pie size depending on data

// %% [markdown]
// Make the size of the pie chart dependent on the data: map total count ('..sum..' variable) to the `size`.
//
// Note that it has its own special representation of the size in the legend.

// %%
val data2 = mapOf(
    "x" to listOf(1, 1, 1, 1, 1, 1.5, 1.5,   2,   2,   2),
    "y" to listOf(1, 1, 1, 1, 1,   2,   2, 1.5, 1.5, 1.5),
    "s" to listOf(3, 1, 2, 1, 4,   1,   3,   3,   3,  1),
    "n" to listOf('a', 'b', 'a', 'c', 'a',  'a', 'b', 'c', 'a',  'b')
)


letsPlot(data2) +
    geomPie(hole = 0.3, tooltips = tooltipContent) { 
        x = "x"
        y = "y"
        fill = asDiscrete("n", orderBy = "..count..", order = -1)
        weight = "s"
        size = "..sum.."
    } +
    xlim(0.5 to 2.5) + ylim(0.5 to 2.5)
// Out:
//    <div id="xnVFdI"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("xnVFdI");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[0.5,2.5]
// },{
// "aesthetic":"y",
// "limits":[0.5,2.5]
// }],
// "layers":[{
// "hole":0.3,
// "mapping":{
// "x":"x",
// "y":"y",
// "size":"..sum..",
// "fill":"n",
// "weight":"s"
// },
// "stat":"count2d",
// "position":"identity",
// "geom":"pie",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"n",
// "order_by":"..count..",
// "order":-1
// }
// }]
// },
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "data":{
// "..sum..":[11.0,4.0,7.0,11.0,7.0,11.0,4.0,7.0],
// "..count..":[9.0,1.0,3.0,1.0,3.0,1.0,3.0,1.0],
// "x":[1.0,1.5,2.0,1.0,2.0,1.0,1.5,2.0],
// "y":[1.0,2.0,1.5,1.0,1.5,1.0,2.0,1.5],
// "..prop..":[0.8181818181818182,0.25,0.42857142857142855,0.09090909090909091,0.42857142857142855,0.09090909090909091,0.75,0.14285714285714285],
// "n":["a","a","a","c","c","b","b","b"]
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"int",
// "column":"s"
// }]
// },
// "spec_id":"13"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6abceaa3-1714-43af-82b1-e94a30cf376c width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pmKMxJJ .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pmKMxJJ .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmKMxJJ .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmKMxJJ .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pmKMxJJ .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmKMxJJ .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmKMxJJ .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmKMxJJ .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dIYaOzf .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmKMxJJ .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pmKMxJJ .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dIYaOzf .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmKMxJJ .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pmKMxJJ .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dIYaOzf .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dIYaOzf .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dIYaOzf .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pmKMxJJ">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(27.034701220281416 0.0 ) ">
//           <g>
//             <line x1="18.456053622071806" y1="0.0" x2="18.456053622071806" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="110.73632173243085" y1="0.0" x2="110.73632173243085" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="203.01658984278993" y1="0.0" x2="203.01658984278993" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="295.29685795314896" y1="0.0" x2="295.29685795314896" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="387.577126063508" y1="0.0" x2="387.577126063508" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(27.034701220281416 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="406.03317968557985" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="406.03317968557985" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="406.03317968557985" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="406.03317968557985" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="406.03317968557985" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c7m2zdx)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (406.03317968557985, 341.0)]">
//         <g transform="translate(27.034701220281416 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <path d="

// %% [markdown]
// Mapping `fill` and `size` to the same variable:

// %%
letsPlot(data = mapOf("n" to listOf("a", "b", "c"), "s" to listOf(1, 2, 3))) + 
    geomPie(stat = Stat.identity) { fill = "n"; slice = "s"; size = "n" } +
    blankTheme
// Out:
//    <div id="Oi9pgT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Oi9pgT");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "s":[1.0,2.0,3.0],
// "n":["a","b","c"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "slice":"s",
// "size":"n",
// "fill":"n"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"n"
// },{
// "type":"int",
// "column":"s"
// }]
// },
// "spec_id":"15"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=569b5666-8aef-4e36-b46d-519038292d0b width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pcuUCpO .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pcuUCpO .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pcuUCpO .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pcuUCpO .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pcuUCpO .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pcuUCpO .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pcuUCpO .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pcuUCpO .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dPGfkQz .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pcuUCpO .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pcuUCpO .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dPGfkQz .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pcuUCpO .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pcuUCpO .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dPGfkQz .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dPGfkQz .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dPGfkQz .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pcuUCpO">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cKWUpDc)" clip-bounds-jfx="[rect (0.0, 0.0), (452.0484863613295, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M226.02424318066474 193.5 L220.1195245184981 190.0909090909091 A6.8181818181818175 6.8181818181818175 0.0 0 1 226.02424318066474 186.6818181818182 L226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M226.02424318066474 193.5 L226.02424318066474 166.22727272727272 A27.27272727272727 27.27272727272727 0.0 0 1 249.64311782933123 207.13636363636363 L226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M226.02424318066474 193.5 L267.35727381583115 217.36363636363637 A47.72727272727273 47.72727272727273 0.0 0 1 184.69121254549836 169.63636363636363 L226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M220.1195245184981 190.0909090909091 A6.8181818181818175 6.8181818181818175 0.0 0 1 226.02424318066474 186.6818181818182 M226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M226.02424318066474 166.22727272727272 A27.27272727272727 27.27272727272727 0.0 0 1 249.64311782933123 207.13636363636363 M226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M267.35727381583115 217.36363636363637 A47.72727272727273 47.72727272727273 0.0 0 1 184.69121254549836 169.63636363636363 M226.02424318066474 193.5 A0.0 0.0 0.0 0 0 226.02424318066474 193.5 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M226.02424318066474 193.5 L219.79476499207894 189.9034090909091 M226.02424318066474 193.5 L226.02424318066474 186.3068181818182 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M226.02424318066474 193.5 L226.02424318066474 165.85227272727272 M226.02424318066474 193.5 L249.9678773557504 207.32386363636363 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-op

// %% [markdown]
// ## 3. Explode

// %% [markdown]
// Use values to explode slices away from their center point, detaching it from the main pie.

// %%
val length = mapOf(
  "name" to listOf("20-50 km", "50-75 km", "10-20 km", "75-100 km", "3-5 km", "7-10 km", "5-7 km", ">100 km", "2-3 km"),
  "count" to listOf(1109, 696, 353, 192, 168, 86, 74, 65, 53),
  "explode" to listOf(0, 0, 0, 0.1, 0.1, 0.2, 0.3, 0.4, 0.6)
)

ggplot(length) + blankTheme +
    geomPie(stat = Stat.identity, stroke = 1, color = "black", size = 20) {
        fill = "name"; slice = "count"; explode = "explode"
    } +
    scaleFillGradient(low = "dark_blue", high = "light_green")
// Out:
//    <div id="wsTLZa"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("wsTLZa");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "explode":[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6],
// "name":["20-50 km","50-75 km","10-20 km","75-100 km","3-5 km","7-10 km","5-7 km",">100 km","2-3 km"],
// "count":[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_gradient",
// "high":"light_green",
// "low":"dark_blue"
// }],
// "layers":[{
// "mapping":{
// "slice":"count",
// "explode":"explode",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"black",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"name"
// },{
// "type":"int",
// "column":"count"
// },{
// "type":"int",
// "column":"explode"
// }]
// },
// "spec_id":"17"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=18fa1502-12fb-4b28-a8da-d7b69ffdb8da width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pjbVdJg .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pjbVdJg .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjbVdJg .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjbVdJg .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pjbVdJg .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjbVdJg .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjbVdJg .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjbVdJg .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d61PecO .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjbVdJg .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pjbVdJg .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d61PecO .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjbVdJg .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pjbVdJg .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d61PecO .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d61PecO .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d61PecO .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pjbVdJg">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c9d0t54)" clip-bounds-jfx="[rect (0.0, 0.0), (464.72588384193625, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M232.36294192096813 193.5 L171.88871168342118 273.1421212498522 A100.0 100.0 0.0 0 1 232.36294192096813 93.5 L232.36294192096813 193.5 A0.0 0.0 0.0 0 0 232.36294192096813 193.5 " fill="rgb(0,0,128)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M232.36294192096813 193.5 L232.36294192096813 93.5 A100.0 100.0 0.0 0 1 332.3606694608426 192.82584359304573 L232.36294192096813 193.5 A0.0 0.0 0.0 0 0 232.36294192096813 193.5 " fill="rgb(55,35,139)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M232.36294192096813 193.5 L332.3606694608426 192.82584359304573 A100.0 100.0 0.0 0 1 302.9941247245247 264.2900841627595 L232.36294192096813 193.5 A0.0 0.0 0.0 0 0 232.36294192096813 193.5 " fill="rgb(84,65,150)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M237.7469891470039 201.926863916536 L308.37817195056044 272.71694807929555 A100.0 100.0 0.0 0 1 272.3007097709691 295.7673689825306 L237.7469891470039 201.926863916536 A0.0 0.0 0.0 0 0 237.7469891470039 201.926863916536 " fill="rgb(108,95,161)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.99605374120512 203.3657460834243 L268.5497743651703 297.2062511494189 A100.0 100.0 0.0 0 1 231.52437992503323 303.335195559484 L233.99605374120512 203.3657460834243 A0.0 0.0 0.0 0 0 233.99605374120512 203.3657460834243 " fill="rgb(131,125,172)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M229.94191254637357 213.35292464014685 L227.4702387302017 313.32237411620656 A100.0 100.0 0.0 0 1 208.31623434291447 310.98657684183615 L229.94191254637357 213.35292464014685 A0.0 0.0 0.0 0 0 229.94191254637357 213.35292464014685 " fill="rgb(152,156,182)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M223.46508509151275 222.15009849620964 L201.83940688805365 319.783750697899 A100.0 100.0 0.0 0 1 185.97664646873378 314.8572555533977 L223.46508509151275 222.150098496

// %%
val calories = mapOf(
    "slice" to listOf(35, 25, 25, 15),
    "label" to listOf("Apples", "Bananas", "Cherries", "Dates"),
    "explode" to listOf(0.1, 0, 0, 0)
)

val p4 = ggplot(calories) +
    blankTheme +
    scaleFillBrewer(palette="Set1") +
    ggsize(w, h)

gggrid(plots = listOf(
    p4 + geomPie(stat = Stat.identity, size = 18) {
        fill = "label"; slice = "slice"; explode = "explode"
    } + theme().legendPositionNone(),
    p4 + geomPie(stat = Stat.identity, size = 18, hole = 0.8) {
        fill = "label"; slice = "slice"; explode = "explode"
    }),
       ncol = 2,
       cellWidth = w,
       cellHeight = h
)
// Out:
//    <div id="jRlI8C"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("jRlI8C");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "kind":"ggbunch",
// "items":[{
// "x":0,
// "width":400,
// "y":0,
// "feature_spec":{
// "mapping":{
// },
// "data":{
// "slice":[35.0,25.0,25.0,15.0],
// "explode":[0.1,0.0,0.0,0.0],
// "label":["Apples","Bananas","Cherries","Dates"]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "mapping":{
// "slice":"slice",
// "explode":"explode",
// "fill":"label"
// },
// "stat":"identity",
// "size":18.0,
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"slice"
// },{
// "type":"str",
// "column":"label"
// },{
// "type":"float",
// "column":"explode"
// }]
// },
// "spec_id":"19"
// },
// "height":250
// },{
// "x":400,
// "width":400,
// "y":0,
// "feature_spec":{
// "mapping":{
// },
// "data":{
// "slice":[35.0,25.0,25.0,15.0],
// "explode":[0.1,0.0,0.0,0.0],
// "label":["Apples","Bananas","Cherries","Dates"]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.8,
// "mapping":{
// "slice":"slice",
// "explode":"explode",
// "fill":"label"
// },
// "stat":"identity",
// "size":18.0,
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"slice"
// },{
// "type":"str",
// "column":"label"
// },{
// "type":"float",
// "column":"explode"
// }]
// },
// "spec_id":"20"
// },
// "height":250
// }]
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" id=d358bebc-3fd3-4e04-bfce-b05157cb9a2a width="100%" height="100%" style="max-width: 800.0px; max-height: 250.0px;" viewBox="0 0 800.0 250.0" preserveAspectRatio="xMinYMin meet">
// <style type="text/css">
//
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pZrdhSM .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pZrdhSM .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pZrdhSM .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pZrdhSM .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pZrdhSM .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pZrdhSM .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pZrdhSM .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pZrdhSM .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dNnUlRx .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pZrdhSM .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pZrdhSM .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dNnUlRx .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pZrdhSM .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pZrdhSM .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dNnUlRx .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dNnUlRx .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dNnUlRx .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//
//
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p5xSPEk .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #p5xSPEk .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p5xSPEk .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p5xSPEk .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p5xSPEk .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p5xSPEk .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p5xSPEk .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p5xSPEk .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dqlaEq6 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p5xSPEk .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p5xSPEk .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dqlaEq6 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p5xSPEk .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p5xSPEk .facet-strip-text-y {
// fil
