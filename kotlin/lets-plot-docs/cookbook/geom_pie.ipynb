// %% [markdown]
// # geomPie()

// %% [markdown]
// A pie chart is a circular statistical graphic, which is divided into slices to illustrate numerical proportion.

// %% [markdown]
// 1. [Default presentation](#1.-Default-presentation)
//
//     1.1. [Basic pie chart](#1.1.-Basic-pie-chart)
//
//     1.2. [Improve appearance](#1.2.-Improve-appearance)
//
//     1.3. [Adding labels to pie sectors](#1.3.-Adding-labels-to-pie-sectors)
//
//     1.4. [Use "count2d" statistical transformation](#1.4.-Use-"count2d"-statistical-transformation)
//
//
// 2. [Pie size depending on data](#2.-Pie-size-depending-on-data)
//
//
// 3. [Explode](#3.-Explode)

// %%
%use dataframe
%useLatestDescriptors
%use lets-plot
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>
//    <div id="7PNeFq"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("7PNeFq").appendChild(div);
//            };
//            var e = document.getElementById("7PNeFq");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.12.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.8.1.
// Outputs: Web (HTML+JS), Kotlin Notebook (Swing), Static SVG (hidden)

// %%
val blankTheme = theme(line=elementBlank(), axis=elementBlank())

// %%
val (w, h) = 400 to 250

val data = mapOf(
    "name" to listOf('a', 'b', 'c', 'd', 'b'),
    "value" to listOf(40, 90, 10,  50,  20)
)

val p = letsPlot(data) + ggsize(w,h)

// %% [markdown]
// ## 1. Default presentation

// %% [markdown]
// ### 1.1. Basic pie chart

// %% [markdown]
// Use "identity" statistical transformation to leave the data unchanged.

// %%
p + geomPie(stat = Stat.identity) { slice = "value"; fill = "name" }
// Out:
//    <div id="67hjuQ"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("67hjuQ").appendChild(div);
//            };
//            var e = document.getElementById("67hjuQ");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="v0HuML" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("v0HuML");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"1"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=477df51d-1004-4a45-9121-55c730abbbbf width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pdd0PeY .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pdd0PeY .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdd0PeY .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdd0PeY .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pdd0PeY .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdd0PeY .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdd0PeY .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdd0PeY .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daIRBA5 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdd0PeY .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdd0PeY .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daIRBA5 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdd0PeY .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdd0PeY .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daIRBA5 .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daIRBA5 .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #daIRBA5 .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pdd0PeY">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="29.124550581235383" y1="0.0" x2="29.124550581235383" y2="204.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="87.37365174370616" y1="0.0" x2="87.37365174370616" y2="204.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="145.62275290617694" y1="0.0" x2="145.62275290617694" y2="204.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="203.87185406864774" y1="0.0" x2="203.87185406864774" y2="204.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="262.1209552311185" y1="0.0" x2="262.1209552311185" y2="204.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="183.60000000000002" x2="291.2455058123539" y2="183.60000000000002" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="142.8" x2="291.2455058123539" y2="142.8" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="102.0" x2="291.2455058123539" y2="102.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="61.199999999999996" x2="291.2455058123539" y2="61.199999999999996" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="20.39999999999999" x2="291.2455058123539" y2="20.39999999999999" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cSCdlFm)" clip-bounds-jfx="[rect (31.015306675749617, 0.0), (291.2455058123539, 204.0)]">
//         <g transform="translate(31.015306675749617 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <path d="M145.62275290617694 102.0 L99.07906547396674 83.73294878168024 A50.0 50.0 0.0 0 1 145.62275290617694 52.0 L145.62275290617694 102.0 A0.0 0.0 0.0 0 0 145.62275290617694 102.0 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M145.62275290617694 102.0 L145.62275290617694 52.0 A50.0 50.0 0.0 0 1 167.31693986205485 147.04844339512096 L145.62

// %% [markdown]
// ### 1.2. Improve appearance

// %% [markdown]
// - add stroke (`stroke` and `color`)
// - make the pie bigger (`size`)
// - add hole to draw donut-like chart (`hole`)
// - use blank theme (remove axis and grid)
// - use better colors

// %%
p +
    geomPie(stat = Stat.identity,
            size = 20, stroke = 1, color = "white", hole = 0.5) { slice = "value"; fill = "name" } +
    blankTheme + 
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="GZT207" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("GZT207");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=19e61360-e24a-4dc4-b74a-31095689b59c width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pyQRpEx .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pyQRpEx .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pyQRpEx .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pyQRpEx .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pyQRpEx .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pyQRpEx .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pyQRpEx .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pyQRpEx .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dajZgVw .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pyQRpEx .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pyQRpEx .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dajZgVw .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pyQRpEx .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pyQRpEx .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dajZgVw .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dajZgVw .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dajZgVw .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pyQRpEx">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#czAPcUD)" clip-bounds-jfx="[rect (0.0, 0.0), (337.2608124881035, 238.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M122.08671881184155 100.73294878168024 L75.54303137963134 82.46589756336047 A100.0 100.0 0.0 0 1 168.63040624405176 19.0 L168.63040624405176 69.0 A50.0 50.0 0.0 0 0 122.08671881184155 100.73294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M168.63040624405176 69.0 L168.63040624405176 19.0 A100.0 100.0 0.0 0 1 212.01878015580758 209.0968867902419 L190.32459319992967 164.04844339512096 A50.0 50.0 0.0 0 0 168.63040624405176 69.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M190.32459319992967 164.04844339512096 L212.01878015580758 209.0968867902419 A100.0 100.0 0.0 0 1 183.53463286166922 217.88308262251286 L176.08251955286048 168.44154131125643 A50.0 50.0 0.0 0 0 190.32459319992967 164.04844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M176.08251955286048 168.44154131125643 L183.53463286166922 217.88308262251286 A100.0 100.0 0.0 0 1 71.13761502586941 141.25209339563145 L119.88401063496059 130.12604669781572 A50.0 50.0 0.0 0 0 176.08251955286048 168.44154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M119.88401063496059 130.12604669781572 L71.13761502586941 141.25209339563145 A100.0 100.0 0.0 0 1 75.54303137963132 82.46589756336054 L122.08671881184154 100.73294878168028 A50.0 50.0 0.0 0 0 119.88401063496059 130.12604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M75.54303137963134 82.46589756336047 A100.0 100.0 0.0 0 1 168.63040624405176 19.0 M168.63040624405176 69.0 A50.0 50.0 0.0 0 0 122.08671881184155 100.73294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M168.63040624405176 19.0 A100.0 100.0 0.0 0 1 212.0

// %% [markdown]
// ### 1.3. Adding labels to pie sectors

// %% [markdown]
// Let's label the sectors with their names - configure annotations via `layerLabels()` function:

// %%
p + 
    geomPie(
        stat = Stat.identity,
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16)
    ) { slice = "value"; fill = "name" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="I5KNmJ" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("I5KNmJ");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// "name":["a","b","c","d","b"],
// "value":[40.0,90.0,10.0,50.0,20.0]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "slice":"value",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"5"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=7ab851a9-c029-4923-b472-cd4e5cbfd1e5 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pfdP5FD .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pfdP5FD .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pfdP5FD .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pfdP5FD .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pfdP5FD .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pfdP5FD .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pfdP5FD .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pfdP5FD .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dHwX612 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pfdP5FD .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pfdP5FD .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dHwX612 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pfdP5FD .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pfdP5FD .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dHwX612 .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dHwX612 .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dHwX612 .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pfdP5FD">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#ckpxvg6)" clip-bounds-jfx="[rect (0.0, 0.0), (388.0, 238.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M147.45631256778978 100.73294878168024 L100.91262513557959 82.46589756336047 A100.0 100.0 0.0 0 1 194.0 19.0 L194.0 69.0 A50.0 50.0 0.0 0 0 147.45631256778978 100.73294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 69.0 L194.0 19.0 A100.0 100.0 0.0 0 1 237.38837391175582 209.0968867902419 L215.6941869558779 164.04844339512096 A50.0 50.0 0.0 0 0 194.0 69.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M215.6941869558779 164.04844339512096 L237.38837391175582 209.0968867902419 A100.0 100.0 0.0 0 1 208.90422661761747 217.88308262251286 L201.45211330880872 168.44154131125643 A50.0 50.0 0.0 0 0 215.6941869558779 164.04844339512096 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M201.45211330880872 168.44154131125643 L208.90422661761747 217.88308262251286 A100.0 100.0 0.0 0 1 96.50720878181765 141.25209339563145 L145.25360439090883 130.12604669781572 A50.0 50.0 0.0 0 0 201.45211330880872 168.44154131125643 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M145.25360439090883 130.12604669781572 L96.50720878181765 141.25209339563145 A100.0 100.0 0.0 0 1 100.91262513557956 82.46589756336054 L147.45631256778978 100.73294878168028 A50.0 50.0 0.0 0 0 145.25360439090883 130.12604669781572 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M100.91262513557959 82.46589756336047 A100.0 100.0 0.0 0 1 194.0 19.0 M194.0 69.0 A50.0 50.0 0.0 0 0 147.45631256778978 100.73294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 19.0 A100.0 100.0 0.0 0 1 237.38837391175582 209.0968867902419 M215

// %% [markdown]
// ### 1.4. Use "count2d" statistical transformation

// %% [markdown]
// `geomPie()` uses `count2d` stat by default.
// It allows to make a slice sizes proportional to the number of cases in each group  (or if the weight aesthetic is supplied, the sum of the weights). Also `count2d` provides variables for proportion ('..prop..') and proportion in percent ('..proppct..').

// %% [markdown]
// Using `layerTooltips()` prepare the information for tooltips by adding the variables provided by 'count2d':

// %%
val tooltipContent = layerTooltips()
                        .line("count|@{..count..} (@{..prop..})")
                        .line("total|@{..sum..}")
                        .format("..prop..", ".0%")
                        .format("..count..", ".1f")
                        .format("..sum..", ".1f")

// %% [markdown]
// Apply 'count2d' to get slices proportional to the number of cases.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = "name" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="6iTYqA" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("6iTYqA");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[5.0,5.0,5.0,5.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..count..":[1.0,2.0,1.0,1.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["a","b","c","d"],
// "..prop..":[0.2,0.4,0.2,0.2]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"7"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=748e2df3-244a-4948-a345-93ee026117a9 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pzQs7V3 .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pzQs7V3 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pzQs7V3 .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pzQs7V3 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pzQs7V3 .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pzQs7V3 .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pzQs7V3 .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pzQs7V3 .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dXx5k3M .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pzQs7V3 .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pzQs7V3 .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dXx5k3M .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pzQs7V3 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pzQs7V3 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dXx5k3M .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dXx5k3M .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dXx5k3M .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pzQs7V3">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c6KImtE)" clip-bounds-jfx="[rect (0.0, 0.0), (388.0, 238.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M146.44717418524232 103.54915028125262 L98.89434837048465 88.09830056250524 A100.0 100.0 0.0 0 1 194.0 19.0 L194.0 69.0 A50.0 50.0 0.0 0 0 146.44717418524232 103.54915028125262 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 69.0 L194.0 19.0 A100.0 100.0 0.0 0 1 252.77852522924732 199.90169943749476 L223.38926261462365 159.45084971874738 A50.0 50.0 0.0 0 0 194.0 69.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M223.38926261462365 159.45084971874738 L252.77852522924732 199.90169943749476 A100.0 100.0 0.0 0 1 135.2214747707527 199.90169943749476 L164.61073738537635 159.45084971874738 A50.0 50.0 0.0 0 0 223.38926261462365 159.45084971874738 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M164.61073738537635 159.45084971874738 L135.2214747707527 199.90169943749476 A100.0 100.0 0.0 0 1 98.89434837048464 88.09830056250527 L146.44717418524232 103.54915028125264 A50.0 50.0 0.0 0 0 164.61073738537635 159.45084971874738 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M98.89434837048465 88.09830056250524 A100.0 100.0 0.0 0 1 194.0 19.0 M194.0 69.0 A50.0 50.0 0.0 0 0 146.44717418524232 103.54915028125262 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 19.0 A100.0 100.0 0.0 0 1 252.77852522924732 199.90169943749476 M223.38926261462365 159.45084971874738 A50.0 50.0 0.0 0 0 194.0 69.0 " fill="none" strok

// %% [markdown]
// Compute weighted sum instead of simple count with aesthetic `weight`.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = "name"; weight = "value" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="NpYZiO" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("NpYZiO");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name",
// "weight":"value"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[210.0,210.0,210.0,210.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..count..":[40.0,110.0,10.0,50.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["a","b","c","d"],
// "..prop..":[0.19047619047619047,0.5238095238095238,0.047619047619047616,0.23809523809523808]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"9"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6dca154c-7619-49e3-ae88-9668b7b80567 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pdhum2G .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pdhum2G .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdhum2G .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdhum2G .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pdhum2G .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdhum2G .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdhum2G .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdhum2G .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmpUUTC .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdhum2G .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pdhum2G .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmpUUTC .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdhum2G .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pdhum2G .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmpUUTC .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmpUUTC .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmpUUTC .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pdhum2G">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c2HyC5w)" clip-bounds-jfx="[rect (0.0, 0.0), (388.0, 238.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M147.45631256778978 100.73294878168024 L100.91262513557959 82.46589756336047 A100.0 100.0 0.0 0 1 194.0 19.0 L194.0 69.0 A50.0 50.0 0.0 0 0 147.45631256778978 100.73294878168024 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 69.0 L194.0 19.0 A100.0 100.0 0.0 1 1 179.09577338238256 217.88308262251286 L186.54788669119128 168.44154131125643 A50.0 50.0 0.0 1 0 194.0 69.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M186.54788669119128 168.44154131125643 L179.09577338238256 217.88308262251286 A100.0 100.0 0.0 0 1 150.61162608824418 209.0968867902419 L172.3058130441221 164.04844339512096 A50.0 50.0 0.0 0 0 186.54788669119128 168.44154131125643 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M172.3058130441221 164.04844339512096 L150.61162608824418 209.0968867902419 A100.0 100.0 0.0 0 1 100.91262513557956 82.46589756336054 L147.45631256778978 100.73294878168028 A50.0 50.0 0.0 0 0 172.3058130441221 164.04844339512096 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M100.91262513557959 82.46589756336047 A100.0 100.0 0.0 0 1 194.0 19.0 M194.0 69.0 A50.0 50.0 0.0 0 0 147.45631256778978 100.73294878168024 " fill="none" stroke-width="1.0" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M194.0 19.0 A100.0 100.0 0.0 1 1 179.09577338238256 217.88308262

// %% [markdown]
// Order sectors by count.
//
// The following ordering rule is used for the pie chart: the first slice goes to the left of 12 o'clock and others go clockwise.

// %%
p +
    geomPie(
        size = 20, stroke = 1, color = "white", hole = 0.5,
        labels = layerLabels().line("@name").size(16),
        tooltips = tooltipContent
    ) { fill = asDiscrete("name", orderBy = "..count.."); weight = "value" } +
    blankTheme + 
    theme().legendPositionNone() +
    scaleFillBrewer(palette = "Set1")
// Out:
//    <div id="5GQCIH" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("5GQCIH");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.5,
// "mapping":{
// "fill":"name",
// "weight":"value"
// },
// "stat":"count2d",
// "size":20.0,
// "color":"white",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data_meta":{
// "mapping_annotations":[{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"name",
// "order_by":"..count.."
// }
// }]
// },
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "labels":{
// "lines":["@name"],
// "annotation_size":16
// },
// "data":{
// "..sum..":[210.0,210.0,210.0,210.0],
// "..x..":[0.0,0.0,0.0,0.0],
// "..count..":[110.0,50.0,40.0,10.0],
// "..y..":[0.0,0.0,0.0,0.0],
// "name":["b","d","a","c"],
// "..prop..":[0.5238095238095238,0.23809523809523808,0.19047619047619047,0.047619047619047616]
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"value"
// }]
// },
// "spec_id":"11"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=e25fdbf5-c995-4516-9544-7e5c3bb4bfb1 width="100%" height="100%" style="max-width: 400.0px; max-height: 250.0px;" viewBox="0 0 400.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pgkGVgG .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pgkGVgG .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgkGVgG .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgkGVgG .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pgkGVgG .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgkGVgG .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgkGVgG .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgkGVgG .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dzf54Uj .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgkGVgG .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgkGVgG .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dzf54Uj .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgkGVgG .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgkGVgG .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dzf54Uj .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dzf54Uj .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dzf54Uj .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pgkGVgG">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 250.0 L400.0 250.0 L400.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cfCdHD7)" clip-bounds-jfx="[rect (0.0, 0.0), (388.0, 238.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M201.45211330880875 168.44154131125643 L208.9042266176175 217.88308262251286 A100.0 100.0 0.0 1 1 193.99999999999997 19.0 L193.99999999999997 69.0 A50.0 50.0 0.0 1 0 201.45211330880875 168.44154131125643 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M193.99999999999997 69.0 L193.99999999999997 19.0 A100.0 100.0 0.0 0 1 293.720379718118 111.52699064135753 L243.860189859059 115.26349532067876 A50.0 50.0 0.0 0 0 193.99999999999997 69.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M243.860189859059 115.26349532067876 L293.720379718118 111.52699064135753 A100.0 100.0 0.0 0 1 237.38837391175588 209.09688679024188 L215.69418695587794 164.04844339512096 A50.0 50.0 0.0 0 0 243.860189859059 115.26349532067876 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M215.69418695587794 164.04844339512096 L237.38837391175588 209.09688679024188 A100.0 100.0 0.0 0 1 208.9042266176175 217.88308262251286 L201.45211330880875 168.44154131125643 A50.0 50.0 0.0 0 0 215.69418695587794 164.04844339512096 " fill="rgb(152,78,163)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M208.9042266176175 217.88308262251286 A100.0 100.0 0.0 1 1 193.99999999999997 19.0 M193.99999999999997 69.0 A50.0 50.0 0.0 1 0 201.45211330880875 168.44154131125643 "

// %% [markdown]
// ## 2. Pie size depending on data

// %% [markdown]
// Make the size of the pie chart dependent on the data: map total count ('..sum..' variable) to the `size`.
//
// Note that it has its own special representation of the size in the legend.

// %%
val data2 = mapOf(
    "x" to listOf(1, 1, 1, 1, 1, 1.5, 1.5,   2,   2,   2),
    "y" to listOf(1, 1, 1, 1, 1,   2,   2, 1.5, 1.5, 1.5),
    "s" to listOf(3, 1, 2, 1, 4,   1,   3,   3,   3,  1),
    "n" to listOf('a', 'b', 'a', 'c', 'a',  'a', 'b', 'c', 'a',  'b')
)


letsPlot(data2) +
    geomPie(hole = 0.3, tooltips = tooltipContent) { 
        x = "x"
        y = "y"
        fill = asDiscrete("n", orderBy = "..count..", order = -1)
        weight = "s"
        size = "..sum.."
    } +
    xlim(0.5 to 2.5) + ylim(0.5 to 2.5)
// Out:
//    <div id="Lomksr" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("Lomksr");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"x",
// "limits":[0.5,2.5]
// },{
// "aesthetic":"y",
// "limits":[0.5,2.5]
// }],
// "layers":[{
// "hole":0.3,
// "mapping":{
// "x":"x",
// "y":"y",
// "size":"..sum..",
// "fill":"n",
// "weight":"s"
// },
// "stat":"count2d",
// "position":"identity",
// "geom":"pie",
// "data_meta":{
// "mapping_annotations":[{
// "aes":"fill",
// "annotation":"as_discrete",
// "parameters":{
// "label":"n",
// "order_by":"..count..",
// "order":-1
// }
// }]
// },
// "tooltips":{
// "lines":["count|@{..count..} (@{..prop..})","total|@{..sum..}"],
// "formats":[{
// "field":"..prop..",
// "format":".0%"
// },{
// "field":"..count..",
// "format":".1f"
// },{
// "field":"..sum..",
// "format":".1f"
// }]
// },
// "data":{
// "..sum..":[11.0,4.0,7.0,11.0,7.0,11.0,4.0,7.0],
// "..count..":[9.0,1.0,3.0,1.0,3.0,1.0,3.0,1.0],
// "x":[1.0,1.5,2.0,1.0,2.0,1.0,1.5,2.0],
// "y":[1.0,2.0,1.5,1.0,1.5,1.0,2.0,1.5],
// "..prop..":[0.8181818181818182,0.25,0.42857142857142855,0.09090909090909091,0.42857142857142855,0.09090909090909091,0.75,0.14285714285714285],
// "n":["a","a","a","c","c","b","b","b"]
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"int",
// "column":"s"
// }]
// },
// "spec_id":"13"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=5dd9c9f3-984f-4469-b862-4b0a4840bebd width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #ptLy8v4 .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #ptLy8v4 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #ptLy8v4 .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ptLy8v4 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #ptLy8v4 .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #ptLy8v4 .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ptLy8v4 .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #ptLy8v4 .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dsxx25e .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ptLy8v4 .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #ptLy8v4 .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dsxx25e .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ptLy8v4 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #ptLy8v4 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dsxx25e .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dsxx25e .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dsxx25e .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="ptLy8v4">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <g transform="translate(23.034701220281416 0.0 ) ">
//           <g>
//             <line x1="19.63699023368399" y1="0.0" x2="19.63699023368399" y2="354.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="117.82194140210399" y1="0.0" x2="117.82194140210399" y2="354.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="216.00689257052397" y1="0.0" x2="216.00689257052397" y2="354.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="314.191843738944" y1="0.0" x2="314.191843738944" y2="354.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="412.376794907364" y1="0.0" x2="412.376794907364" y2="354.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(23.034701220281416 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="337.90909090909093" x2="432.01378514104806" y2="337.90909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="257.4545454545455" x2="432.01378514104806" y2="257.4545454545455" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="177.0" x2="432.01378514104806" y2="177.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="96.54545454545456" x2="432.01378514104806" y2="96.54545454545456" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="16.090909090909122" x2="432.01378514104806" y2="16.090909090909122" stroke="rgb(233

// %% [markdown]
// Mapping `fill` and `size` to the same variable:

// %%
letsPlot(data = mapOf("n" to listOf("a", "b", "c"), "s" to listOf(1, 2, 3))) + 
    geomPie(stat = Stat.identity) { fill = "n"; slice = "s"; size = "n" } +
    blankTheme
// Out:
//    <div id="VJro0b" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("VJro0b");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// "s":[1.0,2.0,3.0],
// "n":["a","b","c"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "slice":"s",
// "size":"n",
// "fill":"n"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"n"
// },{
// "type":"int",
// "column":"s"
// }]
// },
// "spec_id":"23"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=3bd8e34a-05c1-42a4-80a3-217f7ab0dd26 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pb97uN1 .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pb97uN1 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pb97uN1 .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pb97uN1 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pb97uN1 .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pb97uN1 .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pb97uN1 .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pb97uN1 .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dAxLh2q .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pb97uN1 .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pb97uN1 .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dAxLh2q .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pb97uN1 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pb97uN1 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dAxLh2q .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dAxLh2q .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dAxLh2q .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pb97uN1">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cyO0AaM)" clip-bounds-jfx="[rect (0.0, 0.0), (466.0290918167977, 388.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M233.01454590839884 194.0 L227.10982724623221 190.5909090909091 A6.8181818181818175 6.8181818181818175 0.0 0 1 233.01454590839884 187.1818181818182 L233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="rgb(228,26,28)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.01454590839884 194.0 L233.01454590839884 166.72727272727272 A27.27272727272727 27.27272727272727 0.0 0 1 256.63342055706534 207.63636363636363 L233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="rgb(55,126,184)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.01454590839884 194.0 L274.34757654356525 217.86363636363637 A47.72727272727273 47.72727272727273 0.0 0 1 191.68151527323246 170.13636363636363 L233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="rgb(77,175,74)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M227.10982724623221 190.5909090909091 A6.8181818181818175 6.8181818181818175 0.0 0 1 233.01454590839884 187.1818181818182 M233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.01454590839884 166.72727272727272 A27.27272727272727 27.27272727272727 0.0 0 1 256.63342055706534 207.63636363636363 M233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M274.34757654356525 217.86363636363637 A47.72727272727273 47.72727272727273 0.0 0 1 191.68151527323246 170.13636363636363 M233.01454590839884 194.0 A0.0 0.0 0.0 0 0 233.01454590839884 194.0 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M233.01454590839884 194.0 L226.78506771981304 190.4034090909091 M233.01454590839884 194.0 L233.01454590839884 186.8068181818182 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">

// %% [markdown]
// ## 3. Explode

// %% [markdown]
// Use values to explode slices away from their center point, detaching it from the main pie.

// %%
val length = mapOf(
  "name" to listOf("20-50 km", "50-75 km", "10-20 km", "75-100 km", "3-5 km", "7-10 km", "5-7 km", ">100 km", "2-3 km"),
  "count" to listOf(1109, 696, 353, 192, 168, 86, 74, 65, 53),
  "explode" to listOf(0, 0, 0, 0.1, 0.1, 0.2, 0.3, 0.4, 0.6)
)

ggplot(length) + blankTheme +
    geomPie(stat = Stat.identity, stroke = 1, color = "black", size = 20) {
        fill = "name"; slice = "count"; explode = "explode"
    } +
    scaleFillGradient(low = "dark_blue", high = "light_green")
// Out:
//    <div id="mHzVDX" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("mHzVDX");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// },
// "data":{
// "explode":[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6],
// "name":["20-50 km","50-75 km","10-20 km","75-100 km","3-5 km","7-10 km","5-7 km",">100 km","2-3 km"],
// "count":[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_gradient",
// "high":"light_green",
// "low":"dark_blue"
// }],
// "layers":[{
// "mapping":{
// "slice":"count",
// "explode":"explode",
// "fill":"name"
// },
// "stat":"identity",
// "size":20.0,
// "color":"black",
// "position":"identity",
// "geom":"pie",
// "stroke":1.0,
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"name"
// },{
// "type":"int",
// "column":"count"
// },{
// "type":"int",
// "column":"explode"
// }]
// },
// "spec_id":"17"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=b6ce8e0a-b300-433a-a639-3aca15d443d3 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pW993tR .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pW993tR .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pW993tR .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pW993tR .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pW993tR .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pW993tR .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pW993tR .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pW993tR .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d97rVnT .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pW993tR .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pW993tR .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d97rVnT .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pW993tR .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pW993tR .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d97rVnT .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d97rVnT .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d97rVnT .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pW993tR">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.0 6.0 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c7IZNBm)" clip-bounds-jfx="[rect (0.0, 0.0), (478.70648929740446, 388.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M239.35324464870223 194.0 L178.87901441115528 273.6421212498522 A100.0 100.0 0.0 0 1 239.35324464870223 94.0 L239.35324464870223 194.0 A0.0 0.0 0.0 0 0 239.35324464870223 194.0 " fill="rgb(0,0,139)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M239.35324464870223 194.0 L239.35324464870223 94.0 A100.0 100.0 0.0 0 1 339.35097218857663 193.32584359304573 L239.35324464870223 194.0 A0.0 0.0 0.0 0 0 239.35324464870223 194.0 " fill="rgb(53,37,142)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M239.35324464870223 194.0 L339.35097218857663 193.32584359304573 A100.0 100.0 0.0 0 1 309.9844274522588 264.7900841627595 L239.35324464870223 194.0 A0.0 0.0 0.0 0 0 239.35324464870223 194.0 " fill="rgb(77,65,144)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M244.737291874738 202.426863916536 L315.36847467829455 273.21694807929555 A100.0 100.0 0.0 0 1 279.2910124987032 296.2673689825306 L244.737291874738 202.426863916536 A0.0 0.0 0.0 0 0 244.737291874738 202.426863916536 " fill="rgb(95,93,146)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M240.98635646893922 203.8657460834243 L275.5400770929044 297.7062511494189 A100.0 100.0 0.0 0 1 238.51468265276733 303.835195559484 L240.98635646893922 203.8657460834243 A0.0 0.0 0.0 0 0 240.98635646893922 203.8657460834243 " fill="rgb(109,121,147)" stroke-width="1.0" fill-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M236.93221527410768 213.85292464014685 L234.4605414579358 313.82237411620656 A100.0 100.0 0.0 0 1 215.30653707064857 311.48657684183615 L236.93221527410768 213.85292464014685 A0.0 0.0 0.0 0 0 236.93221527410768 213.85292464014685 " fill="rgb(121,149,148)" stroke-width="1.0" f

// %%
val calories = mapOf(
    "slice" to listOf(35, 25, 25, 15),
    "label" to listOf("Apples", "Bananas", "Cherries", "Dates"),
    "explode" to listOf(0.1, 0, 0, 0)
)

val p4 = ggplot(calories) +
    blankTheme +
    scaleFillBrewer(palette="Set1") +
    ggsize(w, h)

gggrid(plots = listOf(
    p4 + geomPie(stat = Stat.identity, size = 18) {
        fill = "label"; slice = "slice"; explode = "explode"
    } + theme().legendPositionNone(),
    p4 + geomPie(stat = Stat.identity, size = 18, hole = 0.8) {
        fill = "label"; slice = "slice"; explode = "explode"
    }),
       ncol = 2
) + ggsize(2 * w, h)
// Out:
//    <div id="esXlqL" ></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("esXlqL");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "mapping":{
// },
// "data":{
// "slice":[35.0,25.0,25.0,15.0],
// "explode":[0.1,0.0,0.0,0.0],
// "label":["Apples","Bananas","Cherries","Dates"]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "mapping":{
// "slice":"slice",
// "explode":"explode",
// "fill":"label"
// },
// "stat":"identity",
// "size":18.0,
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// },
// "legend_position":"none"
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"slice"
// },{
// "type":"str",
// "column":"label"
// },{
// "type":"float",
// "column":"explode"
// }]
// },
// "spec_id":"19"
// },{
// "mapping":{
// },
// "data":{
// "slice":[35.0,25.0,25.0,15.0],
// "explode":[0.1,0.0,0.0,0.0],
// "label":["Apples","Bananas","Cherries","Dates"]
// },
// "ggsize":{
// "width":400.0,
// "height":250.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Set1"
// }],
// "layers":[{
// "hole":0.8,
// "mapping":{
// "slice":"slice",
// "explode":"explode",
// "fill":"label"
// },
// "stat":"identity",
// "size":18.0,
// "position":"identity",
// "geom":"pie",
// "data":{
// }
// }],
// "theme":{
// "axis":{
// "blank":true
// },
// "line":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"slice"
// },{
// "type":"str",
// "column":"label"
// },{
// "type":"float",
// "column":"explode"
// }]
// },
// "spec_id":"20"
// }],
// "ggsize":{
// "width":800.0,
// "height":250.0
// },
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=8cf50e19-2b15-4246-927b-9ae59afae8e3 width="100%" height="100%" style="max-width: 800.0px; max-height: 250.0px;" viewBox="0 0 800.0 250.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pU6YU6b .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pU6YU6b .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pU6YU6b .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pU6YU6b .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pU6YU6b .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pU6YU6b .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pU6YU6b .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pU6YU6b .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pU6YU6b .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pU6YU6b .axis-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pU6YU6b .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pU6YU6b .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-text {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-title {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// .tooltip-label {
// fill: #474747;
// font-weight: bold;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pU6YU6b">
//     <rect x="0.0" y="0.0" height="250.0" width="800.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="392.0" height="238.0" x="6.0" y="6.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pgxt29B .plot-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pgxt29B .plot-subtitle {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgxt29B .plot-caption {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgxt29B .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
// font-style: normal;
//
// }
// #pgxt29B .legend-title {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgxt29B .legend-item {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgxt29B .axis-title-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pgxt29B .axis-text-x {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #diKlhL3 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pgxt29B .axis-title-y {
// fill: #474747;
// font-weight: normal;
// font-style: normal;
// font-family: sans-serif;
// font-size: 15.0px;
//
// }
