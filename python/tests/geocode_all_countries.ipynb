# %%
from lets_plot import *
from lets_plot.geo_data import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="Bo8cju"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("Bo8cju").appendChild(div);
#                     };
#                     var e = document.getElementById("Bo8cju");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def get_data(country, level, *, res=6):
    def print_log(message):
        print("{0}\n    {1}".format(country, message))
    try:
        gdf = geocode(level=level).scope(country).get_boundaries(res)
        if gdf.empty:
            raise Exception("Failure: There is no data for the '{0}' level".format(level))
        print_log("Success: Data is processed")
        return gdf
    except Exception as e:
        print_log(e)
        return None

# %%
def get_plot(country, gdf, level):
    if level == 'state':
        map_color = "#1c9099"
        bg_color = "#ece2f0"
    else:
        map_color = "#dd1c77"
        bg_color = "#e7e1ef"
    return ggplot() + \
        geom_map(data=gdf, fill=map_color, color="black", alpha=1) + \
        ggtitle(country, "Level: {0}".format(level)) + \
        theme_void() + \
        theme(plot_background=element_rect(fill=bg_color), \
              plot_title=element_text(size=22))

# %%
countries_df = geocode_countries().get_geocodes()
countries_list = sorted(countries_df["found name"])

# %%
states_dict = {country: get_data(country, 'state') for country in countries_list}
states_plots = [get_plot(country, states, 'state') for country, states in states_dict.items() if states is not None]
# Out:
# Afghanistan
#     Success: Data is processed
# Albania
#     Success: Data is processed
# Algeria
#     Success: Data is processed
# Andorra
#     Failure: There is no data for the 'state' level
# Angola
#     Success: Data is processed
# Anguilla
#     Failure: There is no data for the 'state' level
# Antigua and Barbuda
#     Success: Data is processed
# Argentina
#     Success: Data is processed
# Armenia
#     Success: Data is processed
# Australia
#     Success: Data is processed
# Austria
#     Success: Data is processed
# Azerbaijan
#     Success: Data is processed
# Bahrain
#     Success: Data is processed
# Bangladesh
#     Success: Data is processed
# Barbados
#     Failure: There is no data for the 'state' level
# Belarus
#     Success: Data is processed
# Belgium
#     Success: Data is processed
# Belize
#     Success: Data is processed
# Benin
#     Success: Data is processed
# Bermuda
#     Failure: There is no data for the 'state' level
# Bhutan
#     Success: Data is processed
# Bolivia
#     Success: Data is processed
# Bosnia and Herzegovina
#     Success: Data is processed
# Botswana
#     Success: Data is processed
# Brazil
#     Success: Data is processed
# British Indian Ocean Territory
#     Failure: There is no data for the 'state' level
# British Virgin Islands
#     Failure: There is no data for the 'state' level
# Brunei
#     Success: Data is processed
# Bulgaria
#     Success: Data is processed
# Burkina Faso
#     Success: Data is processed
# Burundi
#     Success: Data is processed
# Cambodia
#     Success: Data is processed
# Cameroon
#     Success: Data is processed
# Canada
#     Success: Data is processed
# Cape Verde
#     Failure: There is no data for the 'state' level
# Cayman Islands
#     Failure: There is no data for the 'state' level
# Central African Republic
#     Success: Data is processed
# Chad
#     Success: Data is processed
# Chile
#     Success: Data is processed
# China
#     Success: Data is processed
# Colombia
#     Success: Data is processed
# Comoros
#     Success: Data is processed
# Congo-Brazzaville
#     Success: Data is processed
# Cook Islands
#     Success: Data is processed
# Costa Rica
#     Success: Data is processed
# Croatia
#     Success: Data is processed
# Cuba
#     Success: Data is processed
# Cyprus
#     Success: Data is processed
# Czech Republic
#     Success: Data is processed
# Democratic Republic of the Congo
#     Success: Data is processed
# Denmark
#     Success: Data is processed
# Djibouti
#     Success: Data is processed
# Dominica
#     Success: Data is processed
# Dominican Republic
#     Success: Data is processed
# East Timor
#     Success: Data is processed
# Ecuador
#     Success: Data is processed
# Egypt
#     Success: Data is processed
# El Salvador
#     Success: Data is processed
# Equatorial Guinea
#     Success: Data is processed
# Eritrea
#     Success: Data is processed
# Estonia
#     Success: Data is processed
# Eswatini
#     Success: Data is processed
# Ethiopia
#     Success: Data is processed
# Falkland Islands
#     Failure: There is no data for the 'state' level
# Faroe Islands
#     Success: Data is processed
# Federated States of Micronesia
#     Success: Data is processed
# Fiji
#     Success: Data is processed
# Finland
#     Success: Data is processed
# France
#     Success: Data is processed
# Gabon
#     Success: Data is processed
# Georgia
#     Success: Data is processed
# Germany
#     Success: Data is processed
# Ghana
#     Success: Data is processed
# Gibraltar
#     Success: Data is processed
# Greece
#     Success: Data is processed
# Greenland
#     Failure: There is no data for the 'state' level
# Grenada
#     Failure: There is no data for the 'state' level
# Guatemala
#     Success: Data is processed
# Guernsey
#     Success: Data is processed
# Guinea
#     Success: Data is processed
# Guinea-Bissau
#     Success: Data is processed
# Guyana
#     Success: Data is processed
# Haiti
#     Success: Data is processed
# Honduras
#     Success: Data is processed
# Hungary
#     Success: Data is processed
# Iceland
#     Failure: There is no data for the 'state' level
# India
#     Success: Data is processed
# Indonesia
#     Success: Data is processed
# Iran
#     Success: Data is processed
# Iraq
#     Success: Data is processed
# Ireland
#     Success: Data is processed
# Isle of Man
#     Failure: There is no data for the 'state' level
# Israel
#     Success: Data is processed
# Italy
#     Success: Data is processed
# Ivory Coast
#     Success: Data is processed
# Jamaica
#     Failure: There is no data for the 'state' level
# Japan
#     Success: Data is processed
# Jersey
#     Failure: There is no data for the 'state' level
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 states_dict = {country: get_data(country, 'state') for country in countries_list}
#       2 states_plots = [get_plot(country, states, 'state') for country, states in states_dict.items() if states is not None]
#
# Cell In[6], line 1, in <dictcomp>(.0)
# ----> 1 states_dict = {country: get_data(country, 'state') for country in countries_list}
#       2 states_plots = [get_plot(country, states, 'state') for country, states in states_dict.items() if states is not None]
#
# Cell In[3], line 5, in get_data(country, level, res)
#       3     print("{0}\n    {1}".format(country, message))
#       4 try:
# ----> 5     gdf = geocode(level=level).scope(country).get_boundaries(res)
#       6     if gdf.empty:
#       7         raise Exception("Failure: There is no data for the '{0}' level".format(level))
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/site-packages/lets_plot/geo_data/geocoder.py:313, in Geocoder.get_boundaries(self, resolution)
#     241 def get_boundaries(self, resolution=None) -> 'GeoDataFrame':
#     242     """
#     243     Return boundaries for given regions in the form of `GeoDataFrame`.
#     244
#    (...)
#     311
#     312     """
# --> 313     return self._geocode().boundaries(resolution, self._inc_res)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/site-packages/lets_plot/geo_data/geocoder.py:933, in NamesGeocoder._geocode(self)
#     931 if self._geocodes is None:
#     932     request: GeocodingRequest = self._build_request()
# --> 933     response: Response = GeocodingService().do_request(request)
#     934     if not isinstance(response, SuccessResponse):
#     935         _raise_exception(response)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/site-packages/lets_plot/geo_data/gis/geocoding_service.py:30, in GeocodingService.do_request(self, request)
#      22 request_str = json.dumps(request_json)
#      24 request = urllib.request.Request(
#      25     url=get_global_str(GEOCODING_PROVIDER_URL) + GEOCODING_ROUTE,
#      26     headers={'Content-Type': 'application/json', 'Accept-Encoding': 'gzip'},
#      27     method='POST',
#      28     data=bytearray(request_str, 'utf-8')
#      29 )
# ---> 30 response = urllib.request.urlopen(request)
#      31 if response.info().get('Content-Encoding') == 'gzip':
#      32     content = response.read()
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346 try:
#    1347     try:
# -> 1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1280 def request(self, method, url, body=None, headers={}, *,
#    1281             encode_chunked=False):
#    1282     """Send a complete request to the server."""
# -> 1283     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1325 if isinstance(body, str):
#    1326     # RFC 2616 Section 3.7.1 says that text default has a
#    1327     # default charset of iso-8859-1.
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276 else:
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 msg = b"\r\n".join(self._buffer)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#    1043     if hasattr(message_body, 'read'):
#    1044         # Let file-like take precedence over byte-like.  This
#    1045         # is needed to allow the current position of mmap'ed
#    1046         # files to be taken into account.
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     974 if self.sock is None:
#     975     if self.auto_open:
# --> 976         self.connect()
#     977     else:
#     978         raise NotConnected()
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:1448, in HTTPSConnection.connect(self)
#    1445 def connect(self):
#    1446     "Connect to a host on a given (SSL) port."
# -> 1448     super().connect()
#    1450     if self._tunnel_host:
#    1451         server_hostname = self._tunnel_host
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/http/client.py:942, in HTTPConnection.connect(self)
#     940 """Connect to the host and port specified in __init__."""
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#     945 try:
#
# File ~/Applications/miniconda3/envs/lets-plot-examples/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     843 if source_address:
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#     847 err = None
#
# KeyboardInterrupt:

# %%
gggrid(states_plots, ncol=3)

# %%
counties_dict = {country: get_data(country, 'county') for country in countries_list}
counties_plots = [get_plot(country, counties, 'county') for country, counties in counties_dict.items() if counties is not None]

# %%
gggrid(counties_plots, ncol=3)
