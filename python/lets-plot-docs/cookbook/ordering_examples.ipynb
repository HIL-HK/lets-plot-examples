# %%
import numpy as np
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="z325Lu"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("z325Lu").appendChild(div);
#                     };
#                     var e = document.getElementById("z325Lu");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")

# %%
p = ggplot(mpg) + theme(axis_title_x='blank')

# %%
p1 = p + ggtitle("default") + geom_boxplot( aes('class','hwy'))

p2 = (p + ggtitle("alphabetically") 
            + geom_boxplot(aes(as_discrete('class',order=1), 'hwy')))
p3 = (p + ggtitle("middle ↑") \
                   + geom_boxplot(aes(as_discrete('class',order=1, order_by='..middle..'), 'hwy')))
p4 = (p + ggtitle("middle ↓") \
                   + geom_boxplot(aes(as_discrete('class',order=-1, order_by='..middle..'), 'hwy')))
p5 = (p + ggtitle("ymax ↑") \
                   + geom_boxplot(aes(as_discrete('class',order=1, order_by='..ymax..'), 'hwy')))
p6 = (p + ggtitle("ymax ↓") \
                   + geom_boxplot(aes(as_discrete('class',order=-1, order_by='..ymax..'), 'hwy')))
p7 = (p + ggtitle("ymin ↑") \
                   + geom_boxplot(aes(as_discrete('class',order=1, order_by='..ymin..'), 'hwy')))
p8 = (p + ggtitle("ymin ↓") \
                   + geom_boxplot(aes(as_discrete('class',order=-1, order_by='..ymin..'), 'hwy')))


w, h = 470, 300

bunch = GGBunch()

bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)
bunch.add_plot(p4, w, h, w, h)
bunch.add_plot(p5, 0, h*2, w, h)
bunch.add_plot(p6, w, h*2, w, h)
bunch.add_plot(p7, 0, h*3, w, h)
bunch.add_plot(p8, w, h*3, w, h)

bunch.show()
# Out:
#    <div id="cBWVa4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "show_legend":false,
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "show_legend":false,
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"middle ↑"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"..middle..",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "show_legend":false,
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"..middle..",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"middle ↓"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"..middle..",
# "order":-1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,

# %%
ordered_class = as_discrete('class', order=1)

p1 = (p + ggtitle("x='class', color='class'") 
            + geom_boxplot(aes('class', 'hwy', color='class'))
     )

p3 = (p + ggtitle("x=as_discrete('class', order=1), color='class'") 
            + geom_boxplot(aes(ordered_class, 'hwy', color='class'))
     )

p4 = (p + ggtitle("x=as_discrete('class', order=1), color=as_discrete('class')") 
            + geom_boxplot(aes(ordered_class, 'hwy', color=as_discrete('class')))
     )


p5 = p + ggtitle("x='class', color='drv'") + geom_boxplot(aes('class','hwy', color='drv'))

p7 = (p + ggtitle("x=as_discrete('class', order=1), color=as_discrete('drv', order=1)") 
            + geom_boxplot(aes(
                as_discrete('class', order=1), 'hwy',  
                color=as_discrete('drv', order=1)))
     )

p8 = (p + ggtitle("x=as_discrete('class', order_by='..middle..')") 
            + geom_boxplot(aes(
                as_discrete('class', order_by='..middle..', order=1), 'hwy', color='drv'))
     )


bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)
bunch.add_plot(p4, w, h, w, h)
bunch.add_plot(p5, 0, h*2, w, h)
bunch.add_plot(p7, 0, h*3, w, h)
bunch.add_plot(p8, w, h*3, w, h)
bunch.show()
# Out:
#    <div id="y10EuV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x='class', color='class'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "show_legend":false,
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x=as_discrete('class', order=1), color='class'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "show_legend":false,
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x=as_discrete('class', order=1), color=as_discrete('class')"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"class"
# },
# "aes":"color",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "x":"class",
# "y":"hwy",
# "color":"class"
# },
# "show_legend":false,
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"class"
# },
# "aes":"color",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,27.0,27.0,27.0,17.5,17.5,17.5,17.5,17.5,17.5,17.5,17.5,25.0,23.0,17.0,17.0,17.0,17.0,26.0,26.0],
# "..lower..":[26.0,26.0,26.0,26.0,26.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,24.0,22.0,16.0,16.0,16.0,16.0,24.5,24.5],
# "..upper..":[29.0,29.0,29.0,29.0,29.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,26.0,24.0,18.0,18.0,18.0,18.0,30.5,30.5],
# "..ymin..":[23.0,23.0,23.0,23.0,23.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,14.0,23.0,21.0,15.0,15.0,15.0,15.0,20.0,20.0],
# "..ymax..":[33.0,33.0,33.0,33.0,32.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,22.0,26.0,24.0,20.0,20.0,20.0,20.0,36.0,36.0],
# "class":["compact","compact","compact","compact","midsize","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","pickup","subcompact","subcompact"],
# "hwy":[35.0,37.0,35.0,44.0,NaN,12.0,12.0,25.0,24.0,27.0,25.0,26.0,23.0,NaN,17.0,12.0,12.0,12.0,22.0,44.0,41.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "

# %%
        
p1 = (ggplot(mpg, aes('class', 'hwy')) + 
         geom_crossbar(aes(color='class'), stat='boxplot') +  
         scale_color_brewer(type='qual', palette='Dark2') + 
         ggtitle('default'))

p2 = (ggplot(mpg, aes(x=as_discrete('class', order_by="..middle..", order=1), y = 'hwy')) + 
         geom_crossbar(aes(color='class'), stat='boxplot') + 
         scale_color_brewer(type='qual', palette='Dark2') +
         ggtitle('middle ↑, order option also applies to \'color\'') )

p3 = (ggplot(mpg, aes(x=as_discrete('class', order_by="..middle.."), y = 'hwy')) + 
         geom_crossbar(aes(color=as_discrete('class', order=1)), stat='boxplot') +
         scale_color_brewer(type='qual', palette='Dark2') + 
         ggtitle('\'class\' with \'order_by\' + \'class\' with \'order\': options are combined') )

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)

bunch.show()
# Out:
#    <div id="B5RtA8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"default"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "type":"qual",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"crossbar",
# "stat":"boxplot",
# "mapping":{
# "color":"class"
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[28.29787234042553,27.292682926829272,18.1290322580645,24.8,22.363636363636363,16.878787878787882,28.142857142857146]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"class"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"..middle..",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"middle ↑, order option also applies to 'color'"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "type":"qual",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"crossbar",
# "stat":"boxplot",
# "mapping":{
# "color":"class"
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[28.29787234042553,27.292682926829272,18.1290322580645,24.8,22.363636363636363,16.878787878787882,28.142857142857146]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"class"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"..middle.."
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"'class' with 'order_by' + 'class' with 'order': options are combined"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "type":"qual",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"crossbar",
# "stat":"boxplot",
# "mapping":{
# "color":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"color",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..middle..":[27.0,27.0,17.5,25.0,23.0,17.0,26.0],
# "..lower..":[26.0,26.0,17.0,24.0,22.0,16.0,24.5],
# "..upper..":[29.0,29.0,19.0,26.0,24.0,18.0,30.5],
# "..ymin..":[23.0,23.0,14.0,23.0,21.0,15.0,20.0],
# "..ymax..":[33.0,32.0,22.0,26.0,24.0,20.0,36.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[28.29787234042553,27.292682926829272,18.1290322580645,24.8,22.363636363636363,16.878787878787882,28.142857142857146]
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("B5RtA8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
p1 = (p + ggtitle("default") + geom_bar(aes('class', 'hwy')))

p2 = (p + ggtitle("alphabetically") 
               + geom_bar(aes(as_discrete('class', order=1), 'hwy')))


p3 = (p + ggtitle("y ↓") 
               + geom_bar(aes(as_discrete('class', order_by='hwy'), 'hwy')))
p4 = (p + ggtitle("y ↑") 
               + geom_bar(aes(as_discrete('class', order_by='hwy', order=1), 'hwy')))

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)
bunch.add_plot(p4, w, h, w, h)
bunch.show()
# Out:
#    <div id="8Ivggz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# },
# "data":{
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"y ↓"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"hwy"
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"y ↑"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order_by":"hwy",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"],
# "hwy":[47.0,41.0,62.0,5.0,11.0,33.0,35.0]
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("8Ivggz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# geom_bar

p1 = (p + ggtitle("default") + geom_bar(aes('manufacturer', fill='class')))

p2 = (p + ggtitle("x alphabetically") 
               + geom_bar(aes(as_discrete('manufacturer', order=1), fill='class')))


p3 = (p + ggtitle("x alphabetically + sampling_pick(4)") 
               + geom_bar(aes(as_discrete('manufacturer', order=1), fill='class'), 
                         sampling=sampling_pick(4)))

p4 = (p + ggtitle("fill alphabetically") 
               + geom_bar(aes('manufacturer', fill=as_discrete('class',order=1))))

p5 = (p + ggtitle("x and fill alphabetically") 
               + geom_bar(aes(as_discrete('manufacturer', order=1), fill=as_discrete('class',order=1))))

p6 = (p + ggtitle("x by count (sum is taken)") 
               + geom_bar(aes(as_discrete('manufacturer',order_by='..count..'), fill='class')))

p7 = (p + ggtitle("x by count + sampling_pick(4)") 
               + geom_bar(aes(as_discrete('manufacturer',order_by='..count..'), fill='class'),
                             sampling=sampling_pick(4)))

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, 0, h, w, h)
bunch.add_plot(p3, w, h, w, h)
bunch.add_plot(p4, 0, h*2, w, h)
bunch.add_plot(p5, w, h*2, w, h)
bunch.add_plot(p6, 0, h*3, w, h)
bunch.add_plot(p7, w, h*3, w, h)
bunch.show()
# Out:
#    <div id="eqCBNg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"manufacturer",
# "fill":"class"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
# "manufacturer":["audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota","chevrolet","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen"],
# "class":["compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"manufacturer",
# "fill":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"manufacturer",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0,5.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0],
# "manufacturer":["audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota","chevrolet","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen"],
# "class":["compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv","2seater","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x alphabetically + sampling_pick(4)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"manufacturer",
# "fill":"class"
# },
# "sampling":{
# "name":"pick",
# "n":4.0
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"manufacturer",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[15.0,3.0,5.0,9.0,7.0,9.0,5.0,11.0,19.0,7.0,9.0],
# "manufacturer":["audi","audi","chevrolet","chevrolet","dodge","ford","chevrolet","dodge","dodge","ford","ford"],
# "class":["compact","midsize","midsize","suv","suv","suv","2seater","minivan","pickup","pickup","subcompact"]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_pick(n=4) was applied to [bar/count stat] layer"]
# }
# },{
# "x":0.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"fill alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"manufacturer",
# "fill":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[5.0,15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0],
# "manufacturer":["chevrolet","audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota"],
# "class":["2seater","compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","midsize","midsize","midsize","minivan","pickup","pickup","pickup","subcompact","subcompact","subcompact","subcompact","subcompact","suv","suv","suv","suv","suv","suv","suv","suv","suv","suv"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "axis_title_x":"blank"
# },
# "ggtitle":{
# "text":"x and fill alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"manufacturer",
# "fill":"class"
# },
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"manufacturer",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"class",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[5.0,15.0,2.0,4.0,12.0,14.0,3.0,5.0,7.0,7.0,5.0,7.0,7.0,11.0,19.0,7.0,7.0,9.0,9.0,7.0,4.0,6.0,9.0,7.0,9.0,8.0,4.0,3.0,4.0,4.0,6.0,8.0],
# "manufacturer":["chevrolet","audi","nissan","subaru","toyota","volkswagen","audi","chevrolet","hyundai","nissan","pontiac","toyota","volkswagen","dodge","dodge","ford","toyota","ford","honda","hyundai","subaru","volkswagen","chevrolet","dodge","ford","jeep","land rover","lincoln","mercury","nissan","subaru","toyota"],
# "class":["2seater","compact","compact","compact","compact","compact","midsize","midsize","midsize","midsize","m

# %%
pp = ggplot(mpg, aes(x='fl', fill='drv'))
p1 = pp + geom_bar() + ggtitle('Default')
p2 = pp + geom_bar(position='dodge') + ggtitle("With Dodge Position")

p_order1 = ggplot(mpg, aes(x=as_discrete('fl',order=1), fill=as_discrete('drv',order=1)))
title1 = ggtitle('x and fill alphabetically')
p3 = p_order1 + geom_bar() + title1
p4 = p_order1 + geom_bar(position='dodge') + title1

p_order2 = ggplot(mpg, aes(x=as_discrete('fl',order_by="..count.."), fill='drv'))
title2 = ggtitle('x by count')
p5 = p_order2 + geom_bar() + title2
p6 = p_order2 + geom_bar(position='dodge') + title2


bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)
bunch.add_plot(p4, w, h, w, h)
bunch.add_plot(p5, 0, h*2, w, h)
bunch.add_plot(p6, w, h*2, w, h)
bunch.show()
# Out:
#    <div id="iZ7bVJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
# "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"With Dodge Position"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
# "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"class"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"fl",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"drv",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"x and fill alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[20.0,75.0,6.0,2.0,25.0,76.0,1.0,1.0,3.0,17.0,1.0,7.0],
# "fl":["p","r","e","d","p","r","e","c","d","r","e","p"],
# "drv":["4","4","4","4","f","f","f","f","f","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"class"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"fl",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"drv",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"x and fill alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# "..count..":[20.0,75.0,6.0,2.0,25.0,76.0,1.0,1.0,3.0,17.0,1.0,7.0],
# "fl":["p","r","e","d","p","r","e","c","d","r","e","p"],
# "drv":["4","4","4","4","f","f","f","f","f","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"fl"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"class"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"fl",
# "order_by":"..count.."
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"x by count"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
# "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"fl",
# "fill":"drv"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"fl"
# },{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"class"
# }],
# "mapping_annotations":[{
# "parameters":{
# "label":"fl",
# "order_by":"..count.."
# },
# "aes":"x",
# "annotation":"as_discrete"
# }]
# },
# "ggtitle":{
# "text":"x by count"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# "..count..":[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# "fl":["p","r","e","c","d","p","r","e","d","r","e","p"],
# "drv":["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("iZ7bVJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# diamonds

diamonds = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv')

# %%
pd = ggplot(diamonds)

p1 = pd + geom_bar(aes('cut', fill = 'clarity')) + ggtitle('Default')
p2 = pd + geom_bar(aes('cut', fill = 'clarity'), position = 'fill') + ggtitle('position=\'fill\'')

p3 = pd + ggtitle('x and fill alphabetically') \
   + geom_bar(aes(as_discrete('cut',order=1), fill = as_discrete('clarity',order=1)), position = 'fill') 
p4 = pd + ggtitle('x by count') \
        + geom_bar(aes(as_discrete('cut',order_by='..count..'), 
                       fill = as_discrete('clarity',order=1)),
                   position = 'fill')

p5 = pd + geom_bar(aes('cut', fill = 'clarity'), position = 'dodge') + ggtitle('position=\'dodge\'')
p6 = pd + ggtitle('x by count and fill alphabetically') \
        + geom_bar(aes(as_discrete('cut',order_by='..count..', order=1),
                      fill = as_discrete('clarity',order=1)),
                   position = 'dodge')


bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.add_plot(p3, 0, h, w, h)
bunch.add_plot(p4, w, h, w, h)
bunch.add_plot(p5, 0, h*2, w, h)
bunch.add_plot(p6, w, h*2, w, h)
bunch.show()
# Out:
#    <div id="0L1Dcb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"rownames"
# },{
# "type":"float",
# "column":"carat"
# },{
# "type":"str",
# "column":"cut"
# },{
# "type":"str",
# "column":"color"
# },{
# "type":"str",
# "column":"clarity"
# },{
# "type":"float",
# "column":"depth"
# },{
# "type":"float",
# "column":"table"
# },{
# "type":"int",
# "column":"price"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut",
# "fill":"clarity"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0],
# "cut":["Ideal","Good","Premium","Very Good","Fair","Premium","Very Good","Good","Ideal","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair","Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good"],
# "clarity":["SI2","SI2","SI2","SI2","SI2","SI1","SI1","SI1","SI1","SI1","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS2","VVS2","VVS2","VVS2","VVS2","VVS1","VVS1","VVS1","VVS1","VVS1","I1","I1","I1","I1","I1","IF","IF","IF","IF","IF"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":0.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"rownames"
# },{
# "type":"float",
# "column":"carat"
# },{
# "type":"str",
# "column":"cut"
# },{
# "type":"str",
# "column":"color"
# },{
# "type":"str",
# "column":"clarity"
# },{
# "type":"float",
# "column":"depth"
# },{
# "type":"float",
# "column":"table"
# },{
# "type":"int",
# "column":"price"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# "ggtitle":{
# "text":"position='fill'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut",
# "fill":"clarity"
# },
# "position":"fill",
# "data_meta":{
# },
# "data":{
# "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0],
# "cut":["Ideal","Good","Premium","Very Good","Fair","Premium","Very Good","Good","Ideal","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair","Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good"],
# "clarity":["SI2","SI2","SI2","SI2","SI2","SI1","SI1","SI1","SI1","SI1","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS2","VVS2","VVS2","VVS2","VVS2","VVS1","VVS1","VVS1","VVS1","VVS1","I1","I1","I1","I1","I1","IF","IF","IF","IF","IF"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"rownames"
# },{
# "type":"float",
# "column":"carat"
# },{
# "type":"str",
# "column":"cut"
# },{
# "type":"str",
# "column":"color"
# },{
# "type":"str",
# "column":"clarity"
# },{
# "type":"float",
# "column":"depth"
# },{
# "type":"float",
# "column":"table"
# },{
# "type":"int",
# "column":"price"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# "ggtitle":{
# "text":"x and fill alphabetically"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut",
# "fill":"clarity"
# },
# "position":"fill",
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"cut",
# "order":1.0
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"clarity",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0,3575.0,3240.0,1560.0,4282.0,408.0,2598.0,1081.0,2949.0,2100.0,466.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,789.0,2047.0,616.0,186.0,17.0,1235.0,2606.0,870.0,286.0,69.0],
# "cut":["Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good","Premium","Very Good","Good","Ideal","Fair","Ideal","Good","Premium","Very Good","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair"],
# "clarity":["I1","I1","I1","I1","I1","IF","IF","IF","IF","IF","SI1","SI1","SI1","SI1","SI1","SI2","SI2","SI2","SI2","SI2","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS1","VVS1","VVS1","VVS1","VVS1","VVS2","VVS2","VVS2","VVS2","VVS2"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":470.0,
# "y":300.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"rownames"
# },{
# "type":"float",
# "column":"carat"
# },{
# "type":"str",
# "column":"cut"
# },{
# "type":"str",
# "column":"color"
# },{
# "type":"str",
# "column":"clarity"
# },{
# "type":"float",
# "column":"depth"
# },{
# "type":"float",
# "column":"table"
# },{
# "type":"int",
# "column":"price"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# "ggtitle":{
# "text":"x by count"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut",
# "fill":"clarity"
# },
# "position":"fill",
# "data_meta":{
# "mapping_annotations":[{
# "parameters":{
# "label":"cut",
# "order_by":"..count.."
# },
# "aes":"x",
# "annotation":"as_discrete"
# },{
# "parameters":{
# "label":"clarity",
# "order":1.0
# },
# "aes":"fill",
# "annotation":"as_discrete"
# }]
# },
# "data":{
# "..count..":[205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0,3575.0,3240.0,1560.0,4282.0,408.0,2598.0,1081.0,2949.0,2100.0,466.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,789.0,2047.0,616.0,186.0,17.0,1235.0,2606.0,870.0,286.0,69.0],
# "cut":["Premium","Very Good","Fair","Ideal","Good","Ideal","Premium","Very Good","Fair","Good","Premium","Very Good","Good","Ideal","Fair","Ideal","Good","Premium","Very Good","Fair","Good","Very Good","Ideal","Premium","Fair","Premium","Fair","Very Good","Good","Ideal","Very Good","Ideal","Premium","Good","Fair","Very Good","Ideal","Premium","Good","Fair"],
# "clarity":["I1","I1","I1","I1","I1","IF","IF","IF","IF","IF","SI1","SI1","SI1","SI1","SI1","SI2","SI2","SI2","SI2","SI2","VS1","VS1","VS1","VS1","VS1","VS2","VS2","VS2","VS2","VS2","VVS1","VVS1","VVS1","VVS1","VVS1","VVS2","VVS2","VVS2","VVS2","VVS2"]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":600.0,
# "width":470.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"rownames"
# },{
# "type":"float",
# "column":"carat"
# },{
# "type":"str",
# "column":"cut"
# },{
# "type":"str",
# "column":"color"
# },{
# "type":"str",
# "column":"clarity"
# },{
# "type":"float",
# "column":"depth"
# },{
# "type":"float",
# "column":"table"
# },{
# "type":"int",
# "column":"price"
# },{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# "ggtitle":{
# "text":"position='dodge'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cut",
# "fill":"clarity"
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# "..count..":[2598.0,1081.0,2949.0,2100.0,466.0,3575.0,3240.0,1560.0,4282.0,408.0,648.0,1775.0,3589.0,1989.0,170.0,3357.0,261.0,2591.0,978.0,5071.0,1235.0,2606.0,870.0,286.0,69.0,789.0,2047.0,616.0,186.0,17.0,205.0,84.0,210.0,146.0,96.0,1212.0,230.0,268.0,9.0,71.0],
# "
