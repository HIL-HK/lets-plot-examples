# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="ORzwsL"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("ORzwsL").appendChild(div);
#                     };
#                     var e = document.getElementById("ORzwsL");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
from lets_plot.geo_data import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %% [markdown]
# ### Sweden and Finland

# %% [markdown]
# #### Create countries geocoder.

# %%
country_gcoder = geocode_countries(['Finland', 'Sweden'])
country_gcoder.get_geocodes()
# Out:
#       id  country found name                              centroid  \
# 0  54224  Finland    Finland  [27.5426266740774, 64.9500560760498]
# 1  52822   Sweden     Sweden  [14.8960665316738, 62.1977656334639]
#
#                                             position  \
# 0  [20.5486419796944, 59.8079609870911, 31.586707...
# 1  [11.1130450665951, 55.3366836905479, 24.152978...
#
#                                                limit
# 0  [19.3040004372597, 59.7582100331783, 31.586707...
# 1  [10.9653197228909, 55.3366836905479, 24.166640...

# %%
map_options = theme_void() + coord_map()

# %% [markdown]
# #### Plot  boundary polygons.

# %%
(ggplot() + 
 geom_polygon(aes(fill='found name'), 
              data=country_gcoder.get_boundaries(),
              tooltips=layer_tooltips().line("^fill"),
              color="white") +
 map_options + 
 scale_fill_hue(name="Country"))
# Out:
#    <div id="mNvgsk"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("mNvgsk");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "coord":{
# "name":"map",
# "flip":false
# },
# "kind":"plot",
# "scales":[{
# "name":"Country",
# "aesthetic":"fill",
# "scale_mapper_kind":"color_hue"
# }],
# "layers":[{
# "geom":"polygon",
# "data":{
# "found name":["Finland","Sweden"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[19.537953436, 60.240034014], [19.68530193, 60.212172568], [19.547176212, 60.14621973], [19.537953436, 60.240034014]]], [[[19.876678884, 60.427848995], [20.275000334, 60.285749584], [20.166964978, 60.17497167], [19.975499511, 60.299250484], [20.054748058, 60.11462599], [19.980865627, 60.073804818], [20.22312507, 60.08263126], [20.179602206, 59.968582392], [19.977556651, 60.071976559], [19.956429005, 60.060303211], [19.750499725, 60.093999803], [19.68794927, 60.261360258], [19.803749621, 60.323000103], [19.819983691, 60.20110175], [19.876678884, 60.427848995]]], [[[21.201046407, 63.179045767], [21.083919704, 63.307897747], [21.456010491, 63.245109916], [21.201046407, 63.179045767]]], [[[21.790844053, 60.397922248], [21.937886775, 60.443366915], [22.049437165, 60.352198631], [21.790844053, 60.397922248]]], [[[23.027961999, 59.910013676], [22.814837694, 59.979776591], [23.265607059, 60.062167346], [22.883348325, 60.16052678], [22.78343305, 60.017721802], [22.49955073, 60.016078949], [22.365066111, 60.089276433], [22.618820518, 60.150737911], [22.413321733, 60.160884708], [22.465958744, 60.237451047], [22.544550832, 60.247407639], [22.64600873, 60.405339897], [22.205429453, 60.442482496], [22.019981393, 60.458116511], [21.742659509, 60.481495857], [21.76874872, 60.521640334], [21.843540072, 60.636724681], [21.584244221, 60.648337305], [21.718055606, 60.592185259], [21.586015821, 60.491070002], [21.327779442, 60.697368085], [21.472941935, 60.705546141], [21.380757093, 60.835106224], [21.179328561, 60.859512985], [21.287373304, 61.009342521], [21.439910531, 60.912033319], [21.297768205, 61.087078303], [21.492154598, 61.0732086], [21.438357532, 61.193260252], [21.611732841, 61.229930073], [21.447092146, 61.430051029], [21.600116193, 61.445131749], [21.450061351, 61.508867741], [21.63378194, 61.514055133], [21.46118179, 61.59922868], [21.679068357, 61.562695652], [21.279176474, 61.993211657], [21.430356503, 62.21956864], [21.308360249, 62.256341726], [21.366074681, 62.370994091], [21.111486107, 62.489811927], [21.223032475, 62.607918978], [21.056767702, 62.624430656], [21.466551572, 63.056374937], [21.684491783, 63.052564859], [21.539687365, 63.267450035], [21.644858875, 63.267126997], [21.984606832, 63.266083449], [22.003828883, 63.158474565], [22.364777774, 63.289425373], [22.203188092, 63.474343568], [22.402940243, 63.43827188], [22.323025167, 63.581896126], [22.447055876, 63.475370854], [22.519173771, 63.595938832], [22.428193241, 63.60369578], [22.754496038, 63.717472404], [22.699284106, 63.841275126], [22.939017266, 63.892042637], [22.940961868, 63.769218922], [23.072195649, 63.917188346], [23.370506912, 63.912232965], [23.397044688, 64.083108455], [23.618630022, 64.045565575], [23.685501516, 64.219697267], [24.370946735, 64.545239657], [24.541885257, 64.818111509], [25.097660422, 64.921841919], [25.313213468, 64.830035269], [25.39443478, 64.895392656], [25.191768408, 65.008903742], [25.487118512, 64.959533662], [25.226920098, 65.127637088], [25.352572203, 65.229531527], [25.259133428, 65.410658419], [25.365047157, 65.42614013], [25.182058811, 65.590894818], [24.144143164, 65.841332674], [23.64561975, 66.301390529], [23.995662779, 66.822048873], [23.552376777, 67.170384675], [23.762714267, 67.430317551], [23.394422829, 67.484276891], [23.559286147, 67.619676143], [23.479069322, 67.842778265], [23.651196063, 67.96070829], [22.844843566, 68.382964432], [22.043957412, 68.47957626], [20.54864198, 69.059970081], [21.057542861, 69.036290199], [21.003312618, 69.222337604], [21.627085805, 69.276587963], [22.374522239, 68.716666102], [23.167581707, 68.628519326], [23.871460408, 68.836519271], [24.9031654, 68.554592282], [25.157126337, 68.799892366], [25.774641931, 69.013480693], [25.701685846, 69.250467271], [25.971235782, 69.707112014], [26.486687958, 69.944331944], [27.039759457, 69.910558909], [27.955634594, 70.092293322], [28.404226005, 69.81842503], [29.133908898, 69.6953 ...

# %% [markdown]
# #### Plot ploygons on interactive base-map.
#
# Note: *nbviewer* won't load base-map tiles due to its CSP.

# %%
(ggplot() + geom_livemap() + 
 geom_polygon(aes(fill='found name'), 
              data=country_gcoder.get_boundaries(),
              tooltips=layer_tooltips().line("^fill"),
              color="white") +
 scale_fill_hue(name="Country"))
# Out:
#    <div id="Otj5a7"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Otj5a7");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "name":"Country",
# "aesthetic":"fill",
# "scale_mapper_kind":"color_hue"
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "data":{
# "found name":["Finland","Sweden"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[19.537953436, 60.240034014], [19.68530193, 60.212172568], [19.547176212, 60.14621973], [19.537953436, 60.240034014]]], [[[19.876678884, 60.427848995], [20.275000334, 60.285749584], [20.166964978, 60.17497167], [19.975499511, 60.299250484], [20.054748058, 60.11462599], [19.980865627, 60.073804818], [20.22312507, 60.08263126], [20.179602206, 59.968582392], [19.977556651, 60.071976559], [19.956429005, 60.060303211], [19.750499725, 60.093999803], [19.68794927, 60.261360258], [19.803749621, 60.323000103], [19.819983691, 60.20110175], [19.876678884, 60.427848995]]], [[[21.201046407, 63.179045767], [21.083919704, 63.307897747], [21.456010491, 63.245109916], [21.201046407, 63.179045767]]], [[[21.790844053, 60.397922248], [21.937886775, 60.443366915], [22.049437165, 60.352198631], [21.790844053, 60.397922248]]], [[[23.027961999, 59.910013676], [22.814837694, 59.979776591], [23.265607059, 60.062167346], [22.883348325, 60.16052678], [22.78343305, 60.017721802], [22.49955073, 60.016078949], [22.365066111, 60.089276433], [22.618820518, 60.150737911], [22.413321733, 60.160884708], [22.465958744, 60.237451047], [22.544550832, 60.247407639], [22.64600873, 60.405339897], [22.205429453, 60.442482496], [22.019981393, 60.458116511], [21.742659509, 60.481495857], [21.76874872, 60.521640334], [21.843540072, 60.636724681], [21.584244221, 60.648337305], [21.718055606, 60.592185259], [21.586015821, 60.491070002], [21.327779442, 60.697368085], [21.472941935, 60.705546141], [21.380757093, 60.835106224], [21.179328561, 60.859512985], [21.287373304, 61.009342521], [21.439910531, 60.912033319], [21.297768205, 61.087078303], [21.492154598, 61.0732086], [21.438357532, 61.193260252], [21.611732841, 61.229930073], [21.447092146, 61.430051029], [21.600116193, 61.445131749], [21.450061351, 61.508867741], [21.63378194, 61.514055133], [21.46118179, 61.59922868], [21.679068357, 61.562695652], [21.279176474, 61.993211657], [21.430356503, 62.21956864], [21.308360249, 62.256341726], [21.366074681, 62.370994091], [21.111486107, 62.489811927], [21.223032475, 62.607918978], [21.056767702, 62.624430656], [21.466551572, 63.056374937], [21.684491783, 63.052564859], [21.539687365, 63.267450035], [21.644858875, 63.267126997], [21.984606832, 63.266083449], [22.003828883, 63.158474565], [22.364777774, 63.289425373], [22.203188092, 63.474343568], [22.402940243, 63.43827188], [22.323025167, 63.581896126], [22.447055876, 63.475370854], [22.519173771, 63.595938832], [22.428193241, 63.60369578], [22.754496038, 63.717472404], [22.699284106, 63.841275126], [22.939017266, 63.892042637], [22.940961868, 63.769218922], [23.072195649, 63.917188346], [23.370506912, 63.912232965], [23.397044688, 64.083108455], [23.618630022, 64.045565575], [23.685501516, 64.219697267], [24.370946735, 64.545239657], [24.541885257, 64.818111509], [25.097660422, 64.921841919], [25.313213468, 64.830035269], [25.39443478, 64.895392656], [25.191768408, 65.008903742], [25.487118512, 64.959533662], [25.226920098, 65.127637088], [25.352572203, 65.229531527], [25.259133428, 65.410658419], [25.365047157, 65.42614013], [25.182058811, 65.590894818], [24.144143164, 65.841332674], [23.64561975, 66.301390529], [23.995662779, 66.822048873], [23.552376777, 67.170384675], [23.762714267, 67.430317551], [23.394422829, 67.484276891], [23.559286147, 67.619676143], [23.479069322, 67.842778265], [23.651196063, 67.96070829], [22.844843566, 68.382964432], [22.043957412, 68.47957626], [20.54864198, 69.059970081], [21.057542861, 69.036290199], [21.003312618, 69.222337604], [21.627085805, 69.276587963], [22.374522239, 68.716666102], [23.167581707, 68.628519326], [23.871460408, 68.836519271], [24.9031654, 68.554592282], [25.157126337, 68.799892366], [25.774641931, 69.013480693], [25.701685846, 69.250467271], [25.971235782, 69.707112014], [26.486687958, 69.944331944], [27.039759457, 69.910558909], [27.955634594, 70.092293322], [28.404226005, 69.81842503], [29.133908898, 69.6953 ...

# %% [markdown]
# ### The World

# %% [markdown]
# #### Create countries geocoder.

# %%
world_gcoder = geocode_countries()
world_gcoder.get_geocodes().head(3)
# Out:
#       id   country found name                              centroid  \
# 0   9407   Andorra    Andorra   [1.58972340139334, 42.542395144701]
# 1  14296  Slovakia   Slovakia  [19.6367939386235, 48.6726971715689]
# 2  16239   Austria    Austria  [14.7548074169977, 47.6964113116264]
#
#                                             position  \
# 0  [1.41357779502869, 42.4288237094879, 1.7866636...
# 1  [16.8331897258759, 47.7314288914204, 22.565710...
# 2  [9.5307482779026, 46.3722757995129, 17.1607759...
#
#                                                limit
# 0  [1.41357779502869, 42.4288237094879, 1.7866636...
# 1  [16.8331897258759, 47.7314288914204, 22.565710...
# 2  [9.5307482779026, 46.3722757995129, 17.1607759...

# %% [markdown]
# #### World choropleth.

# %%
(ggplot() + 
 geom_polygon(aes(fill='found name'), 
              data=world_gcoder.get_boundaries(), 
              color="white", 
              tooltips=layer_tooltips().line("^fill"),
              show_legend=False) +
 map_options +
 scale_fill_brewer(name="Country", palette="Dark2") + 
 ggsize(900, 600))
# Out:
#    <div id="zokXth"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("zokXth");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "coord":{
# "name":"map",
# "flip":false
# },
# "ggsize":{
# "width":900.0,
# "height":600.0
# },
# "kind":"plot",
# "scales":[{
# "name":"Country",
# "aesthetic":"fill",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"polygon",
# "data":{
# "found name":["Andorra","Slovakia","Austria","Hungary","Georgia","Vatican City","Poland","Cambodia","Laos","Vietnam","Denmark","Myanmar","Germany","Czech Republic","Switzerland","Belgium","Sweden","Faroe Islands","Albania","North Macedonia","Montenegro","Finland","San Marino","Moldova","Belarus","Brazil","Russia","Ukraine","United Kingdom","Isle of Man","Ireland","Latvia","Lithuania","Estonia","Australia","South Africa","Eswatini","Romania","Ecuador","Mexico","Colombia","United States","Mongolia","Chile","Rwanda","Turkey","Kyrgyzstan","Bhutan","Nepal","Bangladesh","Jordan","Syria","Lebanon","Bulgaria","Greece","North Korea","Algeria","Tunisia","Libya","Mauritania","The Gambia","Senegal","Guinea-Bissau","Sierra Leone","Guinea","Ivory Coast","Liberia","Ghana","Togo","Burkina Faso","Benin","Mali","Niger","Nigeria","Sudan","Central African Republic","Equatorial Guinea","Gabon","Congo-Brazzaville","Democratic Republic of the Congo","Uganda","Kenya","Somalia","Ethiopia","Djibouti","Cameroon","Namibia","Angola","Burundi","Tanzania","Zambia","Zimbabwe","Mozambique","Malawi","Uzbekistan","Tajikistan","Kazakhstan","Croatia","Slovenia","Turkmenistan","Bolivia","Guernsey","China","Venezuela","British Virgin Islands","Argentina","Uruguay","Paraguay","Suriname","Guyana","Nicaragua","Costa Rica","Panama","Honduras","Belize","Peru","Portugal","Eritrea","Iceland","Afghanistan","India","Indonesia","Iraq","Iran","Yemen","Qatar","Kuwait","Oman","East Timor","Pakistan","Saudi Arabia","South Korea","United Arab Emirates","Cyprus","Dominica","Dominican Republic","Haiti","Cuba","Papua New Guinea","Armenia","Azerbaijan","Malta","Italy","Jersey","Bahrain","Japan","Philippines","Madagascar","Taiwan","Cape Verde","Comoros","Mauritius","São Tomé and Príncipe","Seychelles","Maldives","Singapore","Sri Lanka","Saint Kitts and Nevis","Antigua and Barbuda","Montserrat","The Bahamas","Turks and Caicos Islands","Barbados","Saint Vincent and the Grenadines","Grenada","Saint Lucia","Jamaica","Trinidad and Tobago","New Zealand","Kiribati","Fiji","Marshall Islands","Federated States of Micronesia","Nauru","Palau","Monaco","Liechtenstein","Gibraltar","Spain","Canada","Israel","Egypt","El Salvador","Guatemala","Niue","South Sudan","Palestine","Serbia","Solomon Islands","Samoa","Botswana","Saint Helena, Ascension and Tristan da Cunha","South Georgia and the South Sandwich Islands","Bermuda","British Indian Ocean Territory","Thailand","Kosovo","Lesotho","Brunei","Malaysia","Luxembourg","Anguilla","Vanuatu","Tuvalu","Greenland","Cook Islands","Cayman Islands","Falkland Islands","Pitcairn Islands","Tokelau","Tonga","France","Netherlands","Chad","Bosnia and Herzegovina","Norway","Morocco","Sahrawi Arab Democratic Republic"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[1.725891531, 42.502698451], [1.413577795, 42.535377145], [1.441990435, 42.603722513], [1.725891531, 42.502698451]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.940195113, 48.616540432], [18.850906938, 49.517148435], [22.565710098, 49.087994993], [22.155255675, 48.403387964], [20.54649353, 48.54429245], [18.646086752, 47.759091854], [17.160775959, 48.006657064], [16.940195113, 48.616540432]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[9.607054442, 47.060772032], [9.530748278, 47.270581126], [9.550565779, 47.537175268], [10.454439372, 47.555796504], [13.006620258, 47.464384139], [12.758125663, 48.126069009], [13.839552104, 48.771617711], [16.940195113, 48.616540432], [17.160775959, 48.006657064], [16.113886982, 46.869059801], [13.714062274, 46.522985101], [12.185959518, 47.09214583], [10.469654202, 46.85491249], [9.607054442, 47.060772032]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.113886982, 46.869059801], [17.160775959, 48.006657064], [18.646086752, 47.759091854], [20.54649353, 48.54429245], [22.155255675, 48.403387964], [22.897709906, 47.95404017], [21.180593222, 46.304115504], [20.264275521, 46.126353443], [18.890209347, 45.922052264], [17.86203146, 45.767734051], [16.596770436, 46.475902945], [16.113886982, 46.869059801]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[41.547048837, 41.520685405], [41.439710855, 42.738699317], [40.008500218, 43.385607898], [45.158373713, 42.707530707], [46.422069669, 41.908043325], [46.631185412, 41.097776145], [45.0138174, 41.296466142], [43.474144936, 41.12303853], [41.547048837, 41.520685405]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[12.445743531, 41.901960075], [12.457656562, 41.905821115], [12.446459681, 41.901663691], [12.445743531, 41.901960075]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[14.267430156, 53.697997481], [14.606995136, 53.401023299], [14.724173748, 54.008663276], [14.727052152, 54.023589492], [17.353460491, 54.749242365], [19.638423622, 54.458674639], [19.648877531, 54.453256577], [19.224144369, 54.335435182], [19.803781807, 54.442411065], [22.792006731, 54.363324791], [23.514977396, 53.956268728], [23.938640356, 52.712915987], [23.178334683, 52.283141613], [23.617829382, 51.507983208], [24.070104808, 50.503388643], [22.565710098, 49.087994993], [18.850906938, 49.517148435], [17.713032067, 50.322559476], [16.689307988, 50.098467618], [16.343080401, 50.661508888], [14.823359549, 50.870568305], [14.267430156, 53.697997481]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[102.909258753, 11.650609374], [102.340085953, 13.559656888], [103.168813437, 14.334851503], [105.206471533, 14.343339354], [106.105346829, 13.909675777], [106.001334786, 14.371697009], [107.556612343, 14.686085433], [107.543897331, 12.350877821], [105.809729844, 11.618715227], [106.190949529, 10.788906813], [105.082874, 10.956653506], [104.438729435, 10.422834903], [103.565179557, 10.538879335], [103.553743958, 11.167402714], [103.121870756, 10.871128589], [102.909258753, 11.650609374]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[105.206471533, 14.343339354], [105.636286139, 15.655733496], [104.736716151, 16.541755646], [104.721579105, 17.506719232], [103.405734301, 18.448610455], [101.109918952, 17.479941398], [101.28764078, 19.568919539], [100.513037592, 19.523327351], [100.578495562, 20.167793781], [100.084652603, 20.352274776], [101.147455126, 21.561965793], [101.840359569, 21.207006276], [101.549634933, 22.246204019], [102.144409418, 22.39975512], [103.113404363, 20.897184312], [104.639554471, 20.669311881], [104.830963612, 19.791356474], [103.875756562, 19.305671453], [105.133899003, 18.716703951], [107.452609688, 16.08805865], [107.556612343, 14.686085433], [106.001334786, 14.371697009], [106.105346829, 13.909675777], [105.206471533, 14.343339354]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[102.144409418, 22.39975512], [102.48469457, 22 ...

# %% [markdown]
# ### New York State and New York City.

# %%
(ggplot() + 
 geom_polygon(map=geocode_states("New York"), fill="#01327A") +
 geom_polygon(map=geocode_cities("New York"), fill="#F2C010") +
 map_options)
# Out:
#    <div id="vZnkw1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("vZnkw1");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "coord":{
# "name":"map",
# "flip":false
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"polygon",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "state":["New York"],
# "found name":["New York"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-74.07221809, 40.624639839], [-74.052254409, 40.599785149], [-74.0733473, 40.578297973], [-74.136368483, 40.529493839], [-74.140301943, 40.535472482], [-74.127431363, 40.542025119], [-74.133059978, 40.546819568], [-74.217251837, 40.503626615], [-74.247838408, 40.49608022], [-74.255678505, 40.507649928], [-74.23987627, 40.520106107], [-74.246163368, 40.5456689], [-74.21196118, 40.558577031], [-74.196900576, 40.596484691], [-74.201560915, 40.622630864], [-74.194627404, 40.637400448], [-74.179200679, 40.645139962], [-74.153993279, 40.637066513], [-74.071540833, 40.645186901], [-74.07221809, 40.624639839]]], [[[-74.017211348, 40.665104985], [-74.019072801, 40.671586543], [-74.016650485, 40.665303188], [-74.017211348, 40.665104985]]], [[[-74.016650485, 40.665303188], [-74.015246175, 40.665799455], [-74.016503245, 40.664921254], [-74.016650485, 40.665303188]]], [[[-74.010331482, 40.669232905], [-74.019279331, 40.679611713], [-73.99435088, 40.704430193], [-73.970766217, 40.699981749], [-73.974616528, 40.707703829], [-73.967497945, 40.70344314], [-73.957937211, 40.724568218], [-73.958456218, 40.747105479], [-73.936329335, 40.777014792], [-73.909719139, 40.79091534], [-73.890133649, 40.77361241], [-73.869363964, 40.785717219], [-73.872550428, 40.780820847], [-73.851281852, 40.765325725], [-73.862612844, 40.766854584], [-73.858961016, 40.762100369], [-73.83821547, 40.764337331], [-73.840566427, 40.753751993], [-73.836438507, 40.76311022], [-73.858982474, 40.785194188], [-73.853583187, 40.794139355], [-73.839064389, 40.797062963], [-73.831426799, 40.788557678], [-73.819669336, 40.800925344], [-73.792707771, 40.788793713], [-73.777918071, 40.796753168], [-73.753186762, 40.764545202], [-73.754952997, 40.777622312], [-73.746200949, 40.783237517], [-73.764878511, 40.813231319], [-73.753459007, 40.821509957], [-73.753613234, 40.838131607], [-73.719998449, 40.820463896], [-73.709340692, 40.793432593], [-73.699370921, 40.833708644], [-73.70595172, 40.839940757], [-73.709523082, 40.833487362], [-73.70942384, 40.841394514], [-73.727817088, 40.832747072], [-73.737672865, 40.847744644], [-73.727318197, 40.856308937], [-73.730387986, 40.865990371], [-73.714021146, 40.871201903], [-73.675638735, 40.857165903], [-73.649851978, 40.82780242], [-73.657268286, 40.825668722], [-73.649538159, 40.800657123], [-73.644090593, 40.822821558], [-73.65308404, 40.848356187], [-73.635617495, 40.861724317], [-73.652050048, 40.857057273], [-73.654478788, 40.878713429], [-73.633345664, 40.902882814], [-73.617892116, 40.898146033], [-73.570406288, 40.915509313], [-73.547553867, 40.908952653], [-73.521974981, 40.918149948], [-73.507725745, 40.90122655], [-73.517208695, 40.900596231], [-73.519845307, 40.886499882], [-73.532970697, 40.88512525], [-73.524403721, 40.91175288], [-73.548571765, 40.903452784], [-73.541882336, 40.876868069], [-73.505942076, 40.872540325], [-73.509196937, 40.893095434], [-73.494910151, 40.895139277], [-73.487953842, 40.876725912], [-73.465447286, 40.868587899], [-73.473231196, 40.894525051], [-73.49737376, 40.923216641], [-73.492885083, 40.937884301], [-73.482750356, 40.939324647], [-73.4936589, 40.939590186], [-73.484788835, 40.947917104], [-73.430722207, 40.929762572], [-73.432358181, 40.924524402], [-73.475417197, 40.912002325], [-73.433722258, 40.908890963], [-73.444763571, 40.899664164], [-73.425615281, 40.895675719], [-73.419780135, 40.884545892], [-73.419023752, 40.895233154], [-73.433246166, 40.906160474], [-73.39640066, 40.909253061], [-73.373980075, 40.892612636], [-73.381325305, 40.902546197], [-73.374837041, 40.913857073], [-73.359372765, 40.901382118], [-73.36321637, 40.888492763], [-73.354247063, 40.890772641], [-73.352681994, 40.923793316], [-73.370069414, 40.930278897], [-73.378661871, 40.9250848], [-73.369471282, 40.931127816], [-73.381632417, 40.942458808], [-73.38227883, 40.92798695], [-73.387628496, 40.922711045], [-73.402049392, 40.92966333], [-73.406579643, 40.91 ...

# %% [markdown]
# ### The US states.

# %% [markdown]
# #### Create state geocoder for the US [48 contiguous states](https://en.wikipedia.org/wiki/Contiguous_United_States) (aka CONUS).

# %%
conus_gcoder = geocode_states('us-48').inc_res()

# %% [markdown]
# #### The US choropleth.

# %%
conus_plot = (ggplot() +
              geom_polygon(aes(fill='found name'), 
                           data=conus_gcoder.get_boundaries(), 
                           show_legend=False, 
                           color="white",
                           tooltips=layer_tooltips().line("^fill")) +
              map_options +
              scale_fill_brewer(name="State", palette="Dark2") + 
              ggsize(900, 500))
conus_plot
# Out:
#    <div id="lDuYdo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("lDuYdo");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "coord":{
# "name":"map",
# "flip":false
# },
# "ggsize":{
# "width":900.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "name":"State",
# "aesthetic":"fill",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"polygon",
# "data":{
# "found name":["Vermont","Massachusetts","New York","Maine","New Hampshire","Texas","Illinois","Missouri","Kansas","Oklahoma","Arkansas","Nebraska","Iowa","South Dakota","North Dakota","Kentucky","Indiana","Tennessee","Mississippi","Alabama","Georgia","Colorado","Wyoming","Utah","New Mexico","Arizona","Florida","Ohio","West Virginia","Washington, D.C.","Pennsylvania","Delaware","Maryland","Montana","Idaho","Wisconsin","Minnesota","Nevada","California","Oregon","Washington","Michigan","Connecticut","South Carolina","Virginia","North Carolina","Louisiana","New Jersey","Rhode Island"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-73.264812827, 42.745851427], [-73.241486996, 43.532800823], [-73.306081295, 43.628079593], [-73.431332409, 43.587917536], [-73.350592554, 43.771938533], [-73.437740207, 44.045006186], [-73.293382376, 44.437484443], [-73.39023158, 44.618352503], [-73.343166858, 45.010724813], [-71.501019001, 45.013445914], [-71.495000124, 44.904694408], [-71.632812023, 44.75102663], [-71.535065621, 44.588342607], [-71.57683298, 44.502403289], [-71.815446317, 44.354298413], [-72.032795101, 44.320483804], [-72.031645775, 44.078772515], [-72.380346358, 43.573625386], [-72.443469465, 43.007158935], [-72.55723536, 42.853898853], [-72.45844692, 42.726960629], [-73.264812827, 42.745851427]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-70.590709448, 42.640413791], [-70.664619058, 42.579921931], [-70.680081993, 42.660752982], [-70.590709448, 42.640413791]]], [[[-70.775981694, 41.301322281], [-70.838218331, 41.346108466], [-70.587675869, 41.459245384], [-70.524307723, 41.370967552], [-70.564388931, 41.382047385], [-70.775981694, 41.301322281]]], [[[-70.509057641, 41.349722743], [-70.524307723, 41.370967552], [-70.497652849, 41.363599222], [-70.509057641, 41.349722743]]], [[[-70.452117026, 41.351011544], [-70.497652849, 41.363599222], [-70.450901985, 41.420482099], [-70.452117026, 41.351011544]]], [[[-70.005733073, 41.799635142], [-70.054313242, 41.994095296], [-70.244920403, 42.061484456], [-70.05968973, 42.040678561], [-69.944784496, 41.738651664], [-69.964077026, 41.653155684], [-70.266269445, 41.609372646], [-70.260423571, 41.655648798], [-70.655617565, 41.515067518], [-70.613299012, 41.676493585], [-70.66116035, 41.682598293], [-70.54360047, 41.775182784], [-70.624970645, 41.765300184], [-70.673997402, 41.692212671], [-70.745884627, 41.738547832], [-70.715554208, 41.676488221], [-70.761378407, 41.721443385], [-70.764547437, 41.641313732], [-70.867828578, 41.639167964], [-70.852345526, 41.581952423], [-70.930094719, 41.613078117], [-70.953369588, 41.514277607], [-71.120329052, 41.496714503], [-71.132558584, 41.660366803], [-71.196589619, 41.676403731], [-71.157300621, 41.711516529], [-71.225592345, 41.711642593], [-71.340480745, 41.797033399], [-71.381326765, 42.018935233], [-71.799188107, 42.008053511], [-73.48735705, 42.049532533], [-73.264812827, 42.745851427], [-72.45844692, 42.726960629], [-71.294871122, 42.697243094], [-71.031196564, 42.859296799], [-70.816150457, 42.872041315], [-70.803633928, 42.818905413], [-70.913219601, 42.834100127], [-70.814177692, 42.792761922], [-70.867689103, 42.75584802], [-70.823812187, 42.681557536], [-70.672908425, 42.609548271], [-70.888870507, 42.540080398], [-70.835538805, 42.490588278], [-70.93372643, 42.459020019], [-70.905513614, 42.416313887], [-70.967291594, 42.445076555], [-70.953240842, 42.344158441], [-71.05831638, 42.381489426], [-71.041788608, 42.279054523], [-70.955394655, 42.280032188], [-70.974306911, 42.222064286], [-70.858196765, 42.264563888], [-70.919422209, 42.306226641], [-70.767381191, 42.254016101], [-70.59916243, 42.004526407], [-70.656681061, 42.060349882], [-70.729250908, 41.989438981], [-70.539216399, 41.926655173], [-70.489202589, 41.779796183], [-70.542153418, 41.775121093], [-70.273253208, 41.723829458], [-70.005733073, 41.799635142]], [[-70.351747423, 41.701586992], [-70.272541791, 41.723693758], [-70.273253208, 41.723829458], [-70.351747423, 41.701586992]]], [[[-70.050631911, 41.392463744], [-70.020074704, 41.349530731], [-70.092486441, 41.295796931], [-70.050631911, 41.392463744]]], [[[-70.013150722, 41.354668736], [-70.011452058, 41.337415875], [-70.020074704, 41.349530731], [-70.013150722, 41.354668736]]], [[[-69.960858375, 41.266331524], [-70.236177742, 41.28494069], [-70.095821768, 41.291693151], [-70.008452833, 41.306953579], [-70.011452058, 41.337415875], [-69.960858375, 41.266331524]]], [[[-69.935987592, 41.777635664], [-69.931948185, 41.70491159], [-69.944784496, 41.738651664], [-69.935987592, 41.777 ...

# %% [markdown]
# #### Add the states of Alaska and Hawaii.

# %%
alaska_plot = (ggplot() + geom_map(map=geocode_states('alaska'), 
                                   fill="light-blue", 
                                   color="#172048",
                                   tooltips=layer_tooltips().line("Alaska")) +
               xlim(-180, -130) + map_options)
hawaii_plot = (ggplot() + geom_map(map=geocode_states('hawaii'), 
                                   fill="#00A954", 
                                   color="#D91023",
                                   tooltips=layer_tooltips().line("Hawaii")) +
               xlim(-162, -154) + ylim(18, 23) +
               map_options)

bunch = GGBunch()
bunch.add_plot(conus_plot, 0, 0, 800, 400)
bunch.add_plot(alaska_plot, 0, 300, 200, 200)
bunch.add_plot(hawaii_plot, 200, 370, 200, 125)
bunch.show()
# Out:
#    <div id="croYGa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("croYGa");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":800.0,
# "height":400.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "coord":{
# "name":"map",
# "flip":false
# },
# "ggsize":{
# "width":900.0,
# "height":500.0
# },
# "kind":"plot",
# "scales":[{
# "name":"State",
# "aesthetic":"fill",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"polygon",
# "data":{
# "found name":["Vermont","Massachusetts","New York","Maine","New Hampshire","Texas","Illinois","Missouri","Kansas","Oklahoma","Arkansas","Nebraska","Iowa","South Dakota","North Dakota","Kentucky","Indiana","Tennessee","Mississippi","Alabama","Georgia","Colorado","Wyoming","Utah","New Mexico","Arizona","Florida","Ohio","West Virginia","Washington, D.C.","Pennsylvania","Delaware","Maryland","Montana","Idaho","Wisconsin","Minnesota","Nevada","California","Oregon","Washington","Michigan","Connecticut","South Carolina","Virginia","North Carolina","Louisiana","New Jersey","Rhode Island"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-73.264812827, 42.745851427], [-73.241486996, 43.532800823], [-73.306081295, 43.628079593], [-73.431332409, 43.587917536], [-73.350592554, 43.771938533], [-73.437740207, 44.045006186], [-73.293382376, 44.437484443], [-73.39023158, 44.618352503], [-73.343166858, 45.010724813], [-71.501019001, 45.013445914], [-71.495000124, 44.904694408], [-71.632812023, 44.75102663], [-71.535065621, 44.588342607], [-71.57683298, 44.502403289], [-71.815446317, 44.354298413], [-72.032795101, 44.320483804], [-72.031645775, 44.078772515], [-72.380346358, 43.573625386], [-72.443469465, 43.007158935], [-72.55723536, 42.853898853], [-72.45844692, 42.726960629], [-73.264812827, 42.745851427]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-70.590709448, 42.640413791], [-70.664619058, 42.579921931], [-70.680081993, 42.660752982], [-70.590709448, 42.640413791]]], [[[-70.775981694, 41.301322281], [-70.838218331, 41.346108466], [-70.587675869, 41.459245384], [-70.524307723, 41.370967552], [-70.564388931, 41.382047385], [-70.775981694, 41.301322281]]], [[[-70.509057641, 41.349722743], [-70.524307723, 41.370967552], [-70.497652849, 41.363599222], [-70.509057641, 41.349722743]]], [[[-70.452117026, 41.351011544], [-70.497652849, 41.363599222], [-70.450901985, 41.420482099], [-70.452117026, 41.351011544]]], [[[-70.005733073, 41.799635142], [-70.054313242, 41.994095296], [-70.244920403, 42.061484456], [-70.05968973, 42.040678561], [-69.944784496, 41.738651664], [-69.964077026, 41.653155684], [-70.266269445, 41.609372646], [-70.260423571, 41.655648798], [-70.655617565, 41.515067518], [-70.613299012, 41.676493585], [-70.66116035, 41.682598293], [-70.54360047, 41.775182784], [-70.624970645, 41.765300184], [-70.673997402, 41.692212671], [-70.745884627, 41.738547832], [-70.715554208, 41.676488221], [-70.761378407, 41.721443385], [-70.764547437, 41.641313732], [-70.867828578, 41.639167964], [-70.852345526, 41.581952423], [-70.930094719, 41.613078117], [-70.953369588, 41.514277607], [-71.120329052, 41.496714503], [-71.132558584, 41.660366803], [-71.196589619, 41.676403731], [-71.157300621, 41.711516529], [-71.225592345, 41.711642593], [-71.340480745, 41.797033399], [-71.381326765, 42.018935233], [-71.799188107, 42.008053511], [-73.48735705, 42.049532533], [-73.264812827, 42.745851427], [-72.45844692, 42.726960629], [-71.294871122, 42.697243094], [-71.031196564, 42.859296799], [-70.816150457, 42.872041315], [-70.803633928, 42.818905413], [-70.913219601, 42.834100127], [-70.814177692, 42.792761922], [-70.867689103, 42.75584802], [-70.823812187, 42.681557536], [-70.672908425, 42.609548271], [-70.888870507, 42.540080398], [-70.835538805, 42.490588278], [-70.93372643, 42.459020019], [-70.905513614, 42.416313887], [-70.967291594, 42.445076555], [-70.953240842, 42.344158441], [-71.05831638, 42.381489426], [-71.041788608, 42.279054523], [-70.955394655, 42.280032188], [-70.974306911, 42.222064286], [-70.858196765, 42.264563888], [-70.919422209, 42.306226641], [-70.767381191, 42.254016101], [-70.59916243, 42.004526407], [-70.656681061, 42.060349882], [-70.729250908, 41.989438981], [-70.539216399, 41.926655173], [-70.489202589, 41.779796183], [-70.542153418, 41.775121093], [-70.273253208, 41.723829458], [-70.005733073, 41.799635142]], [[-70.351747423, 41.701586992], [-70.272541791, 41.723693758], [-70.273253208, 41.723829458], [-70.351747423, 41.701586992]]], [[[-70.050631911, 41.392463744], [-70.020074704, 41.349530731], [-70.092486441, 41.295796931], [-70.050631911, 41.392463744]]], [[[-70.013150722, 41.354668736], [-70.011452058, 41.337415875], [-70.020074704, 41.349530731], [-70.013150722, 41.354668736]]], [[[-69.960858375, 41.266331524], [-70.236177742, 41.28494069], [-70.095821768, 41.291693151], [-70.008452833, 41.306953579], [-70.011452058, 41.337415875], [-69.960858375, 41.266331524]]], [[[-69.935987592, 41.777635664], [-69.931948185, 41.70491159], [-69.944784496, 41.738651664], [-69.935987592, 41.777 ...

# %% [markdown]
# ### Resolving ambiguity.

# %% [markdown]
# #### There are many cities named "Warwick".

# %%
# Create a Warwick city geocoder.
world_warwicks = geocode_cities('warwick').allow_ambiguous()

# Plot Warwicks.
(ggplot() + geom_map(map=geocode_countries())
    + geom_point(map=world_warwicks, size=3, color="red")
    + coord_map(xlim=[-130, 20])
    + theme_void())
# Out:
#    <div id="AlRcfa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("AlRcfa");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"map",
# "xlim":[-130.0,20.0],
# "flip":false
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "country":["Andorra","Slovakia","Austria","Hungary","Georgia","Vatican City","Poland","Cambodia","Laos","Vietnam","Denmark","Myanmar","Germany","Czech Republic","Switzerland","Belgium","Sweden","Faroe Islands","Albania","North Macedonia","Montenegro","Finland","San Marino","Moldova","Belarus","Brazil","Russia","Ukraine","United Kingdom","Isle of Man","Ireland","Latvia","Lithuania","Estonia","Australia","South Africa","Eswatini","Romania","Ecuador","Mexico","Colombia","United States","Mongolia","Chile","Rwanda","Turkey","Kyrgyzstan","Bhutan","Nepal","Bangladesh","Jordan","Syria","Lebanon","Bulgaria","Greece","North Korea","Algeria","Tunisia","Libya","Mauritania","The Gambia","Senegal","Guinea-Bissau","Sierra Leone","Guinea","Ivory Coast","Liberia","Ghana","Togo","Burkina Faso","Benin","Mali","Niger","Nigeria","Sudan","Central African Republic","Equatorial Guinea","Gabon","Congo-Brazzaville","Democratic Republic of the Congo","Uganda","Kenya","Somalia","Ethiopia","Djibouti","Cameroon","Namibia","Angola","Burundi","Tanzania","Zambia","Zimbabwe","Mozambique","Malawi","Uzbekistan","Tajikistan","Kazakhstan","Croatia","Slovenia","Turkmenistan","Bolivia","Guernsey","China","Venezuela","British Virgin Islands","Argentina","Uruguay","Paraguay","Suriname","Guyana","Nicaragua","Costa Rica","Panama","Honduras","Belize","Peru","Portugal","Eritrea","Iceland","Afghanistan","India","Indonesia","Iraq","Iran","Yemen","Qatar","Kuwait","Oman","East Timor","Pakistan","Saudi Arabia","South Korea","United Arab Emirates","Cyprus","Dominica","Dominican Republic","Haiti","Cuba","Papua New Guinea","Armenia","Azerbaijan","Malta","Italy","Jersey","Bahrain","Japan","Philippines","Madagascar","Taiwan","Cape Verde","Comoros","Mauritius","São Tomé and Príncipe","Seychelles","Maldives","Singapore","Sri Lanka","Saint Kitts and Nevis","Antigua and Barbuda","Montserrat","The Bahamas","Turks and Caicos Islands","Barbados","Saint Vincent and the Grenadines","Grenada","Saint Lucia","Jamaica","Trinidad and Tobago","New Zealand","Kiribati","Fiji","Marshall Islands","Federated States of Micronesia","Nauru","Palau","Monaco","Liechtenstein","Gibraltar","Spain","Canada","Israel","Egypt","El Salvador","Guatemala","Niue","South Sudan","Palestine","Serbia","Solomon Islands","Samoa","Botswana","Saint Helena, Ascension and Tristan da Cunha","South Georgia and the South Sandwich Islands","Bermuda","British Indian Ocean Territory","Thailand","Kosovo","Lesotho","Brunei","Malaysia","Luxembourg","Anguilla","Vanuatu","Tuvalu","Greenland","Cook Islands","Cayman Islands","Falkland Islands","Pitcairn Islands","Tokelau","Tonga","France","Netherlands","Chad","Bosnia and Herzegovina","Norway","Morocco","Sahrawi Arab Democratic Republic"],
# "found name":["Andorra","Slovakia","Austria","Hungary","Georgia","Vatican City","Poland","Cambodia","Laos","Vietnam","Denmark","Myanmar","Germany","Czech Republic","Switzerland","Belgium","Sweden","Faroe Islands","Albania","North Macedonia","Montenegro","Finland","San Marino","Moldova","Belarus","Brazil","Russia","Ukraine","United Kingdom","Isle of Man","Ireland","Latvia","Lithuania","Estonia","Australia","South Africa","Eswatini","Romania","Ecuador","Mexico","Colombia","United States","Mongolia","Chile","Rwanda","Turkey","Kyrgyzstan","Bhutan","Nepal","Bangladesh","Jordan","Syria","Lebanon","Bulgaria","Greece","North Korea","Algeria","Tunisia","Libya","Mauritania","The Gambia","Senegal","Guinea-Bissau","Sierra Leone","Guinea","Ivory Coast","Liberia","Ghana","Togo","Burkina Faso","Benin","Mali","Niger","Nigeria","Sudan","Central African Republic","Equatorial Guinea","Gabon","Congo-Brazzaville","Democratic Republic of the Congo","Uganda","Kenya","Somalia","Ethiopia","Djibouti","Cameroon","Namibia","Angola","Burundi","Tanzania","Zambia","Zimbabwe","Mozambique","Malawi","Uzbekistan","Tajikistan","Kazakhstan","Croatia","Slovenia","Turkmenistan","Bolivia","Guernsey","China","Venezuela","British Virgin Islands","Argentina","Uruguay","Paraguay","Suriname","Guyana","Nicaragua","Costa Rica","Panama","Honduras","Belize","Peru","Portugal","Eritrea","Iceland","Afghanistan","India","Indonesia","Iraq","Iran","Yemen","Qatar","Kuwait","Oman","East Timor","Pakistan","Saudi Arabia","South Korea","United Arab Emirates","Cyprus","Dominica","Dominican Republic","Haiti","Cuba","Papua New Guinea","Armenia","Azerbaijan","Malta","Italy","Jersey","Bahrain","Japan","Philippines","Madagascar","Taiwan","Cape Verde","Comoros","Mauritius","São Tomé and Príncipe","Seychelles","Maldives","Singapore","Sri Lanka","Saint Kitts and Nevis","Antigua and Barbuda","Montserrat","The Bahamas","Turks and Caicos Islands","Barbados","Saint Vincent and the Grenadines","Grenada","Saint Lucia","Jamaica","Trinidad and Tobago","New Zealand","Kiribati","Fiji","Marshall Islands","Federated States of Micronesia","Nauru","Palau","Monaco","Liechtenstein","Gibraltar","Spain","Canada","Israel","Egypt","El Salvador","Guatemala","Niue","South Sudan","Palestine","Serbia","Solomon Islands","Samoa","Botswana","Saint Helena, Ascension and Tristan da Cunha","South Georgia and the South Sandwich Islands","Bermuda","British Indian Ocean Territory","Thailand","Kosovo","Lesotho","Brunei","Malaysia","Luxembourg","Anguilla","Vanuatu","Tuvalu","Greenland","Cook Islands","Cayman Islands","Falkland Islands","Pitcairn Islands","Tokelau","Tonga","France","Netherlands","Chad","Bosnia and Herzegovina","Norway","Morocco","Sahrawi Arab Democratic Republic"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[1.725891531, 42.502698451], [1.413577795, 42.535377145], [1.441990435, 42.603722513], [1.725891531, 42.502698451]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.940195113, 48.616540432], [18.850906938, 49.517148435], [22.565710098, 49.087994993], [22.155255675, 48.403387964], [20.54649353, 48.54429245], [18.646086752, 47.759091854], [17.160775959, 48.006657064], [16.940195113, 48.616540432]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[9.607054442, 47.060772032], [9.530748278, 47.270581126], [9.550565779, 47.537175268], [10.454439372, 47.555796504], [13.006620258, 47.464384139], [12.758125663, 48.126069009], [13.839552104, 48.771617711], [16.940195113, 48.616540432], [17.160775959, 48.006657064], [16.113886982, 46.869059801], [13.714062274, 46.522985101], [12.185959518, 47.09214583], [10.469654202, 46.85491249], [9.607054442, 47.060772032]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.113886982, 46.869059801], [17.160775959, 48.006657064], [18.646086752, 47.759091854], [20.54649353, 48.54429245], [22.155255675, 48.403387964], [22.897709906, 47.95404017], [21.180593222, 46.304115504], [20.264275521, 46.126353443], [18.890209347, 45.922052264], [17.86203146, 45.767734051], [16.596770436, 46.475902945], [16.113886982, 46.869059801]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[41.547048837, 41.520685405], [41.439710855, 42.738699317], [40.008500218, 43.385607898], [45.158373713, 42.707530707], [46.422069669, 41.908043325], [46.631185412, 41.097776145], [45.0138174, 41.296466142], [43.474144936, 41.12303853], [41.547048837, 41.520685405]]]]}","{\"type\": \"MultiPolygon\", \"coordinate

# %% [markdown]
# #### Find one Warwick which is closest to Boston, US.
#
# Note that the name "Boston" is not unique either. Therefore we will need two geocoders: one for Boston, US, and the other for the town of Warwick near Boston.

# %%
boston_us = geocode_cities('boston').countries('US')
warwick_near_boston = world_warwicks.where('warwick', closest_to=boston_us)

# Let's also geocode Massachusetts counties. 
counties_ma = geocode_counties().scope("Massachusetts")

# %%
(ggplot() + geom_map(map=counties_ma)
    + geom_point(map=warwick_near_boston, size=7, color="red") \
    + geom_polygon(map=boston_us)
    + theme_void())
# Out:
#    <div id="TVN9xH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("TVN9xH");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "county":["Berkshire County","Essex County","Hampden County","Hampshire County","Worcester County","Franklin County","Bristol County","Middlesex County","Norfolk County","Plymouth County","Barnstable County","Suffolk County","Nantucket County","Dukes County"],
# "found name":["Berkshire County","Essex County","Hampden County","Hampshire County","Worcester County","Franklin County","Bristol County","Middlesex County","Norfolk County","Plymouth County","Barnstable County","Suffolk County","Nantucket County","Dukes County"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-73.497018367, 42.049623728], [-73.508209884, 42.086133957], [-73.352388293, 42.510039657], [-73.264812827, 42.745851427], [-73.023011684, 42.741137445], [-73.023709059, 42.70268932], [-72.948896885, 42.70406127], [-72.954121828, 42.698455453], [-72.951368541, 42.694031149], [-72.95416072, 42.690434307], [-72.974041253, 42.688186616], [-72.977656871, 42.685780674], [-72.9757981, 42.679407746], [-72.989136726, 42.67861113], [-72.98891142, 42.674430907], [-72.995756418, 42.673539072], [-72.975768596, 42.660869658], [-72.961217612, 42.667324394], [-72.954557687, 42.664135247], [-72.951038629, 42.641005218], [-72.97540918, 42.55603686], [-72.979035527, 42.541617304], [-72.968582958, 42.540012002], [-73.011682034, 42.379682958], [-73.065771461, 42.389110923], [-73.068508655, 42.380719632], [-73.06271106, 42.328951657], [-73.040719628, 42.320231795], [-73.029410094, 42.308573574], [-73.016650826, 42.311137766], [-73.009231836, 42.304410785], [-73.000277281, 42.312662601], [-73.001850396, 42.251016051], [-73.034920692, 42.143652588], [-73.071118444, 42.148204297], [-73.069285154, 42.13086918], [-73.061093688, 42.118699998], [-73.072530627, 42.111848295], [-73.075086772, 42.105365396], [-73.058245182, 42.06706211], [-73.061573803, 42.061626613], [-73.054040819, 42.057563066], [-73.05688262, 42.047691196], [-73.053258955, 42.039816231], [-73.48735705, 42.049532533], [-73.497018367, 42.049623728]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-71.0010539, 42.431892157], [-71.009779125, 42.433131337], [-71.012370139, 42.439700067], [-71.009502858, 42.440964729], [-71.01875782, 42.450117767], [-71.02583617, 42.444709092], [-71.054213941, 42.476902306], [-71.052620709, 42.486102283], [-71.039854735, 42.496055961], [-71.04375869, 42.501252741], [-71.034899354, 42.506757975], [-71.041080505, 42.520123422], [-71.038690656, 42.524259388], [-71.067567319, 42.524680495], [-71.0751459, 42.531030625], [-71.070979089, 42.555889338], [-71.057125479, 42.574041188], [-71.035459936, 42.570259273], [-71.028311849, 42.574081421], [-71.033998132, 42.585492879], [-71.05876565, 42.609077543], [-71.135405749, 42.599079609], [-71.154419929, 42.615268081], [-71.164877862, 42.598021477], [-71.182046682, 42.608445883], [-71.171756387, 42.616546154], [-71.256188303, 42.657145411], [-71.242490262, 42.662346214], [-71.238178611, 42.669419199], [-71.255132854, 42.736474425], [-71.24542594, 42.742546946], [-71.22382611, 42.74648577], [-71.181786507, 42.737340778], [-71.186139733, 42.790935338], [-71.166646779, 42.808880657], [-71.132805347, 42.82147631], [-71.064413041, 42.806274891], [-71.044920087, 42.848667204], [-71.031196564, 42.859296799], [-70.967018008, 42.868799865], [-70.929594487, 42.885031253], [-70.914630443, 42.886647284], [-70.885602236, 42.882834524], [-70.847718716, 42.860867232], [-70.816150457, 42.872041315], [-70.811861604, 42.821768671], [-70.803633928, 42.818905413], [-70.81750229, 42.822889835], [-70.827014744, 42.820644826], [-70.823096037, 42.824552804], [-70.825582445, 42.829091102], [-70.819520652, 42.829791158], [-70.819617212, 42.837729156], [-70.819992721, 42.829995006], [-70.824874341, 42.833685726], [-70.824316442, 42.830845267], [-70.829466429, 42.829948528], [-70.826837718, 42.829508185], [-70.826676786, 42.826022655], [-70.83270371, 42.825620323], [-70.82726419, 42.825576067], [-70.829627216, 42.82256797], [-70.838296115, 42.823065519], [-70.834272802, 42.829178274], [-70.838234425, 42.82476604], [-70.843588114, 42.830619961], [-70.838875473, 42.822527736], [-70.845953822, 42.825051695], [-70.842025727, 42.821733803], [-70.861706436, 42.815366238], [-70.863408297, 42.818535268], [-70.864453018, 42.814863324], [-70.87595433, 42.823314965], [-70.871290997, 42.829260889], [-70.875804126, 42.826045454], [-70.900909603, 42.837737203], [-70.913219601, 42.834100127], [-70.897197425, 42.831679434], [-70.848153234, 42.799521089], [-70.824539065, 42.799786627], [-70.82143 ...

# %% [markdown]
# #### Filter Warwicks using Shaply `box`.

# %%
from shapely.geometry import box
warwicks_in_box = (world_warwicks
    .where('warwick', scope=box(-72, 41.5, -71, 42)))

# %%
(ggplot() + geom_map(map=counties_ma)
    + geom_rect(xmin=-72, ymin=41.5, xmax=-71, ymax=42, alpha=0, color="magenta", linetype="dashed")
    + geom_point(map=warwicks_in_box, size=7, color="red")
    + geom_polygon(map=boston_us)
    + theme_void())
# Out:
#    <div id="ApEBkj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("ApEBkj");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "county":["Berkshire County","Essex County","Hampden County","Hampshire County","Worcester County","Franklin County","Bristol County","Middlesex County","Norfolk County","Plymouth County","Barnstable County","Suffolk County","Nantucket County","Dukes County"],
# "found name":["Berkshire County","Essex County","Hampden County","Hampshire County","Worcester County","Franklin County","Bristol County","Middlesex County","Norfolk County","Plymouth County","Barnstable County","Suffolk County","Nantucket County","Dukes County"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-73.497018367, 42.049623728], [-73.508209884, 42.086133957], [-73.352388293, 42.510039657], [-73.264812827, 42.745851427], [-73.023011684, 42.741137445], [-73.023709059, 42.70268932], [-72.948896885, 42.70406127], [-72.954121828, 42.698455453], [-72.951368541, 42.694031149], [-72.95416072, 42.690434307], [-72.974041253, 42.688186616], [-72.977656871, 42.685780674], [-72.9757981, 42.679407746], [-72.989136726, 42.67861113], [-72.98891142, 42.674430907], [-72.995756418, 42.673539072], [-72.975768596, 42.660869658], [-72.961217612, 42.667324394], [-72.954557687, 42.664135247], [-72.951038629, 42.641005218], [-72.97540918, 42.55603686], [-72.979035527, 42.541617304], [-72.968582958, 42.540012002], [-73.011682034, 42.379682958], [-73.065771461, 42.389110923], [-73.068508655, 42.380719632], [-73.06271106, 42.328951657], [-73.040719628, 42.320231795], [-73.029410094, 42.308573574], [-73.016650826, 42.311137766], [-73.009231836, 42.304410785], [-73.000277281, 42.312662601], [-73.001850396, 42.251016051], [-73.034920692, 42.143652588], [-73.071118444, 42.148204297], [-73.069285154, 42.13086918], [-73.061093688, 42.118699998], [-73.072530627, 42.111848295], [-73.075086772, 42.105365396], [-73.058245182, 42.06706211], [-73.061573803, 42.061626613], [-73.054040819, 42.057563066], [-73.05688262, 42.047691196], [-73.053258955, 42.039816231], [-73.48735705, 42.049532533], [-73.497018367, 42.049623728]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-71.0010539, 42.431892157], [-71.009779125, 42.433131337], [-71.012370139, 42.439700067], [-71.009502858, 42.440964729], [-71.01875782, 42.450117767], [-71.02583617, 42.444709092], [-71.054213941, 42.476902306], [-71.052620709, 42.486102283], [-71.039854735, 42.496055961], [-71.04375869, 42.501252741], [-71.034899354, 42.506757975], [-71.041080505, 42.520123422], [-71.038690656, 42.524259388], [-71.067567319, 42.524680495], [-71.0751459, 42.531030625], [-71.070979089, 42.555889338], [-71.057125479, 42.574041188], [-71.035459936, 42.570259273], [-71.028311849, 42.574081421], [-71.033998132, 42.585492879], [-71.05876565, 42.609077543], [-71.135405749, 42.599079609], [-71.154419929, 42.615268081], [-71.164877862, 42.598021477], [-71.182046682, 42.608445883], [-71.171756387, 42.616546154], [-71.256188303, 42.657145411], [-71.242490262, 42.662346214], [-71.238178611, 42.669419199], [-71.255132854, 42.736474425], [-71.24542594, 42.742546946], [-71.22382611, 42.74648577], [-71.181786507, 42.737340778], [-71.186139733, 42.790935338], [-71.166646779, 42.808880657], [-71.132805347, 42.82147631], [-71.064413041, 42.806274891], [-71.044920087, 42.848667204], [-71.031196564, 42.859296799], [-70.967018008, 42.868799865], [-70.929594487, 42.885031253], [-70.914630443, 42.886647284], [-70.885602236, 42.882834524], [-70.847718716, 42.860867232], [-70.816150457, 42.872041315], [-70.811861604, 42.821768671], [-70.803633928, 42.818905413], [-70.81750229, 42.822889835], [-70.827014744, 42.820644826], [-70.823096037, 42.824552804], [-70.825582445, 42.829091102], [-70.819520652, 42.829791158], [-70.819617212, 42.837729156], [-70.819992721, 42.829995006], [-70.824874341, 42.833685726], [-70.824316442, 42.830845267], [-70.829466429, 42.829948528], [-70.826837718, 42.829508185], [-70.826676786, 42.826022655], [-70.83270371, 42.825620323], [-70.82726419, 42.825576067], [-70.829627216, 42.82256797], [-70.838296115, 42.823065519], [-70.834272802, 42.829178274], [-70.838234425, 42.82476604], [-70.843588114, 42.830619961], [-70.838875473, 42.822527736], [-70.845953822, 42.825051695], [-70.842025727, 42.821733803], [-70.861706436, 42.815366238], [-70.863408297, 42.818535268], [-70.864453018, 42.814863324], [-70.87595433, 42.823314965], [-70.871290997, 42.829260889], [-70.875804126, 42.826045454], [-70.900909603, 42.837737203], [-70.913219601, 42.834100127], [-70.897197425, 42.831679434], [-70.848153234, 42.799521089], [-70.824539065, 42.799786627], [-70.82143 ...

# %% [markdown]
# #### Explore the details on an interactive map.
#
# Note: nbviewer won't load base-map tiles due to its CSP.

# %%
(ggplot() + geom_livemap()
    + geom_rect(xmin=-72, ymin=41.5, xmax=-71, ymax=42, alpha=0, color="magenta", linetype="dashed")
    + geom_point(map=warwicks_in_box, size=7, color="red")
    + geom_polygon(map=boston_us))
# Out:
#    <div id="MMcxMM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("MMcxMM");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-72.0,
# "ymin":41.5,
# "xmax":-71.0,
# "ymax":42.0,
# "alpha":0.0,
# "color":"magenta",
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "city":["warwick","warwick"],
# "found name":["Warwick","West Warwick"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-71.4332938210472, 41.715542525053]}","{\"type\": \"Point\", \"coordinates\": [-71.5257788638961, 41.6969098895788]}"]
# },
# "size":7.0,
# "color":"red",
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "mapping":{
# },
# "data_meta":{
# },
# "map":{
# "city":["boston"],
# "found name":["Boston"],
# "country":["US"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-71.040506512, 42.279931837], [-71.040751934, 42.278722176], [-71.041406393, 42.277820964], [-71.04316324, 42.276512062], [-71.044338048, 42.276033294], [-71.045813262, 42.276094984], [-71.048582643, 42.277625166], [-71.049237102, 42.277774026], [-71.052596569, 42.277379746], [-71.054401696, 42.276729319], [-71.05524525, 42.27605341], [-71.055585891, 42.275420416], [-71.055575162, 42.274763283], [-71.054986417, 42.273866095], [-71.053712368, 42.272762379], [-71.053489745, 42.271956385], [-71.05369091, 42.271527237], [-71.060978472, 42.267164677], [-71.061828732, 42.266917917], [-71.063102782, 42.267054708], [-71.064696014, 42.268318013], [-71.065032631, 42.268996603], [-71.064781845, 42.269877698], [-71.065459102, 42.270718561], [-71.067523062, 42.271216105], [-71.068051457, 42.270667599], [-71.069409996, 42.270330986], [-71.071679145, 42.270565677], [-71.073197275, 42.269997055], [-71.076855808, 42.270166032], [-71.078875512, 42.269292984], [-71.0808523, 42.269032813], [-71.082614511, 42.268352881], [-71.089050472, 42.269476713], [-71.089820266, 42.269250069], [-71.090190411, 42.268786053], [-71.089859158, 42.267486538], [-71.09021455, 42.266364047], [-71.090818048, 42.266191047], [-71.094131917, 42.266842816], [-71.095353663, 42.265340797], [-71.096431911, 42.264447632], [-71.097483337, 42.262799434], [-71.098864675, 42.26230055], [-71.100731492, 42.260781096], [-71.102799475, 42.259501698], [-71.103824079, 42.259446714], [-71.105001569, 42.26051422], [-71.107585877, 42.26039084], [-71.108955145, 42.26100774], [-71.110465229, 42.26083474], [-71.111461669, 42.260480693], [-71.113325804, 42.258701069], [-71.10954389, 42.255123045], [-71.109346747, 42.247701462], [-71.126376092, 42.238873078], [-71.1256814, 42.237612455], [-71.124762744, 42.237140392], [-71.124084145, 42.236099708], [-71.122637093, 42.235091209], [-71.122603565, 42.234148424], [-71.1229375, 42.233959331], [-71.124053299, 42.23403309], [-71.124460995, 42.23387216], [-71.124718487, 42.233456423], [-71.124524027, 42.23261556], [-71.125229448, 42.231767992], [-71.125950962, 42.231527938], [-71.126609445, 42.230975409], [-71.127529442, 42.230826548], [-71.128830314, 42.229480096], [-71.129203141, 42.228678125], [-71.13010034, 42.228379062], [-71.130749434, 42.227622688], [-71.142677218, 42.235690676], [-71.146642864, 42.255466364], [-71.152313054, 42.258046617], [-71.158593446, 42.254858851], [-71.171324551, 42.265059168], [-71.171694696, 42.265988542], [-71.173607111, 42.266457923], [-71.174316555, 42.266889754], [-71.174582094, 42.267561639], [-71.174501628, 42.268362269], [-71.173215508, 42.269487442], [-71.172953993, 42.270007784], [-71.174784601, 42.273117768], [-71.174852997, 42.273850002], [-71.174415797, 42.27475926], [-71.174764484, 42.275553184], [-71.176364422, 42.276355155], [-71.177461445, 42.276579117], [-71.183047146, 42.275563913], [-71.185357869, 42.279301526], [-71.187808067, 42.279974752], [-71.189929694, 42.281000685], [-71.190974414, 42.281834842], [-71.191249341, 42.282702526], [-71.178612113, 42.294320374], [-71.164702177, 42.303540356], [-71.152113229, 42.294298916], [-71.146882921, 42.296990481], [-71.140185446, 42.301821081], [-71.136501431, 42.305914082], [-71.131862551, 42.312887742], [-71.123712659, 42.322426903], [-71.123367995, 42.322282065], [-71.121529341, 42.323592308], [-71.120070219, 42.322515415], [-71.119437218, 42.322445678], [-71.118869931, 42.322567717], [-71.118397862, 42.323164501], [-71.116536409, 42.323648634], [-71.115965098, 42.326089415], [-71.115039736, 42.327018789], [-71.113559157, 42.330213262], [-71.113254726, 42.332106878], [-71.11219123, 42.333510998], [-71.110533625, 42.335039838], [-71.110990942, 42.335467646], [-71.110707968, 42.336018833], [-71.11155957, 42.337042083], [-71.110884994, 42.338593722], [-71.110579222, 42.340153408], [-71.109553277, 42.34120348], [-71.108445525, 42.34156021], [-71.108028442, 42.342187839], [-71.106514335, 42.34281681 ...
