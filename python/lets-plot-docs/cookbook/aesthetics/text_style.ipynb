# %% [markdown]
# # Text

# %%
from lets_plot import *

from common import docs_dark_theme

# %%
LetsPlot.setup_html()
# Out:
#             <div id="arueU3"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("arueU3").appendChild(div);
#                     };
#                     var e = document.getElementById("arueU3");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Font Family

# %%
def get_font_family_plot():
    families = ['sans', 'serif', 'mono']
    data = dict(
        y = list(range(len(families))),
        f = families
    )
    return ggplot(data) + \
        geom_label(aes(y='y', label='f', family='f'), \
                   x=0, size=1, size_unit='y') + \
        scale_y_reverse(limits=[-.5, len(families) - .5]) + \
        ggsize(200, 400) + \
        theme_void()

# %%
family_plot = get_font_family_plot()
ggsave(family_plot, "aesthetics_font_family.png")
family_plot
# Out:
#    <div id="lSnbqM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("lSnbqM");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "y":[0.0,1.0,2.0],
# "f":["sans","serif","mono"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"f"
# }]
# },
# "ggsize":{
# "width":200.0,
# "height":400.0
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-0.5,2.5],
# "trans":"reverse"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "y":"y",
# "label":"f",
# "family":"f"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "x":0.0,
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
family_plot_dark = get_font_family_plot() + docs_dark_theme()
ggsave(family_plot_dark, "aesthetics_font_family_dark.png")
family_plot_dark
# Out:
#    <div id="Pwtzm0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Pwtzm0");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "y":[0.0,1.0,2.0],
# "f":["sans","serif","mono"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"f"
# }]
# },
# "ggsize":{
# "width":200.0,
# "height":400.0
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank",
# "plot_background":{
# "fill":"#14181e",
# "blank":false
# },
# "geom":{
# "pen":"white",
# "paper":"#14181e"
# },
# "flavor":"high_contrast_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-0.5,2.5],
# "trans":"reverse"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "y":"y",
# "label":"f",
# "family":"f"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "x":0.0,
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Font Face

# %%
def get_font_face_plot():
    faces = ['plain', 'bold', 'italic', 'bold italic']
    data = dict(
        y = list(range(len(faces))),
        f = faces
    )
    return ggplot(data) + \
        geom_label(aes(y='y', label='f', fontface='f'), \
                   x=0, size=1, size_unit='y') + \
        scale_y_reverse(limits=[-.5, len(faces) - .5]) + \
        ggsize(300, 400) + \
        theme_void()

# %%
face_plot = get_font_face_plot()
ggsave(face_plot, "aesthetics_font_face.png")
face_plot
# Out:
#    <div id="HYtNYT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("HYtNYT");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "y":[0.0,1.0,2.0,3.0],
# "f":["plain","bold","italic","bold italic"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"f"
# }]
# },
# "ggsize":{
# "width":300.0,
# "height":400.0
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-0.5,3.5],
# "trans":"reverse"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "y":"y",
# "label":"f",
# "fontface":"f"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "x":0.0,
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
face_plot_dark = get_font_face_plot() + docs_dark_theme()
ggsave(face_plot_dark, "aesthetics_font_face_dark.png")
face_plot_dark
# Out:
#    <div id="YtUcM9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("YtUcM9");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "y":[0.0,1.0,2.0,3.0],
# "f":["plain","bold","italic","bold italic"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"f"
# }]
# },
# "ggsize":{
# "width":300.0,
# "height":400.0
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank",
# "plot_background":{
# "fill":"#14181e",
# "blank":false
# },
# "geom":{
# "pen":"white",
# "paper":"#14181e"
# },
# "flavor":"high_contrast_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "limits":[-0.5,3.5],
# "trans":"reverse"
# }],
# "layers":[{
# "geom":"label",
# "mapping":{
# "y":"y",
# "label":"f",
# "fontface":"f"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "x":0.0,
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
