# %%
from lets_plot.geo_data import *
from lets_plot import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="pwbSbW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("pwbSbW").appendChild(div);
#                     };
#                     var e = document.getElementById("pwbSbW");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
country = 'Russia'
gdf = geocode_states().scope(country).get_boundaries()

ggplot() + \
    geom_map(data=gdf, color='white', fill='#636363', \
             tooltips=layer_tooltips().line('@{found name}')) + \
    ggsize(800, 600) + ggtitle('{0} States'.format(country)) + \
    theme_void()
# Out:
#    <div id="qoj5Yt"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"Russia States"
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# "found name":["Moscow Oblast","Ryazan Oblast","Lipetsk Oblast","Tambov Oblast","Voronezh Oblast","Penza Oblast","Ulyanovsk Oblast","Saratov Oblast","Samara Oblast","Nizhny Novgorod Oblast","Republic of Mordovia","Vladimir Oblast","Kursk Oblast","Oryol Oblast","Volgograd Oblast","Orenburg Oblast","Bashkortostan","Chelyabinsk Oblast","Tatarstan","Sverdlovsk Oblast","Chuvashia","Tula Oblast","Yaroslavl Oblast","Kaluga Oblast","Smolensk Oblast","Bryansk Oblast","Belgorod Oblast","Rostov Oblast","Ivanovo Oblast","Kostroma Oblast","Novgorod Oblast","Moscow","Kaliningrad","Stavropol Krai","Krasnodar Krai","Republic of Kalmykia","Republic of Dagestan","Chechen Republic","Karachay-Cherkessia","Kabardino-Balkaria","Republic of North Ossetia-Alania","Astrakhan Oblast","Kirov Oblast","Vologda Oblast","Mari El","Udmurtia","Perm Krai","Komi Republic","Kurgan Oblast","Tyumen Oblast","Omsk Oblast","Novosibirsk Oblast","Tomsk Oblast","Khanty-Mansiysk Autonomous Okrug – Ugra","Arkhangelsk Oblast","Kemerovo Oblast","Altai Krai","Altai Republic","Tuva Republic","Irkutsk Oblast","Buryatia","Zabaykalsky Krai","Amur Oblast","Jewish Autonomous Oblast","Khabarovsk Krai","Primorsky Krai","Magadan Oblast","Chukotka Autonomous Okrug","Kamchatka Krai","Sakha Republic","Pskov Oblast","Leningrad oblast","Krasnoyarsk Krai","Republic of Khakassia","Yamalo-Nenets Autonomous Okrug","Ingushetia","Republic of Adygea","Nenets Autonomous Okrug","Saint Petersburg","Republic of Karelia","Sakhalin Oblast","Tver Oblast","Murmansk Oblast","Sevastopol","Republic of Crimea"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[35.148495734, 55.957501084], [35.434270352, 56.458655745], [37.055547684, 56.526247412], [37.066831738, 56.75562188], [37.698306888, 56.958512217], [38.244298697, 56.793463826], [38.318130523, 56.658578217], [38.268103302, 56.524768174], [38.573242128, 55.994318426], [39.889101684, 55.833195448], [40.190922618, 55.365007818], [38.849022835, 54.625619352], [38.940648437, 54.407988936], [38.665982187, 54.256713688], [38.45664382, 54.653588086], [37.26870954, 54.841801375], [37.045631558, 55.142173916], [37.967427671, 55.716248453], [37.341570407, 55.956827849], [37.415457219, 55.664764792], [36.803100854, 55.440832525], [36.937239468, 55.241390169], [35.334221274, 55.271751434], [35.148495734, 55.957501084]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[38.665982187, 54.256713688], [38.940648437, 54.407988936], [38.849022835, 54.625619352], [40.190922618, 55.365007818], [41.792763323, 55.101420432], [41.776476949, 55.098644346], [42.485490739, 55.009354949], [42.44232595, 54.825398326], [42.629171312, 54.375923127], [42.164254636, 54.258241206], [42.689073086, 54.129277915], [42.261956781, 54.087655395], [42.350969911, 53.853729218], [42.143629789, 53.802798092], [40.170693398, 53.312621713], [39.757765979, 53.58665362], [39.326882511, 53.39125067], [38.937522322, 53.574174643], [38.665982187, 54.256713688]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[37.738034427, 52.019084841], [38.067213893, 52.33021304], [37.721715868, 52.600016445], [37.866469324, 53.012216985], [38.565863371, 52.991079837], [38.531574011, 53.307619393], [38.937522322, 53.574174643], [39.326882511, 53.39125067], [39.757765979, 53.58665362], [40.170693398, 53.312621713], [39.915694445, 52.708851099], [40.733435601, 52.251247466], [40.534140766, 51.945692897], [38.292610645, 51.965940893], [37.738034427, 52.019084841]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[40.534140766, 51.945692897], [40.733435601, 52.251247466], [39.915694445, 52.708851099], [40.170693398, 53.312621713], [42.143629789, 53.802798092], [42.236841917, 53.359372616], [43.20907563, 52.700332403], [43.0397062, 52.37063393], [42.52086103, 51.596121937], [40.534140766, 51.945692897]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[38.289001733, 51.296468228], [38.139101118, 51.639282703], [38.519270718, 51.747971177], [38.292610645, 51.965940893], [40.534140766, 51.945692897], [42.52086103, 51.596121937], [42.880893946, 51.233024597], [41.928096861, 51.194125861], [41.168105006, 50.774513036], [41.539097428, 50.574381351], [41.400994509, 50.202805549], [40.92100516, 49.70048815], [40.135391504, 49.617102295], [39.179943055, 49.888802022], [39.119270146, 50.624593645], [38.289001733, 51.296468228]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[42.143629789, 53.802798092], [42.350969911, 53.853729218], [43.287126737, 53.999318249], [44.498975426, 53.643166423], [44.832569808, 53.964060545], [45.813633353, 53.975716084], [46.908163726, 53.362606019], [46.801069826, 52.620827705], [45.074777305, 52.306313217], [44.532591552, 52.532595098], [44.319917858, 52.291266024], [43.0397062, 52.37063393], [43.20907563, 52.700332403], [42.236841917, 53.359372616], [42.143629789, 53.802798092]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[45.796719342, 53.986498564], [46.705199629, 54.325358123], [46.44279778, 54.761624783], [47.267834544, 54.673405588], [47.290809005, 54.674267918], [47.355589718, 54.627394974], [48.881741166, 54.625206292], [49.288298339, 54.891446382], [49.560146928, 54.562064409], [50.09245947, 54.50660035], [50.035856813, 53.819146156], [48.488910198, 53.770662546], [47.930440754, 53.361598849], [48.588748723, 52.895802408], [48.428632915, 52.814406753], [46.801069826, 52.620827705], [46.908163726, 53.362606019], [45.813633353, 53.975716084], [45.796719342, 53.986498564]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[42.880893946, 51.233024597], [42.52086103,  ...
