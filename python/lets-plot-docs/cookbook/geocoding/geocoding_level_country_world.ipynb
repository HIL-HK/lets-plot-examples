# %%
from lets_plot.geo_data import *
from lets_plot import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="WG8OGw"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("WG8OGw").appendChild(div);
#                     };
#                     var e = document.getElementById("WG8OGw");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
gdf = geocode_countries().get_boundaries(2)

ggplot() + \
    geom_map(data=gdf, color='white', fill='#0868ac', \
             tooltips=layer_tooltips().line('@{found name}')) + \
    ggsize(800, 600) + ggtitle('World') + \
    theme_void()
# Out:
#    <div id="bT5O0e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("bT5O0e");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"World"
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# "found name":["Andorra","Slovakia","Austria","Hungary","Georgia","Vatican City","Poland","Cambodia","Laos","Vietnam","Denmark","Myanmar","Germany","Czech Republic","Switzerland","Belgium","Sweden","Faroe Islands","Albania","North Macedonia","Montenegro","Finland","San Marino","Moldova","Belarus","Brazil","Russia","Ukraine","United Kingdom","Isle of Man","Ireland","Latvia","Lithuania","Estonia","Australia","South Africa","Eswatini","Romania","Ecuador","Mexico","Colombia","United States","Mongolia","Chile","Rwanda","Turkey","Kyrgyzstan","Bhutan","Nepal","Bangladesh","Jordan","Syria","Lebanon","Bulgaria","Greece","North Korea","Algeria","Tunisia","Libya","Mauritania","The Gambia","Senegal","Guinea-Bissau","Sierra Leone","Guinea","Ivory Coast","Liberia","Ghana","Togo","Burkina Faso","Benin","Mali","Niger","Nigeria","Sudan","Central African Republic","Equatorial Guinea","Gabon","Congo-Brazzaville","Democratic Republic of the Congo","Uganda","Kenya","Somalia","Ethiopia","Djibouti","Cameroon","Namibia","Angola","Burundi","Tanzania","Zambia","Zimbabwe","Mozambique","Malawi","Uzbekistan","Tajikistan","Kazakhstan","Croatia","Slovenia","Turkmenistan","Bolivia","Guernsey","China","Venezuela","British Virgin Islands","Argentina","Uruguay","Paraguay","Suriname","Guyana","Nicaragua","Costa Rica","Panama","Honduras","Belize","Peru","Portugal","Eritrea","Iceland","Afghanistan","India","Indonesia","Iraq","Iran","Yemen","Qatar","Kuwait","Oman","East Timor","Pakistan","Saudi Arabia","South Korea","United Arab Emirates","Cyprus","Dominica","Dominican Republic","Haiti","Cuba","Papua New Guinea","Armenia","Azerbaijan","Malta","Italy","Jersey","Bahrain","Japan","Philippines","Madagascar","Taiwan","Cape Verde","Comoros","Mauritius","São Tomé and Príncipe","Seychelles","Maldives","Singapore","Sri Lanka","Saint Kitts and Nevis","Antigua and Barbuda","Montserrat","The Bahamas","Turks and Caicos Islands","Barbados","Saint Vincent and the Grenadines","Grenada","Saint Lucia","Jamaica","Trinidad and Tobago","New Zealand","Kiribati","Fiji","Marshall Islands","Federated States of Micronesia","Nauru","Palau","Monaco","Liechtenstein","Gibraltar","Spain","Canada","Israel","Egypt","El Salvador","Guatemala","Niue","South Sudan","Palestine","Serbia","Solomon Islands","Samoa","Botswana","Saint Helena, Ascension and Tristan da Cunha","South Georgia and the South Sandwich Islands","Bermuda","British Indian Ocean Territory","Thailand","Kosovo","Lesotho","Brunei","Malaysia","Luxembourg","Anguilla","Vanuatu","Tuvalu","Greenland","Cook Islands","Cayman Islands","Falkland Islands","Pitcairn Islands","Tokelau","Tonga","France","Netherlands","Chad","Bosnia and Herzegovina","Norway","Morocco","Sahrawi Arab Democratic Republic"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[1.725891531, 42.502698451], [1.413577795, 42.535377145], [1.441990435, 42.603722513], [1.725891531, 42.502698451]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.940195113, 48.616540432], [18.850906938, 49.517148435], [19.467376471, 49.613762945], [20.079020709, 49.178476632], [20.325081199, 49.403028488], [21.630944163, 49.447309077], [22.565710098, 49.087994993], [22.155255675, 48.403387964], [20.54649353, 48.54429245], [19.937382638, 48.131118268], [18.833267391, 48.04823935], [18.646086752, 47.759091854], [17.160775959, 48.006657064], [16.842703521, 48.352397829], [16.940195113, 48.616540432]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[9.607054442, 47.060772032], [9.530748278, 47.270581126], [9.550565779, 47.537175268], [10.232348442, 47.270578444], [10.454439372, 47.555796504], [11.269884557, 47.397564948], [12.257028669, 47.74303481], [13.006620258, 47.464384139], [12.758125663, 48.126069009], [13.839552104, 48.771617711], [14.701261371, 48.582611829], [15.020972639, 49.020525366], [16.940195113, 48.616540432], [16.842703521, 48.352397829], [17.160775959, 48.006657064], [17.093089074, 47.708261311], [16.447321773, 47.696305364], [16.714523435, 47.53993392], [16.445458978, 47.407215536], [16.512319744, 47.001554221], [16.113886982, 46.869059801], [16.038091779, 46.656139344], [15.041036904, 46.651770025], [14.565175474, 46.372454166], [13.714062274, 46.522985101], [12.442498058, 46.688490808], [12.185959518, 47.09214583], [10.469654202, 46.85491249], [9.607054442, 47.060772032]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[16.113886982, 46.869059801], [16.512319744, 47.001554221], [16.445458978, 47.407215536], [16.714523435, 47.53993392], [16.447321773, 47.696305364], [17.093089074, 47.708261311], [17.160775959, 48.006657064], [18.646086752, 47.759091854], [18.833267391, 48.04823935], [19.937382638, 48.131118268], [20.54649353, 48.54429245], [22.155255675, 48.403387964], [22.897709906, 47.95404017], [22.036722153, 47.532665133], [21.180593222, 46.304115504], [20.264275521, 46.126353443], [18.890209347, 45.922052264], [17.86203146, 45.767734051], [16.596770436, 46.475902945], [16.113886982, 46.869059801]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[41.547048837, 41.520685405], [41.777276248, 41.863743961], [41.439710855, 42.738699317], [40.008500218, 43.385607898], [40.661775023, 43.563048095], [42.860266417, 43.178557456], [43.964510411, 42.546937466], [45.158373713, 42.707530707], [45.77550441, 42.488450557], [45.647516102, 42.186408341], [46.422069669, 41.908043325], [46.19229421, 41.626859307], [46.702415496, 41.328843087], [46.631185412, 41.097776145], [45.461212546, 41.455920786], [45.0138174, 41.296466142], [43.474144936, 41.12303853], [42.826584578, 41.592704058], [41.547048837, 41.520685405]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[12.445743531, 41.901960075], [12.457656562, 41.905821115], [12.446459681, 41.901663691], [12.445743531, 41.901960075]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[14.267430156, 53.697997481], [14.606995136, 53.401023299], [14.724173748, 54.008663276], [14.727052152, 54.023589492], [17.353460491, 54.749242365], [18.332313895, 54.833943844], [18.818965852, 54.628674388], [18.396674842, 54.747069776], [18.655974716, 54.34796378], [19.638423622, 54.458674639], [19.648877531, 54.453256577], [19.224144369, 54.335435182], [19.390768558, 54.144504815], [19.803781807, 54.442411065], [22.792006731, 54.363324791], [23.514977396, 53.956268728], [23.938640356, 52.712915987], [23.178334683, 52.283141613], [23.653640896, 52.072729021], [23.617829382, 51.507983208], [24.145736396, 50.869013965], [24.070104808, 50.503388643], [22.640830725, 49.529992193], [22.891552895, 49.007849246], [22.565710098, 49.087994993], [21.630944163, 49.447309077], [20.325081199, 49.403028488], [20.079020709, 49.178476632], [19.467376471, 49.613762945], [18.850906938, 49.517148435], [18.5729080 ...
