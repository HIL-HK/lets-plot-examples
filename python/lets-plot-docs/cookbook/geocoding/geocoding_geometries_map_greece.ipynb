# %%
from lets_plot.geo_data import *
from lets_plot import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="a4dryi"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("a4dryi").appendChild(div);
#                     };
#                     var e = document.getElementById("a4dryi");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
country = 'Greece'
gdf = geocode_counties().scope(country).inc_res(4).get_boundaries()

ggplot() + \
    geom_map(data=gdf, color='white', fill='#1a242f', \
             tooltips=layer_tooltips().line('@{found name}')) + \
    ggsize(800, 600) + ggtitle(country) + \
    theme_void()
# Out:
#    <div id="k5gjnV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("k5gjnV");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"Greece"
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# "found name":["Preveza Regional Unit","Karditsa Regional Unit","Larisa Regional Unit","Phthiotis Regional Unit","Regional Unit of Magnesia","Lasithi Regional Unit","Heraklion Regional Unit","Rethymno Regional Unit","Chania Regional Unit","Regional Unit of Boeotia","Regional Unit of Phocis","Euboea Regional Unit","Arta Regional Unit","Ioannina Regional Unit","Thesprotia Regional Unit","Trikala Regional Unit","Imathia Regional Unit","Pieria Regional Unit","Thessaloniki Regional Unit","Chalkidiki Regional Unit","Corinthia Regional Unit","Achaea Regional Unit","Arcadia Regional Unit","Argolis Regional Unit","Serres Regional Unit","Kavala Regional Unit","Drama Regional Unit","Kilkis Regional Unit","Xanthi Regional Unit","Rodopi Regional Unit","Evros Regional Unit","Lefkada Regional Unit","Aetolia-Acarnania Regional Unit","Kastoria Regional Unit","Florina Regional Unit","Kozani Regional Unit","Pella Regional Unit","Regional Unit of Islands","Kefallonia Regional Unit","Regional Unit of Evrytania","Elis Regional Unit","Messenia Regional Unit","Laconia Regional Unit","Corfu Regional Unit","Grevena Regional Unit","Samos Regional Unit","Chios Regional Unit","Regional Unit of Central Athens","Regional Unit of North Athens","Regional Unit of West Athens","Regional Unit of South Athens","Regional Unit of Piraeus","Regional Unit of East Attica","Regional Unit of West Attica","Sporades Regional Unit","Thasos Regional Unit","Zakynthos Regional Unit","Ithaca Regional Unit","Lemnos Regional Unit","Ikaria Regional Unit","Kea-Kythnos Regional Unit","Milos Regional Unit","Thira Regional Unit","Naxos Regional Unit","Paros Regional Unit","Andros Regional Unit","Mykonos Regional Unit","Tinos Regional Unit","Kalmynos Regional Unit","Kos Regional Unit","Rhodes Regional Unit","Karpathos Regional Unit","Lesbos Regional Unit"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[20.37212044, 39.356335849], [20.405641347, 39.318695068], [20.444692969, 39.311105758], [20.464113504, 39.273246378], [20.441080034, 39.282242507], [20.419564694, 39.274103343], [20.39483875, 39.285383373], [20.386844426, 39.277642518], [20.340234339, 39.283820987], [20.301138461, 39.315678924], [20.332223922, 39.345820248], [20.37212044, 39.356335849]]], [[[20.523641109, 39.304331839], [20.546386242, 39.291250706], [20.544335693, 39.308046699], [20.554320216, 39.314756244], [20.580904931, 39.302469045], [20.608327836, 39.326826185], [20.63860327, 39.334115088], [20.680413544, 39.287911355], [20.686852187, 39.281109273], [20.698521137, 39.286959171], [20.705557913, 39.335228205], [20.717438757, 39.336028844], [20.741616189, 39.381057769], [20.765847266, 39.370758086], [20.789523125, 39.373451024], [20.813962072, 39.347035289], [20.841443986, 39.352474809], [20.864097923, 39.369198382], [20.881209075, 39.365877807], [20.909757167, 39.377253056], [20.911705792, 39.394222051], [20.937939137, 39.394714236], [20.941291898, 39.384942949], [20.976741314, 39.406845868], [20.99235177, 39.393296689], [20.970863253, 39.35934931], [20.97099334, 39.346430451], [20.99046886, 39.344976693], [20.962933302, 39.318650812], [20.955622941, 39.293168485], [20.928917527, 39.284828156], [20.925468206, 39.271701425], [20.899987221, 39.257693589], [20.88520959, 39.251700193], [20.869275928, 39.260222912], [20.858568549, 39.247596413], [20.877421796, 39.216665179], [20.899127573, 39.202684164], [20.892302692, 39.162739366], [20.879792869, 39.171597362], [20.837833732, 39.132005274], [20.817467719, 39.141854346], [20.795574188, 39.111257046], [20.763319284, 39.101273865], [20.770663172, 39.053252935], [20.7789056, 39.045643508], [20.762007684, 39.035629481], [20.75456053, 39.007778764], [20.828479528, 38.969480842], [20.830956548, 38.95998314], [20.819668472, 38.954835981], [20.785730481, 38.972442001], [20.752563626, 38.974851966], [20.756877959, 38.950598091], [20.745049417, 38.94442901], [20.726369172, 38.949218094], [20.699653029, 38.997657448], [20.714988559, 39.014429301], [20.70489943, 39.048376679], [20.661070794, 39.088000953], [20.637936741, 39.09287855], [20.604920089, 39.115002751], [20.530197769, 39.190392941], [20.47487855, 39.219006747], [20.480352938, 39.238857776], [20.473695695, 39.238301218], [20.470601767, 39.263226986], [20.477342159, 39.274618328], [20.510775894, 39.287425876], [20.523641109, 39.304331839]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[21.372857988, 39.174475372], [21.35363996, 39.190720171], [21.348496825, 39.209467471], [21.369844526, 39.236188978], [21.394445747, 39.246881604], [21.427828521, 39.281240702], [21.429425776, 39.295778275], [21.411978006, 39.303885251], [21.410159469, 39.328045249], [21.399252266, 39.327916503], [21.398266554, 39.345074594], [21.381234527, 39.356322438], [21.377087831, 39.374974519], [21.422276348, 39.412596524], [21.475502104, 39.401697367], [21.489281952, 39.38615799], [21.515509933, 39.376094341], [21.559783816, 39.407280385], [21.571934223, 39.428066164], [21.59588635, 39.431874901], [21.58724159, 39.445759356], [21.595843434, 39.456026852], [21.63435325, 39.427780509], [21.660681814, 39.4471246], [21.702949405, 39.446490258], [21.743120849, 39.482646435], [21.756863147, 39.475303888], [21.751642227, 39.450054914], [21.772410572, 39.461459666], [21.800812483, 39.462477565], [21.842925847, 39.513778836], [21.879795492, 39.507527947], [21.891426891, 39.5202443], [21.90096885, 39.514812827], [21.895285249, 39.506434947], [21.90400511, 39.494159818], [21.93650946, 39.494741857], [21.91954717, 39.530274421], [21.939677149, 39.526366442], [21.997265518, 39.556325376], [22.014761567, 39.554246664], [22.048377693, 39.532374591], [22.091873735, 39.556944966], [22.141988128, 39.544106573], [22.177349031, 39.550644457], [22.175908685, 39.53242287], [22.188371569, 39.506472498], [22.210511863, 39.504950345], [22.2366955 ...
