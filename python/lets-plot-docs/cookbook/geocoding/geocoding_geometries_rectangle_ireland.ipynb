# %%
from lets_plot.geo_data import *
from lets_plot import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="H5JXBp"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("H5JXBp").appendChild(div);
#                     };
#                     var e = document.getElementById("H5JXBp");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
country = 'Ireland'
country_gdf = geocode_countries(names=country).inc_res(4).get_boundaries()
gdf = geocode_counties().scope(country).get_boundaries()

ggplot() + \
    geom_map(data=country_gdf, fill='#95a5a6', size=0) + \
    geom_rect(data=gdf, color='#95a5a6', size=1, alpha=0) + \
    geom_rect(data=gdf, color='white', size=.5, alpha=0, \
              tooltips=layer_tooltips().line('@{found name}')) + \
    ggsize(800, 600) + ggtitle(country) + \
    theme_void()
# Out:
#    <div id="3fqjEO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("3fqjEO");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"Ireland"
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-10.65036267, 52.077084929], [-10.656951517, 52.073559165], [-10.662462115, 52.076111287], [-10.65036267, 52.077084929]]], [[[-10.597877204, 52.041302919], [-10.606210828, 52.041403502], [-10.617697388, 52.049298584], [-10.597877204, 52.041302919]]], [[[-10.51953122, 52.110722512], [-10.508315563, 52.104408592], [-10.580378473, 52.072424591], [-10.51953122, 52.110722512]]], [[[-10.591780543, 52.125580609], [-10.572256744, 52.135400176], [-10.578865707, 52.124328017], [-10.591780543, 52.125580609]]], [[[-10.352622718, 51.935772747], [-10.331604928, 51.927988976], [-10.320941806, 51.934418231], [-10.316245258, 51.923942864], [-10.285796821, 51.926301867], [-10.290921181, 51.91384837], [-10.352237821, 51.891248077], [-10.391440988, 51.892554313], [-10.429552495, 51.880134344], [-10.409802049, 51.911372691], [-10.382278562, 51.913450062], [-10.350703597, 51.924683154], [-10.352622718, 51.935772747]]], [[[-10.289586782, 53.61921832], [-10.261707902, 53.608641028], [-10.284833908, 53.607297242], [-10.303663015, 53.602551073], [-10.289586782, 53.61921832]]], [[[-10.303849429, 51.931407452], [-10.3130427, 51.939252913], [-10.28745845, 51.938357055], [-10.303849429, 51.931407452]]], [[[-10.25559783, 51.735414416], [-10.236432105, 51.734411269], [-10.263920724, 51.72570616], [-10.25559783, 51.735414416]]], [[[-10.247977674, 53.549104035], [-10.258092284, 53.542415947], [-10.26124388, 53.547529578], [-10.247977674, 53.549104035]]], [[[-10.20773381, 53.524457216], [-10.21491006, 53.522454947], [-10.228106529, 53.523602933