# %% [markdown]
# # MPG Correlogram
#
# A correlogram provides a quick overview of the entire dataset and allows analysing the relationship between each pair of numerical variables.

# %%
import numpy as np
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="tPzBpu"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("tPzBpu").appendChild(div);
#                     };
#                     var e = document.getElementById("tPzBpu");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
df.drop(columns=["Unnamed: 0"], inplace=True)
print(df.shape)
df.head()
# Out:
# (234, 11)
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
corr_df = df.corr(numeric_only=True).stack().to_frame().reset_index()
corr_df.columns = ["x", "y", "corr"]
corr_df.head()
# Out:
#        x      y      corr
# 0  displ  displ  1.000000
# 1  displ   year  0.147843
# 2  displ    cyl  0.930227
# 3  displ    cty -0.798524
# 4  displ    hwy -0.766020

# %%
corr_df0 = corr_df[corr_df["x"] == corr_df["y"]]

corr_df1 = corr_df[corr_df["x"] < corr_df["y"]]
corr_df1 = pd.concat([
    corr_df1.assign(half="corr"),
    corr_df1.assign(corr=np.where(corr_df1["corr"] > 0, 1 - corr_df1["corr"], -1 - corr_df1["corr"]), half="remainder")
]).reset_index(drop=True)

corr_df2 = corr_df[corr_df["x"] > corr_df["y"]]
corr_df2 = corr_df2.assign(angle=np.where(corr_df2["corr"] > 0, np.pi / 4, 3 * np.pi / 4))

vars = sorted(corr_df["x"].unique())

# %% [markdown]
# ### The Correlogram
#
# Let's plot a correlogram of the mpg dataset variables. Here's how it should be interpreted:
#
# - The filled portion of the pie shows the correlation magnitude.
# - The diagonal of the squares shows the sign of the correlation.
# - The depth of the figures shading shows the correlation magnitude.
# - The names of the variables are on the diagonal.

# %%
ggplot() + \
    geom_pie(aes("x", "y", slice="corr", paint_a="corr"), \
             data=corr_df1, stat='identity', \
             size=1, size_unit='x', spacer_width=1, \
             fill_by='paint_a', tooltips='none') + \
    geom_pie(aes("x", "y", slice="corr", paint_b="half"), \
             data=corr_df1, stat='identity', \
             size=1, size_unit='x', show_legend=False, \
             fill_by='paint_b', tooltips='none') + \
    geom_point(aes("x", "y", paint_a="corr"), \
               data=corr_df2, shape=22, size=1, stroke=1, size_unit='x', \
               color="white", fill_by='paint_a', tooltips='none') + \
    geom_spoke(aes("x", "y", angle="angle"), \
               radius=np.sqrt(2), data=corr_df2, \
               pivot='middle', size=1, color="white") + \
    geom_text(aes("x", "y", label="x"), \
              data=corr_df0, size=1, size_unit='x') + \
    scale_x_discrete(breaks=vars, expand=[.1, 0]) + scale_y_discrete(breaks=vars, expand=[.1, 0]) + \
    scale_gradient2('paint_a', low="#a50026", mid="white", high="#313695") + \
    scale_manual('paint_b', values=["rgba(0, 0, 0, 0)", "lightgrey"]) + \
    coord_fixed() + \
    ggsize(660, 600) + \
    theme_void()
# Out:
#    <div id="FbNIbJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("FbNIbJ");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "flip":false
# },
# "ggsize":{
# "width":660.0,
# "height":600.0
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "breaks":["cty","cyl","displ","hwy","year"],
# "expand":[0.1,0.0],
# "discrete":true,
# "reverse":false
# },{
# "aesthetic":"y",
# "breaks":["cty","cyl","displ","hwy","year"],
# "expand":[0.1,0.0],
# "discrete":true,
# "reverse":false
# },{
# "aesthetic":"paint_a",
# "low":"#a50026",
# "mid":"white",
# "high":"#313695",
# "midpoint":0.0,
# "scale_mapper_kind":"color_gradient2"
# },{
# "aesthetic":"paint_b",
# "values":["rgba(0, 0, 0, 0)","lightgrey"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "data":{
# "x":["displ","displ","cyl","cyl","cyl","cty","cty","cty","cty","hwy","displ","displ","cyl","cyl","cyl","cty","cty","cty","cty","hwy"],
# "y":["year","hwy","displ","year","hwy","displ","year","cyl","hwy","year","year","hwy","displ","year","hwy","displ","year","cyl","hwy","year"],
# "corr":[0.147842816450222,-0.7660200208864679,0.9302271024198506,0.12224534743554387,-0.7619123538971951,-0.7985239689348549,-0.03723229085998419,-0.8057714082675281,0.9559159136495721,0.0021576430766139217,0.852157183549778,-0.23397997911353208,0.06977289758014937,0.8777546525644562,-0.23808764610280486,-0.2014760310651451,-0.9627677091400159,-0.19422859173247187,0.04408408635042793,0.9978423569233861]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "slice":"corr",
# "paint_a":"corr"
# },
# "tooltips":"none",
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"x"
# },{
# "type":"str",
# "column":"y"
# },{
# "type":"float",
# "column":"corr"
# },{
# "type":"str",
# "column":"half"
# }]
# },
# "spacer_width":1.0,
# "size_unit":"x",
# "fill_by":"paint_a",
# "size":1.0
# },{
# "geom":"pie",
# "stat":"identity",
# "data":{
# "x":["displ","displ","cyl","cyl","cyl","cty","cty","cty","cty","hwy","displ","displ","cyl","cyl","cyl","cty","cty","cty","cty","hwy"],
# "y":["year","hwy","displ","year","hwy","displ","year","cyl","hwy","year","year","hwy","displ","year","hwy","displ","year","cyl","hwy","year"],
# "corr":[0.147842816450222,-0.7660200208864679,0.9302271024198506,0.12224534743554387,-0.7619123538971951,-0.7985239689348549,-0.03723229085998419,-0.8057714082675281,0.9559159136495721,0.0021576430766139217,0.852157183549778,-0.23397997911353208,0.06977289758014937,0.8777546525644562,-0.23808764610280486,-0.2014760310651451,-0.9627677091400159,-0.19422859173247187,0.04408408635042793,0.9978423569233861],
# "half":["corr","corr","corr","corr","corr","corr","corr","corr","corr","corr","remainder","remainder","remainder","remainder","remainder","remainder","remainder","remainder","remainder","remainder"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "slice":"corr",
# "paint_b":"half"
# },
# "show_legend":false,
# "tooltips":"none",
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"x"
# },{
# "type":"str",
# "column":"y"
# },{
# "type":"float",
# "column":"corr"
# },{
# "type":"str",
# "column":"half"
# }]
# },
# "size_unit":"x",
# "fill_by":"paint_b",
# "size":1.0
# },{
# "geom":"point",
# "data":{
# "x":["displ","displ","year","year","year","year","cyl","hwy","hwy","hwy"],
# "y":["cyl","cty","displ","cyl","cty","hwy","cty","displ","cyl","cty"],
# "corr":[0.9302271024198506,-0.7985239689348549,0.147842816450222,0.12224534743554387,-0.03723229085998419,0.0021576430766139217,-0.8057714082675281,-0.7660200208864679,-0.7619123538971951,0.9559159136495721]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "paint_a":"corr"
# },
# "tooltips":"none",
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"x"
# },{
# "type":"str",
# "column":"y"
# },{
# "type":"float",
# "column":"corr"
# },{
# "type":"float",
# "column":"angle"
# }]
# },
# "size_unit":"x",
# "fill_by":"paint_a",
# "shape":22.0,
# "size":1.0,
# "stroke":1.0,
# "color":"white"
# },{
# "geom":"spoke",
# "data":{
# "x":["displ","displ","year","year","year","year","cyl","hwy","hwy","hwy"],
# "y":["cyl","cty","displ","cyl","cty","hwy","cty","displ","cyl","cty"],
# "angle":[0.7853981633974483,2.356194490192345,0.7853981633974483,0.7853981633974483,2.356194490192345,0.7853981633974483,2.356194490192345,2.356194490192345,2.356194490192345,0.7853981633974483]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "angle":"angle"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"x"
# },{
# "type":"str",
# "column":"y"
# },{
# "type":"float",
# "column":"corr"
# },{
# "type":"float",
# "column":"angle"
# }]
# },
# "pivot":"middle",
# "radius":1.4142135623730951,
# "size":1.0,
# "color":"white"
# },{
# "geom":"text",
# "data":{
# "x":["displ","year","cyl","cty","hwy"],
# "y":["displ","year","cyl","cty","hwy"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"x"
# },{
# "type":"str",
# "column":"y"
# },{
# "type":"float",
# "column":"corr"
# }]
# },
# "size_unit":"x",
# "size":1.0
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
