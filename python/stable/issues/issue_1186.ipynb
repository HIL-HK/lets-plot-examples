# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="ur0yoj"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# Display integer values without fractional part in tooltips [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1186

# %%
d = {
    'l': [3]
}

ggplot(d, aes(color='l')) + geom_point() + ggsize(300, 200)
# Out:
#    <div id="kQHKck"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("kQHKck");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "l":[3.0]
# },
# "mapping":{
# "color":"l"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"l"
# }]
# },
# "ggsize":{
# "width":300.0,
# "height":200.0
# },
# ...

# %%
d = {
    'l': [3_000_000],
}

ggplot(d, aes(color='l')) + geom_point() + ggsize(300, 200)
# Out:
#    <div id="b836uR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("b836uR");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "l":[3000000.0]
# },
# "mapping":{
# "color":"l"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"l"
# }]
# },
# "ggsize":{
# "width":300.0,
# "height":200.0
# },
# ...
