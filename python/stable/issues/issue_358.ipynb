# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="pp5tEH"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# https://github.com/JetBrains/lets-plot/issues/358 [Closed]
#
# Outlier tooltips: the spout sometimes is too long

# %%
ggplot() + geom_boxplot(aes(y=[0, 0, 1, 1, 1, 5, 3]))
# Out:
#    <div id="hNpben"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("hNpben");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "..x..":[0.0],
# "..middle..":[1.0],
# "..lower..":[0.5],
# "..upper..":[2.0],
# "..ymin..":[0.0],
# "..ymax..":[3.0]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "y":"y1"
# },
# "show_legend":false,
# ...

# %%
ggplot() + geom_boxplot(aes(y=[0.0, 0.0, 1.0, 1.0, 1.0, 5.0, 3.0]))
# Out:
#    <div id="GB1BcL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("GB1BcL");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "..x..":[0.0],
# "..middle..":[1.0],
# "..lower..":[0.5],
# "..upper..":[2.0],
# "..ymin..":[0.0],
# "..ymax..":[3.0]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# "y":"y1"
# },
# "show_legend":false,
# ...
