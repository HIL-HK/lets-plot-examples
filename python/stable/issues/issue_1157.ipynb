# %% [markdown]
# geom_histogram: wrong plot area when y='..density..' [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1157

# %%
from lets_plot import *
LetsPlot.setup_html()

ggplot({'x': [-.5, 0, 0, .5]}, aes(x='x')) + geom_histogram(aes(y='..density..'), binwidth=.5)

# The plot area is expected to be 1, but it was 2.
# Out:
#             <div id="uLm60b"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/b1b7450b950074bd3a02cde85664d56541d0e12a/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("uLm60b").appendChild(div);
#                     };
#                     var e = document.getElementById("uLm60b");
#                     e.appendChild(script);
#                 })()
#             </script>
#    <div id="kkb43K"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("kkb43K");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "y":"..density.."
# },
# "data_meta":{
# },
# "binwidth":0.5,
# "data":{
# "..density..":[0.5,1.0,0.5,0.0],
# "x":[-0.6,-0.09999999999999998,0.4,0.9]
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
data = {
    'x': [0] * 4 + [2, 2] * 4 + [4] * 4,
    'g': ["A", "B"] * 8,
    't': ["t1", "t1", "t2", "t2"] * 4,
}

# %%
ggplot(data, aes(x='x')) + geom_histogram(aes(y='..density..'), binwidth=2, center=0)
# Out:
#    <div id="agOQWq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("agOQWq");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"str",
# "column":"g"
# },{
# "type":"str",
# "column":"t"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "y":"..density.."
# },
# "data_meta":{
# },
# "binwidth":2.0,
# "center":0.0,
# "data":{
# "..density..":[0.125,0.25,0.125,0.0],
# "x":[0.0,2.0,4.0,6.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data, aes(x='x')) + geom_histogram(aes(y='..density..', fill='g'), binwidth=2, center=0)
# Out:
#    <div id="Jl9N2t"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Jl9N2t");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"str",
# "column":"g"
# },{
# "type":"str",
# "column":"t"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "y":"..density..",
# "fill":"g"
# },
# "data_meta":{
# },
# "binwidth":2.0,
# "center":0.0,
# "data":{
# "..density..":[0.125,0.25,0.125,0.0,0.125,0.25,0.125,0.0],
# "x":[0.0,2.0,4.0,6.0,0.0,2.0,4.0,6.0],
# "g":["A","A","A","A","B","B","B","B"]
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data, aes(x='x')) + geom_histogram(aes(y='..density..'), binwidth=2, center=0) + facet_grid(x='g')
# Out:
#    <div id="iub1AG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("iub1AG");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"str",
# "column":"g"
# },{
# "type":"str",
# "column":"t"
# }]
# },
# "facet":{
# "name":"grid",
# "x":"g",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "y":"..density.."
# },
# "data_meta":{
# "series_annotations":[]
# },
# "binwidth":2.0,
# "center":0.0,
# "data":{
# "..density..":[0.125,0.25,0.125,0.0,0.125,0.25,0.125,0.0],
# "x":[0.0,2.0,4.0,6.0,0.0,2.0,4.0,6.0],
# "g":["A","A","A","A","B","B","B","B"]
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data, aes(x='x')) + geom_histogram(aes(y='..density..', fill='t'), binwidth=2, center=0) + facet_grid(x='g')
# Out:
#    <div id="zDdEUG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("zDdEUG");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"str",
# "column":"g"
# },{
# "type":"str",
# "column":"t"
# }]
# },
# "facet":{
# "name":"grid",
# "x":"g",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "y":"..density..",
# "fill":"t"
# },
# "data_meta":{
# "series_annotations":[{
# "column":"t",
# "factor_levels":["t1","t2"]
# }]
# },
# "binwidth":2.0,
# "center":0.0,
# "data":{
# "..density..":[0.125,0.25,0.125,0.0,0.125,0.25,0.125,0.0,0.125,0.25,0.125,0.0,0.125,0.25,0.125,0.0],
# "x":[0.0,2.0,4.0,6.0,0.0,2.0,4.0,6.0,0.0,2.0,4.0,6.0,0.0,2.0,4.0,6.0],
# "t":["t1","t1","t1","t1","t2","t2","t2","t2","t1","t1","t1","t1","t2","t2","t2","t2"],
# "g":["A","A","A","A","A","A","A","A","B","B","B","B","B","B","B","B"]
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
