# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="LNHRnI"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# https://github.com/JetBrains/lets-plot/issues/478 [CLOSED]
#
# coord_fixed should adjust dimensions of "geom" panel accordingly.

# %%
data = dict(
    x = [-100, 100, -100, 100],
    y = [10, 10, -10, -10],
    c = ["a", "b", "c", "d"]
)
p = ggplot(data) + geom_point(aes("x", "y", color="c"), size = 5) + theme_grey()
p + coord_fixed() + ggtitle("Fixed")
# Out:
#    <div id="pYDvCz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("pYDvCz");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-100.0,100.0,-100.0,100.0],
# "y":[10.0,10.0,-10.0,-10.0],
# "c":["a","b","c","d"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"c"
# }]
# },
# "theme":{
# "name":"grey"
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "flip":false
# },
# "ggtitle":{
# ...

# %%
p + coord_fixed(ylim=[5, 15]) + ggtitle("Fixed with limits")
# Out:
#    <div id="bGpW9z"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("bGpW9z");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-100.0,100.0,-100.0,100.0],
# "y":[10.0,10.0,-10.0,-10.0],
# "c":["a","b","c","d"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"str",
# "column":"c"
# }]
# },
# "theme":{
# "name":"grey"
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "ylim":[5.0,15.0],
# "flip":false
# },
# ...
