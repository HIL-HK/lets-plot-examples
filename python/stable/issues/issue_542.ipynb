# %%
import numpy as np
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="9xat6A"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# `panel_border` parameter in `theme()` [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/542

# %%
df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")

# %%
p_plot = ggplot(df) + geom_point(aes('cty', 'hwy'))

# %%
w, h = 400, 300
e_rect = element_rect(color='#9e9eff', fill='#f0f8ff', size=8)

# %%
# compare theme parameters: panel_background and panel_border

bunch = GGBunch()
bunch.add_plot(p_plot + ggtitle("panel_background=e_rect") + theme(panel_background=e_rect), 0, 0, w, h)
bunch.add_plot(p_plot + ggtitle("panel_border=e_rect") + theme(panel_border=e_rect), w, 0, w, h)
bunch.show()
# Out:
#    <div id="EgBQns"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("EgBQns");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# ...
