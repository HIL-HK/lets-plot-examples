# %% [markdown]
#  geom_imshow and scale_y_reverse [closed]
#
# https://github.com/JetBrains/lets-plot/issues/1210

# %%
import numpy as np
from lets_plot import *
LetsPlot.setup_html()

# %%
img_array = np.array([
            [[255, 0, 0, 255], [0, 255, 0, 255], [0, 0, 255, 255]],
            [[0, 255, 0, 77], [0, 0, 255, 77], [255, 0, 0, 77]]
])
ggplot() + geom_imshow(img_array)

# %%
ggplot() + geom_imshow(img_array) + scale_y_reverse()
