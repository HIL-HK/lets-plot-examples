# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="qdHT4S"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# linetype = 0 ('blank') should make lines invisible [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/712

# %%
ggplot({"a": [1,2]}, aes("a","a")) + geom_line(linetype=0)
# Out:
#    <div id="aFIBno"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("aFIBno");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "a":[1.0,2.0]
# },
# "mapping":{
# "x":"a",
# "y":"a"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"a"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "data_meta":{
# },
# "linetype":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
# ...

# %%
ggplot({"a": [1,2]}, aes("a","a")) + geom_line(linetype='blank')
# Out:
#    <div id="O6S43N"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("O6S43N");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "a":[1.0,2.0]
# },
# "mapping":{
# "x":"a",
# "y":"a"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"a"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "data_meta":{
# },
# "linetype":"blank",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
# ...

# %%
ggplot({"a": [1,2]}, aes("a","a")) + geom_line()
# Out:
#    <div id="E0PcDd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("E0PcDd");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "a":[1.0,2.0]
# },
# "mapping":{
# "x":"a",
# "y":"a"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"a"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
# ...
