# %% [markdown]
# geom_imshow: unclear error message when mixing transparencies #1088 [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1088

# %%
from lets_plot import *
import numpy as np

LetsPlot.setup_html()

# %%
img_array = np.array([
    [[0, 0, 255, 255], [0, 0, 255, 127]],
    [[255, 0, 0, 127], [255, 0, 0, 255]]
])
ggplot() + geom_imshow(img_array, alpha=.5)

# problem is that we are using the alpha channel in the image and the alpha param 
# of the geom_imshow() function at the same time, and Lets-Plot cannot handle this case
