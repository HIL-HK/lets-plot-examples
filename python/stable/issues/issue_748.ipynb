# %%
from lets_plot import *
import numpy as np
import pandas as pd

LetsPlot.setup_html()
# Out:
#             <div id="NCREuE"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# geom_segment() doesn't take into account the alpha [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/748

# %%
ggplot() + \
    geom_segment(x=0, y=0, xend=1, yend=1, arrow=arrow(length=23), size=2, alpha=0.2)
# Out:
#    <div id="Fa8KwS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Fa8KwS");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":23.0
# },
# "x":0.0,
# ...

# %%
ggplot() + \
        geom_segment(x=2, y=10, xend=4, yend=9, alpha=0.2, size=2, \
                    arrow=arrow(type='closed', length=23)) + \
        geom_segment(x=3, y=6, xend=3, yend=9, alpha=0.2, size=2,\
                    arrow=arrow(type='open', length=23)) + \
        geom_segment(x=4, y=7, xend=5, yend=10, alpha=0.2, size=2,\
                    arrow=arrow(type='closed', ends='both', length=23)) + \
        geom_segment(x=5, y=8, xend=7, yend=7, alpha=0.2,\
                    arrow=arrow(type='open', ends='first', angle=120, length=23))
# Out:
#    <div id="llp5bC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("llp5bC");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":23.0,
# ...

# %%
np.random.seed(42)
x = np.random.uniform(1, 50, size=40)
data = pd.DataFrame({'x': x, 'y': np.sin(x)})

# %%
p = ggplot(data, aes(x='x', y='y'))
p + geom_line(size=2, alpha=0.2)
# Out:
#    <div id="TwEXof"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("TwEXof");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...
