# %%
import numpy as np

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="oXt5oD"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# https://github.com/JetBrains/lets-plot/issues/406 [CLOSED]
#
# Wrong tooltip formatting when used with log10 scales

# %%
np.random.seed(42)

n = 1000
x = np.linspace(-10, 10, n)
y = x ** 2 + np.random.normal(size=n)
z = 2.0 ** x + np.random.normal(size=n)
data = {'x': x, 'y': y, 'z': z}

# %%
ggplot(data, aes(x='x', y='y')) + \
    geom_point(aes(color='z')) + \
    scale_y_log10() + scale_color_gradient(low='red', high='green', trans='log10')
# Out:
#    <div id="yMsBkD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("yMsBkD");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...
