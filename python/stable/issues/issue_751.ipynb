# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="Zbikdr"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# `geom_pointrange()`: 'size' aesthetic shouldn't affect line width [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/751

# %%
ggplot() + geom_pointrange(x=0, ymin=0, ymax=2, y=1, size=10)
# Out:
#    <div id="Tzj5eb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Tzj5eb");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "ymin":0.0,
# "ymax":2.0,
# "y":1.0,
# "size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
# ...

# %%
ggplot() + geom_pointrange(x=0, ymin=0, ymax=2, y=1, size=10, linewidth=5)
# Out:
#    <div id="PfhZwg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("PfhZwg");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "ymin":0.0,
# "ymax":2.0,
# "y":1.0,
# "size":10.0,
# "linewidth":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
# ...

# %%
ggplot() + geom_pointrange(x=0, ymin=0, ymax=2, y=1, linewidth=5)
# Out:
#    <div id="bIQWvh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("bIQWvh");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "ymin":0.0,
# "ymax":2.0,
# "y":1.0,
# "linewidth":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
# ...

# %%
ggplot() + geom_pointrange(x=0, ymin=0, ymax=2, y=1)
# Out:
#    <div id="Ze7uqK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Ze7uqK");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "ymin":0.0,
# "ymax":2.0,
# "y":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
# ...
