# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="fD3g6k"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# `element_blank()` has no effect on plot title/subtitle/caption in theme() [CLOSED]
#
# " ... +  theme(plot_title=element_blank(), plot_subtitle=element_blank(), plot_caption=element_blank())"
#
# does not hide these elements on the plot.
#
# https://github.com/JetBrains/lets-plot/issues/913

# %%
mpg = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
mpg
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
p = ggplot(mpg) + geom_point(aes('displ', 'hwy', color = 'drv'))

p1 = p + ggtitle("The plot title using 'ggtitle()'")

p1
# Out:
#    <div id="Dr1AAb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Dr1AAb");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %%
p1 + theme(plot_title=element_blank())
# Out:
#    <div id="8o8t4B"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("8o8t4B");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %%
p2 = p + labs(title = "The plot title", subtitle = "The plot subtitle", caption = "The plot caption")

p2
# Out:
#    <div id="lYJQOB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("lYJQOB");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %%
p2 + theme(plot_title=element_blank(), plot_subtitle=element_blank(), plot_caption=element_blank())
# Out:
#    <div id="fkGMv5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("fkGMv5");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...
