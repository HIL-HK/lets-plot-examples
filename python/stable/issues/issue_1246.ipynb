# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="sGU2AY"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/1561a8f14654a770a66d34a80cb6d7ec56f43e32/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# Badly formatted zero break for the "~g" format [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1246
#
# The same applies to the "\~e" and "\~s" formats.

# %%
data = {
    "x": [1.7, 1.4, 1.5, 1.4, 1.5],
    "y": [
      0.05999999999999994,
      0.10999999999999982,
      -0.04000000000000009,
      0.009999999999999842,
      -0.1400000000000001
    ]
}

ggplot(data, aes('x', 'y')) + geom_point() + scale_y_continuous(format="~g")
# Out:
#    <div id="KHNXA2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("KHNXA2");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.7,1.4,1.5,1.4,1.5],
# "y":[0.05999999999999994,0.10999999999999982,-0.04000000000000009,0.009999999999999842,-0.1400000000000001]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "format":"~g"
# }],
# ...

# %%
ggplot(data, aes('x', 'y')) + geom_point() + scale_y_continuous(format="g")
# Out:
#    <div id="jmUVny"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("jmUVny");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.7,1.4,1.5,1.4,1.5],
# "y":[0.05999999999999994,0.10999999999999982,-0.04000000000000009,0.009999999999999842,-0.1400000000000001]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "format":"g"
# }],
# ...

# %%
ggplot(data, aes('x', 'y')) + geom_point() + scale_y_continuous(format="~s")
# Out:
#    <div id="GgrFys"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("GgrFys");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.7,1.4,1.5,1.4,1.5],
# "y":[0.05999999999999994,0.10999999999999982,-0.04000000000000009,0.009999999999999842,-0.1400000000000001]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "format":"~s"
# }],
# ...

# %%
ggplot(data, aes('x', 'y')) + geom_point() + scale_y_continuous(format="~e")
# Out:
#    <div id="dLT2th"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("dLT2th");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.7,1.4,1.5,1.4,1.5],
# "y":[0.05999999999999994,0.10999999999999982,-0.04000000000000009,0.009999999999999842,-0.1400000000000001]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "format":"~e"
# }],
# ...

# %%
ggplot(data, aes('x', 'y')) + geom_point() + scale_y_continuous(format="e")
# Out:
#    <div id="YRegG3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("YRegG3");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.7,1.4,1.5,1.4,1.5],
# "y":[0.05999999999999994,0.10999999999999982,-0.04000000000000009,0.009999999999999842,-0.1400000000000001]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"y",
# "format":"e"
# }],
# ...
