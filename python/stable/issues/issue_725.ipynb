# %%
import numpy as np
import pandas as pd
from IPython.display import SVG, Image, HTML
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="JVq3vm"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# HTML export: exclude computation messages from the output. [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/725

# %%
ps5 = ggplot() + geom_point(aes(
    x = [v for v in range(10)],
    y = [v for v in range(10)],
), sampling=sampling_random(5, seed=10))

ps4 = ggplot() + geom_point(aes(
    x = [v for v in range(10)],
    y = [v for v in range(10)],
), sampling=sampling_random(4, seed=10))

ps3 = ggplot() + geom_point(aes(
    x = [v for v in range(10)],
    y = [v for v in range(10)],
), sampling=sampling_random(3, seed=10))

ps2 = ggplot() + geom_point(aes(
    x = [v for v in range(10)],
    y = [v for v in range(10)],
), sampling=sampling_random(2, seed=10))

# %%
ps5
# Out:
#    <div id="9v91cH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("9v91cH");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "sampling":{
# "name":"random",
# "n":5.0,
# "seed":10.0
# },
# ...

# %%
ggsave(ps5, "issue725_ps5.svg")
# Out:
# INFO [PlotSvgExportCommon] : [when SVG generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_ps5.svg'

# %%
display(SVG(_))

# %%
ggsave(ps5, "issue725_ps5.png")
# Out:
# INFO [PlotSvgExportCommon] : [when SVG generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_ps5.png'

# %%
display(Image(_))

# %%
ggsave(ps5, "issue725_ps5.html")
# Out:
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_ps5.html'

# %%
display(HTML(_))
# Out:
#             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
#    &lt;head>
#        &lt;meta charset=&quot;UTF-8&quot;>
#        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
#        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
#    &lt;/head>
#    &lt;body>
#           &lt;div id=&quot;9EOQN8&quot;>&lt;/div>
#    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: &quot;FIXED&quot;,
#        height_mode: &quot;FIXED&quot;,
#        width: 600.0,
#        height: 400.0
#    };
#
# ...

# %%
ggbunch(
    [
        ps5 + ggtitle('ps5'),
        ps4 + labs(caption='ps4')
    ],
    [
        (0, 0, 1, .5),
        (0, .5, 1, .5),
    ]
) + labs(title='bunch')
# Out:
#    <div id="BmeRzL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("BmeRzL");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtitle":{
# "text":"bunch"
# },
# "kind":"subplots",
# "layout":{
# "regions":[[0.0,0.0,1.0,0.5],[0.0,0.5,1.0,0.5]],
# "name":"free"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# ...

# %%
ggsave(_, "issue725_bunch.html")
# Out:
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=4, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_bunch.html'

# %%
display(HTML(_))
# Out:
#             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
#    &lt;head>
#        &lt;meta charset=&quot;UTF-8&quot;>
#        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
#        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
#    &lt;/head>
#    &lt;body>
#           &lt;div id=&quot;S4tbwM&quot;>&lt;/div>
#    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: &quot;FIXED&quot;,
#        height_mode: &quot;FIXED&quot;,
#        width: 600.0,
#        height: 400.0
#    };
#
# ...

# %%
gggrid([None, ps5, ps4], ncol=2)
# Out:
#    <div id="quZXT1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("quZXT1");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":["blank",{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# ...

# %%
ggsave(_, "issue725_ggrid1.html")
# Out:
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=4, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_ggrid1.html'

# %%
display(HTML(_))
# Out:
#             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
#    &lt;head>
#        &lt;meta charset=&quot;UTF-8&quot;>
#        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
#        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
#    &lt;/head>
#    &lt;body>
#           &lt;div id=&quot;bEFbim&quot;>&lt;/div>
#    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: &quot;FIXED&quot;,
#        height_mode: &quot;FIXED&quot;,
#        width: 600.0,
#        height: 400.0
#    };
#
# ...

# %%
gggrid([None, ps5, ps4, gggrid([ps3, None])], ncol=2) + ggtitle('2 grids 3 plots')
# Out:
#    <div id="2rZx3W"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("2rZx3W");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtitle":{
# "text":"2 grids 3 plots"
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":["blank",{
# "mapping":{
# },
# "data_meta":{
# },
# ...

# %%
ggsave(_, "issue725_ggrid2.html")
# Out:
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=5, seed=10) was applied to [point/identity stat] layer
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=4, seed=10) was applied to [point/identity stat] layer
# INFO [PlotHtmlHelper] : [when HTML generating] sampling_random(n=3, seed=10) was applied to [point/identity stat] layer
# '/Users/earkhipova/Projects/lets-plot-examples/python/stable/issues/lets-plot-images/issue725_ggrid2.html'

# %%
display(HTML(_))
# Out:
#             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
#    &lt;head>
#        &lt;meta charset=&quot;UTF-8&quot;>
#        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
#        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
#    &lt;/head>
#    &lt;body>
#           &lt;div id=&quot;Snq9RX&quot;>&lt;/div>
#    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: &quot;FIXED&quot;,
#        height_mode: &quot;FIXED&quot;,
#        width: 600.0,
#        height: 400.0
#    };
#
# ...
