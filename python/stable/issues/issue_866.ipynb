# %%
from lets_plot import *
from lets_plot.bistro.corr import *
LetsPlot.setup_html()
# Out:
#             <div id="UyqQmA"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# Combination of `corr_plot()` and `theme_void()` looks weird on axes
#
# Link: https://github.com/JetBrains/lets-plot/issues/866

# %%
data = {
    'x': [0, 1, 2],
    'y': [2, 0, 1],
}

corr_plot(data).tiles().build() + theme_void()
# Out:
#    <div id="Yyxoxq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Yyxoxq");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "theme":{
# "axis_title":{
# "blank":true
# },
# "axis_line":{
# "blank":true
# },
# "panel_grid":{
# "blank":true
# },
# "axis_ticks_x":{
# "blank":false
# },
# "axis_ticks_y":{
# ...
