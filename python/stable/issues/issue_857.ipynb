# %%
from lets_plot import *
from lets_plot import tilesets
LetsPlot.setup_html()
# Out:
#             <div id="31wEp6"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("31wEp6").appendChild(div);
#                     };
#                     var e = document.getElementById("31wEp6");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# `theme / flavor` plot background is not shown on plot with `geom_livemap()` layer. [CLOSED]
#
# Link: https://github.com/JetBrains/lets-plot/issues/857

# %%
d = {
    'x': [20, 30, 40],
    'y': [60, 60, 60],
    's': [1, 5, 10],
    'g': ['A', 'B', 'C']
}

p = ggplot(d, aes(x='x', y='y', color='g', size='s')) + flavor_darcula()
gggrid([
    p + geom_point() + ggtitle("geom_point()"),
    p + geom_livemap() + geom_point() + ggtitle("geom_livemap() + geom_point()")
])
# Out:
#    <div id="duKd3i"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("duKd3i");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_point()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_livemap() + geom_point()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# без рамок в легенде у livemap

p = ggplot(d, aes(x='x', y='y')) + flavor_darcula()
gggrid([
    p + geom_point(aes(color='g', size='s')) + ggtitle("geom_point()"),
    p + geom_livemap() + geom_point(aes(color='g', size='s')) + ggtitle("geom_livemap() + geom_point()")
])
# Out:
#    <div id="2nKlvI"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("2nKlvI");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_point()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_livemap() + geom_point()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# фасеты и параметры фона

p + geom_livemap() + geom_point(aes(color='g', size='s')) + facet_wrap(facets='g', ncol=3) \
    + theme(plot_background=element_rect(color='orange', size=10)) + ggsize(800, 300)
# Out:
#    <div id="YVJBLr"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("YVJBLr");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula",
# "plot_background":{
# "color":"orange",
# "size":10.0,
# "blank":false
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"g",
# "ncol":3.0,
# "order":1.0,
# "dir":"h"
# },
# "ggsize":{
# "width":800.0,
# "height":300.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
p = ggplot(d, aes(x='x', y='y', color='g', size='s')) + flavor_darcula()
gggrid([
    p + geom_point() + ggtitle("geom_point()"),
    p + geom_livemap() + ggtitle("geom_livemap()")
])
# Out:
#    <div id="NOO2Y2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("NOO2Y2");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_point()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "x":[20.0,30.0,40.0],
# "y":[60.0,60.0,60.0],
# "s":[1.0,5.0,10.0],
# "g":["A","B","C"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "color":"g",
# "size":"s"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"s"
# },{
# "type":"str",
# "column":"g"
# }]
# },
# "theme":{
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"geom_livemap()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
