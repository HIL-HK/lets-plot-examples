# %% [markdown]
# Incorrect position for bar annotations when specifying `scale_x_reverse()`/`scale_y_reverse()`
# [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1057

# %%
import pandas as pd
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="6SNcRe"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/b1b7450b950074bd3a02cde85664d56541d0e12a/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %%
mpg_df = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")

p = ggplot(mpg_df) + geom_bar(aes("trans"),labels=layer_labels().line('@..count..')) 
p
# Out:
#    <div id="DQZQcQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("DQZQcQ");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# ...

# %%
# The default position of the annotations is at the base of the bars.

p + scale_y_reverse()
# Out:
#    <div id="WcqiU3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("WcqiU3");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# ...
