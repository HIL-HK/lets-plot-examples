# %% [markdown]
# # [Issue #1290](https://github.com/JetBrains/lets-plot/issues/1290) - `geom_bin2d`: wrong geometry size when `bins=[n, 1]`

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="CRgTvt"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("CRgTvt").appendChild(div);
#                     };
#                     var e = document.getElementById("CRgTvt");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Original Examples

# %%
data = {
    'x': [0, 0, 1, 2],
    'y': [0, 0, 1, 2],
}

# %%
ggplot(data, aes('x', 'y')) + geom_bin2d(bins=[2, 1]) + geom_point(color="red")
# Out:
#    <div id="TCYpD8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("TCYpD8");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "data":{
# "..count..":[2.0,2.0],
# "x":[0.25,1.75],
# "y":[1.0,1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data, aes('x', 'y')) + geom_bin2d(bins=[1, 2]) + geom_point(color="red")
# Out:
#    <div id="LANh33"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("LANh33");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,2.0],
# "data":{
# "..count..":[2.0,2.0],
# "x":[1.0,1.0],
# "y":[0.25,1.75]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
ggplot(data, aes('x', 'y')) + geom_bin2d(bins=[1, 1]) + geom_point(color="red")
# Out:
#    <div id="1gDrRS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("1gDrRS");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,1.0],
# "data":{
# "..count..":[4.0],
# "x":[1.0],
# "y":[1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Additional Tests

# %%
def get_test(data, bins, geom):
    return ggplot(data, aes('x', 'y')) + \
        geom(bins=bins, color="white", size=.5) + \
        geom_point(color="red") + \
        ggtitle("{geom}(bins={bins})".format(geom=geom.__name__, bins=bins))

# %%
data1 = {
    'x': [0, 0, 1, 2],
    'y': [0, 0, 1, 2],
}

data2 = {
    'x': [0, 0, 20, 40],
    'y': [0, 0, 0, 0],
}

data3 = {
    'x': [0, 0, 0, 0],
    'y': [0, 0, 20, 40],
}

# %%
gggrid([
    get_test(data1, [2, 1], geom_bin2d),
    get_test(data1, [1, 2], geom_bin2d),
    get_test(data1, [1, 1], geom_bin2d),
    get_test(data1, [2, 1], geom_hex),
    get_test(data1, [1, 2], geom_hex),
    get_test(data1, [1, 1], geom_hex),

    get_test(data2, [2, 1], geom_bin2d),
    get_test(data2, [1, 2], geom_bin2d),
    get_test(data2, [1, 1], geom_bin2d),
    get_test(data2, [2, 1], geom_hex),
    get_test(data2, [1, 2], geom_hex),
    get_test(data2, [1, 1], geom_hex),

    get_test(data3, [2, 1], geom_bin2d),
    get_test(data3, [1, 2], geom_bin2d),
    get_test(data3, [1, 1], geom_bin2d),
    get_test(data3, [2, 1], geom_hex),
    get_test(data3, [1, 2], geom_hex),
    get_test(data3, [1, 1], geom_hex),
], ncol=3)
# Out:
#    <div id="hULC3l"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("hULC3l");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":6.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[2, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[0.25,1.75],
# "y":[1.0,1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[1, 2])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,2.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[1.0,1.0],
# "y":[0.25,1.75]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[1, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[4.0],
# "x":[1.0],
# "y":[1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[2, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[0.0,2.0],
# "y":[1.0,1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[1, 2])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,2.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[-0.5,2.5],
# "y":[0.0,2.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# },{
# "data":{
# "x":[0.0,0.0,1.0,2.0],
# "y":[0.0,0.0,1.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[1, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[4.0],
# "x":[1.0],
# "y":[1.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[2, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[5.0,35.0],
# "y":[0.0,0.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[1, 2])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,2.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[NaN,4.0],
# "x":[NaN,20.0],
# "y":[-0.25,0.25]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[1, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[4.0],
# "x":[20.0],
# "y":[0.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[2, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[0.0,40.0],
# "y":[0.0,0.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[1, 2])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,2.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[2.0,2.0],
# "x":[-10.0,50.0],
# "y":[-0.25,0.25]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# },{
# "data":{
# "x":[0.0,0.0,20.0,40.0],
# "y":[0.0,0.0,0.0,0.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_hex(bins=[1, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"hex",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[1.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[4.0],
# "x":[20.0],
# "y":[0.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# },{
# "data":{
# "x":[0.0,0.0,0.0,0.0],
# "y":[0.0,0.0,20.0,40.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"geom_bin2d(bins=[2, 1])"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bin2d",
# "mapping":{
# },
# "data_meta":{
# },
# "bins":[2.0,1.0],
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[NaN,4.0],
# "x":[NaN,0.25],
# "y":[20.0,20.0]
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "d
