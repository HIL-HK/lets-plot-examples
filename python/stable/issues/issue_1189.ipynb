# %%
from lets_plot import *
import pandas as pd

LetsPlot.setup_html()
# Out:
#             <div id="DHc6C3"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/1561a8f14654a770a66d34a80cb6d7ec56f43e32/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# ggmarginal: bottom boxplot is broken [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1189

# %%
data = {
    "x": [0, 0, 1, 1, 1, 2],
    "y": [0, 0, 2, 2, 2, 1],
}

# %%
ggplot(data, aes("x", "y")) + \
    geom_point() + \
    ggmarginal("trbl", layer=geom_violin(color='blue', fill='blue', alpha=.1)) + \
    ggmarginal("trbl", layer=geom_boxplot(color='red', fill='red', alpha=.1))
# Out:
#    <div id="qBH889"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("qBH889");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[0.0,0.0,1.0,1.0,1.0,2.0],
# "y":[0.0,0.0,2.0,2.0,2.0,1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"violin",
# "mapping":{
# ...
