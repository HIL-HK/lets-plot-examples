# %%
from lets_plot import *
from IPython.display import display, HTML, SVG
LetsPlot.setup_html()
# Out:
#             <div id="FmIGZ8"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# `gggrid`: composite plot is not visible if saved with `ggsave` [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/942

# %%
p = gggrid(
    [
        ggplot() + geom_point(x=0, y=0, size=24, color='red'),
        gggrid([
            ggplot() + geom_point(x=0, y=0, size=24, color='green')
        ])
    ], 
    ncol=2
)

p
# Out:
#    <div id="g9Xtf7"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("g9Xtf7");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":24.0,
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "kind":"subplots",
# "layout":{
# ...

# %%
print("HTML")
p.show()
# Out:
# HTML
#    <div id="mSFNfV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("mSFNfV");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":0.0,
# "y":0.0,
# "size":24.0,
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "kind":"subplots",
# ...

# %%
print("SVG")
display(SVG(ggsave(p, 'invisible_composite.svg')))
# Out:
# SVG
