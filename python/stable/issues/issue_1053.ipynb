# %% [markdown]
# Add tooltips for geom_curve()
#
# https://github.com/JetBrains/lets-plot/issues/1053

# %%
import pandas as pd
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="R8xj7G"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/b1b7450b950074bd3a02cde85664d56541d0e12a/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("R8xj7G").appendChild(div);
#                     };
#                     var e = document.getElementById("R8xj7G");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def curve_plot(curvature=0.5, angle=90.0, ncp=5):
    return ggplot() \
            + geom_curve(x=-10, y=1, xend=10, yend=-1, 
                         curvature=curvature, angle=angle, ncp=ncp,
                         arrow=arrow(ends='both'), tooltips=layer_tooltips().line("Tooltip")) \
            + ggtitle("curvature={0}, angle={1}, ncp={2}".format(curvature, angle, ncp)) \
            + xlim(-15,15)

# %%
gggrid([
    curve_plot(angle=0),
    curve_plot(ncp=1),
    curve_plot(angle=45),
    curve_plot(curvature=-1, angle=45),
    curve_plot(curvature=0.7, angle=30),
    curve_plot(curvature=-0.7, angle=30),
], ncol=2)
# Out:
#    <div id="BSzGio"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("BSzGio");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=0.5, angle=0, ncp=5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":0.5,
# "angle":0.0,
# "ncp":5.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=0.5, angle=90.0, ncp=1"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":0.5,
# "angle":90.0,
# "ncp":1.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=0.5, angle=45, ncp=5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":0.5,
# "angle":45.0,
# "ncp":5.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=-1, angle=45, ncp=5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":-1.0,
# "angle":45.0,
# "ncp":5.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=0.7, angle=30, ncp=5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":0.7,
# "angle":30.0,
# "ncp":5.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"curvature=-0.7, angle=30, ncp=5"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[-15.0,15.0]
# }],
# "layers":[{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["Tooltip"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "ends":"both"
# },
# "curvature":-0.7,
# "angle":30.0,
# "ncp":5.0,
# "x":-10.0,
# "y":1.0,
# "xend":10.0,
# "yend":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Annotate Objects on Plot

# %%
mpg = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
mpg.head(3)
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact

# %%
(ggplot(mpg) + geom_bar(aes(x="class"))
     + geom_curve(x=5, y=55, xend=3, yend=6,
                size_start=50, linetype='dashed',
                arrow=arrow(length=10, ends='last', type="closed"),
                tooltips=layer_tooltips().line("2seater"))
     + geom_text(label="Zoom Zoom!", x=5, y=55)
)
# Out:
#    <div id="N30JNV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("N30JNV");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"class"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[47.0,41.0,62.0,5.0,11.0,33.0,35.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# },{
# "geom":"curve",
# "mapping":{
# },
# "tooltips":{
# "formats":[],
# "lines":["2seater"]
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":10.0,
# "ends":"last",
# "type":"closed"
# },
# "x":5.0,
# "y":55.0,
# "xend":3.0,
# "yend":6.0,
# "size_start":50.0,
# "linetype":"dashed",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "label":"Zoom Zoom!",
# "x":5.0,
# "y":55.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
