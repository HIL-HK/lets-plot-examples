# %% [markdown]
# ggsave: theme option face="italic" doesn't work [Closed]
#
# https://github.com/JetBrains/lets-plot/issues/1391

# %%
from IPython.display import Image
from lets_plot import *

LetsPlot.setup_html()

# %%
p = ggplot() + geom_blank() + theme(
    axis_title_x=element_text(face='italic'),
    axis_text_x=element_text(face='bold_italic'), 

    axis_title_y=element_text(face='italic'),
    axis_text_y=element_text(face='bold_italic')
)

display(Image(ggsave(p, "missing_italic_face.png", scale=1)))

# %%
p1 = ggplot() + geom_text(x=0, y=0, label="Test", fontface='italic', size=12) + \
    geom_label(x=0, y=0.1, label="Test label", fontface='bold_italic') + theme(
    axis_title_x=element_text(face='italic'),
    axis_text_x=element_text(face='bold_italic'),
    axis_title_y=element_text(face='italic'),
    axis_text_y=element_text(face='bold_italic')
)

display(Image(ggsave(p1, "missing_italic.png", scale=1)))
