# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="mmRWrU"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# `geom_crossbar`: an error occurs if the mapped values of aesthetics are not populated. [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/886

# %%
data = {
    'drink': ['coffee','tea','water', 'milk'],
    'mean': [3, 4, 6, 2],
    'upper': [1, 5, 7, 4],
    'lower': [6, 3, 2, 1]
}

ggplot(data, aes(x='drink', y='mean', ymin='lower', ymax='upper', color='mean')) + geom_crossbar()
# Out:
#    <div id="aI8QhX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("aI8QhX");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "drink":["coffee","tea","water","milk"],
# "mean":[3.0,4.0,6.0,2.0],
# "upper":[1.0,5.0,7.0,4.0],
# "lower":[6.0,3.0,2.0,1.0]
# },
# "mapping":{
# "x":"drink",
# "y":"mean",
# "ymin":"lower",
# ...
