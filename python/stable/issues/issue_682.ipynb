# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="30DpJc"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# livemap: wrong position when path goes through the antimeridian [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/682

# %%
data = {
    'lon': [-122.25165, 139.4130],
    'lat': [37.464958, 35.4122],
}

# %%
ggplot(data) + geom_livemap() + \
    geom_segment(
        xend=data['lon'][0], 
        yend=data['lat'][0], 
        x=data['lon'][1], 
        y=data['lat'][1], 
        flat=True)
# Out:
#    <div id="tdJhbl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("tdJhbl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"lon"
# },{
# "type":"float",
# "column":"lat"
# }]
# },
# "kind":"plot",
# "scales":[],
# ...

# %% [markdown]
# https://github.com/JetBrains/lets-plot/issues/691
# livemap: wrong position if segment goes through the antimeridian

# %%
data = {
    'lon': [-73.7997, 124.0012],
    'lat': [5.6408, 1.3256],
}

# %%
ggplot(data, ) + \
    geom_livemap(tiles=maptiles_lets_plot(theme='dark')) + \
    geom_segment(xend=data['lon'][0], yend=data['lat'][0], x=data['lon'][1], y=data['lat'][1], color='white', flat=True)
# Out:
#    <div id="dIKGWQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("dIKGWQ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"lon"
# },{
# "type":"float",
# "column":"lat"
# }]
# },
# "kind":"plot",
# "scales":[],
# ...
