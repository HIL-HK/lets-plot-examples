# %%
from lets_plot import *
import numpy as np
from IPython.display import SVG

LetsPlot.setup_html()
# Out:
#             <div id="BJ2I5X"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# `ggsave()` doesn't save `geom_raster()` layer to a file
#
# https://github.com/JetBrains/lets-plot/issues/778

# %%
data = {
    "x": [ -1.0, 1.0, -1.0, 1.0 ],
    "y": [ -1.0, -1.0, 1.0, 1.0 ],
    "z": [ 0.024, 0.094, 0.094, 0.024 ]
}
p = ggplot(data) + \
    geom_raster(aes(x='x', y='y', fill='z'), data=data) + \
    geom_point(aes(x='x', y='y'), size=8, color='red', data=data) + \
    scale_fill_gradient(low="#54278f", high="#f2f0f7")

print("Plot")
p.show()

print("Image")
plot_filename = ggsave(p, 'issue_ggsave_raster1.svg')
display(SVG(plot_filename))
# Out:
# Plot
#    <div id="eWXU2o"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("eWXU2o");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# ...

# %%
p1 = ggplot(data) + \
    geom_raster(aes(x='x', y='y', fill='z'), data=data)
p1.show()

fullpath_png = ggsave(p1, 'plot1.png')
# Out:
#    <div id="8JXYmQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("8JXYmQ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"z"
# }]
# },
# ...

# %%
from IPython.display import Image

Image(filename=fullpath_png, width=600, height=400)
