# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="BsnVJh"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# "Variable not found" error in ggmarginal [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/681

# %%
ggplot({'x': [], 'y': []}, aes('x', 'y')) + \
    geom_point() + \
    ggmarginal("t", layer=geom_histogram())
# Out:
#    <div id="XptKq5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("XptKq5");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"histogram",
# "mapping":{
# "y":"..density.."
# },
# "data_meta":{
# },
# "marginal":true,
# "margin_side":"t",
# "data":{
# "..x..":[],
# "..count..":[],
# "..group..":[]
# }
# }],
# ...

# %%
ggplot(data={'x': [1, 2], 'y': [1, 2]}) + \
    geom_smooth(aes('x', 'y'), tooltips=layer_tooltips().line('@..se..'))
# Out:
#    <div id="sveR9l"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("sveR9l");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"smooth",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["@..se.."]
# },
# "data_meta":{
# },
# "data":{
# "..ymin..":[],
# "..ymax..":[],
# "..se..":[],
# ...
