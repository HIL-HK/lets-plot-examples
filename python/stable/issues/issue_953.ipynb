# %%
from lets_plot import *
import numpy as np
LetsPlot.setup_html()
# Out:
#             <div id="zcqXsM"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %% [markdown]
# `scale_continuous()` fails with non-color aesthetics [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/953

# %%
np.random.seed(42)
x = np.random.randint(-5, 5, size=25)

ggplot({'x': x}, aes(x='x')) + geom_histogram(bins=8) + \
    scale_continuous('x', breaks=[-5, -2, 1, 4])
# Out:
#    <div id="qAi4Dm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("qAi4Dm");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# ...

# %%
ggplot({'x': x}, aes(x='x')) + geom_histogram(bins=8)
# Out:
#    <div id="Y7xdQN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Y7xdQN");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# ...

# %%
ggplot({'x': x}, aes(x='x')) + geom_histogram(bins=8) + \
    scale_continuous('x', breaks=[-3, -2, 1, 3])
# Out:
#    <div id="ggTKfC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ggTKfC");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# ...
