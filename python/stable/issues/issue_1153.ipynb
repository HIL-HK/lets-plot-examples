# %% [markdown]
# `waterfall_plot`: tooltips doesn't work with column names from original dataset [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/1153

# %%
from lets_plot import *
LetsPlot.setup_html()

from lets_plot.bistro import *
# Out:
#             <div id="XN4dVi"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
data = {
    'cat': ['A', 'B'],
    'val': [1, 2],
}

# %%
waterfall_plot(data, 'cat', 'val', relative_tooltips=layer_tooltips().line("@cat/@..xlabel.."))
# Out:
#    <div id="ybXEIf"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ybXEIf");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"..ymin.."
# },{
# "type":"int",
# "column":"..ymiddle.."
# },{
# "type":"int",
# "column":"..ymax.."
# },{
# ...
