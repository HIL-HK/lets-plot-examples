# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="2fZFzz"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("2fZFzz").appendChild(div);
#                     };
#                     var e = document.getElementById("2fZFzz");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# Incorrect 'plot_background' area (with empty space capture) [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/918

# %%
margins = theme(plot_margin=[5, 0, 0, 40])

p = ggplot() \
    + geom_point(aes(x=[0, 1, 2], y=[1, 2, 3])) \
    + theme(
        plot_background=element_rect(size=5, fill='light_grey', color='grey'),
        panel_background=element_rect(fill='orange'),
        panel_grid_minor=element_line(),
    )

gggrid([
    p + ggtitle('Default'),
    p + coord_fixed(0.3) + ggtitle('coord_fixed()'),
    p + margins + ggtitle('plot_margin=[5, 0, 0, 40]'),
    p + margins + coord_fixed(0.3) + ggtitle('plot_margin=[5, 0, 0, 40] + coord_fixed()'),
], ncol=2)
# Out:
#    <div id="K9NrYV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("K9NrYV");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0,1.0,2.0],
# "y":[1.0,2.0,3.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# }
# },
# "coord":{
# "name":"fixed",
# "ratio":0.3,
# "flip":false
# },
# "ggtitle":{
# "text":"coord_fixed()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0,1.0,2.0],
# "y":[1.0,2.0,3.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# },
# "plot_margin":[5.0,0.0,0.0,40.0]
# },
# "ggtitle":{
# "text":"plot_margin=[5, 0, 0, 40]"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0,1.0,2.0],
# "y":[1.0,2.0,3.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# },
# "plot_margin":[5.0,0.0,0.0,40.0]
# },
# "coord":{
# "name":"fixed",
# "ratio":0.3,
# "flip":false
# },
# "ggtitle":{
# "text":"plot_margin=[5, 0, 0, 40] + coord_fixed()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0,1.0,2.0],
# "y":[1.0,2.0,3.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
p = ggplot() \
    + geom_livemap() \
    + geom_point(aes(x=[10, 20, 30], y=[0, 10, 20])) \
    + theme(
        plot_background=element_rect(size=5, fill='light_grey', color='grey'),
        panel_background=element_rect(fill='orange'),
        panel_grid_minor=element_line(),
    )

gggrid([
    p,
    p + margins,
    p + margins + facet_grid(x='x'),
])
# Out:
#    <div id="h4IXVh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("h4IXVh");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[10.0,20.0,30.0],
# "y":[0.0,10.0,20.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# },
# "plot_margin":[5.0,0.0,0.0,40.0]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# "x":[10.0,20.0,30.0],
# "y":[0.0,10.0,20.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "panel_background":{
# "fill":"orange",
# "blank":false
# },
# "panel_grid_minor":{
# "blank":false
# },
# "plot_background":{
# "fill":"light_grey",
# "color":"grey",
# "size":5.0,
# "blank":false
# },
# "plot_margin":[5.0,0.0,0.0,40.0]
# },
# "facet":{
# "name":"grid",
# "x":"x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[]
# },
# "data":{
# "x":[10.0,20.0,30.0],
# "y":[0.0,10.0,20.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
