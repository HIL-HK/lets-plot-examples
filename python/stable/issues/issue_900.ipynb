# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="Xv65xN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
# ...

# %% [markdown]
# `ggsave()` to .html does not work with special characters [CLOSED]
#
# https://github.com/JetBrains/lets-plot/issues/900

# %%
plot = ggplot() + geom_label(x=1, y=0, label='Espírito  €, ü, ä, ö')
plot
# Out:
#    <div id="Ron1GK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Ron1GK");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"label",
# "mapping":{
# },
# "data_meta":{
# },
# "x":1.0,
# "y":0.0,
# "label":"Espírito  €, ü, ä, ö",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
# ...

# %%
p=ggsave(plot, 'plot1.png', iframe=True)

# %%
from IPython.display import Image

display(Image(p))

# %%
p2=ggsave(plot, 'plot2.png', iframe=False)

# %%
display(Image(p2))

# %%
p3=ggsave(plot, "plot1.html", iframe=True)

# %%
from IPython.display import HTML

display(HTML(p3))
# Out:
#             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
#    &lt;head>
#        &lt;meta charset=&quot;UTF-8&quot;>
#        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
#        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js&quot;>&lt;/script>
#    &lt;/head>
#    &lt;body>
#           &lt;div id=&quot;f9dg7t&quot;>&lt;/div>
#    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
#
#    (function() {
#    // ----------
#
#        var plotSpec={
# &quot;mapping&quot;:{
# },
# &quot;data_meta&quot;:{
# },
# &quot;kind&quot;:&quot;plot&quot;,
# &quot;scales&quot;:[],
# &quot;layers&quot;:[{
# &quot;geom&quot;:&quot;label&quot;,
# &quot;mapping&quot;:{
# },
# &quot;data_meta&quot;:{
# },
# &quot;x&quot;:1.0,
# ...

# %%
p4=ggsave(plot, "plot2.html", iframe=False)

# %%
display(HTML(p4))
# Out:
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <script type="text/javascript" data-lets-plot-script="library" src="https://files.lp.hil-hk.com/artifacts/js/c0d2015a24882243305c16f3b08bd34fd07b2387/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="poy0U5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("poy0U5");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"label",
# "mapping":{
# ...
