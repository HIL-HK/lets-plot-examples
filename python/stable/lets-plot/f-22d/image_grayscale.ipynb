# %% [markdown]
# ## Using parameters `norm, vmain, vmax` and `cmap` in `geom_imshow()`
#
# You can use parameters `norm, vmain, vmax` and `cmap` when rendering grayscale images.
#
# A grayscale image is specified by Numpy's 2D array where each element's value
# represents the luminance of corresponding pixel in the image.

# %%
import numpy as np
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="Dn3TIU"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("Dn3TIU").appendChild(div);
#                     };
#                     var e = document.getElementById("Dn3TIU");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# Generate 2D Numpy arrays. 
# First two arrays both contain float numbers but have different range of values.
# The 3rd array contains int-s.
arr_f0 = np.linspace(.3, .7, 30).reshape(1, -1)
arr_f1 = np.linspace(30., 170., 30).reshape(1, -1)
arr_i = np.linspace(30, 170, 30, dtype=int).reshape(1, -1)

# %%
print("arr_f0: shape {}, data range [{}-{}] {}".format(arr_f0.shape, arr_f0.min(), arr_f0.max(), arr_f0.dtype))
print("arr_f1: shape {}, data range [{}-{}] {}".format(arr_f1.shape, arr_f1.min(), arr_f1.max(), arr_f1.dtype))
print("arr_i : shape {}, data range [{}-{}] {}".format(arr_i.shape, arr_i.min(), arr_i.max(), arr_i.dtype))
# Out:
# arr_f0: shape (1, 30), data range [0.3-0.7] float64
# arr_f1: shape (1, 30), data range [30.0-170.0] float64
# arr_i : shape (1, 30), data range [30-170] int64

# %%
# Setup suitable plot options for the demo.
p = (ggplot() + ggsize(450, 60) + geom_rect(xmin=-0.5, ymin=-0.5, xmax=29.5, ymax=0.5, color="black", alpha=0) + 
coord_cartesian() + theme_classic() + theme(axis="blank"))

# %% [markdown]
# #### Image normalization
#
# By default, `geom_imshow()` applies a linear scaling to transform data values to range [0-255].

# %%
(p + geom_imshow(arr_f0)).show()
(p + geom_imshow(arr_f1)).show()
(p + geom_imshow(arr_i)).show()
# Out:
#    <div id="tzbeIL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("tzbeIL");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[0.3,0.7]
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="YeiUwz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("YeiUwz");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="akfVO9"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("akfVO9");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ##
#
# You can disable image normalization using the `norm` parameter.

# %%
(p + geom_imshow(arr_f0, norm=False)).show()
(p + geom_imshow(arr_f1, norm=False)).show()
(p + geom_imshow(arr_i, norm=False)).show()
# Out:
#    <div id="FLb9Bo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("FLb9Bo");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.001176470588235294,
# "end":0.002745098039215686,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[0.3,0.7]
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="D6EXhy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("D6EXhy");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.11764705882352941,
# "end":0.6666666666666666,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="4EUxaK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("4EUxaK");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.11764705882352941,
# "end":0.6666666666666666,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Define normalization range using `vmin, vmax` parameters

# %%
# Set upper limit less than the data max value.
(p + geom_imshow(arr_f0, vmax=.5)).show()
(p + geom_imshow(arr_f1, vmax=100)).show()
(p + geom_imshow(arr_i, vmax=100)).show()
# Out:
#    <div id="FfT8OX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("FfT8OX");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[0.3,0.5]
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="56j2nT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("56j2nT");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,100.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="CiFVhp"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("CiFVhp");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,100.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# Set limits wider than the data entire range.
(p + geom_imshow(arr_f0, vmin=.4, vmax=.6)).show()
(p + geom_imshow(arr_f1, vmin=70, vmax=120)).show()
(p + geom_imshow(arr_i, vmin=50, vmax=150)).show()
# Out:
#    <div id="EU1pEe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("EU1pEe");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[0.4,0.6]
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="0nbX06"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("0nbX06");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[70.0,120.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="cWdf2B"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("cWdf2B");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "start":0.0,
# "end":1.0,
# "scale_mapper_kind":"color_grey"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[50.0,150.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Colormaps

# %%
(p + geom_imshow(arr_f0, cmap="magma")).show()
(p + geom_imshow(arr_f1, cmap="viridis")).show()
(p + geom_imshow(arr_i, cmap="plasma")).show()
# Out:
#    <div id="wV7WRZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("wV7WRZ");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "colors":["#000004","#030312","#0A0822","#140E36","#1E1149","#2A115C","#38106C","#471078","#54137D","#601880","#6D1D81","#792282","#882781","#942C80","#A1307E","#AE347B","#BD3977","#CA3E72","#D6456C","#E24D66","#EC5860","#F3655C","#F8745C","#FB835F","#FD9266","#FEA36F","#FEB27A","#FEC185","#FECF92","#FDE0A1","#FCEEB0","#FCFDBF"],
# "scale_mapper_kind":"color_gradientn"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[0.3,0.7]
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="sTqWoV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("sTqWoV");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "colors":["#440154","#470D60","#48186A","#482475","#472E7C","#453882","#424186","#3E4C8A","#3A548C","#365D8D","#32658E","#2E6D8E","#2B758E","#287D8E","#25848E","#228C8D","#1F948C","#1E9C89","#20A386","#25AB82","#2EB37C","#3ABA76","#48C16E","#58C765","#69CD5B","#7FD34E","#93D741","#A8DB34","#BDDF26","#D5E21A","#EAE51A","#FDE725"],
# "scale_mapper_kind":"color_gradientn"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
#    <div id="JfhyY3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("JfhyY3");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":450.0,
# "height":60.0
# },
# "coord":{
# "name":"cartesian",
# "flip":false
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"paint_c",
# "colors":["#0D0887","#220690","#310597","#41049D","#4E02A2","#5B01A5","#6700A8","#7501A8","#8104A7","#8D0BA5","#9814A0","#A21D9A","#AD2793","#B6308B","#BF3984","#C7427C","#CF4C74","#D6556D","#DD5E66","#E3685F","#E97257","#EF7C51","#F3874A","#F79143","#FA9C3C","#FCA934","#FDB52E","#FDC229","#FCCE25","#F9DD25","#F5EB27","#F0F921"],
# "scale_mapper_kind":"color_gradientn"
# }],
# "layers":[{
# "geom":"rect",
# "mapping":{
# },
# "data_meta":{
# },
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color":"black",
# "alpha":0.0,
# "data":{
# }
# },{
# "geom":"image",
# "mapping":{
# "paint_c":"paint_c"
# },
# "show_legend":true,
# "inherit_aes":false,
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "xmin":-0.5,
# "ymin":-0.5,
# "xmax":29.5,
# "ymax":0.5,
# "color_by":"paint_c",
# "data":{
# "paint_c":[30.0,170.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
