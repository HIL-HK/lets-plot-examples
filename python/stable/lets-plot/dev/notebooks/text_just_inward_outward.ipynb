# %%
from lets_plot import *
import pandas as pd

LetsPlot.setup_html()
# Out:
#             <div id="eYMvji"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("eYMvji").appendChild(div);
#                     };
#                     var e = document.getElementById("eYMvji");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = {
   'x' : [1, 1, 2, 2, 1.5],
   'y' : [1, 2, 1, 2, 1.5],
   'text': ["bottom-left", "top-left", "bottom-right", "top-right", "center"]
}

w, h = 400, 250

p = ggplot(df, aes('x', 'y')) + geom_point(size=3) + ggsize(w,h) + theme_classic()

# %%
p + geom_text(aes(label = 'text'), size=8, hjust = 'inward', angle=0)
# Out:
#    <div id="J9VPxt"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("J9VPxt");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
angles = [0,45,90,135,180,225,270,315]

def justificationWithAngles(hjust=None, vjust=None):
    bunch = GGBunch()
    for i in range(len(angles)):
        angle = angles[i]
    
        row = int(i / 2)
        column = i % 2
    
        pp = p + geom_text(aes(label = 'text'), size=8, hjust = hjust, vjust = vjust, angle=angle) +\
             ggtitle("Angle: " + str(angle))
    
        bunch.add_plot(pp, column * w, row  * h, w, h)
                                                                                              
    return bunch.show()

# %%
justificationWithAngles(hjust='inward')
# Out:
#    <div id="WxsjBK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("WxsjBK");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# }
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
justificationWithAngles(hjust='outward')
# Out:
#    <div id="RVmMVb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("RVmMVb");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# }
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
justificationWithAngles(vjust='inward')
# Out:
#    <div id="2pgx3S"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("2pgx3S");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"19"
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"20"
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"21"
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"22"
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"23"
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"24"
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"25"
# }
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
justificationWithAngles(vjust='outward')
# Out:
#    <div id="L46eJ3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("L46eJ3");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"26"
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"27"
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"28"
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"29"
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"30"
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"31"
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"32"
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"33"
# }
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
