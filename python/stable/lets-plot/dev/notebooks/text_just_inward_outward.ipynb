# %%
from lets_plot import *
import pandas as pd

LetsPlot.setup_html()
# Out:
#             <div id="9T2kCc"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("9T2kCc").appendChild(div);
#                     };
#                     var e = document.getElementById("9T2kCc");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = {
   'x' : [1, 1, 2, 2, 1.5],
   'y' : [1, 2, 1, 2, 1.5],
   'text': ["bottom-left", "top-left", "bottom-right", "top-right", "center"]
}

w, h = 400, 250

p = ggplot(df, aes('x', 'y')) + geom_point(size=3) + ggsize(w,h) + theme_classic()

# %%
p + geom_text(aes(label = 'text'), size=8, hjust = 'inward', angle=0)
# Out:
#    <div id="GjhgRL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GjhgRL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
angles = [0,45,90,135,180,225,270,315]

def justificationWithAngles(hjust=None, vjust=None):
    bunch = GGBunch()
    for i in range(len(angles)):
        angle = angles[i]
    
        row = int(i / 2)
        column = i % 2
    
        pp = p + geom_text(aes(label = 'text'), size=8, hjust = hjust, vjust = vjust, angle=angle) +\
             ggtitle("Angle: " + str(angle))
    
        bunch.add_plot(pp, column * w, row  * h, w, h)
                                                                                              
    return bunch.show()

# %%
justificationWithAngles(hjust='inward')
# Out:
#    <div id="NUxgZz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"inward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("NUxgZz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
justificationWithAngles(hjust='outward')
# Out:
#    <div id="fy4I7T"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "hjust":"outward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("fy4I7T");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
justificationWithAngles(vjust='inward')
# Out:
#    <div id="z7NxpT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"inward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("z7NxpT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
justificationWithAngles(vjust='outward')
# Out:
#    <div id="ohv09s"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":0.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 45"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":45.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 90"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":90.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":250.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 135"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":135.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 180"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":180.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":500.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 225"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":225.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":0.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 270"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":270.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":750.0,
# "width":400.0,
# "height":250.0,
# "feature_spec":{
# "data":{
# "x":[1.0,1.0,2.0,2.0,1.5],
# "y":[1.0,2.0,1.0,2.0,1.5],
# "text":["bottom-left","top-left","bottom-right","top-right","center"]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"unknown(mixed types)",
# "column":"x"
# },{
# "type":"unknown(mixed types)",
# "column":"y"
# },{
# "type":"str",
# "column":"text"
# }]
# },
# "ggsize":{
# "width":400.0,
# "height":250.0
# },
# "theme":{
# "name":"classic"
# },
# "ggtitle":{
# "text":"Angle: 315"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "label":"text"
# },
# "data_meta":{
# },
# "size":8.0,
# "vjust":"outward",
# "angle":315.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("ohv09s");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
