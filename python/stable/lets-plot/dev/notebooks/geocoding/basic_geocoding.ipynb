# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="QVZM1r"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
from lets_plot.geo_data import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
na=geocode_countries(['usa', 'canada'])
na

# %%
na_boundaries=na.get_boundaries(1)

# %%
ggplot() + geom_polygon(aes(fill='found name'), map=na_boundaries)
# Out:
#    <div id="26i1Dn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("26i1Dn");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"polygon",
# "mapping":{
# "fill":"found name"
# },
# "data_meta":{
# },
# "map":{
# "country":["usa","canada"],
# "found name":["United States","Canada"],
# ...

# %%
countries=geocode_countries().get_boundaries(1)
countries
# Out:
#                               country                        found name  \
# 0                             Andorra                           Andorra
# 1                            Slovakia                          Slovakia
# 2                             Austria                           Austria
# 3                             Hungary                           Hungary
# 4                             Georgia                           Georgia
# ..                                ...                               ...
# 213                              Chad                              Chad
# 214            Bosnia and Herzegovina            Bosnia and Herzegovina
# 215                            Norway                            Norway
# 216                           Morocco                           Morocco
# 217  Sahrawi Arab Democratic Republic  Sahrawi Arab Democratic Republic
#
#                                               geometry
# ...

# %%
ggplot() + geom_polygon(aes(fill='found name'), data=countries) + ggsize(900, 400) + theme(legend_position='none')
# Out:
#    <div id="xNKkMJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("xNKkMJ");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":900.0,
# "height":400.0
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"polygon",
# "data":{
# ...
