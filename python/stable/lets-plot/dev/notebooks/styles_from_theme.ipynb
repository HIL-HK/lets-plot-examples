# %%
import numpy as np
import pandas as pd

from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="0EtHdv"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("0EtHdv").appendChild(div);
#                     };
#                     var e = document.getElementById("0EtHdv");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
w, h = 600, 400

# %%
# default theme
p = (
    ggplot({'x': list(range(5)), 'y': list(range(5))}, aes('x', 'y')) +
    geom_point(aes(size='y', fill="y"),tooltips=layer_tooltips().title("TITLE").line('label|value')) +
    labs(title='The plot title', 
         subtitle="The plot subtitle",
         caption="The plot caption",
         x='X axis label', 
         y='Y axis label', 
         fill='Fill legend title',
         size='Size legend title'
    )
)
p
# Out:
#    <div id="0tkM0t"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("0tkM0t");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"The plot title",
# "subtitle":"The plot subtitle"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# theme functions

gggrid([p + ggtitle("theme_grey()") + theme_grey(), 
        p + ggtitle("theme_none()") + theme_none()], 
       ncol=2)
# Out:
#    <div id="8i1Gtl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("8i1Gtl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"theme_grey()"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"theme_none()"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "name":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
e_line = element_line(color='light_green', size=3)
e_rect = element_rect(color='#2c7fb8', fill='#edf8b1', size=2)
e_text = element_text(color='#f1a354', face='italic')

# tooltips

gggrid([p + theme(axis_tooltip=e_rect) + ggtitle("axis_tooltip = e_rect", 
                                                 subtitle="axis tooltip -> fill + text/border color + stroke width"),
        p + theme(axis_tooltip=e_line) + ggtitle("axis_tooltip = e_line", 
                                                 subtitle="axis tooltip -> text/border color + stroke width"),
        p + theme(axis_tooltip=e_text) + ggtitle("axis_tooltip = e_text", 
                                                 subtitle="axis tooltip -> text/border color"),
        p + theme(axis_tooltip_text=e_text) + ggtitle("axis_tooltip_text = e_text", 
                                                      subtitle="axis tooltip -> text color + font face"),
        p + theme(tooltip_text=e_text) + ggtitle("tooltip_text = e_text", 
                                                 subtitle="all tooltip -> text color + font face"),
       p + theme(tooltip=e_rect, tooltip_text=e_text) + ggtitle("+ tooltip=e_rect", 
                                                                subtitle="-> tooltip rect")],
ncol=2)
# Out:
#    <div id="9veyw3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("9veyw3");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"axis_tooltip = e_rect",
# "subtitle":"axis tooltip -> fill + text/border color + stroke width"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_tooltip":{
# "fill":"#edf8b1",
# "color":"#2c7fb8",
# "size":2.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"axis_tooltip = e_line",
# "subtitle":"axis tooltip -> text/border color + stroke width"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_tooltip":{
# "color":"light_green",
# "size":3.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"axis_tooltip = e_text",
# "subtitle":"axis tooltip -> text/border color"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_tooltip":{
# "color":"#f1a354",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"axis_tooltip_text = e_text",
# "subtitle":"axis tooltip -> text color + font face"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_tooltip_text":{
# "color":"#f1a354",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"tooltip_text = e_text",
# "subtitle":"all tooltip -> text color + font face"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "tooltip_text":{
# "color":"#f1a354",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# },{
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"+ tooltip=e_rect",
# "subtitle":"-> tooltip rect"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "tooltip":{
# "fill":"#edf8b1",
# "color":"#2c7fb8",
# "size":2.0,
# "blank":false
# },
# "tooltip_text":{
# "color":"#f1a354",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# Theme options  
theme_opts = theme(
        plot_title=element_text('red', face='bold_italic'),
        plot_subtitle=element_text('pink', face='normal'),
        plot_caption=element_text('gray', face='italic'),
    
        legend_title=element_text('#cc8f00'),
        legend_text=element_text('orange', face='italic'),
    
        axis_title_x=element_text('dark_green'),
        axis_text_x=element_text('#00b300'),
        axis_tooltip_text_x=element_text(color='light_green'),

        axis_title_y=element_text('dark_blue'),
        axis_text_y=element_text(color='#9e9eff'),
        axis_tooltip_text_y=element_text(color='light_blue'),

        tooltip=element_rect(color='#54278f', fill='#fcfbfd'),
        tooltip_text=element_text(color='#54278f', face='italic')    
)

# %%
p2 = p + theme_opts
p2
# Out:
#    <div id="5MS5mS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("5MS5mS");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"The plot title",
# "subtitle":"The plot subtitle"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_title_x":{
# "color":"dark_green",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_blue",
# "blank":false
# },
# "axis_text_x":{
# "color":"#00b300",
# "blank":false
# },
# "axis_text_y":{
# "color":"#9e9eff",
# "blank":false
# },
# "legend_text":{
# "color":"orange",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#cc8f00",
# "blank":false
# },
# "plot_title":{
# "color":"red",
# "face":"bold_italic",
# "blank":false
# },
# "plot_subtitle":{
# "color":"pink",
# "face":"normal",
# "blank":false
# },
# "plot_caption":{
# "color":"gray",
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text_x":{
# "color":"light_green",
# "blank":false
# },
# "axis_tooltip_text_y":{
# "color":"light_blue",
# "blank":false
# },
# "tooltip":{
# "fill":"#fcfbfd",
# "color":"#54278f",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
p2 + coord_flip()
# Out:
#    <div id="XQHiAN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("XQHiAN");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "ggtitle":{
# "text":"The plot title",
# "subtitle":"The plot subtitle"
# },
# "caption":{
# "text":"The plot caption"
# },
# "guides":{
# "x":{
# "title":"X axis label"
# },
# "y":{
# "title":"Y axis label"
# },
# "fill":{
# "title":"Fill legend title"
# },
# "size":{
# "title":"Size legend title"
# }
# },
# "theme":{
# "axis_title_x":{
# "color":"dark_green",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_blue",
# "blank":false
# },
# "axis_text_x":{
# "color":"#00b300",
# "blank":false
# },
# "axis_text_y":{
# "color":"#9e9eff",
# "blank":false
# },
# "legend_text":{
# "color":"orange",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#cc8f00",
# "blank":false
# },
# "plot_title":{
# "color":"red",
# "face":"bold_italic",
# "blank":false
# },
# "plot_subtitle":{
# "color":"pink",
# "face":"normal",
# "blank":false
# },
# "plot_caption":{
# "color":"gray",
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text_x":{
# "color":"light_green",
# "blank":false
# },
# "axis_tooltip_text_y":{
# "color":"light_blue",
# "blank":false
# },
# "tooltip":{
# "fill":"#fcfbfd",
# "color":"#54278f",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
data = dict(
    supp = ['OJ', 'OJ', 'OJ', 'VC', 'VC', 'VC'],
    dose = [0.5, 1.0, 2.0, 0.5, 1.0, 2.0],
    length = [13.23, 22.70, 26.06, 7.98, 16.77, 26.14],
    len_min = [11.83, 21.2, 24.50, 4.24, 15.26, 23.35],
    len_max = [15.63, 24.9, 27.11, 10.72, 19.28, 28.93]
)

# %%
# bars

bar_labels=labs(
     title="Tooth length per dose",
     subtitle="geom_bar", 
     caption="The ToothGrowth dataset",
     x = "Dosage levels (mg)",
     y ="Tooth length", 
     color="Supplements",
     fill="Supplements"
)

bar_theme = theme(
        title=element_text('#3f007d'),

        plot_subtitle=element_text(face='bold_italic'),
        plot_caption=element_text(face='italic'),

        legend_title=element_text('#d95f0e'),
        legend_text=element_text('#fe9929', face='italic'),

        axis_title=element_text(face='bold'),
        axis_tooltip_text=element_text(color='light_pink'),
    
        axis_title_x=element_text('#a50f15'),
        axis_text_x=element_text('pink'),

        axis_title_y=element_text('dark_green'),
        axis_text_y=element_text('#a1d99b'),

        tooltip_text=element_text(color='#54278f', face='italic')
)


bar = (
    ggplot(data) + 
    geom_bar(aes(x='dose', color='supp', y='length', fill='supp'), stat='identity', position='dodge') +  
    bar_labels +
    bar_theme
)
bar
# Out:
#    <div id="DBIN7o"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("DBIN7o");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"Tooth length per dose",
# "subtitle":"geom_bar"
# },
# "caption":{
# "text":"The ToothGrowth dataset"
# },
# "guides":{
# "x":{
# "title":"Dosage levels (mg)"
# },
# "y":{
# "title":"Tooth length"
# },
# "color":{
# "title":"Supplements"
# },
# "fill":{
# "title":"Supplements"
# }
# },
# "theme":{
# "title":{
# "color":"#3f007d",
# "blank":false
# },
# "axis_title":{
# "face":"bold",
# "blank":false
# },
# "axis_title_x":{
# "color":"#a50f15",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_green",
# "blank":false
# },
# "axis_text_x":{
# "color":"pink",
# "blank":false
# },
# "axis_text_y":{
# "color":"#a1d99b",
# "blank":false
# },
# "legend_text":{
# "color":"#fe9929",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#d95f0e",
# "blank":false
# },
# "plot_subtitle":{
# "face":"bold_italic",
# "blank":false
# },
# "plot_caption":{
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"light_pink",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"dose",
# "y":"length",
# "color":"supp",
# "fill":"supp"
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# coord flip
bar + coord_flip()
# Out:
#    <div id="G8LDUu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("G8LDUu");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"Tooth length per dose",
# "subtitle":"geom_bar"
# },
# "caption":{
# "text":"The ToothGrowth dataset"
# },
# "guides":{
# "x":{
# "title":"Dosage levels (mg)"
# },
# "y":{
# "title":"Tooth length"
# },
# "color":{
# "title":"Supplements"
# },
# "fill":{
# "title":"Supplements"
# }
# },
# "theme":{
# "title":{
# "color":"#3f007d",
# "blank":false
# },
# "axis_title":{
# "face":"bold",
# "blank":false
# },
# "axis_title_x":{
# "color":"#a50f15",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_green",
# "blank":false
# },
# "axis_text_x":{
# "color":"pink",
# "blank":false
# },
# "axis_text_y":{
# "color":"#a1d99b",
# "blank":false
# },
# "legend_text":{
# "color":"#fe9929",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#d95f0e",
# "blank":false
# },
# "plot_subtitle":{
# "face":"bold_italic",
# "blank":false
# },
# "plot_caption":{
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"light_pink",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"dose",
# "y":"length",
# "color":"supp",
# "fill":"supp"
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# orientation "y"
(
    ggplot(data) +
    geom_bar(aes(x='length', color='supp', y='dose', fill='supp'), 
             stat='identity', position='dodge', orientation="y") +
    bar_labels +
    bar_theme
)
# Out:
#    <div id="nIqZC8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("nIqZC8");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"Tooth length per dose",
# "subtitle":"geom_bar"
# },
# "caption":{
# "text":"The ToothGrowth dataset"
# },
# "guides":{
# "x":{
# "title":"Dosage levels (mg)"
# },
# "y":{
# "title":"Tooth length"
# },
# "color":{
# "title":"Supplements"
# },
# "fill":{
# "title":"Supplements"
# }
# },
# "theme":{
# "title":{
# "color":"#3f007d",
# "blank":false
# },
# "axis_title":{
# "face":"bold",
# "blank":false
# },
# "axis_title_x":{
# "color":"#a50f15",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_green",
# "blank":false
# },
# "axis_text_x":{
# "color":"pink",
# "blank":false
# },
# "axis_text_y":{
# "color":"#a1d99b",
# "blank":false
# },
# "legend_text":{
# "color":"#fe9929",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#d95f0e",
# "blank":false
# },
# "plot_subtitle":{
# "face":"bold_italic",
# "blank":false
# },
# "plot_caption":{
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"light_pink",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"length",
# "y":"dose",
# "color":"supp",
# "fill":"supp"
# },
# "position":"dodge",
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# Outlier Tooltips

crossbar = (
      ggplot(data, aes(x='dose', color='supp')) +
      geom_crossbar(aes(ymin='len_min', ymax='len_max', middle='length'), fatten=5) +
      labs(title='geom_crossbar') +
      theme(
        plot_title=element_text('#990000', face='bold_italic'),

        legend_title=element_text('#cc8f00'),
        legend_text=element_text('orange', face='italic'),
    
        axis_title=element_text('#9b2d30'),
        axis_text=element_text('pink'),
        axis_tooltip=element_rect(color='pink', fill='#6c4675', size = 2.0),
        axis_tooltip_text=element_text(color='pink'),

        tooltip=element_rect(color='dark_blue', fill='#fff5ee'),
        tooltip_text=element_text(color='dark_blue', face='italic')
    )
)

crossbar
# Out:
# WARN: using 'middle' aesthetic parameter for crossbar was deprecated.
#       Please, use `y` aesthetic instead.
#    <div id="m6RCNB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("m6RCNB");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"geom_crossbar"
# },
# "theme":{
# "axis_title":{
# "color":"#9b2d30",
# "blank":false
# },
# "axis_text":{
# "color":"pink",
# "blank":false
# },
# "legend_text":{
# "color":"orange",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#cc8f00",
# "blank":false
# },
# "plot_title":{
# "color":"#990000",
# "face":"bold_italic",
# "blank":false
# },
# "axis_tooltip":{
# "fill":"#6c4675",
# "color":"pink",
# "size":2.0,
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"pink",
# "blank":false
# },
# "tooltip":{
# "fill":"#fff5ee",
# "color":"dark_blue",
# "blank":false
# },
# "tooltip_text":{
# "color":"dark_blue",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "y":"length",
# "ymin":"len_min",
# "ymax":"len_max"
# },
# "data_meta":{
# },
# "fatten":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# facets

crossbar + facet_grid('supp') + theme(strip_text=element_text(color='#990000', face='bold'))
# Out:
#    <div id="sbNHkW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("sbNHkW");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"geom_crossbar"
# },
# "theme":{
# "axis_title":{
# "color":"#9b2d30",
# "blank":false
# },
# "axis_text":{
# "color":"pink",
# "blank":false
# },
# "legend_text":{
# "color":"orange",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#cc8f00",
# "blank":false
# },
# "plot_title":{
# "color":"#990000",
# "face":"bold_italic",
# "blank":false
# },
# "axis_tooltip":{
# "fill":"#6c4675",
# "color":"pink",
# "size":2.0,
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"pink",
# "blank":false
# },
# "tooltip":{
# "fill":"#fff5ee",
# "color":"dark_blue",
# "blank":false
# },
# "tooltip_text":{
# "color":"dark_blue",
# "face":"italic",
# "blank":false
# },
# "strip_text":{
# "color":"#990000",
# "face":"bold",
# "blank":false
# }
# },
# "facet":{
# "name":"grid",
# "x":"supp",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "y":"length",
# "ymin":"len_min",
# "ymax":"len_max"
# },
# "data_meta":{
# },
# "fatten":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
pg = gggrid([bar, crossbar], ncol=2)
pg
# Out:
#    <div id="G2UfDT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("G2UfDT");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"Tooth length per dose",
# "subtitle":"geom_bar"
# },
# "caption":{
# "text":"The ToothGrowth dataset"
# },
# "guides":{
# "x":{
# "title":"Dosage levels (mg)"
# },
# "y":{
# "title":"Tooth length"
# },
# "color":{
# "title":"Supplements"
# },
# "fill":{
# "title":"Supplements"
# }
# },
# "theme":{
# "title":{
# "color":"#3f007d",
# "blank":false
# },
# "axis_title":{
# "face":"bold",
# "blank":false
# },
# "axis_title_x":{
# "color":"#a50f15",
# "blank":false
# },
# "axis_title_y":{
# "color":"dark_green",
# "blank":false
# },
# "axis_text_x":{
# "color":"pink",
# "blank":false
# },
# "axis_text_y":{
# "color":"#a1d99b",
# "blank":false
# },
# "legend_text":{
# "color":"#fe9929",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#d95f0e",
# "blank":false
# },
# "plot_subtitle":{
# "face":"bold_italic",
# "blank":false
# },
# "plot_caption":{
# "face":"italic",
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"light_pink",
# "blank":false
# },
# "tooltip_text":{
# "color":"#54278f",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"dose",
# "y":"length",
# "color":"supp",
# "fill":"supp"
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# },{
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"supp"
# },{
# "type":"float",
# "column":"dose"
# },{
# "type":"float",
# "column":"length"
# },{
# "type":"float",
# "column":"len_min"
# },{
# "type":"float",
# "column":"len_max"
# }]
# },
# "ggtitle":{
# "text":"geom_crossbar"
# },
# "theme":{
# "axis_title":{
# "color":"#9b2d30",
# "blank":false
# },
# "axis_text":{
# "color":"pink",
# "blank":false
# },
# "legend_text":{
# "color":"orange",
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "color":"#cc8f00",
# "blank":false
# },
# "plot_title":{
# "color":"#990000",
# "face":"bold_italic",
# "blank":false
# },
# "axis_tooltip":{
# "fill":"#6c4675",
# "color":"pink",
# "size":2.0,
# "blank":false
# },
# "axis_tooltip_text":{
# "color":"pink",
# "blank":false
# },
# "tooltip":{
# "fill":"#fff5ee",
# "color":"dark_blue",
# "blank":false
# },
# "tooltip_text":{
# "color":"dark_blue",
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "y":"length",
# "ymin":"len_min",
# "ymax":"len_max"
# },
# "data_meta":{
# },
# "fatten":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %%
# Save to SVG
ggsave(pg, "bars_bunch.svg")


from IPython.display import SVG
display(SVG(filename="lets-plot-images/bars_bunch.svg"))
