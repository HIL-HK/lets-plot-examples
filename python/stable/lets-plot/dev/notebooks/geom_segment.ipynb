# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="9tWiBS"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("9tWiBS").appendChild(div);
#                     };
#                     var e = document.getElementById("9tWiBS");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
LetsPlot.set_theme(theme_minimal())

# %% [markdown]
# #### Draw arrows
#
# - the arrowhead always points to the specified coordinate of the segment
# - the segment itself is drawn so that it does not intersect with its arrow
# - no beveled corners (previously, acute angle could be drawn beveled)

# %%
def plot_with_arrows(angle, type='open'):
    return ggplot() \
            + geom_vline(xintercept=0) \
            + geom_vline(xintercept=1) \
            + geom_segment(x=0, xend=1, y=0, yend=0,
                           size=5,
                           alpha=0.5,
                           arrow=arrow(ends='both', type=type, length=75, angle=angle)) \
            + ggsize(600, 350)

# %%
plot_with_arrows(10)
# Out:
#    <div id="p9Tw0r"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("p9Tw0r");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"minimal"
# },
# "ggsize":{
# "width":600.0,
# "height":350.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":0.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":1.0,
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":10.0,
# "length":75.0,
# "ends":"both",
# "type":"open"
# },
# "x":0.0,
# "xend":1.0,
# "y":0.0,
# "yend":0.0,
# "size":5.0,
# "alpha":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
plot_with_arrows(30)
# Out:
#    <div id="2H8MDp"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("2H8MDp");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"minimal"
# },
# "ggsize":{
# "width":600.0,
# "height":350.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":0.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":1.0,
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":30.0,
# "length":75.0,
# "ends":"both",
# "type":"open"
# },
# "x":0.0,
# "xend":1.0,
# "y":0.0,
# "yend":0.0,
# "size":5.0,
# "alpha":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### 'space' parameter - additional space to shorten a segment by moving the start/end

# %%
ggplot() \
    + geom_vline(xintercept=0) \
    + geom_vline(xintercept=1) \
    + geom_segment(x=0, xend=1, y=0, yend=0,
                   size=5, 
                   alpha=0.5,
                   arrow=arrow(ends='both', type='open', length=75, angle=15),
                   spacer=15) \
    + ggsize(600, 200)
# Out:
#    <div id="KAROIS"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("KAROIS");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"minimal"
# },
# "ggsize":{
# "width":600.0,
# "height":200.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":0.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":1.0,
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "length":75.0,
# "ends":"both",
# "type":"open"
# },
# "spacer":15.0,
# "x":0.0,
# "xend":1.0,
# "y":0.0,
# "yend":0.0,
# "size":5.0,
# "alpha":0.5,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### New aesthetics: `size_start,start_end` and `stroke_start,stroke_end`

# %%
x = [-1, 0, 1]
y = [-1, 1, -1]
shape = [1, 16, 21]
size = [1, 2, 3]
stroke = [1, 0, 2]

x_end = x[1:] + [x[0]]
y_end = y[1:] + [y[0]]
size_end = size[1:] + [size[0]]
stroke_end = stroke[1:] + [stroke[0]]

data = {
    'x': x,
    'y': y,
    'shape': shape,
    'size': size,
    'stroke': stroke,
    'x_end': x_end,
    'y_end': y_end,
    'size_end': size_end,
    'stroke_end': stroke_end,
}

plot = ggplot(data, aes('x','y')) \
    + geom_point(aes(size='size', shape='shape', stroke='stroke'), color='#4575b4', fill='#abd9e9') \
    + scale_size(range=[20,30], guide='none') \
    + scale_stroke(range=[0,10], guide='none') \
    + scale_shape_identity() \
    + lims(x=[-1.5, 1.5], y=[-1.5, 1.5])

plot
# Out:
#    <div id="a2h313"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("a2h313");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "shape":[1.0,16.0,21.0],
# "size":[1.0,2.0,3.0],
# "stroke":[1.0,0.0,2.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"shape",
# "guide":"none",
# "scale_mapper_kind":"identity",
# "discrete":true
# },{
# "aesthetic":"x",
# "limits":[-1.5,1.5]
# },{
# "aesthetic":"y",
# "limits":[-1.5,1.5]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"size",
# "shape":"shape",
# "stroke":"stroke"
# },
# "data_meta":{
# },
# "color":"#4575b4",
# "fill":"#abd9e9",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# Draw segments using offsets from start/end using aesthetics

# Also need to set the same scale settings:
se_scales = scale_continuous(['size_start','size_end'], range=[20,30], guide='none') \
    + scale_continuous(['stroke_start','stroke_end'], range=[0,10], guide='none')

plot \
    + geom_segment(aes(xend='x_end', yend='y_end', 
                   size_start='size', size_end='size_end',
                   stroke_start='stroke', stroke_end='stroke_end'),
                   arrow=arrow(type='open', ends='both', length=15, angle=15)) \
    + se_scales
# Out:
#    <div id="mN5fi8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("mN5fi8");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "shape":[1.0,16.0,21.0],
# "size":[1.0,2.0,3.0],
# "stroke":[1.0,0.0,2.0],
# "x_end":[0.0,1.0,-1.0],
# "y_end":[1.0,-1.0,-1.0],
# "size_end":[2.0,3.0,1.0],
# "stroke_end":[0.0,2.0,1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"shape",
# "guide":"none",
# "scale_mapper_kind":"identity",
# "discrete":true
# },{
# "aesthetic":"x",
# "limits":[-1.5,1.5]
# },{
# "aesthetic":"y",
# "limits":[-1.5,1.5]
# },{
# "aesthetic":"size_start",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"size_end",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke_start",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"stroke_end",
# "guide":"none",
# "range":[0.0,10.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"size",
# "shape":"shape",
# "stroke":"stroke"
# },
# "data_meta":{
# },
# "color":"#4575b4",
# "fill":"#abd9e9",
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# "xend":"x_end",
# "yend":"y_end",
# "size_start":"size",
# "size_end":"size_end",
# "stroke_start":"stroke",
# "stroke_end":"stroke_end"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "length":15.0,
# "ends":"both",
# "type":"open"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# For start coordfinate only

plot \
    + geom_segment(aes(xend='x_end', yend='y_end', 
                   size_end='size_end', stroke_end='stroke_end'),
                   arrow=arrow(type='open', ends='last', length=15, angle=15)) \
    + se_scales
# Out:
#    <div id="wPCTLa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("wPCTLa");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "shape":[1.0,16.0,21.0],
# "size":[1.0,2.0,3.0],
# "stroke":[1.0,0.0,2.0],
# "x_end":[0.0,1.0,-1.0],
# "y_end":[1.0,-1.0,-1.0],
# "size_end":[2.0,3.0,1.0],
# "stroke_end":[0.0,2.0,1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"shape",
# "guide":"none",
# "scale_mapper_kind":"identity",
# "discrete":true
# },{
# "aesthetic":"x",
# "limits":[-1.5,1.5]
# },{
# "aesthetic":"y",
# "limits":[-1.5,1.5]
# },{
# "aesthetic":"size_start",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"size_end",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke_start",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"stroke_end",
# "guide":"none",
# "range":[0.0,10.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"size",
# "shape":"shape",
# "stroke":"stroke"
# },
# "data_meta":{
# },
# "color":"#4575b4",
# "fill":"#abd9e9",
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# "xend":"x_end",
# "yend":"y_end",
# "size_end":"size_end",
# "stroke_end":"stroke_end"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "length":15.0,
# "ends":"last",
# "type":"open"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# Example from https://stackoverflow.com/questions/14647988/arranging-arrows-between-points-nicely-in-ggplot2

import pandas as pd
import numpy as np

np.random.seed(7)

points = pd.DataFrame({
    'x': np.random.uniform(size=10),
    'y': np.random.uniform(size=10),
    'class': np.arange(1, 11),
    'size': np.random.uniform(1000, 100000, size=10)
})

trans = pd.DataFrame({
    'from': np.repeat(np.arange(1, 11), 10),
    'to': np.tile(np.arange(1, 11), 10),
    'amount': np.random.uniform(size=100) ** 3
})

trans = pd.merge(trans, points, left_on='from', right_on='class')
trans = pd.merge(trans, points, left_on='to', right_on='class', suffixes=('.to', '.from'))

trans = trans.loc[(trans['amount'] >= 0.6)]

# %%
ggplot(points, aes(x='x', y='y')) \
    + geom_point(aes(size='size'), color="red", shape=1, stroke=0.75) \
    + geom_segment(aes(x='x.from', y='y.from', xend='x.to', yend='y.to', 
                       size_start='size.from', size_end='size.to'), 
                   data=trans,
                   stroke_start=0.75, stroke_end=0.75,
                   alpha=0.7, 
                   arrow=arrow(type='open', ends='both')) \
    + scale_continuous(['size','size_start','size_end'], range=[4,20])
# Out:
#    <div id="hYjJQ5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("hYjJQ5");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[0.07630828937395717,0.7799187922401146,0.4384092314408935,0.7234651778309412,0.9779895119966027,0.5384958704104337,0.5011204636599379,0.07205113335976154,0.26843898010187117,0.49988250082555996],
# "y":[0.6792299961209405,0.8037390361043755,0.3809411331485384,0.06593634690590511,0.28814559930799355,0.9095935277196137,0.2133853535799155,0.4521239618176831,0.9312060196890217,0.024899227550348013],
# "size":[60454.34282894813,95062.82054095092,23799.985023075515,55300.50200436701,91003.70911378639,14183.775130165766,52817.84548670282,75290.57605110145,67232.31084750747,47307.53311475309]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"int",
# "column":"class"
# },{
# "type":"float",
# "column":"size"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "range":[4.0,20.0]
# },{
# "aesthetic":"size_start",
# "range":[4.0,20.0]
# },{
# "aesthetic":"size_end",
# "range":[4.0,20.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"size"
# },
# "data_meta":{
# },
# "color":"red",
# "shape":1.0,
# "stroke":0.75,
# "data":{
# }
# },{
# "geom":"segment",
# "data":{
# "x.to":[0.7799187922401146,0.7234651778309412,0.7234651778309412,0.7234651778309412,0.7234651778309412,0.5384958704104337,0.5011204636599379,0.5011204636599379,0.26843898010187117,0.49988250082555996,0.49988250082555996],
# "y.to":[0.8037390361043755,0.06593634690590511,0.06593634690590511,0.06593634690590511,0.06593634690590511,0.9095935277196137,0.2133853535799155,0.2133853535799155,0.9312060196890217,0.024899227550348013,0.024899227550348013],
# "size.to":[95062.82054095092,55300.50200436701,55300.50200436701,55300.50200436701,55300.50200436701,14183.775130165766,52817.84548670282,52817.84548670282,67232.31084750747,47307.53311475309,47307.53311475309],
# "x.from":[0.07205113335976154,0.07630828937395717,0.5011204636599379,0.07205113335976154,0.26843898010187117,0.26843898010187117,0.7799187922401146,0.7234651778309412,0.5384958704104337,0.9779895119966027,0.26843898010187117],
# "y.from":[0.4521239618176831,0.6792299961209405,0.2133853535799155,0.4521239618176831,0.9312060196890217,0.9312060196890217,0.8037390361043755,0.06593634690590511,0.9095935277196137,0.28814559930799355,0.9312060196890217],
# "size.from":[75290.57605110145,60454.34282894813,52817.84548670282,75290.57605110145,67232.31084750747,67232.31084750747,95062.82054095092,55300.50200436701,14183.775130165766,91003.70911378639,67232.31084750747]
# },
# "mapping":{
# "x":"x.from",
# "y":"y.from",
# "xend":"x.to",
# "yend":"y.to",
# "size_start":"size.from",
# "size_end":"size.to"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"from"
# },{
# "type":"int",
# "column":"to"
# },{
# "type":"float",
# "column":"amount"
# },{
# "type":"float",
# "column":"x.to"
# },{
# "type":"float",
# "column":"y.to"
# },{
# "type":"int",
# "column":"class.to"
# },{
# "type":"float",
# "column":"size.to"
# },{
# "type":"float",
# "column":"x.from"
# },{
# "type":"float",
# "column":"y.from"
# },{
# "type":"int",
# "column":"class.from"
# },{
# "type":"float",
# "column":"size.from"
# }]
# },
# "arrow":{
# "name":"arrow",
# "ends":"both",
# "type":"open"
# },
# "stroke_start":0.75,
# "stroke_end":0.75,
# "alpha":0.7
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# From doc

import numpy as np

T = 25
np.random.seed(42)
t = [0, *np.random.normal(size=T)]
x = np.cumsum(np.cos(t))
y = np.cumsum(np.sin(t))

ggplot({'x': x[:-1], 'y': y[:-1], 'xend': x[1:], 'yend': y[1:]}, aes(x='x', y='y')) \
    + geom_segment(aes(xend='xend', yend='yend', color='xend'),
                 arrow=arrow(type='closed', angle=10)) \
    + scale_color_gradient(low='#2c7bb6', high='#d7191c') \
    + coord_fixed()
# Out:
#    <div id="bBAFdg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("bBAFdg");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[1.0,1.8791531404847617,2.869609849809497,3.6670903857520876,3.7148386939304308,4.687549817459901,5.660264750102799,5.651848360756817,6.371542441697068,7.263348650126051,8.119738311745856,9.014268300749759,9.907762390247205,10.878632058221015,10.542804272115973,10.389292194764975,11.235329986124896,11.764791096351983,12.71582039468639,13.331124944808954,13.488954849714574,13.593908762609537,14.568529378392267,15.566250215468596,15.711779706915152],
# "y":[0.0,0.4765393536485533,0.3387151650834943,0.9420598383778881,1.940919237425675,1.7088996904861244,1.4768961133293876,2.4768606948973435,3.1711520097354065,2.718734407726465,3.2350644838122156,2.788056543421132,2.3389815919563124,2.578589788411324,1.6366663849013645,0.6485196133601216,0.11539668608084142,-0.7329375244500669,-0.4238367743546206,-1.2121262583631727,-2.1995925722784793,-1.2051154854795745,-1.4289785134482247,-1.3615016191531408,-2.350855533139085],
# "xend":[1.8791531404847617,2.869609849809497,3.6670903857520876,3.7148386939304308,4.687549817459901,5.660264750102799,5.651848360756817,6.371542441697068,7.263348650126051,8.119738311745856,9.014268300749759,9.907762390247205,10.878632058221015,10.542804272115973,10.389292194764975,11.235329986124896,11.764791096351983,12.71582039468639,13.331124944808954,13.488954849714574,13.593908762609537,14.568529378392267,15.566250215468596,15.711779706915152,16.567226841534183],
# "yend":[0.4765393536485533,0.3387151650834943,0.9420598383778881,1.940919237425675,1.7088996904861244,1.4768961133293876,2.4768606948973435,3.1711520097354065,2.718734407726465,3.2350644838122156,2.788056543421132,2.3389815919563124,2.578589788411324,1.6366663849013645,0.6485196133601216,0.11539668608084142,-0.7329375244500669,-0.4238367743546206,-1.2121262583631727,-2.1995925722784793,-1.2051154854795745,-1.4289785134482247,-1.3615016191531408,-2.350855533139085,-2.868745675806514]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"float",
# "column":"x"
# },{
# "type":"float",
# "column":"y"
# },{
# "type":"float",
# "column":"xend"
# },{
# "type":"float",
# "column":"yend"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "flip":false
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "low":"#2c7bb6",
# "high":"#d7191c",
# "scale_mapper_kind":"color_gradient"
# }],
# "layers":[{
# "geom":"segment",
# "mapping":{
# "xend":"xend",
# "yend":"yend",
# "color":"xend"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":10.0,
# "type":"closed"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# on LiveMap

# use constants

ggplot(data, aes('x','y')) \
    + geom_livemap() \
    + geom_point(size=20, color='#4575b4', alpha=0.5) \
    + geom_segment(aes(xend='x_end', yend='y_end'),
                   size_start=20, size_end=20,
                   size=4,
                   arrow=arrow(type='closed', ends='last', angle=15))
# Out:
#    <div id="mJubdc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("mJubdc");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "x_end":[0.0,1.0,-1.0],
# "y_end":[1.0,-1.0,-1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":20.0,
# "color":"#4575b4",
# "alpha":0.5,
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# "xend":"x_end",
# "yend":"y_end"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "ends":"last",
# "type":"closed"
# },
# "size_start":20.0,
# "size_end":20.0,
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
# Mappings

ggplot(data, aes('x', 'y')) \
    + geom_livemap() \
    + geom_point(aes(size='size', shape='shape', stroke='stroke'),data=data, color='#4575b4', fill='#abd9e9') \
    + geom_segment(aes(xend='x_end', yend='y_end', 
                       size_start='size', size_end='size_end',
                       stroke_start='stroke', stroke_end='stroke_end'),
                   size=4,
                   arrow=arrow(type='closed', ends='last', angle=15)) \
    + scale_shape_identity() \
    + scale_continuous(['size', 'size_start','size_end'], range=[20,30], guide='none') \
    + scale_continuous(['stroke', 'stroke_start','stroke_end'], range=[0,10], guide='none')
# Out:
#    <div id="brE44e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("brE44e");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "size":[1.0,2.0,3.0],
# "stroke":[1.0,0.0,2.0],
# "x_end":[0.0,1.0,-1.0],
# "y_end":[1.0,-1.0,-1.0],
# "size_end":[2.0,3.0,1.0],
# "stroke_end":[0.0,2.0,1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "guide":"none",
# "scale_mapper_kind":"identity",
# "discrete":true
# },{
# "aesthetic":"size",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"size_start",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"size_end",
# "guide":"none",
# "range":[20.0,30.0]
# },{
# "aesthetic":"stroke",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"stroke_start",
# "guide":"none",
# "range":[0.0,10.0]
# },{
# "aesthetic":"stroke_end",
# "guide":"none",
# "range":[0.0,10.0]
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "data":{
# "x":[-1.0,0.0,1.0],
# "y":[-1.0,1.0,-1.0],
# "shape":[1.0,16.0,21.0],
# "size":[1.0,2.0,3.0],
# "stroke":[1.0,0.0,2.0]
# },
# "mapping":{
# "size":"size",
# "shape":"shape",
# "stroke":"stroke"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# },{
# "type":"int",
# "column":"shape"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"int",
# "column":"stroke"
# },{
# "type":"int",
# "column":"x_end"
# },{
# "type":"int",
# "column":"y_end"
# },{
# "type":"int",
# "column":"size_end"
# },{
# "type":"int",
# "column":"stroke_end"
# }]
# },
# "color":"#4575b4",
# "fill":"#abd9e9"
# },{
# "geom":"segment",
# "mapping":{
# "xend":"x_end",
# "yend":"y_end",
# "size_start":"size",
# "size_end":"size_end",
# "stroke_start":"stroke",
# "stroke_end":"stroke_end"
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "ends":"last",
# "type":"closed"
# },
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### From 'Pushkin as Travller' notebook

# %%
def set_stay_time(data):
    current_moves = moves_df[(moves_df.departure == data['name'])|(moves_df.arrival == data['name'])]
    years = current_moves.year.sort_values().unique()
    years_combined = []
    for year in years:
        if len(years_combined) == 0 or years_combined[-1][1] + 1 != year:
            years_combined.append((year, year))
        else:
            years_combined[-1] = (years_combined[-1][0], year)
    years_combined = [str(year_from) if year_from == year_to else '{0}-{1}'.format(year_from, year_to) \
                      for year_from, year_to in years_combined]
    data['years'] = ', '.join(years_combined)
    return data

places_df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/pushkin/places.csv')
moves_df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/pushkin/moves.csv')
df = moves_df.merge(places_df, left_on='departure', right_on='name')\
             .rename(columns=dict(longitude='from_lon', latitude='from_lat'))\
             .drop(columns=['name'])\
             .merge(places_df, left_on='arrival', right_on='name')\
             .rename(columns=dict(longitude='to_lon', latitude='to_lat'))\
             .drop(columns=['name'])
places_df['years'] = ''
places_df = places_df.apply(set_stay_time, axis=1)

# %%
ggplot() + \
    geom_livemap(const_size_zoomin=3) + \
    geom_segment(aes(x='from_lon', y='from_lat', xend='to_lon', yend='to_lat', color='path'), data=df,
                 size_start=3, size_end=3,
                 tooltips=layer_tooltips().title("Trip").line("@path"),
                 arrow=arrow(type='closed', length=10, angle=15), size=1) + \
    geom_point(aes(x='longitude', y='latitude'), data=places_df, size=3, color='#F7F4F0',
               tooltips=layer_tooltips().title('@name').line('visited in|@years')) + \
    geom_point(aes(x='longitude', y='latitude'), data=places_df, size=1.7, color='black',
               tooltips='none') + \
    scale_color_manual(name='trip name', values=['#addd8e', '#e34a33', '#8856a7', '#2c7fb8',
                                                 '#1c9099', '#006d2c', '#fec44f', '#636363']) + \
    coord_cartesian(xlim=[26, 58], ylim=[38, 62]) + \
    ggtitle("Alexander Pushkin's Trips") + \
    ggsize(800, 600) + \
    theme(axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank')
# Out:
#    <div id="Ii04lE"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Ii04lE");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"minimal",
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "coord":{
# "name":"cartesian",
# "xlim":[26.0,58.0],
# "ylim":[38.0,62.0],
# "flip":false
# },
# "ggtitle":{
# "text":"Alexander Pushkin's Trips"
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "kind":"plot",
# "scales":[{
# "name":"trip name",
# "aesthetic":"color",
# "values":["#addd8e","#e34a33","#8856a7","#2c7fb8","#1c9099","#006d2c","#fec44f","#636363"]
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "const_size_zoomin":3.0,
# "data":{
# }
# },{
# "geom":"segment",
# "data":{
# "path":["To Lyceum","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Southern exile","Mikhailovsky exile","Mikhailovsky exile","Mikhailovsky exile","Mikhailovsky exile","Mikhailovsky exile","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Travel to the Caucasus","Autumn at Boldino","Autumn at Boldino","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Trip researching the Pugachev rebellion","Final journey","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes","Regular routes"],
# "from_lat":[55.751244,59.93863,55.187222,50.431782,48.450001,47.414101,45.0428,44.1497667,44.04861,45.0428,45.04484,44.957813,46.469391,47.00367,46.469391,51.50551,55.187222,57.061332,57.8136,55.751244,52.929697,47.414101,45.0428,44.1497667,43.03667,41.716667,40.60199,55.751244,55.004477,55.751244,56.32753,55.78874,54.32824,51.776272,51.23333,55.004477,59.93863,47.00367,50.431782,47.00367,46.469391,55.751244,59.93863,55.751244,54.728958,55.751244,55.751244,54.728958,59.93863,55.751244],
# "from_lon":[37.618423,30.31413,30.205116,30.516382,34.983334,40.110401,41.9734,43.4577689,43.05944,41.9734,38.97603,34.109547,30.740883,28.907089,30.740883,31.28487,30.205116,28.919346,28.3496,37.618423,36.098689,40.110401,41.9734,43.4577689,44.66778,44.783333,43.09495,37.618423,45.30885,37.618423,44.000717,49.12214,48.38657,55.099594,51.36667,45.30885,30.31413,28.907089,30.516382,28.907089,30.740883,37.618423,30.31413,37.618423,35.971598,37.618423,37.618423,35.971598,30.31413,37.618423],
# "to_lat":[59.93863,55.187222,50.431782,48.450001,47.414101,45.0428,44.1497667,44.04861,45.0428,45.04484,44.957813,46.469391,47.00367,46.469391,51.50551,55.187222,57.061332,57.8136,55.751244,52.929697,47.414101,45.0428,44.1497667,43.03667,41.716667,40.60199,39.90861,55.004477,55.751244,56.32753,55.78874,54.32824,51.776272,51.23333,55.004477,55.751244,57.022162,50.431782,47.00367,46.469391,47.00367,59.93863,55.751244,54.728958,55.751244,59.93863,54.728958,55.751244,55.751244,59.93863],
# "to_lon":[30.31413,30.205116,30.516382,34.983334,40.110401,41.9734,43.4577689,43.05944,41.9734,38.97603,34.109547,30.740883,28.907089,30.740883,31.28487,30.205116,28.919346,28.3496,37.618423,36.098689,40.110401,41.9734,43.4577689,44.66778,44.783333,43.09495,41.27694,45.30885,37.618423,44.000717,49.12214,48.38657,55.099594,51.36667,45.30885,37.618423,28.920945,30.516382,28.907089,30.740883,28.907089,30.31413,37.618423,35.971598,37.618423,30.31413,35.971598,37.618423,37.618423,30.31413]
# },
# "mapping":{
# "x":"from_lon",
# "y":"from_lat",
# "xend":"to_lon",
# "yend":"to_lat",
# "color":"path"
# },
# "tooltips":{
# "formats":[],
# "lines":["@path"],
# "title":"Trip"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"departure"
# },{
# "type":"str",
# "column":"arrival"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"str",
# "column":"path"
# },{
# "type":"float",
# "column":"from_lat"
# },{
# "type":"float",
# "column":"from_lon"
# },{
# "type":"float",
# "column":"to_lat"
# },{
# "type":"float",
# "column":"to_lon"
# }]
# },
# "arrow":{
# "name":"arrow",
# "angle":15.0,
# "length":10.0,
# "type":"closed"
# },
# "size_start":3.0,
# "size_end":3.0,
# "size":1.0
# },{
# "geom":"point",
# "data":{
# "name":["Erzurum","Boldino","Vitebsk","Vladikavkaz","Georgiyevsk","Goryachie Vody","Ekaterinodar","Ekaterinoslav","Kazan","Kars","Kiev","Chișinău","Moscow","Mikhaylovskoye","Nizhny Novgorod","Novocherkassk","Odessa","Orenburg","Oryol","Petersburg","Polotnyany Zavod","Pskov","Svyatogorskij monastery","Simbirsk","Simferopol","Stavropol","Tiflis","Uralsk","Chernihiv"],
# "latitude":[39.90861,55.004477,55.187222,43.03667,44.1497667,44.04861,45.04484,48.450001,55.78874,40.60199,50.431782,47.00367,55.751244,57.061332,56.32753,47.414101,46.469391,51.776272,52.929697,59.93863,54.728958,57.8136,57.022162,54.32824,44.957813,45.0428,41.716667,51.23333,51.50551],
# "longitude":[41.27694,45.30885,30.205116,44.66778,43.4577689,43.05944,38.97603,34.983334,49.12214,43.09495,30.516382,28.907089,37.618423,28.919346,44.000717,40.110401,30.740883,55.099594,36.098689,30.31413,35.971598,28.3496,28.920945,48.38657,34.109547,41.9734,44.783333,51.36667,31.28487],
# "years":["1829","1830, 1833","1820, 1824","1829","1820, 1829","1820","1820","1820","1833","1829","1820-1821","1820-1821, 1823","1811, 1826-1830, 1833-1834, 1836","1824, 1826","1833","1820, 1829","1820-1821, 1823-1824","1833","1829","1811, 1820, 1827-1828, 1833, 1836-1837","1830, 1834","1826","1837","1833","1820","1820, 1829","1829","1833","1824"]
# },
# "mapping":{
# "x":"longitude",
# "y":"latitude"
# },
# "tooltips":{
# "formats":[],
# "lines":["visited in|@years"],
# "title":"@name"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"float",
# "column":"latitude"
# },{
# "type":"float",
# "column":"longitude"
# },{
# "type":"str",
# "column":"years"
# }]
# },
# "size":3.0,
# "color":"#F7F4F0"
# },{
# "geom":"point",
# "data":{
# "latitude":[39.90861,55.004477,55.187222,43.03667,44.1497667,44.04861,45.04484,48.450001,55.78874,40.60199,50.431782,47.00367,55.751244,57.061332,56.32753,47.414101,46.469391,51.776272,52.929697,59.93863,54.728958,57.8136,57.022162,54.32824,44.957813,45.0428,41.716667,51.23333,51.50551],
# "longitude":[41.27694,45.30885,30.205116,44.66778,43.4577689,43.05944,38.97603,34.983334,49.12214,43.09495,30.516382,28.907089,37.618423,28.919346,44.000717,40.110401,30.740883,55.099594,36.098689,30.31413,35.971598,28.3496,28.920945,48.38657,34.109547,41.9734,44.783333,51.36667,31.28487]
# },
# "mapping":{
# "x":"longitude",
# "y":"latitude"
# },
# "tooltips":"none",
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"float",
# "column":"latitude"
# },{
# "type":"float",
# "column":"longitude"
# },{
# "type":"str",
# "column":"years"
# }]
# },
# "size":1.7,
# "color":"black"
# }],
# "metainfo_list":[],
# "spec_id":"11"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDi

# %%
mX = 37.618423
mY = 55.751244
pointSize = 2

ggplot(places_df, aes(x='longitude', y='latitude')) + \
    geom_livemap() + \
    geom_point(size=pointSize, color='red') + \
    geom_segment(xend=mX, yend=mY,
                 size=0.2,
                 size_start=pointSize, size_end=pointSize)
# Out:
#    <div id="Q3sT5s"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Q3sT5s");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# "latitude":[39.90861,55.004477,55.187222,43.03667,44.1497667,44.04861,45.04484,48.450001,55.78874,40.60199,50.431782,47.00367,55.751244,57.061332,56.32753,47.414101,46.469391,51.776272,52.929697,59.93863,54.728958,57.8136,57.022162,54.32824,44.957813,45.0428,41.716667,51.23333,51.50551],
# "longitude":[41.27694,45.30885,30.205116,44.66778,43.4577689,43.05944,38.97603,34.983334,49.12214,43.09495,30.516382,28.907089,37.618423,28.919346,44.000717,40.110401,30.740883,55.099594,36.098689,30.31413,35.971598,28.3496,28.920945,48.38657,34.109547,41.9734,44.783333,51.36667,31.28487]
# },
# "mapping":{
# "x":"longitude",
# "y":"latitude"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"float",
# "column":"latitude"
# },{
# "type":"float",
# "column":"longitude"
# },{
# "type":"str",
# "column":"years"
# }]
# },
# "theme":{
# "name":"minimal"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":2.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "xend":37.618423,
# "yend":55.751244,
# "size":0.2,
# "size_start":2.0,
# "size_end":2.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
