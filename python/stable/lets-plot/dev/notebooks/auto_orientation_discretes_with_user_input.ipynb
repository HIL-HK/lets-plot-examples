# %%
import numpy as np
import pandas as pd
import random
from lets_plot import *
from lets_plot.mapping import as_discrete
from IPython.display import display, Markdown

# %%
def dump_plot(plot, display=None):
    import json

    try:
        import clipboard
    except:
        clipboard = None
        
    from lets_plot._type_utils import standardize_dict
    
    plot_dict = standardize_dict(plot.as_dict())
    plot_json = json.dumps(plot_dict, indent=2)
    
    if clipboard:
        clipboard.copy('')
        clipboard.copy(str(plot_json))
    else:
        if display is None:
            display = True
    
    if display:
        print(plot_json)

    return plot

LetsPlot.setup_html()
# Out:
#             <div id="971Kto"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("971Kto").appendChild(div);
#                     };
#                     var e = document.getElementById("971Kto");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def run_catching(f):
    def colored(s):
        return Markdown('<span style="color: #FF0000">{}</span>'.format(s))
    try:
        plot = f()
        return plot
    except Exception as e:
            display(colored('{}'.format(e)))
            return None

# %% [markdown]
# ### `Aes.X` and `Aes.Y` discrete

# %%
n = 100
np.random.seed(42)
data = {
    'code': np.random.choice(list('abcde'), size=100),
    'value': np.random.normal(size=100),
    'value_str': np.random.choice(list('fghjk'), size=100),
}

# %%
gggrid([
    ggplot(data, aes('code', 'value_str')) + geom_bar(),
    ggplot(data, aes('code', 'value_str')) + geom_bar(orientation='y'),
    ggplot(data, aes('code', 'value_str')) + geom_bar(orientation='x')
])
# Out:
#    <div id="cVKJBw"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("cVKJBw");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value_str"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# },{
# "type":"str",
# "column":"value_str"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "code":["d","e","c","b","a"],
# "value_str":[26.0,19.0,16.0,21.0,18.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value_str"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# },{
# "type":"str",
# "column":"value_str"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "value_str":["h","j","f","k","g"],
# "code":[22.0,21.0,24.0,17.0,16.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value_str"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# },{
# "type":"str",
# "column":"value_str"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"x",
# "data":{
# "code":["d","e","c","b","a"],
# "value_str":[26.0,19.0,16.0,21.0,18.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `Aes.X` - discrete, `Aes.Y` - continues

# %%
np.random.seed(42)
data = {
    'code': np.random.choice(list('abcde'), size=4),
    'value': np.random.normal(size=4)
}

# %%
gggrid([
    ggplot(data, aes('code', 'value')) + geom_bar(),
    ggplot(data, aes('code', 'value')) + geom_bar(orientation='y'),
    ggplot(data, aes('code', 'value')) + geom_bar(orientation='x')
])
# Out:
#    <div id="uNKyMg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("uNKyMg");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "code":["d","e","c"],
# "value":[1.0,2.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "value":[-1.1978064265539556,2.1416584322166123,-0.09462100189797198,-0.928828100033933],
# "code":[1.0,1.0,1.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"x",
# "data":{
# "code":["d","e","c"],
# "value":[1.0,2.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
run_catching(lambda: ggplot(data, aes(x='code', y='value')) + geom_boxplot())
# Out:
#    <div id="shMCDU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("shMCDU");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","c"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# },
# "show_legend":false,
# "data_meta":{
# },
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","e","c"],
# "value":[NaN,2.1416584322166123,-0.928828100033933,NaN]
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
run_catching(lambda: ggplot(data, aes(x='value', y='code')) + geom_boxplot(orientation="y"))
# Out:
#    <div id="9PK5ze"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("9PK5ze");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"value",
# "y":"code"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","c"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# },
# "show_legend":false,
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","e","c"],
# "value":[NaN,2.1416584322166123,-0.928828100033933,NaN]
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
run_catching(lambda: ggplot(data, aes(x='code', y='value')) + geom_boxplot(orientation="x"))
# Out:
#    <div id="K9Cecx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("K9Cecx");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"code",
# "y":"value"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"x",
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","c"]
# }
# },{
# "geom":"point",
# "stat":"boxplot_outlier",
# "mapping":{
# },
# "show_legend":false,
# "data_meta":{
# },
# "orientation":"x",
# "data":{
# "..middle..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..lower..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..upper..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymin..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "..ymax..":[-1.1978064265539556,0.6064151660913397,0.6064151660913397,-0.09462100189797198],
# "code":["d","e","e","c"],
# "value":[NaN,2.1416584322166123,-0.928828100033933,NaN]
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `Aes.X` - continues, `Aes.Y` - discrete

# %%
gggrid([
    ggplot(data, aes('value', 'code')) + geom_bar(),
    ggplot(data, aes('value', 'code')) + geom_bar(orientation='y'),
    ggplot(data, aes('value', 'code')) + geom_bar(orientation='x')
])
# Out:
#    <div id="HGITtN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("HGITtN");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"value",
# "y":"code"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "code":["d","e","c"],
# "value":[1.0,2.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# },{
# "data":{
# },
# "mapping":{
# "x":"value",
# "y":"code"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# "code":["d","e","c"],
# "value":[1.0,2.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "data":{
# },
# "mapping":{
# "x":"value",
# "y":"code"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"code"
# },{
# "type":"float",
# "column":"value"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"x",
# "data":{
# "value":[-1.1978064265539556,2.1416584322166123,-0.09462100189797198,-0.928828100033933],
# "code":[1.0,1.0,1.0,1.0]
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# }]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `Aes.X` and `Aes.Y` continues

# %%
n = 100
np.random.seed(42)
data = {
    'value1': np.random.normal(size=100),
    'value2': 10*np.random.normal(size=100)
}

# %%
gggrid([
    ggplot(data, aes('value1', 'value2')) + geom_lollipop(),
    ggplot(data, aes('value1', 'value2')) + geom_lollipop(orientation='y'),
    ggplot(data, aes('value1', 'value2')) + geom_lollipop(orientation='x')
])
# Out:
#    <div id="C3jlin"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("C3jlin");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "value1":[0.4967141530112327,-0.13826430117118466,0.6476885381006925,1.5230298564080254,-0.23415337472333597,-0.23413695694918055,1.5792128155073915,0.7674347291529088,-0.4694743859349521,0.5425600435859647,-0.46341769281246226,-0.46572975357025687,0.24196227156603412,-1.913280244657798,-1.7249178325130328,-0.5622875292409727,-1.0128311203344238,0.3142473325952739,-0.9080240755212111,-1.4123037013352917,1.465648768921554,-0.22577630048653566,0.06752820468792384,-1.4247481862134568,-0.5443827245251827,0.11092258970986608,-1.1509935774223028,0.37569801834567196,-0.600638689918805,-0.2916937497932768,-0.6017066122293969,1.8522781845089378,-0.013497224737933914,-1.0577109289559,0.822544912103189,-1.2208436499710222,0.2088635950047554,-1.9596701238797756,-1.3281860488984305,0.19686123586912352,0.7384665799954104,0.1713682811899705,-0.11564828238824053,-0.3011036955892888,-1.4785219903674274,-0.7198442083947086,-0.4606387709597875,1.0571222262189157,0.3436182895684614,-1.