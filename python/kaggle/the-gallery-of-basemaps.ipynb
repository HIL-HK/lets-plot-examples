# %% [markdown]
# ## Configuring basemap tiles in [Lets-Plot](https://lets-plot.org)
#
#
# ### Configuring globally
#
# You can configure global Lets-Plot options using the `LestPlot.set(dictionary)` method.
#
# Where the `dictionary` can contain all sorts of Lets-Plot options, including basemap tiles configuration options.
#
# Lets-Plot provides a variety of constantas and functions which make configuring of basemap tiles simple:
#
# ```
# from lets_plot import tilesets
#
# LetsPlot.set(tilesets.LETS_PLOT_DARK)
# ```
#
# ### Configuring for a single plot
#
# Use `tiles` parameter in the `geom_livemap()` function:
# ```
# from lets_plot import tilesets
#
# ggplot() + geom_livemap(tiles=tilesets.LETS_PLOT_DARK)
# ```
#
#
# In this demo we will be using the `tiles` parameter because each plot here is using different map-tile service.

# %%
#!pip install lets-plot --quiet

import lets_plot
lets_plot.__version__
# Out:
# '4.6.1'

# %%
from lets_plot import *
from lets_plot import tilesets
LetsPlot.setup_html()
# Out:
#             <div id="SQYios"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("SQYios").appendChild(div);
#                     };
#                     var e = document.getElementById("SQYios");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def make_map(text, tiles=None):
    return (ggplot() + geom_livemap(location=[13.3, 37.6], zoom=3, tiles=tiles) + 
     ggsize(500, 450) + theme(plot_title=element_text(hjust=0.5)) +
     ggtitle(text))

# %% [markdown]
# ### Lets-Plot vector tiles
#
# Lets-Plot provides its own vector basemap tiles available in four variants:
#
# - color
# - dark
# - light
# - BW
#
# By default Lets-Plot uses its "color" tiles.

# %%
gggrid(
    [
        make_map("Default"),
        make_map("Dark", tilesets.LETS_PLOT_DARK),
        make_map("Light", tilesets.LETS_PLOT_LIGHT),
        make_map("BW", tilesets.LETS_PLOT_BW),
    ],
    ncol=2
) + ggtitle('Lets-Plot Vector Tiles') + theme(plot_title=element_text(hjust=0.5)) + ggsize(1000, 950)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="xt52yK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("xt52yK");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtitle":{
# "text":"Lets-Plot Vector Tiles"
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":950.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Dark"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Light"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"light",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"BW"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"bw",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-f5aa95619c97406780a23364c15cd9ff', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-f5aa95619c97406780a23364c15cd9ff" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %% [markdown]
# ## Raster tiles
#
# You can use `ZXY` raster tiles provided by 3rd party maptile services.
#
# Some services provide free of charge raster tilesets.
#
# The `tilesets` module in Lets-Plot contains many such tilesets pre-cofigured.

# %% [markdown]
# ### OpenStreetMap
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright)

# %%
make_map("OpenStreetMap's Standard tile layer", tilesets.OSM)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="xTHtmJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("xTHtmJ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"OpenStreetMap's Standard tile layer"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].tile.openstreetmap.org/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>",
# "min_zoom":1.0,
# "max_zoom":19.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-014010c89f2c407ca65d2ce34a5b21b2', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-014010c89f2c407ca65d2ce34a5b21b2" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %% [markdown]
# ### OpenTopoMap
#
# Map data: [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright), [SRTM](http://viewfinderpanoramas.org/) | map style: [© OpenTopoMap](https://opentopomap.org/) ([CC-BY-SA](https://creativecommons.org/licenses/by-sa/3.0/))

# %%
make_map("OpenTopoMap", tilesets.OPEN_TOPO_MAP)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="Zw7m3G"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Zw7m3G");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"OpenTopoMap"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://tile.opentopomap.org/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>, <a href=\"http://viewfinderpanoramas.org/\">SRTM</a> | map style: <a href=\"https://opentopomap.org/\">© OpenTopoMap</a> (<a href=\"https://creativecommons.org/licenses/by-sa/3.0/\">CC-BY-SA</a>) ",
# "min_zoom":1.0,
# "max_zoom":16.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-ad512737a13b4df9ba096605a2048f33', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-ad512737a13b4df9ba096605a2048f33" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %% [markdown]
# ### CARTO
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright) [© CARTO](https://carto.com/attributions#basemaps), [© CARTO](https://carto.com/attributions)
#
# Free for none-commercial services only (see [Limitations](https://github.com/CartoDB/basemap-styles#1-web-raster-basemaps), [License](https://github.com/CartoDB/basemap-styles/blob/master/LICENSE.md)).

# %%
gggrid(
    [
        make_map("Positron", tilesets.CARTO_POSITRON_HIRES),
        make_map("Positron (no labels)", tilesets.CARTO_POSITRON_NO_LABELS_HIRES),
        make_map("Dark Matter (no labels)", tilesets.CARTO_DARK_MATTER_NO_LABELS_HIRES),
        make_map("Voyager", tilesets.CARTO_VOYAGER_HIRES),
        make_map("Flat Blue", tilesets.CARTO_FLAT_BLUE),
        make_map("Midnight commander", tilesets.CARTO_MIDNIGHT_COMMANDER),
        make_map("Antique", tilesets.CARTO_ANTIQUE_HIRES),
    ],
    ncol=2
) + ggtitle('CARTO Tiles') + theme(plot_title=element_text(hjust=0.5)) + ggsize(1000, 1900)
# Out:
# WARN: The tileset is no longer available and the corresponding constant will be removed in future releases.
# WARN: The tileset is no longer available and the corresponding constant will be removed in future releases.
# WARN: The tileset is no longer available and the corresponding constant will be removed in future releases.
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="8SeodN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("8SeodN");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtitle":{
# "text":"CARTO Tiles"
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":1900.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":4.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Positron"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/light_all/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Positron (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/light_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Dark Matter (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/dark_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Voyager"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Flat Blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-flatblue/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Midnight commander"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-midnight/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Antique"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-antique/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# },"blank"]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        )

# %% [markdown]
# ### NASA's Global Imagery Browse Services (GIBS)
#
# Imagery provided by services from NASA's Global Imagery Browse Services ([GIBS](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs)), part of NASA's Earth Observing System Data and Information System ([EOSDIS](https://earthdata.nasa.gov)).
#
# [NASA's Global Imagery Browse Services (GIBS)](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs).
#
# Global Imagery Browse Services (GIBS) - [API for Developers](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers).
#
# Global Imagery Browse Services (GIBS) API - [Generic XYZ Tile Access](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers#GIBSAPIforDevelopers-GenericXYZTileAccess).
#
# [GIBS Available Imagery Products](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+Available+Imagery+Products).

# %%
gggrid(
    [
        make_map("CityLights 2012", tilesets.NASA_CITYLIGHTS_2012),
        make_map("Greyscale Shaded Relief (30m)", tilesets.NASA_GREYSCALE_SHADED_RELIEF_30M),
        make_map("Color Shaded Relief (30m)", tilesets.NASA_COLOR_SHADED_RELIEF_30M),
        make_map("Terra TrueColor", tilesets.NASA_TERRA_TRUECOLOR),
    ],
    ncol=2
) + ggtitle('NASA GIBS Tiles') + theme(plot_title=element_text(hjust=0.5)) + ggsize(1000, 950)
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="GWQKJJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("GWQKJJ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtitle":{
# "text":"NASA GIBS Tiles"
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggsize":{
# "width":1000.0,
# "height":950.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"CityLights 2012"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default//GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":8.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Greyscale Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Greyscale_Shaded_Relief/default//GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":12.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Color Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Color_Shaded_Relief/default//GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":12.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Terra TrueColor"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/MODIS_Terra_CorrectedReflectance_TrueColor/default/2015-06-07/GoogleMapsCompatible_Level9/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":9.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-9ba006896a3b4f17885456daee0efe3e', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-9ba006896a3b4f17885456daee0efe3e" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>

# %% [markdown]
# ## Configuring raster tiles manually
#
# In addition to pre-configured tilesets you can configure and use almost any other raster tilesets provided in `ZXY` format.
#
# You can do it with the help of the `LetsPlot.maptiles_zxy()` function.
#
# The following code will configure 'NASA, CityLights 2012' tiles:

# %%
settings = dict(
    url = "https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default/GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
    attribution = '<a href="https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs">© NASA Global Imagery Browse Services (GIBS)</a>',
    max_zoom=8
)

make_map("NASA, CityLights 2012", maptiles_zxy(**settings))
# Out:
#     <div style="border:1px solid #ccc; padding:5px; margin-bottom:5px; width: 100%;
#                 display: flex; align-items: flex-start; justify-content: space-between;
#                 overflow-x: hidden; box-sizing: border-box;">
#         <div style="flex-grow: 1; max-width: calc(100% - 130px); overflow: hidden;">
#                <div id="773ZkT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("773ZkT");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "theme":{
# "plot_title":{
# "hjust":0.5,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"NASA, CityLights 2012"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default/GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, <a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "max_zoom":8.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
#         </div>
#         <button onclick="copyToClipboard('obj-725c67e98123460a9930b324b5010960', this)"
#                 style="cursor: pointer; min-width: 100px; padding: 5px 10px; font-size: 14px;
#                        background: #f5f5f5; border: 1px solid #ccc; border-radius: 5px;
#                        user-select: text; flex-shrink: 0; transition: opacity 0.3s ease;
#                        white-space: nowrap; text-align: center;">
#             Copy Spec
#         </button>
#     </div>
#     <div id="obj-725c67e98123460a9930b324b5010960" data-spec="..." style="display:none;"></div>
#
#     <script>
#         function decodeBase64(base64String) {
#             return atob(base64String);
#         }
#
#         function copyToClipboard(plotId, button) {
#             let base64Spec = document.getElementById(plotId).dataset.spec;
#             if (!base64Spec) {
#                 console.error("Plot spec not found:", plotId);
#                 return;
#             }
#             let rawText = decodeBase64(base64Spec);
#             navigator.clipboard.writeText(rawText).then(() => {
#                 button.textContent = 'Copied!';
#                 button.style.opacity = '0.5';
#                 setTimeout(() => {
#                     button.textContent = 'Copy Spec';
#                     button.style.opacity = '1';
#                 }, 1000);
#             }).catch(err => {
#                 console.error("Failed to copy:", err);
#             });
#         }
#     </script>
