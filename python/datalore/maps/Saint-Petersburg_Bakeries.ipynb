# %% [markdown]
# # Saint-Petersburg Bakeries

# %%
import pandas as pd
import geopandas as gpd
from overpy import Overpass
from shapely.geometry import Polygon
from scipy.spatial import Voronoi

from lets_plot import *
LetsPlot.setup_html()

# %%
def fix_bakery_name(data):
    names_fixes = {
        'Bonape': 'Bonapé',
        'Лавка пекаря': 'Лавка Пекаря',
        'Цех85': 'Цех 85',
    }
    if data['name'] in names_fixes.keys():
        data['name'] = names_fixes[data['name']]
    return data

# %%
def get_areas_gdf(geometry, names):
    diag = Voronoi([[p.x, p.y] for p in geometry])
    regions = [[diag.vertices[i] for i in region if i != -1] for region in diag.regions]
    regions = [Polygon(region) for region in regions if len(region) > 2]
    areas_data = [(name, next((region for region in regions if region.contains(point)), None)) \
                  for name, point in zip(names, geometry)]
    areas_df = pd.DataFrame(areas_data, columns=['name', 'area'])
    areas_gdf = gpd.GeoDataFrame(areas_df, geometry='area')
    areas_gdf = areas_gdf.set_crs(epsg=geometry.crs.to_epsg())
    areas_gdf = areas_gdf.dropna()
    return areas_gdf

# %% [markdown]
# We are going to use the Overpass API to get data about Saint-Petersburg's bakeries from [OSM](https://www.openstreetmap.org).
#
# Then we will draw a Voronoi diagram of the biggest bakery chains. That will help us to find the nearest bakery for each point of the city.

# %%
ovp = Overpass()
spb_bakeries_data = ovp.query("""
    area[name="Санкт-Петербург"];
    nwr[shop=bakery](area);
    out center;
    """)

# %%
spb_bakeries_df = pd.DataFrame([(bakery.tags.get('name'), float(bakery.lon), float(bakery.lat)) \
                                for bakery in spb_bakeries_data.nodes], columns=['name', 'lon', 'lat'])
spb_bakeries_df = spb_bakeries_df.dropna()

# %%
spb_bakeries_gdf = gpd.GeoDataFrame(spb_bakeries_df[['name']], \
                                    geometry=gpd.points_from_xy(spb_bakeries_df.lon, spb_bakeries_df.lat))
spb_bakeries_gdf = spb_bakeries_gdf.apply(fix_bakery_name, axis=1)
top_bakery_chains = spb_bakeries_gdf['name'].value_counts()[:15].keys()
spb_bakeries_gdf = spb_bakeries_gdf[spb_bakeries_gdf['name'].isin(top_bakery_chains)]
spb_bakeries_gdf = spb_bakeries_gdf.set_crs(epsg=4326)

# %%
areas_gdf = get_areas_gdf(spb_bakeries_gdf.geometry.to_crs('EPSG:3857'), spb_bakeries_gdf['name']).to_crs('EPSG:4326')

# %%
ggplot() + \
    geom_livemap(location=[30.308611, 59.937500], zoom=11) + \
    geom_polygon(aes(group='name', fill='name'), \
                 data=areas_gdf, size=.1, color='#636363', alpha=.3, \
                 tooltips=layer_tooltips().line('@name')) + \
    geom_point(aes(group='name', fill='name'), \
               data=spb_bakeries_gdf, shape=21, color='#636363', \
               tooltips=layer_tooltips().line('@name')) + \
    scale_fill_discrete(name='chain') + \
    ggtitle('Top 15 Bakery Chains in Saint Petersburg') + \
    ggsize(800, 600)
# Out:
# <html lang="en">
#    <head>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.3.0/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="bEG3OO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Top 15 Bakery Chains in Saint Petersburg"
# },
# "ggsize":{
# "width":800,
# "height":600
# },
# "kind":"plot",
# "scales":[{
# "name":"chain",
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[30.308611,59.9375]
# },
# "zoom":11,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "data":{
# "name":["Булочные Ф. Вольчека","Лавка Пекаря","Цех 85","буше","Булочные Ф. Вольчека","Цех 85","Булочные Ф. Вольчека","ЛюдиЛюбят","буше","Булочные Ф. Вольчека","Цех 85","буше","буше","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Британские пекарни","буше","Булочные Ф. Вольчека","Цех 85","Выпечка АМ!","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","Цех 85","Булочные Ф. Вольчека","Хлебник","буше","Цех 85","Цех 85","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Буханка","буше","Хлебник","Булочные Ф. Вольчека","Британские пекарни","Булочные Ф. Вольчека","Bonapé","буше","Тили-тесто","Bonapé","Хлебная усадьба","буше","Буханка","буше","Булочные Ф. Вольчека","Лавка Пекаря","Булочные Ф. Вольчека","буше","буше","буше","Лавка Пекаря","Хлебная усадьба","буше","Булочные Ф. Вольчека","Лавка Пекаря","Булочные Ф. Вольчека","Булка хлеба","Цех 85","Цех 85","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","буше","буше","Буханка","буше","Буханка","Лавка Пекаря","Хлебная усадьба","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Цех 85","Bonapé","Буханка","Bonapé","Пекарня","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Буханка","Bonapé","Буханка","Булочные Ф. Вольчека","Цех 85","Булочные Ф. Вольчека","буше","Британские пекарни","Хлебник","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Цех 85","буше","Булка хлеба","Булочные Ф. Вольчека","Bonapé","Выпечка АМ!","Буханка","Булочные Ф. Вольчека","Пекарня","Цех 85","Лавка Пекаря","Bonapé","Bonapé","Цех 85","Булочные Ф. Вольчека","буше","Выпечка АМ!","ЛюдиЛюбят","буше","Булочные Ф. Вольчека","Цех 85","Булочные Ф. Вольчека","Буханка","Британские пекарни","Цех 85","Пекарня","Буханка","Булка хлеба","Bonapé","Хлебная усадьба","Хлебник","Пекарня","Булочные Ф. Вольчека","Британские пекарни","Булочные Ф. Вольчека","Лавка Пекаря","Bonapé","Цех 85","буше","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","ЛюдиЛюбят","ЛюдиЛюбят","Буханка","Булка хлеба","буше","ЛюдиЛюбят","Хлебная усадьба","Булка хлеба","Булка хлеба","буше","Цех 85","Булочные Ф. Вольчека","Цех 85","Лавка Пекаря","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","Хлебная усадьба","буше","Британские пекарни","Выпечка АМ!","Булочные Ф. Вольчека","Цех 85","Британские пекарни","Цех 85","Лавка Пекаря","Булочные Ф. Вольчека","Лавка Пекаря","Цех 85","Булочные Ф. Вольчека","Лавка Пекаря","Тили-тесто","Цех 85","Булочные Ф. Вольчека","Пекарня","Лавка Пекаря","Булочные Ф. Вольчека","Буханка","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Тили-тесто","Тили-тесто","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","Булочные Ф. Вольчека","Пекарня","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","Британские пекарни","Хлебник","Цех 85","Цех 85","Цех 85","Лавка Пекаря","Булочные Ф. Вольчека","Лавка Пекаря","Лавка Пекаря","буше","Лавка Пекаря","Булочные Ф. Вольчека","буше","Цех 85","Хлебник","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Пекарня","Булочные Ф. Вольчека","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Лавка Пекаря","Пекарня","Лавка Пекаря","Пекарня","Лавка Пекаря","Булочные Ф. Вольчека","Хлебная усадьба","Хлебник","Хлебник","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Хлебник","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Пекарня","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Лавка Пекаря","буше","Хлебник ...
# "area":["{\"type\": \"Polygon\", \"coordinates\": [[[30.35466030417398, 59.955619394872734], [30.35659186291887, 59.95905953898577], [30.36117071044635, 59.95986290978235], [30.358262650934083, 59.95473773793304], [30.35466030417398, 59.955619394872734]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.242922117076564, 59.920425783655126], [30.15286333955696, 59.91418575478902], [30.236728462810827, 59.934409264071775], [30.24104870011614, 59.93530104394305], [30.242922117076564, 59.920425783655126]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.35607240776679, 59.94488232392755], [30.35493093215358, 59.944776683646964], [30.354667335645544, 59.94562984515612], [30.37031449133401, 59.951114327567424], [30.37339507033451, 59.951160898081014], [30.368029231207075, 59.9483018726496], [30.35607240776679, 59.94488232392755]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.316620894978843, 59.9222917920638], [30.3173262178445, 59.92176304306477], [30.325896270898028, 59.921757681790524], [30.32967013217981, 59.925671520139296], [30.32077527051965, 59.92867236451579], [30.314673855683324, 59.924223391536074], [30.315576721032738, 59.923166922350696], [30.316620894978843, 59.9222917920638]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.314058420745084, 59.92725426777939], [30.312103146309102, 59.93128750185339], [30.30566114865423, 59.93106963411409], [30.311612741431045, 59.925234992210584], [30.31385888182561, 59.92471817401613], [30.314058420745084, 59.92725426777939]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.475569434173554, 59.90314191103647], [30.472895918353917, 59.90949171072128], [30.55725419650935, 59.88304710664507], [30.476288160947227, 59.90196144460146], [30.475569434173554, 59.90314191103647]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.320573868421757, 59.928839151380515], [30.314058420745084, 59.92725426777939], [30.31385888182561, 59.92471817401613], [30.314673855683324, 59.924223391536074], [30.32077527051965, 59.92867236451579], [30.320573868421757, 59.928839151380515]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.295523707355972, 59.95658955541293], [30.297259537072062, 59.95622405178467], [30.301358759403737, 59.955493142744196], [30.30574213792327, 59.95917617925648], [30.296534641553936, 59.96053195133198], [30.296041929428362, 59.959318504255656], [30.295523707355972, 59.95658955541293]]]}","{\"type\": \"Polygon\", \"coordinates\": [[
