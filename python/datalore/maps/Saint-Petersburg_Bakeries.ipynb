# %% [markdown]
# # Saint-Petersburg Bakeries

# %%
import pandas as pd
import geopandas as gpd
from overpy import Overpass
from shapely.geometry import Polygon
from scipy.spatial import Voronoi

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="xc5UFc"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("xc5UFc").appendChild(div);
#                     };
#                     var e = document.getElementById("xc5UFc");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def fix_bakery_name(data):
    names_fixes = {
        'Bonape': 'Bonapé',
        'Лавка пекаря': 'Лавка Пекаря',
        'Цех85': 'Цех 85',
    }
    if data['name'] in names_fixes.keys():
        data['name'] = names_fixes[data['name']]
    return data

# %%
def get_areas_gdf(geometry, names):
    diag = Voronoi([[p.x, p.y] for p in geometry])
    regions = [[diag.vertices[i] for i in region if i != -1] for region in diag.regions]
    regions = [Polygon(region) for region in regions if len(region) > 2]
    areas_data = [(name, next((region for region in regions if region.contains(point)), None)) \
                  for name, point in zip(names, geometry)]
    areas_df = pd.DataFrame(areas_data, columns=['name', 'area'])
    areas_gdf = gpd.GeoDataFrame(areas_df, geometry='area')
    areas_gdf = areas_gdf.set_crs(epsg=geometry.crs.to_epsg())
    areas_gdf = areas_gdf.dropna()
    return areas_gdf

# %% [markdown]
# We are going to use the Overpass API to get data about Saint-Petersburg's bakeries from [OSM](https://www.openstreetmap.org).
#
# Then we will draw a Voronoi diagram of the biggest bakery chains. That will help us to find the nearest bakery for each point of the city.

# %%
ovp = Overpass()
spb_bakeries_data = ovp.query("""
    area[name="Санкт-Петербург"];
    nwr[shop=bakery](area);
    out center;
    """)

# %%
spb_bakeries_df = pd.DataFrame([(bakery.tags.get('name'), float(bakery.lon), float(bakery.lat)) \
                                for bakery in spb_bakeries_data.nodes], columns=['name', 'lon', 'lat'])
spb_bakeries_df = spb_bakeries_df.dropna()

# %%
spb_bakeries_gdf = gpd.GeoDataFrame(spb_bakeries_df[['name']], \
                                    geometry=gpd.points_from_xy(spb_bakeries_df.lon, spb_bakeries_df.lat))
spb_bakeries_gdf = spb_bakeries_gdf.apply(fix_bakery_name, axis=1)
top_bakery_chains = spb_bakeries_gdf['name'].value_counts()[:15].keys()
spb_bakeries_gdf = spb_bakeries_gdf[spb_bakeries_gdf['name'].isin(top_bakery_chains)]
spb_bakeries_gdf = spb_bakeries_gdf.set_crs(epsg=4326)

# %%
areas_gdf = get_areas_gdf(spb_bakeries_gdf.geometry.to_crs('EPSG:3857'), spb_bakeries_gdf['name']).to_crs('EPSG:4326')

# %%
ggplot() + \
    geom_livemap(location=[30.308611, 59.937500], zoom=11) + \
    geom_polygon(aes(group='name', fill='name'), \
                 data=areas_gdf, size=.1, color='#636363', alpha=.3, \
                 tooltips=layer_tooltips().line('@name')) + \
    geom_point(aes(group='name', fill='name'), \
               data=spb_bakeries_gdf, shape=21, color='#636363', \
               tooltips=layer_tooltips().line('@name')) + \
    scale_fill_discrete(name='chain') + \
    ggtitle('Top 15 Bakery Chains in Saint Petersburg') + \
    ggsize(800, 600)
# Out:
#    <div id="nKeVKD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("nKeVKD");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Top 15 Bakery Chains in Saint Petersburg"
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "kind":"plot",
# "scales":[{
# "name":"chain",
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[30.308611,59.9375]
# },
# "zoom":11.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "data":{
# "name":["Хлебник","Ленинградские булочные","Хлебник","Булочные Ф. Вольчека","Люди любят","Лавка Пекаря","Цех 85","Хлебник","Пироговый дворик","Булочная Ф. Вольчека","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Люди любят","Хлебник","ЛюдиЛюбят","Все дома","Пироговый дворик","Буше","Булочные Ф. Вольчека","Пекарня","Люди любят","Булочные Ф. Вольчека","Цех 85","Буше","Люди любят","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Британские пекарни","Буше","Булочные Ф. Вольчека","Пироговый дворик","Люди любят","Лавка Пекаря","Цех 85","Хлебник","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Лавка Пекаря","Цех 85","Булочные Ф. Вольчека","Хлебник","Хлебник","Хлебник","Пироговый дворик","Хлебник","Хлебник","Люди любят","Буше","Цех 85","Пироговый дворик","Цех 85","Цех 85","Люди любят","Хлебник","Люди любят","Булочная Ф. Вольчека","Люди любят","Пироговый дворик","Ленинградские булочные","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Хлебник","Пироговый дворик","буше","Хлебник","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Пироговый дворик","Буше","Цех 85","Хлебник","Пироговый дворик","Буше","Буханка","буше","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Цех 85","Буше","буше","Лавка Пекаря","Люди любят","Буше","Люди любят","Булочные Ф. Вольчека","Пироговый дворик","Лавка Пекаря","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Пироговый дворик","Цех 85","Цех 85","Булочная Ф. Вольчека","Цех 85","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буше","Буше","Буханка","Буше","Буханка","Лавка Пекаря","Пироговый дворик","Хлебник","Пироговый дворик","Хлебник","Булочная Ф. Вольчека","Цех 85","Буханка","Люди любят","Пекарня","Булочная Ф. Вольчека","Пекарня","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Цех 85","Буханка","Булочные Ф. Вольчека","Хлебник","Цех 85","Булочная Ф. Вольчека","Буше","Британские пекарни","Хлебник","Булочные Ф. Вольчека","Цех 85","Пироговый дворик","Пироговый дворик","Буше","Булочная Ф. Вольчека","Люди любят","Буханка","ЛюдиЛюбят","Булочные Ф. Вольчека","Ленинградские булочные","Пекарня","Цех 85","Лавка Пекаря","Цех 85","Цех 85","Булочные Ф. Вольчека","буше","Люди любят","буше","Булочные Ф. Вольчека","Цех 85","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Буханка","Британские пекарни","Цех 85","Буханка","Пироговый дворик","Ленинградские булочные","Пекарня","Булочные Ф. Вольчека","Британские пекарни","Булочная Ф. Вольчека","Лавка Пекаря","Люди любят","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Люди любят","Люди любят","Хлебник","Буханка","Буше","Цех 85","Булочная Ф. Вольчека","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","ЛюдиЛюбят","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","буше","Британские пекарни","Булочная Ф. Вольчека","Цех 85","Британские пекарни","Цех 85","Все дома","Булочные Ф. Вольчека","Лавка Пекаря","Цех 85","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","Пекарня","Лавка Пекаря","Пироговый дворик","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Ленинградские булочные","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочные Ф. Вольчека","Булочные Ф. Вольчека","Ленинградские булочные","Лавка Пекаря","Булочная Ф. Вольчека","Пекарня","ЛюдиЛюбят","ЛюдиЛюбят","Люди любят","Булочные Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Хлебник","Британские пекарни","Хлебник","Хлебник","Цех 85","Цех 85","Булочные Ф. Вольчека","Лавка Пекаря","Пироговый дворик","Пироговый дворик","Лавка Пекаря","Все дома","Буше","Лавка Пекаря","Хлебник","Буше","Цех 85","Хлебник","Хлебник","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85","Цех 85", ...
