# %% [markdown]
# # US Museums
#
# Here we would like to investigate the income of US museums.
#
# Data is provided by [Kaggle](https://www.kaggle.com/imls/museum-directory).

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import ipywidgets as wg

from lets_plot import *
from lets_plot.geo_data import *
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
LetsPlot.setup_html()
# Out:
#             <div id="kw3iUT"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("kw3iUT").appendChild(div);
#                     };
#                     var e = document.getElementById("kw3iUT");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Preparation

# %%
museums_df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/museums.csv",
                         low_memory=False)
museums_df = museums_df.rename(columns={'State (Administrative Location)': 'State',
                                        'City (Administrative Location)': 'City'})
museums_df = museums_df[['Museum Name', 'Museum Type', 'State', 'City', 'Longitude', 'Latitude', 'Income']]
museums_df.City = museums_df.City.str.capitalize()
museums_df.Income = museums_df.Income.fillna(0)
museums_df = museums_df[museums_df.Income > 0]
museums_df = museums_df[(~museums_df.Latitude.isna())&(~museums_df.Longitude.isna())]

# %% [markdown]
# ##  Total and Mean Income of Museums by State

# %%
state_income_df = museums_df.groupby('State').agg(
    size=('Income', 'size'),
    sum=('Income', 'sum'),
    mean=('Income', 'mean')
).reset_index()

state_income_df = state_income_df.sort_values(by=['sum', 'State'])

p1 = ggplot() + \
    geom_bar(aes(x='State', y='sum', fill='size'), data=state_income_df,
             stat='identity', size=2, color='black', sampling=sampling_pick(n=51),
             tooltips=layer_tooltips().line('@State')\
                                      .format('@sum', '.3~s')\
                                      .line('total income|@sum')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(name='number of museums', low='#006d2c', high='#edf8e9') + \
    ggtitle('Total Income of Museums by State') + \
    scale_y_log10(name='total income') + xlab('state') + \
    theme_classic() + theme(axis='blank', axis_title=element_text())

state_income_df = state_income_df.sort_values(by=['mean', 'State'])

p2 = ggplot() + \
    geom_bar(aes(x='State', y='mean', fill='size'), data=state_income_df,
             stat='identity', size=1, color='black', sampling=sampling_pick(n=51),
             tooltips=layer_tooltips().line('@State')\
                                      .format('@mean', '.3~s')\
                                      .line('mean income|@mean')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(name='number of museums', low='#006d2c', high='#edf8e9') + \
    ggtitle('Mean Income of Museums by State') + \
    scale_y_log10('mean income') + xlab('state') + \
    theme_classic() + theme(axis='blank', axis_title=element_text())

gggrid([p1, p2], ncol=1) + ggsize(800, 400)
# Out:
#    <div id="0QFRuO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("0QFRuO");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggsize":{
# "width":800.0,
# "height":400.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":1.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Total Income of Museums by State"
# },
# "guides":{
# "x":{
# "title":"state"
# }
# },
# "theme":{
# "name":"classic",
# "axis":"blank",
# "axis_title":{
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[{
# "name":"number of museums",
# "aesthetic":"fill",
# "low":"#006d2c",
# "high":"#edf8e9",
# "scale_mapper_kind":"color_gradient"
# },{
# "name":"total income",
# "aesthetic":"y",
# "trans":"log10"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "data":{
# "State":["ND","WY","NV","AK","NM","MT","UT","WV","MS","KS","HI","ID","SD","OK","AL","VT","AR","NE","OR","MI","SC","ME","WI","WA","KY","MN","IA","LA","OH","RI","CO","IN","VA","NC","DE","NH","FL","MO","GA","TX","TN","NJ","MD","DC","IL","CT","AZ","NY","PA","CA","MA"],
# "size":[47.0,56.0,53.0,71.0,99.0,88.0,52.0,76.0,73.0,193.0,70.0,54.0,65.0,147.0,151.0,93.0,82.0,103.0,218.0,336.0,133.0,152.0,318.0,302.0,154.0,249.0,236.0,131.0,494.0,90.0,244.0,278.0,350.0,275.0,59.0,111.0,452.0,227.0,212.0,630.0,199.0,252.0,221.0,90.0,504.0,247.0,138.0,1018.0,726.0,1060.0,527.0],
# "sum":[3.2109065E7,6.6546522E7,8.9384454E7,1.28567774E8,1.69902956E8,1.85799422E8,2.22109279E8,3.35062623E8,4.4349656E8,4.44962206E8,4.81352517E8,5.37928555E8,6.35865407E8,8.00539767E8,9.08930334E8,1.042917631E9,1.42177775E9,1.45174406E9,1.898744483E9,2.22894402E9,2.520476519E9,2.671947832E9,2.984414997E9,3.530348248E9,3.582165777E9,4.039357687E9,4.801952499E9,5.887293467E9,6.460018708E9,8.338068794E9,8.339422744E9,8.427196704E9,1.005165628E10,1.1166751972E10,1.1179893942E10,1.1596932634E10,1.1788647031E10,1.2315913515E10,1.454976357E10,1.8202837361E10,2.4730351688E10,2.8797697227E10,3.2668997384E10,3.2887512131E10,3.406466247E10,5.9696824755E10,8.3448400097E10,8.8196571395E10,1.30703659925E11,1.53284557445E11,1.611586533447E12]
# },
# "mapping":{
# "x":"State",
# "y":"sum",
# "fill":"size"
# },
# "sampling":{
# "name":"pick",
# "n":51.0
# },
# "tooltips":{
# "formats":[{
# "field":"@sum",
# "format":".3~s"
# }],
# "lines":["@State","total income|@sum","number of museums|@size"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"State"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "size":2.0,
# "color":"black"
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Mean Income of Museums by State"
# },
# "guides":{
# "x":{
# "title":"state"
# }
# },
# "theme":{
# "name":"classic",
# "axis":"blank",
# "axis_title":{
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[{
# "name":"number of museums",
# "aesthetic":"fill",
# "low":"#006d2c",
# "high":"#edf8e9",
# "scale_mapper_kind":"color_gradient"
# },{
# "name":"mean income",
# "aesthetic":"y",
# "trans":"log10"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "data":{
# "State":["ND","WY","NV","NM","AK","MT","KS","UT","WV","OK","AL","MS","MI","HI","OR","WI","SD","ID","VT","WA","OH","NE","MN","AR","ME","SC","IA","KY","FL","VA","TX","IN","CO","NC","LA","MO","IL","GA","NY","RI","NH","NJ","TN","CA","MD","PA","DE","CT","DC","AZ","MA"],
# "size":[47.0,56.0,53.0,99.0,71.0,88.0,193.0,52.0,76.0,147.0,151.0,73.0,336.0,70.0,218.0,318.0,65.0,54.0,93.0,302.0,494.0,103.0,249.0,82.0,152.0,133.0,236.0,154.0,452.0,350.0,630.0,278.0,244.0,275.0,131.0,227.0,504.0,212.0,1018.0,90.0,111.0,252.0,199.0,1060.0,221.0,726.0,59.0,247.0,90.0,138.0,527.0],
# "mean":[683171.5957446808,1188330.75,1686499.1320754718,1716191.4747474748,1810813.718309859,2111357.0681818184,2305503.6580310883,4271332.288461538,4408718.72368421,5445848.755102041,6019406.185430463,6075295.342465754,6633761.964285715,6876464.528571429,8709837.07798165,9384952.820754716,9782544.723076923,9961639.907407407,1.1214168075268818E7,1.1689894860927152E7,1.307696094736842E7,1.4094602524271844E7,1.622232002811245E7,1.7338753048780486E7,1.7578604157894738E7,1.895095127067669E7,2.0347256351694915E7,2.3260816733766235E7,2.608107750221239E7,2.8719017942857143E7,2.8893392636507936E7,3.0313657208633095E7,3.417796206557377E7,4.0606370807272725E7,4.494117150381679E7,5.4255125616740085E7,6.758861601190476E7,6.863096023584905E7,8.663710353143418E7,9.264520882222222E7,1.0447687057657658E8,1.1427657629761904E8,1.2427312406030151E8,1.4460807306132075E8,1.4782351757466063E8,1.8003258942837465E8,1.8948972783050847E8,2.416875496153846E8,3.6541680145555556E8,6.046985514275362E8,3.0580389628975334E9]
# },
# "mapping":{
# "x":"State",
# "y":"mean",
# "fill":"size"
# },
# "sampling":{
# "name":"pick",
# "n":51.0
# },
# "tooltips":{
# "formats":[{
# "field":"@mean",
# "format":".3~s"
# }],
# "lines":["@State","mean income|@mean","number of museums|@size"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"State"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "size":1.0,
# "color":"black"
# }],
# "metainfo_list":[],
# "spec_id":"2"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## More Explicit Relation Between Income and Number of Museums

# %%
state_income_df = state_income_df.sort_values(by='size')

p1 = ggplot() + \
    geom_point(aes(x='sum', y='size', fill='State'),
               data=state_income_df, shape=21, color='white', size=5,
               tooltips=layer_tooltips().line('@State')) + \
    scale_fill_discrete(guide='none') + \
    scale_x_continuous('total income', trans="sqrt", format='.3~s') + \
    ylab('number of museums')

p2 = ggplot() + \
    geom_point(aes(x='mean', y='size', fill='State'),
               data=state_income_df, shape=21, color='white', size=5,
               tooltips=layer_tooltips().line('@State')) + \
    scale_fill_discrete(guide='none') + \
    scale_x_continuous('mean income', trans="sqrt", format='.3~s') + \
    ylab('number of museums')

gggrid([p1, p2])
# Out:
#    <div id="qQE8pl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("qQE8pl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "guides":{
# "y":{
# "title":"number of museums"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "discrete":true
# },{
# "name":"total income",
# "aesthetic":"x",
# "trans":"sqrt",
# "format":".3~s"
# }],
# "layers":[{
# "geom":"point",
# "data":{
# "State":["ND","UT","NV","ID","WY","DE","SD","HI","AK","MS","WV","AR","MT","DC","RI","VT","NM","NE","NH","LA","SC","AZ","OK","AL","ME","KY","KS","TN","GA","OR","MD","MO","IA","CO","CT","MN","NJ","NC","IN","WA","WI","MI","VA","FL","OH","IL","MA","TX","PA","NY","CA"],
# "size":[47.0,52.0,53.0,54.0,56.0,59.0,65.0,70.0,71.0,73.0,76.0,82.0,88.0,90.0,90.0,93.0,99.0,103.0,111.0,131.0,133.0,138.0,147.0,151.0,152.0,154.0,193.0,199.0,212.0,218.0,221.0,227.0,236.0,244.0,247.0,249.0,252.0,275.0,278.0,302.0,318.0,336.0,350.0,452.0,494.0,504.0,527.0,630.0,726.0,1018.0,1060.0],
# "sum":[3.2109065E7,2.22109279E8,8.9384454E7,5.37928555E8,6.6546522E7,1.1179893942E10,6.35865407E8,4.81352517E8,1.28567774E8,4.4349656E8,3.35062623E8,1.42177775E9,1.85799422E8,3.2887512131E10,8.338068794E9,1.042917631E9,1.69902956E8,1.45174406E9,1.1596932634E10,5.887293467E9,2.520476519E9,8.3448400097E10,8.00539767E8,9.08930334E8,2.671947832E9,3.582165777E9,4.44962206E8,2.4730351688E10,1.454976357E10,1.898744483E9,3.2668997384E10,1.2315913515E10,4.801952499E9,8.339422744E9,5.9696824755E10,4.039357687E9,2.8797697227E10,1.1166751972E10,8.427196704E9,3.530348248E9,2.984414997E9,2.22894402E9,1.005165628E10,1.1788647031E10,6.460018708E9,3.406466247E10,1.611586533447E12,1.8202837361E10,1.30703659925E11,8.8196571395E10,1.53284557445E11]
# },
# "mapping":{
# "x":"sum",
# "y":"size",
# "fill":"State"
# },
# "tooltips":{
# "formats":[],
# "lines":["@State"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"State"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "shape":21.0,
# "color":"white",
# "size":5.0
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "guides":{
# "y":{
# "title":"number of museums"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "discrete":true
# },{
# "name":"mean income",
# "aesthetic":"x",
# "trans":"sqrt",
# "format":".3~s"
# }],
# "layers":[{
# "geom":"point",
# "data":{
# "State":["ND","UT","NV","ID","WY","DE","SD","HI","AK","MS","WV","AR","MT","DC","RI","VT","NM","NE","NH","LA","SC","AZ","OK","AL","ME","KY","KS","TN","GA","OR","MD","MO","IA","CO","CT","MN","NJ","NC","IN","WA","WI","MI","VA","FL","OH","IL","MA","TX","PA","NY","CA"],
# "size":[47.0,52.0,53.0,54.0,56.0,59.0,65.0,70.0,71.0,73.0,76.0,82.0,88.0,90.0,90.0,93.0,99.0,103.0,111.0,131.0,133.0,138.0,147.0,151.0,152.0,154.0,193.0,199.0,212.0,218.0,221.0,227.0,236.0,244.0,247.0,249.0,252.0,275.0,278.0,302.0,318.0,336.0,350.0,452.0,494.0,504.0,527.0,630.0,726.0,1018.0,1060.0],
# "mean":[683171.5957446808,4271332.288461538,1686499.1320754718,9961639.907407407,1188330.75,1.8948972783050847E8,9782544.723076923,6876464.528571429,1810813.718309859,6075295.342465754,4408718.72368421,1.7338753048780486E7,2111357.0681818184,3.6541680145555556E8,9.264520882222222E7,1.1214168075268818E7,1716191.4747474748,1.4094602524271844E7,1.0447687057657658E8,4.494117150381679E7,1.895095127067669E7,6.046985514275362E8,5445848.755102041,6019406.185430463,1.7578604157894738E7,2.3260816733766235E7,2305503.6580310883,1.2427312406030151E8,6.863096023584905E7,8709837.07798165,1.4782351757466063E8,5.4255125616740085E7,2.0347256351694915E7,3.417796206557377E7,2.416875496153846E8,1.622232002811245E7,1.1427657629761904E8,4.0606370807272725E7,3.0313657208633095E7,1.1689894860927152E7,9384952.820754716,6633761.964285715,2.8719017942857143E7,2.608107750221239E7,1.307696094736842E7,6.758861601190476E7,3.0580389628975334E9,2.8893392636507936E7,1.8003258942837465E8,8.663710353143418E7,1.4460807306132075E8]
# },
# "mapping":{
# "x":"mean",
# "y":"size",
# "fill":"State"
# },
# "tooltips":{
# "formats":[],
# "lines":["@State"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"State"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "shape":21.0,
# "color":"white",
# "size":5.0
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Total and Mean Income of Museums by Type

# %%
type_income_df = museums_df.groupby('Museum Type').agg(
    size=('Income', 'size'),
    sum=('Income', 'sum'),
    mean=('Income', 'mean')
).reset_index()

type_income_df = type_income_df.sort_values(by='sum')

p1 = ggplot() + \
    geom_bar(aes(x='Museum Type', y='sum', fill='size'), data=type_income_df,
             stat='identity', color='black', size=3,
             tooltips=layer_tooltips().line('^x')\
                                      .format('@sum', '.3~s')\
                                      .line('total income|@sum')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(low='#006d2c', high='#edf8e9') + \
    scale_y_log10(name='total income', format='.3~s') + \
    xlab('museum type') + \
    theme(legend_position='none', axis_text_x='blank', axis_ticks='blank', axis_line='blank')

type_income_df = type_income_df.sort_values(by='mean')

p2 = ggplot() + \
    geom_bar(aes(x='Museum Type', y='mean', fill='size'), data=type_income_df,
             stat='identity', color='black', size=3,
             tooltips=layer_tooltips().line('^x')\
                                      .format('@mean', '.3~s')\
                                      .line('mean income|@mean')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(low='#006d2c', high='#edf8e9') + \
    scale_y_log10(name='mean income', format='.3~s') + \
    xlab('museum type') + \
    theme(legend_position='none', axis_text_x='blank', axis_ticks='blank', axis_line='blank')

gggrid([p1, p2])
# Out:
#    <div id="3b25Jx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("3b25Jx");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "guides":{
# "x":{
# "title":"museum type"
# }
# },
# "theme":{
# "axis_text_x":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "low":"#006d2c",
# "high":"#edf8e9",
# "scale_mapper_kind":"color_gradient"
# },{
# "name":"total income",
# "aesthetic":"y",
# "trans":"log10",
# "format":".3~s"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "data":{
# "Museum Type":["CHILDREN'S MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","HISTORY MUSEUM","HISTORIC PRESERVATION","NATURAL HISTORY MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ART MUSEUM","GENERAL MUSEUM"],
# "size":[268.0,225.0,1333.0,5098.0,170.0,534.0,319.0,1635.0,2624.0],
# "sum":[6.48048394E8,1.948785653E9,3.5860017539E10,1.18838030728E11,1.43905362457E11,3.73022718464E11,4.00622860361E11,6.14331675335E11,7.66850014699E11]
# },
# "mapping":{
# "x":"Museum Type",
# "y":"sum",
# "fill":"size"
# },
# "tooltips":{
# "formats":[{
# "field":"@sum",
# "format":".3~s"
# }],
# "lines":["^x","total income|@sum","number of museums|@size"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "color":"black",
# "size":3.0
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "guides":{
# "x":{
# "title":"museum type"
# }
# },
# "theme":{
# "axis_text_x":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank",
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "low":"#006d2c",
# "high":"#edf8e9",
# "scale_mapper_kind":"color_gradient"
# },{
# "name":"mean income",
# "aesthetic":"y",
# "trans":"log10",
# "format":".3~s"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "data":{
# "Museum Type":["CHILDREN'S MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","GENERAL MUSEUM","ART MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","NATURAL HISTORY MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM"],
# "size":[268.0,225.0,5098.0,1333.0,2624.0,1635.0,534.0,170.0,319.0],
# "mean":[2418091.0223880596,8661269.56888889,2.3310716109846998E7,2.6901738588897225E7,2.922446702358994E8,3.7573802772782874E8,6.985444165992509E8,8.465021321E8,1.2558710356144202E9]
# },
# "mapping":{
# "x":"Museum Type",
# "y":"mean",
# "fill":"size"
# },
# "tooltips":{
# "formats":[{
# "field":"@mean",
# "format":".3~s"
# }],
# "lines":["^x","mean income|@mean","number of museums|@size"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "color":"black",
# "size":3.0
# }],
# "metainfo_list":[],
# "spec_id":"6"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Relation Between Income and Number of Museums of Given Type

# %%
type_income_df = type_income_df.sort_values(by='size')

p1 = ggplot() + \
    geom_point(aes(x='sum', y='size', color='Museum Type'),
               data=type_income_df, size=5,
               tooltips=layer_tooltips().line('^color')) + \
    scale_x_continuous('total income', format='.3~s') + \
    scale_y_continuous('number of museums', format='d') + \
    scale_color_discrete(name='')

p2 = ggplot() + \
    geom_point(aes(x='mean', y='size', color='Museum Type'),
               data=type_income_df, size=5,
               tooltips=layer_tooltips().line('^color')) + \
    scale_x_continuous('total income', format='.3~s') + \
    scale_y_continuous('number of museums', format='d') + \
    scale_color_discrete(guide='none')

gggrid([
    p1 + theme(legend_position='none'),
    p2
])
# Out:
#    <div id="yJZk0H"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("yJZk0H");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "name":"total income",
# "aesthetic":"x",
# "format":".3~s"
# },{
# "name":"number of museums",
# "aesthetic":"y",
# "format":"d"
# },{
# "name":"",
# "aesthetic":"color",
# "discrete":true
# }],
# "layers":[{
# "geom":"point",
# "data":{
# "Museum Type":["NATURAL HISTORY MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","CHILDREN'S MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# "size":[170.0,225.0,268.0,319.0,534.0,1333.0,1635.0,2624.0,5098.0],
# "sum":[1.43905362457E11,1.948785653E9,6.48048394E8,4.00622860361E11,3.73022718464E11,3.5860017539E10,6.14331675335E11,7.66850014699E11,1.18838030728E11]
# },
# "mapping":{
# "x":"sum",
# "y":"size",
# "color":"Museum Type"
# },
# "tooltips":{
# "formats":[],
# "lines":["^color"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "size":5.0
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "name":"total income",
# "aesthetic":"x",
# "format":".3~s"
# },{
# "name":"number of museums",
# "aesthetic":"y",
# "format":"d"
# },{
# "aesthetic":"color",
# "guide":"none",
# "discrete":true
# }],
# "layers":[{
# "geom":"point",
# "data":{
# "Museum Type":["NATURAL HISTORY MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","CHILDREN'S MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# "size":[170.0,225.0,268.0,319.0,534.0,1333.0,1635.0,2624.0,5098.0],
# "mean":[8.465021321E8,8661269.56888889,2418091.0223880596,1.2558710356144202E9,6.985444165992509E8,2.6901738588897225E7,3.7573802772782874E8,2.922446702358994E8,2.3310716109846998E7]
# },
# "mapping":{
# "x":"mean",
# "y":"size",
# "color":"Museum Type"
# },
# "tooltips":{
# "formats":[],
# "lines":["^color"]
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"int",
# "column":"size"
# },{
# "type":"float",
# "column":"sum"
# },{
# "type":"float",
# "column":"mean"
# }]
# },
# "size":5.0
# }],
# "metainfo_list":[],
# "spec_id":"8"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Museums on Map

# %% [markdown]
# Let's start from Washington, D.C.

# %%
def plot_museums_on_map(data):
    return ggplot() + \
        geom_livemap() + \
        geom_point(aes(x='Longitude', y='Latitude', fill='Museum Type', size='Income'),
                   data=data, shape=21, color='black',
                   tooltips=layer_tooltips().title('^fill')\
                                            .format('@Longitude', '.4f').line('longitude|@Longitude')\
                                            .format('@Latitude', '.4f').line('latitude|@Latitude')\
                                            .format('@Income', '.3~s')\
                                            .line('income|@Income')) + \
        scale_size(range=[2, 7], guide="none") + \
        scale_fill_discrete(name = "") + \
        ggsize(600, 450) + \
        theme(legend_position='bottom', legend_direction="vertical")

# %%
plot_museums_on_map(museums_df[museums_df.State == 'DC'])
# Out:
#    <div id="Y3Vdnd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Y3Vdnd");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "theme":{
# "legend_position":"bottom",
# "legend_direction":"vertical"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[2.0,7.0]
# },{
# "name":"",
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "data":{
# "Museum Type":["HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","HISTORY MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# "Longitude":[-77.02824,-77.08058,-76.98792,-77.08947,-77.08947,-77.04454,-77.03505,-76.97666,-77.03092,-77.04578,-77.0399,-77.04599,-77.04088,-76.99232,-77.05483,-76.99062,-77.03946,-77.04772,-77.01971,-77.43757,-77.05328,-77.04268,-77.02589,-77.02529,-77.07113,-77.04057,-77.02194,-77.03505,-76.99432,-76.978,-77.43757,-77.07113,-77.04427,-76.98197,-77.02294,-77.03558,-77.02172,-77.02172,-77.02817,-77.04839,-77.01587,-77.04247,-77.04247,-77.08947,-77.08888,-77.08172,-76.99432,-77.43757,-77.03585,-77.02172,-77.0477,-76.95947,-77.01752,-77.0381,-77.00955,-84.38944,-77.02397,-77.03121,-77.03552,-77.03811,-77.02883,-77.03023,-77.05551,-77.01887,-77.01887,-77.01918,-77.04601,-77.05789,-77.04377,-77.0276,-77.04671,-77.03468,-76.99623,-77.02739,-77.00386,-77.00386,-77.01554,-77.024,-77.024,-77.0186,-76.99202,-77.01554,-77.024,-77.00285,-77.43757,-77.03126,-76.99202,-77.03293,-77.03604,-77.03827],
# "Latitude":[38.9169,38.93032,38.867,38.93694,38.93694,38.90305,38.90537,38.92769,38.89803,38.90132,38.90189,38.90211,38.89881,38.88367,38.91616,38.85404,38.89616,38.91169,39.04921,39.05186,38.92401,38.92154,38.917,38.90211,38.90835,38.90133,38.89321,38.90537,38.90451,38.90037,39.05186,38.90835,38.90807,38.88274,38.90255,38.91369,38.92291,38.92291,38.91462,38.91184,38.89846,38.91286,38.91286,38.93694,38.92284,38.94921,38.90451,39.05186,38.92551,38.92291,38.89294,38.91685,38.89779,38.90514,38.89809,33.75703,38.89622,38.89393,38.90647,38.90629,38.90038,38.90477,38.89962,38.91517,38.91517,38.89316,38.90826,38.91344,38.9081,38.89497,38.91199,38.91719,38.93323,38.89535,38.89232,38.89232,38.89007,38.88862,38.88862,38.89247,38.90212,38.89007,38.88862,38.89019,39.05186,38.89974,38.90212,38.88879,38.90852,38.89987],
# "Income":[333682.0,12374.0,19789.0,9.90975218E8,9.90975218E8,244408.0,21000.0,34551.0,15129.0,928768.0,593772.0,8759917.0,2057869.0,173217.0,1318939.0,255982.0,7.2365327E7,196826.0,153350.0,1.652712215E9,1.3477582E7,198592.0,6591877.0,42594.0,1.64260481E9,5389513.0,6264556.0,1386737.0,2.15623354E8,1419339.0,1.652712215E9,1.64260481E9,429387.0,10.0,719612.0,5553292.0,1.376961476E9,1.376961476E9,67863.0,1777520.0,932472.0,276392.0,276392.0,9.90975218E8,4314035.0,150269.0,2.15623354E8,1.652712215E9,220837.0,1.376961476E9,1.009427032E9,2490455.0,7867658.0,6.85911957E8,3533605.0,63401.0,1.9754324E7,9736290.0,139411.0,257139.0,9848036.0,622610.0,1.04737301E8,99712.0,726891.0,6.2624477E7,110101.0,171978.0,5264763.0,4023363.0,3.259727E7,121869.0,4.23815094E8,640618.0,613092.0,613092.0,2.064935223E9,2.064935223E9,2.064935223E9,3.10042203E8,2.064935223E9,2.064935223E9,2.064935223E9,5023859.0,1.652712215E9,31769.0,3337278.0,1.87415604E8,1.9995544E7,1.8153956E7]
# },
# "mapping":{
# "x":"Longitude",
# "y":"Latitude",
# "fill":"Museum Type",
# "size":"Income"
# },
# "tooltips":{
# "formats":[{
# "field":"@Longitude",
# "format":".4f"
# },{
# "field":"@Latitude",
# "format":".4f"
# },{
# "field":"@Income",
# "format":".3~s"
# }],
# "lines":["longitude|@Longitude","latitude|@Latitude","income|@Income"],
# "title":"^fill"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Name"
# },{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"str",
# "column":"State"
# },{
# "type":"str",
# "column":"City"
# },{
# "type":"float",
# "column":"Longitude"
# },{
# "type":"float",
# "column":"Latitude"
# },{
# "type":"float",
# "column":"Income"
# }]
# },
# "shape":21.0,
# "color":"black"
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# There is a problem with the data: some museums are assigned to wrong states.
#
# Well, we can fix it by using geocoding.

# %%
us_sc_df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/refs/heads/master/data/us_state_codes.csv')

states_gdf = geocode_states('US-48').get_boundaries(resolution=4)

states_df = states_gdf.merge(us_sc_df, on='state')
states_df = states_df[['state', 'code', 'geometry']]

states_gdf = gpd.GeoDataFrame(states_df, geometry='geometry')

# %%
def find_state(lon, lat):
    point = Point(lon, lat)
    state_gdf = states_gdf[states_gdf.contains(point)]
    return state_gdf.iloc[0].code if state_gdf.shape[0] == 1 else None

def fix_state(record):
    record.State = find_state(record.Longitude, record.Latitude) or record.State
    return record

museums_df = museums_df.apply(fix_state, axis=1)

# %% [markdown]
# Another try:

# %%
plot_museums_on_map(museums_df[museums_df.State == 'DC'])
# Out:
#    <div id="6as5yA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("6as5yA");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "theme":{
# "legend_position":"bottom",
# "legend_direction":"vertical"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[2.0,7.0]
# },{
# "name":"",
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "data":{
# "Museum Type":["HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# "Longitude":[-77.02824,-77.08058,-76.98792,-77.08947,-77.08947,-77.04454,-77.03505,-76.97666,-77.03092,-77.04578,-77.0399,-77.04599,-77.04088,-76.99232,-77.05483,-76.99062,-77.03946,-77.04772,-77.05328,-77.04268,-77.02589,-77.02529,-77.07113,-77.04057,-77.02194,-77.03505,-76.99432,-76.978,-77.07113,-77.04427,-76.98197,-77.02294,-77.03558,-77.02172,-77.02172,-77.02817,-77.04839,-77.01587,-77.04247,-77.04247,-77.08947,-77.08888,-77.08172,-76.99432,-77.03585,-77.02172,-77.0477,-76.95947,-77.01752,-77.0381,-77.00955,-77.02397,-77.03121,-77.03552,-77.03811,-77.02883,-77.03023,-77.05551,-77.01887,-77.01887,-77.01918,-77.04601,-77.05789,-77.04377,-77.0276,-77.04671,-77.03468,-76.99623,-77.02739,-77.00386,-77.00386,-77.01554,-77.024,-77.024,-77.0186,-76.99202,-77.01554,-77.024,-77.00285,-77.03126,-76.99202,-77.03293,-77.03604,-77.03827],
# "Latitude":[38.9169,38.93032,38.867,38.93694,38.93694,38.90305,38.90537,38.92769,38.89803,38.90132,38.90189,38.90211,38.89881,38.88367,38.91616,38.85404,38.89616,38.91169,38.92401,38.92154,38.917,38.90211,38.90835,38.90133,38.89321,38.90537,38.90451,38.90037,38.90835,38.90807,38.88274,38.90255,38.91369,38.92291,38.92291,38.91462,38.91184,38.89846,38.91286,38.91286,38.93694,38.92284,38.94921,38.90451,38.92551,38.92291,38.89294,38.91685,38.89779,38.90514,38.89809,38.89622,38.89393,38.90647,38.90629,38.90038,38.90477,38.89962,38.91517,38.91517,38.89316,38.90826,38.91344,38.9081,38.89497,38.91199,38.91719,38.93323,38.89535,38.89232,38.89232,38.89007,38.88862,38.88862,38.89247,38.90212,38.89007,38.88862,38.89019,38.89974,38.90212,38.88879,38.90852,38.89987],
# "Income":[333682.0,12374.0,19789.0,9.90975218E8,9.90975218E8,244408.0,21000.0,34551.0,15129.0,928768.0,593772.0,8759917.0,2057869.0,173217.0,1318939.0,255982.0,7.2365327E7,196826.0,1.3477582E7,198592.0,6591877.0,42594.0,1.64260481E9,5389513.0,6264556.0,1386737.0,2.15623354E8,1419339.0,1.64260481E9,429387.0,10.0,719612.0,5553292.0,1.376961476E9,1.376961476E9,67863.0,1777520.0,932472.0,276392.0,276392.0,9.90975218E8,4314035.0,150269.0,2.15623354E8,220837.0,1.376961476E9,1.009427032E9,2490455.0,7867658.0,6.85911957E8,3533605.0,1.9754324E7,9736290.0,139411.0,257139.0,9848036.0,622610.0,1.04737301E8,99712.0,726891.0,6.2624477E7,110101.0,171978.0,5264763.0,4023363.0,3.259727E7,121869.0,4.23815094E8,640618.0,613092.0,613092.0,2.064935223E9,2.064935223E9,2.064935223E9,3.10042203E8,2.064935223E9,2.064935223E9,2.064935223E9,5023859.0,31769.0,3337278.0,1.87415604E8,1.9995544E7,1.8153956E7]
# },
# "mapping":{
# "x":"Longitude",
# "y":"Latitude",
# "fill":"Museum Type",
# "size":"Income"
# },
# "tooltips":{
# "formats":[{
# "field":"@Longitude",
# "format":".4f"
# },{
# "field":"@Latitude",
# "format":".4f"
# },{
# "field":"@Income",
# "format":".3~s"
# }],
# "lines":["longitude|@Longitude","latitude|@Latitude","income|@Income"],
# "title":"^fill"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Museum Name"
# },{
# "type":"str",
# "column":"Museum Type"
# },{
# "type":"str",
# "column":"State"
# },{
# "type":"str",
# "column":"City"
# },{
# "type":"float",
# "column":"Longitude"
# },{
# "type":"float",
# "column":"Latitude"
# },{
# "type":"float",
# "column":"Income"
# }]
# },
# "shape":21.0,
# "color":"black"
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# Now it looks just as expected.
#
# So then we make the same plots for a few other US states.

# %%
gggrid([
    plot_museums_on_map(museums_df[museums_df.State == state]) + \
        theme(legend_position='right') + \
        ggtitle(state)
    for state in ['WA', 'NY', 'MT', 'TX']
], ncol=1)
# Out:
#    <div id="H4XHvB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("H4XHvB");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":1.0,
# "nrow":4.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":600.0,
# "height":450.0
# },
# "theme":{
# "legend_position":"right",
# "legend_direction":"vertical"
# },
# "ggtitle":{
# "text":"WA"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[2.0,7.0]
# },{
# "name":"",
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"point",
# "data":{
# "Museum Type":["GENERAL MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORY MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","ART MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","CHILDREN'S MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","ART MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","CHILDREN'S MUSEUM","CHILDREN'S MUSEUM","CHILDREN'S MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","HISTORY MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","CHILDREN'S MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORY MUSEUM","HISTORY MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","CHILDREN'S MUSEUM","HISTORY MUSEUM","HISTORY MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","GENERAL MUSEUM","CHILDREN'S MUSEUM","CHILDREN'S MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","NATURAL HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","CHILDREN'S MUSEUM","CHILDREN'S MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM", ...

# %% [markdown]
# ## Which Museum Types Bring the Greatest Income to the State?

# %%
total_income_df = museums_df.groupby(['State', 'Museum Type'])["Income"].sum().to_frame().reset_index()
total_income_df = total_income_df.sort_values(by=['State', 'Income'], ascending=[True, False]).reset_index(drop=True)
top_by_income_museums_df = total_income_df.groupby('State').first().reset_index()
top_by_income_museums_gdf = gpd.GeoDataFrame(
    top_by_income_museums_df.merge(states_gdf, left_on='State', right_on='code'),
    geometry='geometry'
)

# %%
ggplot() + \
    geom_polygon(aes(fill='Museum Type', alpha='Income'),
                 data=top_by_income_museums_gdf, color='white',
                 tooltips=layer_tooltips().line('@State')\
                                          .line('most profitable museum type|^fill')\
                                          .format('^alpha', '.3~s')
                                          .line('total income for current museum type|^alpha')) + \
    scale_alpha(name='', range=[.2, 1], trans='log10', format='.3~s') + \
    ggtitle('Most Profitable Museum Types by State') + \
    ggsize(750, 350) + \
    theme_classic() + theme(axis='blank')
# Out:
#    <div id="cWJsbb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("cWJsbb");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Most Profitable Museum Types by State"
# },
# "ggsize":{
# "width":750.0,
# "height":350.0
# },
# "theme":{
# "name":"classic",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[{
# "name":"",
# "aesthetic":"alpha",
# "trans":"log10",
# "format":".3~s",
# "range":[0.2,1.0]
# }],
# "layers":[{
# "geom":"polygon",
# "data":{
# "State":["AL","AR","AZ","CA","CO","CT","DE","FL","GA","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],
# "Museum Type":["ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","CHILDREN'S MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","HISTORY MUSEUM"],
# "Income":[4.68914988E8,1.379212914E9,4.8898841E7,6.6292689195E10,2.945295508E9,1.9179886367E10,3.009956622E9,6.362379873E9,7.477315887E9,4.224464641E9,2.33203474E8,1.6706023585E10,4.411322529E9,2.99123648E8,1.817528061E9,3.282751522E9,6.6900095854E11,1.5098124567E10,1.494861732E9,1.516563262E9,2.751688459E9,1.0279603584E10,2.06622911E8,1.39018575E8,7.777208184E9,1.45886015E8,1.110612754E9,6.039698255E9,1.1714015768E10,6.7614451E7,3.7781896E7,3.787806999E10,5.00238066E9,4.77602508E8,1.378437409E9,7.296718127E10,3.267025424E9,1.076034767E9,1.83384241E8,8.619410627E9,7.994933119E9,1.1409427E8,8.411227058E9,8.20973573E8,2.296141767E9,2.39336465E9,2.70561267E8,2.1717986E7],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-85.605242103, 34.984610081], [-85.184085667, 32.862707824], [-84.96303007, 32.424244434], [-85.005290955, 32.325855643], [-84.88841638, 32.260884494], [-85.061143935, 32.134065628], [-85.140730441, 31.857461482], [-85.041304976, 31.540987641], [-85.107516646, 31.186450571], [-85.001656562, 31.000696868], [-87.598828822, 30.997455418], [-87.634743601, 30.865610093], [-87.406075895, 30.674638152], [-87.450371236, 30.514461994], [-87.388964742, 30.450668335], [-87.539708912, 30.306267589], [-87.60425359, 30.360721797], [-87.609796375, 30.302556753], [-87.751187682, 30.282507241], [-87.707018405, 30.334786177], [-87.753849775, 30.291099697], [-87.825019509, 30.414018631], [-87.906427234, 30.41019246], [-87.913494855, 30.651769638], [-88.011820614, 30.685297251], [-88.086363226, 30.52508086], [-88.143183142, 30.533502996], [-88.093534112, 30.521056205], [-88.128058165, 30.338653922], [-88.395836502, 30.384795964], [-88.473101556, 31.893939525], [-88.097794801, 34.892122149], [-88.200023174, 34.995604455], [-85.605242103, 34.984610081]]], [[[-88.027172238, 30.224967152], [-87.936872989, 30.260506421], [-87.514725477, 30.308111608], [-88.027172238, 30.224967152]]], [[[-87.456230521, 30.305736512], [-87.518255264, 30.279979259], [-87.509202808, 30.286252946], [-87.456230521, 30.305736512]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-94.485849738, 33.638024479], [-94.431219846, 35.394376516], [-94.617855996, 36.499511003], [-90.152584165, 36.497936547], [-90.063980073, 36.303037852], [-90.377889723, 35.995683521], [-89.733094722, 36.000608057], [-89.642910808, 35.891967863], [-89.744405597, 35.908039659], [-89.708016068, 35.815927237], [-89.956254512, 35.733386278], [-89.931036383, 35.660043955], [-89.851176292, 35.657431483], [-89.95674938, 35.590510368], [-89.909022152, 35.520547628], [-90.028620511, 35.555248708], [-90.00263527, 35.429950655], [-90.061999261, 35.39875254], [-90.098718703, 35.478595197], [-90.170599222, 35.418351442], [-90.080658048, 35.385790765], [-90.168794096, 35.279088467], [-90.065392256, 35.137690455], [-90.309297591, 34.995694309], [-90.244476646, 34.937596321], [-90.307383835, 34.846194685], [-90.466154516, 34.890988916], [-90.454968363, 34.735557586], [-90.547611862, 34.784588367], [-90.565645695, 34.721053541], [-90.462552309, 34.687575549], [-90.524480492, 34.628503919], [-90.58841899, 34.670963287], [-90.571145564, 34.420318902], [-90.669342577, 34.313019812], [-90.765763968, 34.362109601], [-90.743081868, 34.302257448], [-90.847807378, 34.206529409], [-90.929015279, 34.244540334], [-90.810884088, 34.155902714], [-90.954300463, 34.138497859], [-90.87052837, 34.080516547], [-90.987947434, 34.019037634], [-90.967632383, 33.96332413], [-91.087921411, 33.975335062], [-91.010318398, 33.929352611], [-91.073011011, 33.857449293], [-90.988466442, 33.784529418], [-91.146617532, 33.732455671], [-91.034565568, 33.673017919], [-91.22785762, 33.683073521], [-91.130445153, 33.606033772], [-91.231418252, 33.560593128], [-91.185203791, 33.500735611], [-91.235181391, 33.438972384], [-91.125108898, 33.472841978], [-91.208702624, 33.408718407], [-91.166303605, 33.379708976], [-91.057620496, 33.445341289], [-91.142218709, 33.348989636], [-91.106141657, 33.241799176], [-91.043623388, 33.27463612], [-91.089861989, 33.139655292], [-91.201779842, 33.125120401], [-91.121195555, 33.059166223], [-91.166072935, 33.004105836], [-94.042964727, 33.019213378], [-94.043423384, 33.552223295], [-94.388095289, 33.54776144], [-94.485849738, 33.638024479]]]]}","{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-114.818357974, 32.499082088], [-114.719961137, 32.718655765], [-114.539008588, 32.749860585], [-114.469154477, 32.844391018], [-114.509588778, 33.022000194], [-114.706819654, 33.088846207], [-114.672287554, 33.25971365], [-114.731474519, 33.30327943], [-114.72538054, 33.405411243], [-114.524175972, 33.552963585], [-114.534388483, 33.93816635], [-114.416719973, ...
