# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="HD2XP4"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("HD2XP4").appendChild(div);
#                     };
#                     var e = document.getElementById("HD2XP4");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
ggplot() + \
    geom_vline(xintercept=2) + \
    geom_vline(xintercept=4, color='#006400', linetype=3, size=1.0) + \
    geom_vline(xintercept=6, color='#ff8000', linetype=2, size=2.0) + \
    geom_vline(xintercept=8, color='#ff00ff', linetype=4, size=3.0) + \
    geom_hline(yintercept=1) + \
    geom_hline(yintercept=3, color='magenta', linetype='dotdash', size=0.7) + \
    geom_hline(yintercept=5, color='dark_green', linetype='twodash', size=1.5) + \
    geom_hline(yintercept=7, color='gray', linetype='dashed', size=2.6) + \
    coord_fixed(ylim=[0, 8], xlim=[1, 9]) + \
    ggtitle('Horizontal and vertical lines of different style')
# Out:
#    <div id="cHLvKP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "xlim":[1.0,9.0],
# "ylim":[0.0,8.0],
# "flip":false
# },
# "ggtitle":{
# "text":"Horizontal and vertical lines of different style"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":2.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":4.0,
# "color":"#006400",
# "linetype":3.0,
# "size":1.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":6.0,
# "color":"#ff8000",
# "linetype":2.0,
# "size":2.0,
# "data":{
# }
# },{
# "geom":"vline",
# "mapping":{
# },
# "data_meta":{
# },
# "xintercept":8.0,
# "color":"#ff00ff",
# "linetype":4.0,
# "size":3.0,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "data_meta":{
# },
# "yintercept":1.0,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "data_meta":{
# },
# "yintercept":3.0,
# "color":"magenta",
# "linetype":"dotdash",
# "size":0.7,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "data_meta":{
# },
# "yintercept":5.0,
# "color":"dark_green",
# "linetype":"twodash",
# "size":1.5,
# "data":{
# }
# },{
# "geom":"hline",
# "mapping":{
# },
# "data_meta":{
# },
# "yintercept":7.0,
# "color":"gray",
# "linetype":"dashed",
# "size":2.6,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cHLvKP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot() + \
    geom_abline(intercept=10, slope=-3.2, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=1, slope=-0.8, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=-1, slope=0.7, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=1, slope=3, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=3, slope=0, color='#5d8aa8', linetype='longdash', size=2) + \
    coord_fixed(ylim=[-3, 6], xlim=[-3, 6]) + \
    ggtitle('Sloping lines')
# Out:
#    <div id="jgUWbk"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"fixed",
# "ratio":1.0,
# "xlim":[-3.0,6.0],
# "ylim":[-3.0,6.0],
# "flip":false
# },
# "ggtitle":{
# "text":"Sloping lines"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"abline",
# "mapping":{
# },
# "data_meta":{
# },
# "slope":-3.2,
# "intercept":10.0,
# "color":"#5d8aa8",
# "linetype":"longdash",
# "size":2.0,
# "data":{
# }
# },{
# "geom":"abline",
# "mapping":{
# },
# "data_meta":{
# },
# "slope":-0.8,
# "intercept":1.0,
# "color":"#5d8aa8",
# "linetype":"longdash",
# "size":2.0,
# "data":{
# }
# },{
# "geom":"abline",
# "mapping":{
# },
# "data_meta":{
# },
# "slope":0.7,
# "intercept":-1.0,
# "color":"#5d8aa8",
# "linetype":"longdash",
# "size":2.0,
# "data":{
# }
# },{
# "geom":"abline",
# "mapping":{
# },
# "data_meta":{
# },
# "slope":3.0,
# "intercept":1.0,
# "color":"#5d8aa8",
# "linetype":"longdash",
# "size":2.0,
# "data":{
# }
# },{
# "geom":"abline",
# "mapping":{
# },
# "data_meta":{
# },
# "slope":0.0,
# "intercept":3.0,
# "color":"#5d8aa8",
# "linetype":"longdash",
# "size":2.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jgUWbk");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
