# %% [markdown]
# Available as executable or viewable Jupyter Notebook:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/HIL-HK/lets-plot-examples/master?filepath=features%2Fstraight_lines.ipynb)

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="YNHodJ"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.4.2.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
p = ggplot() + ggtitle('Horizontal and vertical lines of different style') + \
    geom_vline(xintercept=2) + \
    geom_vline(xintercept=4, color='#006400', linetype=3, size=1.0) + \
    geom_vline(xintercept=6, color='#ff8000', linetype=2, size=2.0) + \
    geom_vline(xintercept=8, color='#ff00ff', linetype=4, size=3.0) + \
    geom_hline(yintercept=1) + \
    geom_hline(yintercept=3, color='magenta', linetype='dotdash', size=0.7) + \
    geom_hline(yintercept=5, color='dark_green', linetype='twodash', size=1.5) + \
    geom_hline(yintercept=7, color='gray', linetype='dashed', size=2.6) + \
    coord_fixed(ylim=[0, 8], xlim=[1, 9])
p
# Out:
#    <div id="Ub4eQq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Horizontal and vertical lines of different style"
# },
# 'coord':{
# 'name':"fixed",
# 'ratio':1.0,
# 'xlim':[1,9],
# 'ylim':[0,8]
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"vline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'xintercept':2,
# 'data':{
# }
# },{
# 'geom':"vline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'xintercept':4,
# 'color':"#006400",
# 'linetype':3,
# 'size':1.0,
# 'data':{
# }
# },{
# 'geom':"vline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'xintercept':6,
# 'color':"#ff8000",
# 'linetype':2,
# 'size':2.0,
# 'data':{
# }
# },{
# 'geom':"vline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'xintercept':8,
# 'color':"#ff00ff",
# 'linetype':4,
# 'size':3.0,
# 'data':{
# }
# },{
# 'geom':"hline",
# 'mapping':{
# },
# 'data_meta':{
# },
# ...

# %%
p2 = ggplot() + ggtitle('Sloping lines') + \
    geom_abline(intercept=10, slope=-3.2, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=1, slope=-0.8, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=-1, slope=0.7, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=1, slope=3, color='#5d8aa8', linetype='longdash', size=2) + \
    geom_abline(intercept=3, slope=0, color='#5d8aa8', linetype='longdash', size=2) + \
    coord_fixed(ylim=[-3, 6], xlim=[-3, 6])
p2
# Out:
#    <div id="wS7Grz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Sloping lines"
# },
# 'coord':{
# 'name':"fixed",
# 'ratio':1.0,
# 'xlim':[-3,6],
# 'ylim':[-3,6]
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"abline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'slope':-3.2,
# 'intercept':10,
# 'color':"#5d8aa8",
# 'linetype':"longdash",
# 'size':2,
# 'data':{
# }
# },{
# 'geom':"abline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'slope':-0.8,
# 'intercept':1,
# 'color':"#5d8aa8",
# 'linetype':"longdash",
# 'size':2,
# 'data':{
# }
# },{
# 'geom':"abline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'slope':0.7,
# 'intercept':-1,
# 'color':"#5d8aa8",
# 'linetype':"longdash",
# 'size':2,
# 'data':{
# }
# },{
# 'geom':"abline",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'slope':3,
# 'intercept':1,
# 'color':"#5d8aa8",
# ...
