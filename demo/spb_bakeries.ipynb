# %% [markdown]
# # Saint-Petersburg Bakeries

# %%
import pandas as pd
import geopandas as gpd
from overpy import Overpass
from shapely.geometry import Polygon
from scipy.spatial import Voronoi

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="z93F4Z"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdnjs.cloudflare.com/ajax/libs/lets-plot/2.0.2/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("z93F4Z").appendChild(div);
#                     };
#                     var e = document.getElementById("z93F4Z");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def fix_bakery_name(data):
    names_fixes = {
        'Bonape': 'Bonapé',
        'Лавка пекаря': 'Лавка Пекаря',
        'Цех85': 'Цех 85',
    }
    if data['name'] in names_fixes.keys():
        data['name'] = names_fixes[data['name']]
    return data

# %%
def get_areas_gdf(geometry, names):
    diag = Voronoi([[p.x, p.y] for p in geometry])
    regions = [[diag.vertices[i] for i in region if i != -1] for region in diag.regions]
    regions = [Polygon(region) for region in regions if len(region) > 2]
    areas_data = [(name, next((region for region in regions if region.contains(point)), None)) \
                  for name, point in zip(names, geometry)]
    areas_df = pd.DataFrame(areas_data, columns=['name', 'area'])
    areas_gdf = gpd.GeoDataFrame(areas_df, geometry='area')
    areas_gdf = areas_gdf.set_crs(epsg=geometry.crs.to_epsg())
    areas_gdf = areas_gdf.dropna()
    return areas_gdf

# %% [markdown]
# We are going to use the Overpass API to get data about Saint-Petersburg's bakeries from [OSM](https://www.openstreetmap.org).
#
# Then we will draw a Voronoi diagram of the biggest bakery chains. That will help us to find the nearest bakery for each point of the city.

# %%
ovp = Overpass()
spb_bakeries_data = ovp.query("""
    area[name="Санкт-Петербург"];
    nwr[shop=bakery](area);
    out center;
    """)

# %%
spb_bakeries_df = pd.DataFrame([(bakery.tags.get('name'), float(bakery.lon), float(bakery.lat)) \
                                for bakery in spb_bakeries_data.nodes], columns=['name', 'lon', 'lat'])
spb_bakeries_df = spb_bakeries_df.dropna()

# %%
spb_bakeries_gdf = gpd.GeoDataFrame(spb_bakeries_df[['name']], \
                                    geometry=gpd.points_from_xy(spb_bakeries_df.lon, spb_bakeries_df.lat))
spb_bakeries_gdf = spb_bakeries_gdf.apply(fix_bakery_name, axis=1)
top_bakery_chains = spb_bakeries_gdf['name'].value_counts()[:15].keys()
spb_bakeries_gdf = spb_bakeries_gdf[spb_bakeries_gdf['name'].isin(top_bakery_chains)]
spb_bakeries_gdf = spb_bakeries_gdf.set_crs(epsg=4326)

# %%
areas_gdf = get_areas_gdf(spb_bakeries_gdf.geometry.to_crs('EPSG:3857'), spb_bakeries_gdf['name']).to_crs('EPSG:4326')

# %%
ggplot() + \
    geom_livemap(location=[30.308611, 59.937500], zoom=11) + \
    geom_polygon(aes(group='name', fill='name'), \
                 data=areas_gdf, size=.1, color='#636363', alpha=.3, \
                 tooltips=layer_tooltips().line('@name')) + \
    geom_point(aes(group='name', fill='name'), \
               data=spb_bakeries_gdf, shape=21, color='#636363', \
               tooltips=layer_tooltips().line('@name')) + \
    scale_fill_discrete(name='chain') + \
    ggtitle('Top 15 Bakery Chains in Saint Petersburg') + \
    ggsize(800, 600)
# Out:
#    <div id="DmceoD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Top 15 Bakery Chains in Saint Petersburg"
# },
# 'ggsize':{
# 'width':800,
# 'height':600
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"chain",
# 'aesthetic':"fill",
# 'discrete':true
# }],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'location':{
# 'type':"coordinates",
# 'data':[30.308611,59.9375]
# },
# 'zoom':11,
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# 'geocoding':{
# 'url':"https://geo2.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"polygon",
# 'data':{
# 'name':["Лавка Пекаря","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","ЛюдиЛюбят","Цех 85","Булочная Ф. Вольчека","Британские пекарни","Булочная Ф. Вольчека","Каравай","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Каравай","Хлебник","Каравай","Цех 85","Цех 85","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Хлебник","Булочная Ф. Вольчека","Британские пекарни","Bonapé","Жан Руа","Bonapé","Хлебная усадьба","Буханка","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Bonapé","Bonapé","Лавка Пекаря","Буше","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Буханка","Буше","Буханка","Хлебная усадьба","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Цех 85","Bonapé","Буханка","Bonapé","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Bonapé","Буханка","Булочная Ф. Вольчека","Цех 85","Буханка","Буше","Каравай","Британские пекарни","Хлебник","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Каравай","Булка хлеба","Булочная Ф. Вольчека","Жан Руа","Жан Руа","Ам!","Ам!","Жан Руа","Буханка","Булочная Ф. Вольчека","Пекарня","Цех 85","Bonapé","Bonapé","Цех 85","Булочная Ф. Вольчека","Буше","Ам!","ЛюдиЛюбят","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Британские пекарни","Цех 85","Пекарня","Буханка","Булка хлеба","Bonapé","Жан Руа","Хлебная усадьба","Хлебник","Пекарня","Булочная Ф. Вольчека","Британские пекарни","Булочная Ф. Вольчека","Лавка Пекаря","Bonapé","Цех 85","Буше","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","ЛюдиЛюбят","ЛюдиЛюбят","Буханка","Булка хлеба","Ам!","ЛюдиЛюбят","Хлебная усадьба","Булка хлеба","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Хлебная усадьба","Британские пекарни","Жан Руа","Ам!","Цех 85","Цех 85","Британские пекарни","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Цех 85","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Буханка","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Пекарня","Жан Руа","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Британские пекарни","Хлебник","Цех 85","Цех 85","Цех 85","Цех 85","Лавка Пекаря","Лавка Пекаря","Лавка Пекаря","Лавка Пекаря","Буше","Лавка Пекаря","Цех 85","Хлебник","Цех 85","Пекарня","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Лавка Пекаря","Пекарня","Лавка Пекаря","Пекарня","Лавка Пекаря","Хлебная усадьба","Хлебник","Хлебник","Хлебник","Пекарня","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Лавка Пекаря","Хлебник","Буше","Цех 85","Булочная Ф. Вольчека","Хлебник","Лавка Пекаря","Булочная Ф. Вольчека","Буханка"],
# 'area':["{\"type\": \"Polygon\", \"coordinates\": [[[30.262615355793887, 59.92616462063308], [30.26458723426625, 59.92924535289489], [30.25592650672095, 59.936397382248735], [30.252080670474093, 59.93811001088305], [30.15286333955696, 59.91418575478902], [30.25867408176509, 59.921517091590665], [30.262615355793887, 59.92616462063308]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.31210062046838, 59.93129271170352], [30.314058420745084, 59.92725426777939], [30.31385888182561, 59.92471817401613], [30.311612741431045, 59.92523499221059], [30.305646108441692, 59.931084377481355], [30.31210062046838, 59.93129271170352]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.475569434173554, 59.90314191103647], [30.48643048083309, 59.885298806497254], [30.56765052126448, 59.8797866130577], [30.472895918353917, 59.90949171072128], [30.475569434173554, 59.90314191103647]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.314058420745084, 59.92725426777939], [30.320573868421757, 59.928839151380515], [30.32612052563132, 59.92424549870001], [30.323105307797686, 59.92131305707203], [30.32011448182012, 59.921471726605084], [30.318339616668137, 59.92224793640637], [30.31643189765787, 59.92315603356368], [30.31385888182561, 59.92471817401613], [30.314058420745084, 59.92725426777939]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.298845238596567, 59.96019172910279], [30.30574213792327, 59.95917617925648], [30.301358759403737, 59.955493142744196], [30.298786984480813, 59.95595170320116], [30.298606882234722, 59.95599077943816], [30.298845238596567, 59.96019172910279]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.31210062046838, 59.93129271170352], [30.31651576271773, 59.93223965409497], [30.3179884952979, 59.932109941394195], [30.320573868421757, 59.928839151380515], [30.314058420745084, 59.92725426777939], [30.31210062046838, 59.93129271170352]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.28920095462818, 59.923030678207404], [30.262615355793887, 59.92616462063308], [30.25867408176509, 59.921517091590665], [30.262969684583783, 59.91838199971832], [30.270380846245324, 59.917052925520686], [30.276967205679224, 59.91846300379093], [30.28920095462818, 59.923030678207404]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.3720163546687, 59.937773988538886], [30.368885882274984, 59.93548488558622], [30.364869965809998, 59.93827587344942], [30.365194758182437, 59.93873096059586], [30.3720163546687, 59.937773988538886]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.305646108441692, 59.931084377481355], [30.29453963250489, 59.9319297292663], [30.297265258939557, 59.925333512244265], [30.311612741431045, 59.92523499221059], [30.305646108441692, 59.931084377481355]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.383684206921888, 59.91865541073099], [30.375893796737905, 59.92684516731335], [30.379260063733323, 59.93012917589243], [30.393451008713274, 59.93353429561129], [30.39616275673451, 59.931977752237394], [30.3975207329156, 59.923816574762526], [30.383684206921888, 59.91865541073099]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.3179884952979, 59.932109941394195], [30.321589649818574, 59.93294721263295], [30.322407507979605, 59.93872265900396], [30.311711865653738, 59.94072647884712], [30.31651576271773, 59.93223965409497], [30.3179884952979, 59.932109941394195]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.360897406610608, 59.929489443118776], [30.3615276963005, 59.9293544158441], [30.36433434497193, 59.932440843084315], [30.360471944899036, 59.93213020514561], [30.359628396796822, 59.931850171341864], [30.360897406610608, 59.929489443118776]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.256524365342763, 59.89581851896559], [30.294564716173905, 59.89029915904453], [30.29468064160144, 59.88859299965974], [30.2170223
