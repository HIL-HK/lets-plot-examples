# %% [markdown]
# Available as executable or viewable Jupyter Notebook:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/HIL-HK/lets-plot-examples/master?filepath=demo%2Fspb_bakeries.ipynb)
#
# [<img alt="nbviewer" src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png" width="109" height="20">](https://nbviewer.jupyter.org/github/HIL-HK/lets-plot-examples/blob/master/demo/spb_bakeries.ipynb)

# %% [markdown]
# ### Preparation

# %%
import pandas as pd
import geopandas as gpd
from overpy import Overpass
from shapely.geometry import Polygon
from scipy.spatial import Voronoi

from lets_plot import *; LetsPlot.setup_html()
LetsPlot.set(maptiles_zxy(url='https://maps.wikimedia.org/osm-intl/{z}/{x}/{y}@2x.png'))
# Out:
#             <div id="SVxNM9"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.0.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("SVxNM9").appendChild(div);
#                     };
#                     var e = document.getElementById("SVxNM9");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def fix_bakery_name(data):
    names_fixes = {
        'Bonape' : 'Bonapé',
        'Лавка пекаря' : 'Лавка Пекаря',
        'Цех85' : 'Цех 85',
    }
    if data['name'] in names_fixes.keys():
        data['name'] = names_fixes[data['name']]
    return data

# %%
def get_areas_gdf(geometry, names):
    diag = Voronoi([[p.x, p.y] for p in geometry])
    regions = [[diag.vertices[i] for i in region if i != -1] for region in diag.regions]
    regions = [Polygon(region) for region in regions if len(region) > 2]
    areas_data = [(name, next((region for region in regions if region.contains(point)), None)) \
                  for name, point in zip(names, geometry)]
    areas_df = pd.DataFrame(areas_data, columns=['name', 'area'])
    areas_gdf = gpd.GeoDataFrame(areas_df, geometry='area')
    areas_gdf = areas_gdf.set_crs(epsg=geometry.crs.to_epsg())
    areas_gdf = areas_gdf.dropna()
    return areas_gdf

# %% [markdown]
# # Saint-Petersburg Bakeries
#
# We are going to use the Overpass API to get data about Saint-Petersburg's bakeries from [OSM](https://www.openstreetmap.org).
#
# Then we will draw a Voronoi diagram of the biggest bakery chains. That will help us to find the nearest bakery for each point of the city.

# %%
ovp = Overpass()
spb_bakeries_data = ovp.query("""
    area[name="Санкт-Петербург"];
    nwr[shop=bakery](area);
    out center;
    """)

# %%
spb_bakeries_df = pd.DataFrame([(bakery.tags.get('name'), float(bakery.lon), float(bakery.lat)) \
                                for bakery in spb_bakeries_data.nodes], columns=['name', 'lon', 'lat'])
spb_bakeries_df = spb_bakeries_df.dropna()

# %%
spb_bakeries_gdf = gpd.GeoDataFrame(spb_bakeries_df[['name']], \
                                    geometry=gpd.points_from_xy(spb_bakeries_df.lon, spb_bakeries_df.lat))
spb_bakeries_gdf = spb_bakeries_gdf.apply(fix_bakery_name, axis=1)
top_bakery_chains = spb_bakeries_gdf['name'].value_counts()[:15].keys()
spb_bakeries_gdf = spb_bakeries_gdf[spb_bakeries_gdf['name'].isin(top_bakery_chains)]
spb_bakeries_gdf = spb_bakeries_gdf.set_crs(epsg=4326)

# %%
areas_gdf = get_areas_gdf(spb_bakeries_gdf.geometry.to_crs('EPSG:3857'), spb_bakeries_gdf['name']).to_crs('EPSG:4326')

# %%
ggplot() + \
    geom_livemap(location=[30.308611, 59.937500], zoom=11) + \
    geom_polygon(aes(group='name', fill='name'), data=areas_gdf, size=.1, color='#636363', alpha=.2) + \
    geom_point(aes(group='name', fill='name'), data=spb_bakeries_gdf, shape=21, color='#636363') + \
    scale_fill_discrete(name='Chain') + \
    ggtitle('Top 15 Bakery Chains in Saint Petersburg') + \
    ggsize(1000, 700)
# Out:
#    <div id="yqjqGe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Top 15 Bakery Chains in Saint Petersburg"
# },
# 'ggsize':{
# 'width':1000,
# 'height':700
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Chain",
# 'aesthetic':"fill",
# 'discrete':true
# }],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'location':{
# 'type':"coordinates",
# 'data':[30.308611,59.9375]
# },
# 'zoom':11,
# 'tiles':{
# 'kind':"raster_zxy",
# 'url':"https://maps.wikimedia.org/osm-intl/{z}/{x}/{y}@2x.png"
# },
# 'geocoding':{
# 'url':"https://geo.datalore.io"
# },
# 'data':{
# }
# },{
# 'geom':"polygon",
# 'data':{
# 'name':["Ленинградские булочные","Лавка Пекаря","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","Каравай","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Каравай","Каравай","Цех 85","Цех 85","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Булочная Ф. Вольчека","Ленинградские булочные","Булочная Ф. Вольчека","Буханка","Булочная Ф. Вольчека","Bonapé","Жан Руа","Тили-тесто","Хлебная усадьба","Булочная Ф. Вольчека","Буханка","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Bonapé","Bonapé","Лавка Пекаря","Буше","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Буханка","Буше","Буханка","Хлебная усадьба","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Цех 85","Bonapé","Буханка","Bonapé","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Тили-тесто","Bonapé","Буханка","Булочная Ф. Вольчека","Цех 85","Буханка","Буше","Каравай","Пекарня","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Пекарня","Каравай","Булка хлеба","Булочная Ф. Вольчека","Жан Руа","Ленинградские булочные","Жан Руа","Ам!","Ам!","Жан Руа","Буханка","Булочная Ф. Вольчека","Ленинградские булочные","Пекарня","Ленинградские булочные","Цех 85","Bonapé","Bonapé","Цех 85","Булочная Ф. Вольчека","Буше","Ам!","ЛюдиЛюбят","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Цех 85","Буханка","Буханка","Булка хлеба","Bonapé","Жан Руа","Хлебная усадьба","Пекарня","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Bonapé","Цех 85","Буше","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","ЛюдиЛюбят","ЛюдиЛюбят","Буханка","Булка хлеба","Буханка","Ам!","ЛюдиЛюбят","Хлебная усадьба","Булка хлеба","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Хлебная усадьба","Жан Руа","Ам!","Цех 85","Цех 85","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Пекарня","Тили-тесто","Цех 85","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Буханка","Ленинградские булочные","Булочная Ф. Вольчека","Тили-тесто","Тили-тесто","Лавка Пекаря","Булочная Ф. Вольчека","Пекарня","Жан Руа","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","