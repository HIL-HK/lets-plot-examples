# %% [markdown]
# Available as executable or viewable Jupyter Notebook:
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/HIL-HK/lets-plot-examples/master?filepath=demo%2Fspb_bakeries.ipynb)
#
# [<img alt="nbviewer" src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.png" width="109" height="20">](https://nbviewer.jupyter.org/github/HIL-HK/lets-plot-examples/blob/master/demo/spb_bakeries.ipynb)

# %% [markdown]
# ### Preparation

# %%
import pandas as pd
import geopandas as gpd
from overpy import Overpass
from shapely.geometry import Polygon
from scipy.spatial import Voronoi

from lets_plot import *; LetsPlot.setup_html()
# Out:
#             <div id="OefaYc"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.3rc1.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("OefaYc").appendChild(div);
#                     };
#                     var e = document.getElementById("OefaYc");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def fix_bakery_name(data):
    names_fixes = {
        'Bonape' : 'Bonapé',
        'Лавка пекаря' : 'Лавка Пекаря',
        'Цех85' : 'Цех 85',
    }
    if data['name'] in names_fixes.keys():
        data['name'] = names_fixes[data['name']]
    return data

# %%
def get_areas_gdf(geometry, names):
    diag = Voronoi([[p.x, p.y] for p in geometry])
    regions = [[diag.vertices[i] for i in region if i != -1] for region in diag.regions]
    regions = [Polygon(region) for region in regions if len(region) > 2]
    areas_data = [(name, next((region for region in regions if region.contains(point)), None)) \
                  for name, point in zip(names, geometry)]
    areas_df = pd.DataFrame(areas_data, columns=['name', 'area'])
    areas_gdf = gpd.GeoDataFrame(areas_df, geometry='area')
    areas_gdf = areas_gdf.set_crs(epsg=geometry.crs.to_epsg())
    areas_gdf = areas_gdf.dropna()
    return areas_gdf

# %% [markdown]
# # Saint-Petersburg Bakeries
#
# We are going to use the Overpass API to get data about Saint-Petersburg's bakeries from [OSM](https://www.openstreetmap.org).
#
# Then we will draw a Voronoi diagram of the biggest bakery chains. That will help us to find the nearest bakery for each point of the city.

# %%
ovp = Overpass()
spb_bakeries_data = ovp.query("""
    area[name="Санкт-Петербург"];
    nwr[shop=bakery](area);
    out center;
    """)

# %%
spb_bakeries_df = pd.DataFrame([(bakery.tags.get('name'), float(bakery.lon), float(bakery.lat)) \
                                for bakery in spb_bakeries_data.nodes], columns=['name', 'lon', 'lat'])
spb_bakeries_df = spb_bakeries_df.dropna()

# %%
spb_bakeries_gdf = gpd.GeoDataFrame(spb_bakeries_df[['name']], \
                                    geometry=gpd.points_from_xy(spb_bakeries_df.lon, spb_bakeries_df.lat))
spb_bakeries_gdf = spb_bakeries_gdf.apply(fix_bakery_name, axis=1)
top_bakery_chains = spb_bakeries_gdf['name'].value_counts()[:15].keys()
spb_bakeries_gdf = spb_bakeries_gdf[spb_bakeries_gdf['name'].isin(top_bakery_chains)]
spb_bakeries_gdf = spb_bakeries_gdf.set_crs(epsg=4326)

# %%
areas_gdf = get_areas_gdf(spb_bakeries_gdf.geometry.to_crs('EPSG:3857'), spb_bakeries_gdf['name']).to_crs('EPSG:4326')

# %%
ggplot() + \
    geom_livemap(location=[30.308611, 59.937500], zoom=11) + \
    geom_polygon(aes(group='name', fill='name'), data=areas_gdf, size=.1, color='#636363', alpha=.2) + \
    geom_point(aes(group='name', fill='name'), data=spb_bakeries_gdf, shape=21, color='#636363') + \
    scale_fill_discrete(name='Chain') + \
    ggtitle('Top 15 Bakery Chains in Saint Petersburg') + \
    ggsize(1000, 700)
# Out:
#    <div id="yWFfP0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Top 15 Bakery Chains in Saint Petersburg"
# },
# 'ggsize':{
# 'width':1000,
# 'height':700
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"Chain",
# 'aesthetic':"fill",
# 'discrete':true
# }],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'location':{
# 'type':"coordinates",
# 'data':[30.308611,59.9375]
# },
# 'zoom':11,
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map data <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap</a> contributors"
# },
# 'geocoding':{
# 'url':"https://geo.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"polygon",
# 'data':{
# 'name':["Лавка Пекаря","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","Цех 85","Булочная Ф. Вольчека","Британские пекарни","Булочная Ф. Вольчека","Каравай","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Каравай","Каравай","Цех 85","Цех 85","ЛюдиЛюбят","Лавка Пекаря","ЛюдиЛюбят","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Хлебник","Булочная Ф. Вольчека","Британские пекарни","Bonapé","Жан Руа","Тили-тесто","Bonapé","Хлебная усадьба","Булочная Ф. Вольчека","Буханка","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Bonapé","Bonapé","Лавка Пекаря","Буше","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Буханка","Буше","Буханка","Хлебная усадьба","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Цех 85","Bonapé","Буханка","Bonapé","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Тили-тесто","Bonapé","Буханка","Булочная Ф. Вольчека","Цех 85","Буханка","Буше","Каравай","Пекарня","Британские пекарни","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Каравай","Булка хлеба","Булочная Ф. Вольчека","Жан Руа","Жан Руа","Жан Руа","Буханка","Булочная Ф. Вольчека","Пекарня","Цех 85","Bonapé","Bonapé","Цех 85","Хлебник","Булочная Ф. Вольчека","Буше","ЛюдиЛюбят","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Буханка","Британские пекарни","Цех 85","Пекарня","Буханка","Буханка","Булка хлеба","Bonapé","Жан Руа","Хлебная усадьба","Пекарня","Булочная Ф. Вольчека","Британские пекарни","Булочная Ф. Вольчека","Лавка Пекаря","Bonapé","Цех 85","Буше","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Булочная Ф. Вольчека","ЛюдиЛюбят","ЛюдиЛюбят","Буханка","Булка хлеба","Буханка","ЛюдиЛюбят","Хлебная усадьба","Булка хлеба","Булка хлеба","Цех 85","Булочная Ф. Вольчека","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Хлебная усадьба","Британские пекарни","Жан Руа","Цех 85","Цех 85","Британские пекарни","Цех 85","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Лавка Пекаря","Пекарня","Тили-тесто","Цех 85","Булочная Ф. Вольчека","Лавка Пекаря","Булочная Ф. Вольчека","Буханка","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Тили-тесто","Тили-тесто","Лавка Пекаря","Булочная Ф. Вольчека","Пекарня","Жан Руа","Булочная Ф. Вольчека","Булочная Ф. Вольчека","Лавка Пекаря","Британские пекарни","Хлебник","Цех 85","Цех 85","Цех 85","Цех 85","Лавка Пекаря","Лавка Пекаря","Лавка Пекаря","Лавка Пекаря","Буше","Лавка Пекаря","Цех 85","Хлебник","Цех 85","Пекарня","Лавка Пекаря","ЛюдиЛюбят","Лавка Пекаря","Пекарня","Лавка Пекаря","Пекарня","Лавка Пекаря","Хлебная усадьба","Буше","Хлебник","Хлебник","Хлебник","Буханка","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Британские пекарни","Лавка Пекаря"],
# 'area':["{\"type\": \"Polygon\", \"coordinates\": [[[30.26571262012841, 59.93100345297242], [30.264300639320727, 59.932667905727456], [30.252080670474083, 59.93811001088304], [30.15286333955688, 59.91418575478902], [30.258674081765093, 59.92151709159068], [30.262615355793905, 59.926164620633095], [30.26571262012841, 59.93100345297242]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.314058420745084, 59.92725426777939], [30.31210062046839, 59.931292711703506], [30.305646108441763, 59.931084377481355], [30.311612741431013, 59.92523499221059], [30.312281991955835, 59.92508100408163], [30.313439060327454, 59.92564991375523], [30.313964441345323, 59.926059835378226], [30.314058420745084, 59.92725426777939]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.47289591835394, 59.90949171072126], [30.56765052126446, 59.87978661305769], [30.486430480833146, 59.88529880649725], [30.475569434173543, 59.903141911036485], [30.47289591835394, 59.90949171072126]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.32057386842178, 59.92883915138049], [30.314058420745084, 59.92725426777939], [30.313964441345323, 59.926059835378226], [30.322562253930982, 59.92719247547565], [30.32057386842178, 59.92883915138049]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.32057386842178, 59.92883915138049], [30.317988303471505, 59.932110184064335], [30.316516610638377, 59.93223983595107], [30.31210062046839, 59.931292711703506], [30.314058420745084, 59.92725426777939], [30.32057386842178, 59.92883915138049]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.262615355793905, 59.926164620633095], [30.258674081765093, 59.92151709159068], [30.262969684583823, 59.91838199971831], [30.27038084624525, 59.9170529255207], [30.276967205678684, 59.91846300379083], [30.289200954628264, 59.92303067820742], [30.262615355793905, 59.926164620633095]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.364868999065628, 59.9382756677799], [30.36520020731266, 59.93873993937848], [30.37532497768707, 59.937298593219985], [30.37248067612376, 59.93525590932326], [30.368916639819343, 59.935464480743946], [30.364868999065628, 59.9382756677799]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.2945396325049, 59.9319297292663], [30.297265258939564, 59.925333512244265], [30.311612741431013, 59.92523499221059], [30.305646108441763, 59.931084377481355], [30.2945396325049, 59.9319297292663]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.3758937967379, 59.92684516731334], [30.38368420692189, 59.91865541073099], [30.39752073291559, 59.923816574762526], [30.396162756734515, 59.931977752237394], [30.393451008713274, 59.93353429561128], [30.379260063733323, 59.93012917589243], [30.3758937967379, 59.92684516731334]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.316516610638377, 59.93223983595107], [30.311711612986155, 59.940726595725685], [30.32240864289447, 59.938722750850665], [30.321589181420297, 59.93294722105018], [30.317988303471505, 59.932110184064335], [30.316516610638377, 59.93223983595107]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.36433434497197, 59.932440843084315], [30.361527696300456, 59.92935441584412], [30.357010838256972, 59.930322052452524], [30.357356262685624, 59.93109587614959], [30.360471944899057, 59.93213020514561], [30.36433434497197, 59.932440843084315]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.21702238329012, 59.885045672591644], [30.296519763424634, 59.888677003734976], [30.29643205904418, 59.890028198463305], [30.25652436534275, 59.89581851896558], [30.249128207157288, 59.89633971006563], [30.211869220353908, 59.88715575034683], [30.21390360293841, 59.88546047195504], [30.21702238329012, 59.885045672591644]]]}","{\"type\": \"Polygon\", \"coordinates\": [[[30.391347544970312, 59.95539709727481], [30.40080724315029, 59.95702257983619], [30.42935850266494, 59.9562591261108], [30.400481888307795, 59.95045823511674], [30.391347544970312, 59.95
