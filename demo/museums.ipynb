# %% [markdown]
# # US Museums
#
# Here we would like to investigate the income of US museums.
#
# Data is provided by [Kaggle](https://www.kaggle.com/imls/museum-directory).

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import ipywidgets as wg

from lets_plot import *
from lets_plot.geo_data import *
LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <div id="mm7XcS"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdnjs.cloudflare.com/ajax/libs/lets-plot/2.0.2/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("mm7XcS").appendChild(div);
#                     };
#                     var e = document.getElementById("mm7XcS");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ## Preparation

# %%
museums_df = pd.read_csv('https://raw.githubusercontent.com/HIL-HK/lets-plot-examples/master/data/museums.csv', \
                         low_memory=False)
museums_df = museums_df.rename(columns={'State (Administrative Location)': 'State', \
                                        'City (Administrative Location)': 'City'})
museums_df = museums_df[['Museum Name', 'Museum Type', 'State', 'City', 'Longitude', 'Latitude', 'Income']]
museums_df.City = museums_df.City.str.capitalize()
museums_df.Income = museums_df.Income.fillna(0)
museums_df = museums_df[museums_df.Income > 0]
museums_df = museums_df[(~museums_df.Latitude.isna())&(~museums_df.Longitude.isna())]

# %% [markdown]
# ##  Total and Mean Income of Museums by State

# %%
state_income_df = museums_df.groupby('State').agg({'Income': [np.size, np.sum, np.mean]})
state_income_df.columns = state_income_df.columns.droplevel(level=0)
state_income_df = state_income_df.reset_index()

state_income_df = state_income_df.sort_values(by='sum')

p1 = ggplot() + \
    geom_bar(aes(x='State', y='sum', fill='size'), data=state_income_df, \
             stat='identity', size=2, color='black', sampling=sampling_pick(n=51), \
             tooltips=layer_tooltips().line('@State')\
                                      .format('@sum', '.0f')\
                                      .line('total income|@sum')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(name='number of museums', low='#006d2c', high='#edf8e9') + \
    ggtitle('Total Income of Museums by State') + \
    scale_y_log10(name='total income') + xlab('state') + \
    theme(axis_text='blank', axis_ticks='blank', axis_line='blank')

state_income_df = state_income_df.sort_values(by='mean')

p2 = ggplot() + \
    geom_bar(aes(x='State', y='mean', fill='size'), data=state_income_df, \
             stat='identity', size=1, color='black', sampling=sampling_pick(n=51), \
             tooltips=layer_tooltips().line('@State')\
                                      .format('@mean', '.2f')\
                                      .line('mean income|@mean')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(name='number of museums', low='#006d2c', high='#edf8e9') + \
    ggtitle('Mean Income of Museums by State') + \
    scale_y_log10('mean income') + xlab('state') + \
    theme(axis_text='blank', axis_ticks='blank', axis_line='blank')

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, 800, 200)
bunch.add_plot(p2, 0, 200, 800, 200)
bunch.show()
# Out:
#    <div id="SVPshy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':800,
# 'height':200,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Total Income of Museums by State"
# },
# 'theme':{
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"number of museums",
# 'aesthetic':"fill",
# 'low':"#006d2c",
# 'high':"#edf8e9",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'name':"total income",
# 'aesthetic':"y",
# 'trans':"log10"
# },{
# 'name':"state",
# 'aesthetic':"x"
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'data':{
# 'State':["ND","WY","NV","AK","NM","MT","UT","WV","MS","KS","HI","ID","SD","OK","AL","VT","AR","NE","OR","MI","SC","ME","WI","WA","KY","MN","IA","LA","OH","RI","CO","IN","VA","NC","DE","NH","FL","MO","GA","TX","TN","NJ","MD","DC","IL","CT","AZ","NY","PA","CA","MA"],
# 'size':[47.0,56.0,53.0,71.0,99.0,88.0,52.0,76.0,73.0,193.0,70.0,54.0,65.0,147.0,151.0,93.0,82.0,103.0,218.0,336.0,133.0,152.0,318.0,302.0,154.0,249.0,236.0,131.0,494.0,90.0,244.0,278.0,350.0,275.0,59.0,111.0,452.0,227.0,212.0,630.0,199.0,252.0,221.0,90.0,504.0,247.0,138.0,1018.0,726.0,1060.0,527.0],
# 'sum':[3.2109065E7,6.6546522E7,8.9384454E7,1.28567774E8,1.69902956E8,1.85799422E8,2.22109279E8,3.35062623E8,4.4349656E8,4.44962206E8,4.81352517E8,5.37928555E8,6.35865407E8,8.00539767E8,9.08930334E8,1.042917631E9,1.42177775E9,1.45174406E9,1.898744483E9,2.22894402E9,2.520476519E9,2.671947832E9,2.984414997E9,3.530348248E9,3.582165777E9,4.039357687E9,4.801952499E9,5.887293467E9,6.460018708E9,8.338068794E9,8.339422744E9,8.427196704E9,1.005165628E10,1.1166751972E10,1.1179893942E10,1.1596932634E10,1.1788647031E10,1.2315913515E10,1.454976357E10,1.8202837361E10,2.4730351688E10,2.8797697227E10,3.2668997384E10,3.2887512131E10,3.406466247E10,5.9696824755E10,8.3448400097E10,8.8196571395E10,1.30703659925E11,1.53284557445E11,1.611586533447E12]
# },
# 'mapping':{
# 'x':"State",
# 'y':"sum",
# 'fill':"size"
# },
# 'sampling':{
# 'name':"pick",
# 'n':51
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@sum",
# 'format':".0f"
# }],
# 'tooltip_lines':["@State","total income|@sum","number of museums|@size"]
# },
# 'data_meta':{
# },
# 'size':2,
# 'color':"black"
# }]
# }
# },{
# 'x':0,
# 'y':200,
# 'width':800,
# 'height':200,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Mean Income of Museums by State"
# },
# 'theme':{
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"number of museums",
# 'aesthetic':"fill",
# 'low':"#006d2c",
# 'high':"#edf8e9",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'name':"mean income",
# 'aesthetic':"y",
# 'trans':"log10"
# },{
# 'name':"state",
# 'aesthetic':"x"
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'data':{
# 'State':["ND","WY","NV","NM","AK","MT","KS","UT","WV","OK","AL","MS","MI","HI","OR","WI","SD","ID","VT","WA","OH","NE","MN","AR","ME","SC","IA","KY","FL","VA","TX","IN","CO","NC","LA","MO","IL","GA","NY","RI","NH","NJ","TN","CA","MD","PA","DE","CT","DC","AZ","MA"],
# 'size':[47.0,56.0,53.0,99.0,71.0,88.0,193.0,52.0,76.0,147.0,151.0,73.0,336.0,70.0,218.0,318.0,65.0,54.0,93.0,302.0,494.0,103.0,249.0,82.0,152.0,133.0,236.0,154.0,452.0,350.0,630.0,278.0,244.0,275.0,131.0,227.0,504.0,212.0,1018.0,90.0,111.0,252.0,199.0,1060.0,221.0,726.0,59.0,247.0,90.0,138.0,527.0],
# 'mean':[683171.5957446808,1188330.75,1686499.1320754718,1716191.4747474748,1810813.718309859,2111357.0681818184,2305503.6580310883,4271332.288461538,4408718.72368421,5445848.755102041,6019406.185430463,6075295.342465754,6633761.964285715,6876464.528571429,8709837.07798165,9384952.820754716,9782544.723076923,9961639.907407407,1.1214168075268818E7,1.1689894860927152E7,1.307696094736842E7,1.4094602524271844E7,1.622232002811245E7,1.7338753048780486E7,1.7578604157894738E7,1.895095127067669E7,2.0347256351694915E7,2.3260816733766235E7,2.608107750221239E7,2.8719017942857143E7,2.8893392636507936E7,3.0313657208633095E7,3.417796206557377E7,4.0606370807272725E7,4.494117150381679E7,5.4255125616740085E7,6.758861601190476E7,6.863096023584905E7,8.663710353143418E7,9.264520882222222E7,1.0447687057657658E8,1.1427657629761904E8,1.2427312406030151E8,1.4460807306132075E8,1.4782351757466063E8,1.8003258942837465E8,1.8948972783050847E8,2.416875496153846E8,3.6541680145555556E8,6.046985514275362E8,3.0580389628975334E9]
# },
# 'mapping':{
# 'x':"State",
# 'y':"mean",
# 'fill':"size"
# },
# 'sampling':{
# 'name':"pick",
# 'n':51
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@mean",
# 'format':".2f"
# }],
# 'tooltip_lines':["@State","mean income|@mean","number of museums|@size"]
# },
# 'data_meta':{
# },
# 'size':1,
# 'color':"black"
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("SVPshy");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## More Explicit Relation Between Income and Number of Museums

# %%
state_income_df = state_income_df.sort_values(by='size')

p1 = ggplot() + \
    geom_point(aes(x='sum', y='size', fill='State'), \
               data=state_income_df, shape=21, color='white', size=5, \
               tooltips=layer_tooltips().line('@State')) + \
    scale_fill_discrete(name='') + \
    xlab('total income') + ylab('number of museums')

p2 = ggplot() + \
    geom_point(aes(x='mean', y='size', fill='State'), \
               data=state_income_df, shape=21, color='white', size=5, \
               tooltips=layer_tooltips().line('@State')) + \
    scale_fill_discrete(name='') + \
    xlab('mean income') + ylab('number of museums')

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, 400, 300)
bunch.add_plot(p2, 400, 0, 400, 300)
bunch.show()
# Out:
#    <div id="Db4Z1Y"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':400,
# 'height':300,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"fill",
# 'discrete':true
# },{
# 'name':"total income",
# 'aesthetic':"x"
# },{
# 'name':"number of museums",
# 'aesthetic':"y"
# }],
# 'layers':[{
# 'geom':"point",
# 'data':{
# 'State':["ND","UT","NV","ID","WY","DE","SD","HI","AK","MS","WV","AR","MT","DC","RI","VT","NM","NE","NH","LA","SC","AZ","OK","AL","ME","KY","KS","TN","GA","OR","MD","MO","IA","CO","CT","MN","NJ","NC","IN","WA","WI","MI","VA","FL","OH","IL","MA","TX","PA","NY","CA"],
,8709837.07798165,1.4782351757466063E8,5.4255125616740085E7,2.0347256351694915E7,3.417796206557377E7,2.416875496153846E8,1.622232002811245E7,1.1427657629761904E8,4.0606370807272725E7,3.0313657208633095E7,1.1689894860927152E7,9384952.820754716,6633761.964285715,2.8719017942857143E7,2.608107750221239E7,1.307696094736842E7,6.758861601190476E7,3.0580389628975334E9,2.8893392636507936E7,1.8003258942837465E8,8.663710353143418E7,1.4460807306132075E8]
# },
# 'mapping':{
# 'x':"mean",
# 'y':"size",
# 'fill':"State"
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["@State"]
# },
# 'data_meta':{
# },
# 'shape':21,
# 'color':"white",
# 'size':5
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("Db4Z1Y");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Total and Mean Income of Museums by Type

# %%
type_income_df = museums_df.groupby('Museum Type').agg({'Income': [np.size, np.sum, np.mean]})
type_income_df.columns = type_income_df.columns.droplevel(level=0)
type_income_df = type_income_df.reset_index()

type_income_df = type_income_df.sort_values(by='sum')

p1 = ggplot() + \
    geom_bar(aes(x='Museum Type', y='sum', fill='size'), data=type_income_df, \
             stat='identity', color='black', size=3, \
             tooltips=layer_tooltips().line('^x')\
                                      .format('@sum', '.0f')\
                                      .line('total income|@sum')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(low='#006d2c', high='#edf8e9') + \
    scale_y_log10(name='total income') + \
    xlab('museum type') + \
    theme(legend_position='none', axis_text_x='blank', axis_ticks='blank', axis_line='blank')

type_income_df = type_income_df.sort_values(by='mean')

p2 = ggplot() + \
    geom_bar(aes(x='Museum Type', y='mean', fill='size'), data=type_income_df, \
             stat='identity', color='black', size=3, \
             tooltips=layer_tooltips().line('^x')\
                                      .format('@mean', '.2f')\
                                      .line('mean income|@mean')\
                                      .line('number of museums|@size')) + \
    scale_fill_gradient(low='#006d2c', high='#edf8e9') + \
    scale_y_log10(name='mean income') + \
    xlab('museum type') + \
    theme(legend_position='none', axis_text_x='blank', axis_ticks='blank', axis_line='blank')

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, 400, 200)
bunch.add_plot(p2, 400, 0, 400, 200)
bunch.show()
# Out:
#    <div id="yDS13q"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':400,
# 'height':200,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'theme':{
# 'axis_text_x':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"fill",
# 'low':"#006d2c",
# 'high':"#edf8e9",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'name':"total income",
# 'aesthetic':"y",
# 'trans':"log10"
# },{
# 'name':"museum type",
# 'aesthetic':"x"
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'data':{
# 'Museum Type':["CHILDREN'S MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","HISTORY MUSEUM","HISTORIC PRESERVATION","NATURAL HISTORY MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ART MUSEUM","GENERAL MUSEUM"],
# 'size':[268.0,225.0,1333.0,5098.0,170.0,534.0,319.0,1635.0,2624.0],
# 'sum':[6.48048394E8,1.948785653E9,3.5860017539E10,1.18838030728E11,1.43905362457E11,3.73022718464E11,4.00622860361E11,6.14331675335E11,7.66850014699E11]
# },
# 'mapping':{
# 'x':"Museum Type",
# 'y':"sum",
# 'fill':"size"
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@sum",
# 'format':".0f"
# }],
# 'tooltip_lines':["^x","total income|@sum","number of museums|@size"]
# },
# 'data_meta':{
# },
# 'color':"black",
# 'size':3
# }]
# }
# },{
# 'x':400,
# 'y':0,
# 'width':400,
# 'height':200,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'theme':{
# 'axis_text_x':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"fill",
# 'low':"#006d2c",
# 'high':"#edf8e9",
# 'scale_mapper_kind':"color_gradient"
# },{
# 'name':"mean income",
# 'aesthetic':"y",
# 'trans':"log10"
# },{
# 'name':"museum type",
# 'aesthetic':"x"
# }],
# 'layers':[{
# 'geom':"bar",
# 'stat':"identity",
# 'data':{
# 'Museum Type':["CHILDREN'S MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","HISTORIC PRESERVATION","HISTORY MUSEUM","GENERAL MUSEUM","ART MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","NATURAL HISTORY MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM"],
# 'size':[268.0,225.0,5098.0,1333.0,2624.0,1635.0,534.0,170.0,319.0],
# 'mean':[2418091.0223880596,8661269.56888889,2.3310716109846998E7,2.6901738588897225E7,2.922446702358994E8,3.7573802772782874E8,6.985444165992509E8,8.465021321E8,1.2558710356144202E9]
# },
# 'mapping':{
# 'x':"Museum Type",
# 'y':"mean",
# 'fill':"size"
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@mean",
# 'format':".2f"
# }],
# 'tooltip_lines':["^x","mean income|@mean","number of museums|@size"]
# },
# 'data_meta':{
# },
# 'color':"black",
# 'size':3
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("yDS13q");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Relation Between Income and Number of Museums of Given Type

# %%
type_income_df = type_income_df.sort_values(by='size')

p1 = ggplot() + \
    geom_point(aes(x='sum', y='size', color='Museum Type'), \
               data=type_income_df, size=5, \
               tooltips=layer_tooltips().line('^color')) + \
    scale_color_discrete(name='') + \
    xlab('total income') + ylab('number of museums')

p2 = ggplot() + \
    geom_point(aes(x='mean', y='size', color='Museum Type'), \
               data=type_income_df, size=5, \
               tooltips=layer_tooltips().line('^color')) + \
    scale_color_discrete(name='') + \
    xlab('mean income') + ylab('number of museums')

bunch = GGBunch()
bunch.add_plot(p1, 0, 0, 400, 300)
bunch.add_plot(p2, 400, 0, 400, 300)
bunch.show()
# Out:
#    <div id="qNFl6k"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'kind':"ggbunch",
# 'items':[{
# 'x':0,
# 'y':0,
# 'width':400,
# 'height':300,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"color",
# 'discrete':true
# },{
# 'name':"total income",
# 'aesthetic':"x"
# },{
# 'name':"number of museums",
# 'aesthetic':"y"
# }],
# 'layers':[{
# 'geom':"point",
# 'data':{
# 'Museum Type':["NATURAL HISTORY MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","CHILDREN'S MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# 'size':[170.0,225.0,268.0,319.0,534.0,1333.0,1635.0,2624.0,5098.0],
# 'sum':[1.43905362457E11,1.948785653E9,6.48048394E8,4.00622860361E11,3.73022718464E11,3.5860017539E10,6.14331675335E11,7.66850014699E11,1.18838030728E11]
# },
# 'mapping':{
# 'x':"sum",
# 'y':"size",
# 'color':"Museum Type"
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["^color"]
# },
# 'data_meta':{
# },
# 'size':5
# }]
# }
# },{
# 'x':400,
# 'y':0,
# 'width':400,
# 'height':300,
# 'feature_spec':{
# 'mapping':{
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"color",
# 'discrete':true
# },{
# 'name':"mean income",
# 'aesthetic':"x"
# },{
# 'name':"number of museums",
# 'aesthetic':"y"
# }],
# 'layers':[{
# 'geom':"point",
# 'data':{
# 'Museum Type':["NATURAL HISTORY MUSEUM","ZOO, AQUARIUM, OR WILDLIFE CONSERVATION","CHILDREN'S MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORY MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# 'size':[170.0,225.0,268.0,319.0,534.0,1333.0,1635.0,2624.0,5098.0],
# 'mean':[8.465021321E8,8661269.56888889,2418091.0223880596,1.2558710356144202E9,6.985444165992509E8,2.6901738588897225E7,3.7573802772782874E8,2.922446702358994E8,2.3310716109846998E7]
# },
# 'mapping':{
# 'x':"mean",
# 'y':"size",
# 'color':"Museum Type"
# },
# 'tooltips':{
# 'tooltip_formats':[],
# 'tooltip_lines':["^color"]
# },
# 'data_meta':{
# },
# 'size':5
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("qNFl6k");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Museums on Map

# %% [markdown]
# Let's start from Washington, D.C.

# %%
def plot_museums_on_map(data):
    return ggplot() + \
        geom_livemap() + \
        geom_point(aes(x='Longitude', y='Latitude', fill='Museum Type', size='Income'), \
                   data=data, shape=21, color='black', \
                   tooltips=layer_tooltips().line('^fill')\
                                            .format('@Longitude', '.4f').line('longitude|@Longitude')\
                                            .format('@Latitude', '.4f').line('latitude|@Latitude')\
                                            .line('income|@Income')) + \
        scale_size(range=[2, 7]) + \
        ggsize(600, 450) + \
        theme(legend_position='none', axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank')

# %%
plot_museums_on_map(museums_df[museums_df.State == 'DC'])
# Out:
#    <div id="cuL9uG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggsize':{
# 'width':600,
# 'height':450
# },
# 'theme':{
# 'axis_title':"blank",
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"size",
# 'range':[2,7]
# }],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# 'geocoding':{
# 'url':"https://geo2.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'data':{
# 'Museum Type':["HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","
7867658.0,6.85911957E8,3533605.0,63401.0,1.9754324E7,9736290.0,139411.0,257139.0,9848036.0,622610.0,1.04737301E8,99712.0,726891.0,6.2624477E7,110101.0,171978.0,5264763.0,4023363.0,3.259727E7,121869.0,4.23815094E8,640618.0,613092.0,613092.0,2.064935223E9,2.064935223E9,2.064935223E9,3.10042203E8,2.064935223E9,2.064935223E9,2.064935223E9,5023859.0,1.652712215E9,31769.0,3337278.0,1.87415604E8,1.9995544E7,1.8153956E7]
# },
# 'mapping':{
# 'x':"Longitude",
# 'y':"Latitude",
# 'fill':"Museum Type",
# 'size':"Income"
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@Longitude",
# 'format':".4f"
# },{
# 'field':"@Latitude",
# 'format':".4f"
# }],
# 'tooltip_lines':["^fill","longitude|@Longitude","latitude|@Latitude","income|@Income"]
# },
# 'data_meta':{
# },
# 'shape':21,
# 'color':"black"
# }]
# };
#            var plotContainer = document.getElementById("cuL9uG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# There is a problem with the data: some museums are assigned to wrong states.
#
# Well, we can fix it by using geocoding.

# %%
us_sc_df = pd.read_csv('https://raw.githubusercontent.com/HIL-HK/lets-plot-examples/master/data/us_state_codes.csv')

states_gdf = geocode_states('US-48').get_boundaries(resolution=4)

states_df = states_gdf.merge(us_sc_df, on='state')
states_df = states_df[['state', 'code', 'geometry']]

states_gdf = gpd.GeoDataFrame(states_df, geometry='geometry')

# %%
def find_state(lon, lat):
    point = Point(lon, lat)
    state_gdf = states_gdf[states_gdf.contains(point)]
    return state_gdf.iloc[0].code if state_gdf.shape[0] == 1 else None

def fix_state(record):
    record.State = find_state(record.Longitude, record.Latitude) or record.State
    return record

museums_df = museums_df.apply(fix_state, axis=1)

# %% [markdown]
# Another try:

# %%
plot_museums_on_map(museums_df[museums_df.State == 'DC'])
# Out:
#    <div id="Orla0m"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggsize':{
# 'width':600,
# 'height':450
# },
# 'theme':{
# 'axis_title':"blank",
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank",
# 'legend_position':"none"
# },
# 'kind':"plot",
# 'scales':[{
# 'aesthetic':"size",
# 'range':[2,7]
# }],
# 'layers':[{
# 'geom':"livemap",
# 'mapping':{
# },
# 'data_meta':{
# },
# 'tiles':{
# 'kind':"vector_lets_plot",
# 'url':"wss://tiles.datalore.jetbrains.com",
# 'theme':"color",
# 'attribution':"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# 'geocoding':{
# 'url':"https://geo2.datalore.jetbrains.com"
# },
# 'data':{
# }
# },{
# 'geom':"point",
# 'data':{
# 'Museum Type':["HISTORY MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","HISTORY MUSEUM","HISTORY MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","GENERAL MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM","HISTORY MUSEUM","GENERAL MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER","HISTORIC PRESERVATION","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","HISTORIC PRESERVATION","ART MUSEUM","HISTORY MUSEUM","HISTORIC PRESERVATION","HISTORIC PRESERVATION","GENERAL MUSEUM","HISTORIC PRESERVATION"],
# 'Longitude':[-77.02824,-77.04454,-77.03505,-76.97666,-77.03092,-77.04578,-77.0399,-77.04599,-77.04088,-77.05483,-77.03946,-77.04772,-77.05328,-77.04268,-77.02589,-77.02529,-77.07113,-77.04057,-77.02194,-77.03505,-76.99432,-76.978,-77.07113,-77.04427,-77.02294,-77.03558,-77.02172,-77.02172,-77.02817,-77.04839,-77.01587,-77.04247,-77.04247,-76.99432,-77.03585,-77.02172,-77.0477,-76.95947,-77.01752,-77.0381,-77.00955,-77.02397,-77.03121,-77.03552,-77.03811,-77.02883,-77.03023,-77.05551,-77.01887,-77.01887,-77.01918,-77.04601,-77.05789,-77.04377,-77.0276,-77.04671,-77.03468,-76.99623,-77.02739,-77.00386,-77.00386,-77.0186,-76.99202,-77.03126,-76.99202,-77.03604,-77.03827],
# 'Latitude':[38.9169,38.90305,38.90537,38.92769,38.89803,38.90132,38.90189,38.90211,38.89881,38.91616,38.89616,38.91169,38.92401,38.92154,38.917,38.90211,38.90835,38.90133,38.89321,38.90537,38.90451,38.90037,38.90835,38.90807,38.90255,38.91369,38.92291,38.92291,38.91462,38.91184,38.89846,38.91286,38.91286,38.90451,38.92551,38.92291,38.89294,38.91685,38.89779,38.90514,38.89809,38.89622,38.89393,38.90647,38.90629,38.90038,38.90477,38.89962,38.91517,38.91517,38.89316,38.90826,38.91344,38.9081,38.89497,38.91199,38.91719,38.93323,38.89535,38.89232,38.89232,38.89247,38.90212,38.89974,38.90212,38.90852,38.89987],
# 'Income':[333682.0,244408.0,21000.0,34551.0,15129.0,928768.0,593772.0,8759917.0,2057869.0,1318939.0,7.2365327E7,196826.0,1.3477582E7,198592.0,6591877.0,42594.0,1.64260481E9,5389513.0,6264556.0,1386737.0,2.15623354E8,1419339.0,1.64260481E9,429387.0,719612.0,5553292.0,1.376961476E9,1.376961476E9,67863.0,1777520.0,932472.0,276392.0,276392.0,2.15623354E8,220837.0,1.376961476E9,1.009427032E9,2490455.0,7867658.0,6.85911957E8,3533605.0,1.9754324E7,9736290.0,139411.0,257139.0,9848036.0,622610.0,1.04737301E8,99712.0,726891.0,6.2624477E7,110101.0,171978.0,5264763.0,4023363.0,3.259727E7,121869.0,4.23815094E8,640618.0,613092.0,613092.0,3.10042203E8,2.064935223E9,31769.0,3337278.0,1.9995544E7,1.8153956E7]
# },
# 'mapping':{
# 'x':"Longitude",
# 'y':"Latitude",
# 'fill':"Museum Type",
# 'size':"Income"
# },
# 'tooltips':{
# 'tooltip_formats':[{
# 'field':"@Longitude",
# 'format':".4f"
# },{
# 'field':"@Latitude",
# 'format':".4f"
# }],
# 'tooltip_lines':["^fill","longitude|@Longitude","latitude|@Latitude","income|@Income"]
# },
# 'data_meta':{
# },
# 'shape':21,
# 'color':"black"
# }]
# };
#            var plotContainer = document.getElementById("Orla0m");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# Now it looks just as expected.
#
# So then we make the same plots for other US states. In order to switch between them, we use the Jupyter widget `select`.

# %%
plots = {}
state_codes = museums_df.State.unique()
state_codes.sort()
for state in state_codes:
    plots[state] = plot_museums_on_map(museums_df[museums_df.State == state])

# %%
wg.interact(lambda option: plots[option].show(), option=wg.Select(options=state_codes, \
                                                                  description='Choose state:', \
                                                                  disabled=False, \
                                                                  rows=1))
# Out:
# interactive(children=(Select(description='Choose state:', options=('AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', '…
# <function __main__.<lambda>(option)>

# %% [markdown]
# ## Which Museum Types Bring the Greatest Income to the State?

# %%
total_income_df = museums_df.groupby(['State', 'Museum Type']).sum().Income.to_frame().reset_index()
total_income_df = total_income_df.sort_values(by=['State', 'Income'], ascending=[True, False]).reset_index(drop=True)
top_by_income_museums_df = total_income_df.groupby('State').first().reset_index()
top_by_income_museums_gdf = gpd.GeoDataFrame(
    top_by_income_museums_df.merge(states_gdf, left_on='State', right_on='code'),
    geometry='geometry'
)

# %%
ggplot() + \
    geom_polygon(aes(fill='Museum Type', alpha='Income'), \
                 data=top_by_income_museums_gdf, color='white', \
                 tooltips=layer_tooltips().line('@State')\
                                          .line('most profitable museum type|^fill')\
                                          .line('total income for current museum type|^alpha')) + \
    scale_alpha(name='', range=[.2, 1], trans='log10') + \
    ggtitle('Most Profitable Museum Types by State') + \
    ggsize(600, 350) + \
    theme(axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank')
# Out:
#    <div id="edrrLV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'mapping':{
# },
# 'data_meta':{
# },
# 'ggtitle':{
# 'text':"Most Profitable Museum Types by State"
# },
# 'ggsize':{
# 'width':600,
# 'height':350
# },
# 'theme':{
# 'axis_title':"blank",
# 'axis_text':"blank",
# 'axis_ticks':"blank",
# 'axis_line':"blank"
# },
# 'kind':"plot",
# 'scales':[{
# 'name':"",
# 'aesthetic':"alpha",
# 'trans':"log10",
# 'range':[0.2,1]
# }],
# 'layers':[{
# 'geom':"polygon",
# 'data':{
# 'State':["AL","AR","AZ","CA","CO","CT","DE","FL","GA","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],
# 'Museum Type':["ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","HISTORIC PRESERVATION","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","CHILDREN'S MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","GENERAL MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","ART MUSEUM","HISTORY MUSEUM"],
# 'Income':[4.68914988E8,1.379212914E9,4.8898841E7,6.6292689195E10,2.945295508E9,1.9179886367E10,3.009956622E9,6.362379873E9,7.477315887E9,4.224464641E9,2.33203474E8,1.6728720325E10,4.411300957E9,3.44845478E8,1.657078897E9,3.282751522E9,6.6900095854E11,1.5098225146E10,1.494861732E9,1.558665965E9,2.846355403E9,1.0088894465E10,2.06679503E8,1.39018575E8,7.777208184E9,1.45886015E8,1.110612754E9,6.039698255E9,1.6670513407E10,6.7614451E7,3.7781896E7,3.7536303618E10,5.120748693E9,4.77406978E8,1.376796948E9,6.8352450003E10,3.267025424E9,1.076034767E9,1.83384241E8,8.619410627E9,7.994933119E9,1.1409427E8,1.4123549972E10,8.20973573E8,2.297782228E9,2.298697706E9,2.70561267E8,2.1717986E7],
# 'geometry':["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[-87.5390625, 30.297017883372], [-87.626953125, 30.221101852486], [-87.802734375, 30.221101852486], [-87.890625, 30.221101852486], [-87.978515625, 30.221101852486], [-88.06640625, 30.221101852486], [-88.06640625, 30.297017883372], [-88.154296875, 30.297017883372], [-88.154296875, 30.372875188118], [-88.2421875, 30.372875188118], [-88.330078125, 30.372875188118], [-88.41796875, 30.372875188118], [-88.41796875, 30.4486736792875], [-88.41796875, 30.524413269924], [-88.41796875, 30.6000938735501], [-88.41796875, 30.6757154041677], [-88.41796875, 30.7512777762578], [-88.41796875, 30.8267809047798], [-88.41796875, 30.9022247051714], [-88.41796875, 30.9776090933487], [-88.41796875, 31.0529339857051], [-88.41796875, 31.128199299112], [-88.41796875,